# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate diffusion-advection data (Dirichlet BC)
# -----------------------
def diffusion_advection_solver_dirichlet(u0, nu=0.01, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D diffusion-advection (Dirichlet BCs u(0,t)=u(1,t)=0).
    
    Solves: ∂u/∂t + c * ∂u/∂x = ν * ∂²u/∂x²
    Uses upwind scheme for advection: if c > 0, backward difference
    Uses central difference for diffusion
    """
    u = u0.copy()
    Nx = len(u)
    traj = [u.copy()]
    
    for _ in range(n_steps):
        un = u.copy()
        
        # Diffusion term: ν * ∂²u/∂x² (central difference)
        # Laplacian on interior points
        lap = (un[2:] - 2*un[1:-1] + un[:-2]) / dx**2
        diffusion = nu * lap
        
        # Advection term: c * ∂u/∂x (upwind scheme)
        if c > 0:
            # Backward difference for c > 0
            advection = c * (un[1:-1] - un[:-2]) / dx
        else:
            # Forward difference for c < 0
            advection = c * (un[2:] - un[1:-1]) / dx
        
        # Combine: ∂u/∂t = -c * ∂u/∂x + ν * ∂²u/∂x²
        u[1:-1] = un[1:-1] + dt * (-advection + diffusion)
        
        # Dirichlet boundaries
        u[0] = 0.0
        u[-1] = 0.0
        
        traj.append(u.copy())
    return np.stack(traj)  # shape (T, Nx)

def generate_diffusion_advection_data(Nx=128, nu=0.01, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)
    
    # initial condition compatible with Dirichlet BC
    u0 = np.sin(2*np.pi * x)   # = 0 at x=0 and x=1
    
    data = diffusion_advection_solver_dirichlet(u0, nu, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
nu = 0.017  # diffusion coefficient
c = 0.4    # advection velocity
n_steps = 5000

x, data = generate_diffusion_advection_data(Nx, nu, c, dt0, n_steps)

# %%
t_plot = n_steps  # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Diffusion-Advection: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) / true * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
def save_integrator_model(model, model_type, path, config):
    """
    Save a trained integrator model.

    Args:
        model: trained torch.nn.Module
        model_type: str ("linear" or "mlp")
        config: dict with required hyperparameters
    """
    torch.save(
        {
            "model_type": model_type,
            "model_state_dict": model.state_dict(),
            "config": config,
        },
        path,
    )

# %%
def load_integrator_model(path):
    """
    Load a saved integrator model.
    """
    device = "cuda"
    checkpoint = torch.load(path, map_location=device)

    model_type = checkpoint["model_type"]
    config = checkpoint["config"]

    if model_type == "linear":
        model = LinearIntegrator(k=config["k"])
    elif model_type == "mlp":
        model = MLPIntegrator(
            k=config["k"],
            hidden=config["hidden"],
            num_layers=config["num_layers"],
        )
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(checkpoint["model_state_dict"])
    model = model.to(device)
    model.eval()

    return model, config

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.716893e+00
# [Epoch 2/150] train MSE = 8.586493e-01
# [Epoch 3/150] train MSE = 4.105615e-01
# [Epoch 4/150] train MSE = 1.886545e-01
# [Epoch 5/150] train MSE = 8.359539e-02
# [Epoch 6/150] train MSE = 3.556293e-02
# [Epoch 7/150] train MSE = 1.434532e-02
# [Epoch 8/150] train MSE = 5.476191e-03
# [Epoch 9/150] train MSE = 2.003503e-03
# [Epoch 10/150] train MSE = 7.479678e-04
# [Epoch 11/150] train MSE = 3.301202e-04
# [Epoch 12/150] train MSE = 2.029191e-04
# [Epoch 13/150] train MSE = 1.674765e-04
# [Epoch 14/150] train MSE = 1.585047e-04
# [Epoch 15/150] train MSE = 1.564209e-04
# [Epoch 16/150] train MSE = 1.559783e-04
# [Epoch 17/150] train MSE = 1.559134e-04
# [Epoch 18/150] train MSE = 1.559008e-04
# [Epoch 19/150] train MSE = 1.558756e-04
# [Epoch 20/150] train MSE = 1.558702e-04
# [Epoch 21/150] train MSE = 1.558828e-04
# [Epoch 22/150] train MSE = 1.558825e-04
# [Epoch 23/150] train MSE = 1.558694e-04
# [Epoch 24/150] train MSE = 1.558696e-04
# [Epoch 25/150] train MSE = 1.558830e-04
# [Epoch 26/150] train MSE = 1.558735e-04
# [Epoch 27/150] train MSE = 1.558812e-04
# [Epoch 28/150] train MSE = 1.558855e-04
# [Epoch 29/150] train MSE = 1.558768e-04
# [Epoch 30/150] train MSE = 1.558712e-04
# [Epoch 31/150] train MSE = 1.558732e-04
# [Epoch 32/150] train MSE = 1.558698e-04
# [Epoch 33/150] train MSE = 1.558688e-04
# [Epoch 34/150] train MSE = 1.558708e-04
# [Epoch 35/150] train MSE = 1.558700e-04
# [Epoch 36/150] train MSE = 1.558870e-04
# [Epoch 37/150] train MSE = 1.558892e-04
# [Epoch 38/150] train MSE = 1.558816e-04
# [Epoch 39/150] train MSE = 1.558516e-04
# [Epoch 40/150] train MSE = 1.558556e-04
# [Epoch 41/150] train MSE = 1.558460e-04
# [Epoch 42/150] train MSE = 1.558670e-04
# [Epoch 43/150] train MSE = 1.558820e-04
# [Epoch 44/150] train MSE = 1.558652e-04
# [Epoch 45/150] train MSE = 1.558601e-04
# [Epoch 46/150] train MSE = 1.558390e-04
# [Epoch 47/150] train MSE = 1.558519e-04
# [Epoch 48/150] train MSE = 1.558558e-04
# [Epoch 49/150] train MSE = 1.558341e-04
# [Epoch 50/150] train MSE = 1.558376e-04
# [Epoch 51/150] train MSE = 1.558312e-04
# [Epoch 52/150] train MSE = 1.558247e-04
# [Epoch 53/150] train MSE = 1.558918e-04
# [Epoch 54/150] train MSE = 1.558533e-04
# [Epoch 55/150] train MSE = 1.558255e-04
# [Epoch 56/150] train MSE = 1.558252e-04
# [Epoch 57/150] train MSE = 1.558098e-04
# [Epoch 58/150] train MSE = 1.558676e-04
# [Epoch 59/150] train MSE = 1.558384e-04
# [Epoch 60/150] train MSE = 1.558383e-04
# [Epoch 61/150] train MSE = 1.558411e-04
# [Epoch 62/150] train MSE = 1.558535e-04
# [Epoch 63/150] train MSE = 1.558176e-04
# [Epoch 64/150] train MSE = 1.558127e-04
# [Epoch 65/150] train MSE = 1.558144e-04
# [Epoch 66/150] train MSE = 1.558256e-04
# [Epoch 67/150] train MSE = 1.557911e-04
# [Epoch 68/150] train MSE = 1.558087e-04
# [Epoch 69/150] train MSE = 1.557986e-04
# [Epoch 70/150] train MSE = 1.557687e-04
# [Epoch 71/150] train MSE = 1.558191e-04
# [Epoch 72/150] train MSE = 1.558557e-04
# [Epoch 73/150] train MSE = 1.558377e-04
# [Epoch 74/150] train MSE = 1.558851e-04
# [Epoch 75/150] train MSE = 1.558180e-04
# [Epoch 76/150] train MSE = 1.557841e-04
# [Epoch 77/150] train MSE = 1.557699e-04
# [Epoch 78/150] train MSE = 1.557693e-04
# [Epoch 79/150] train MSE = 1.558084e-04
# [Epoch 80/150] train MSE = 1.557797e-04
# [Epoch 81/150] train MSE = 1.558165e-04
# [Epoch 82/150] train MSE = 1.558382e-04
# [Epoch 83/150] train MSE = 1.557885e-04
# [Epoch 84/150] train MSE = 1.557537e-04
# [Epoch 85/150] train MSE = 1.557542e-04
# [Epoch 86/150] train MSE = 1.557365e-04
# [Epoch 87/150] train MSE = 1.556639e-04
# [Epoch 88/150] train MSE = 1.557506e-04
# [Epoch 89/150] train MSE = 1.557107e-04
# [Epoch 90/150] train MSE = 1.557345e-04
# [Epoch 91/150] train MSE = 1.557315e-04
# [Epoch 92/150] train MSE = 1.557212e-04
# [Epoch 93/150] train MSE = 1.558092e-04
# [Epoch 94/150] train MSE = 1.557176e-04
# [Epoch 95/150] train MSE = 1.558177e-04
# [Epoch 96/150] train MSE = 1.557189e-04
# [Epoch 97/150] train MSE = 1.557020e-04
# [Epoch 98/150] train MSE = 1.558503e-04
# [Epoch 99/150] train MSE = 1.557864e-04
# [Epoch 100/150] train MSE = 1.556319e-04
# [Epoch 101/150] train MSE = 1.558418e-04
# [Epoch 102/150] train MSE = 1.557510e-04
# [Epoch 103/150] train MSE = 1.556723e-04
# [Epoch 104/150] train MSE = 1.558133e-04
# [Epoch 105/150] train MSE = 1.557112e-04
# [Epoch 106/150] train MSE = 1.557846e-04
# [Epoch 107/150] train MSE = 1.557887e-04
# [Epoch 108/150] train MSE = 1.556602e-04
# [Epoch 109/150] train MSE = 1.556434e-04
# [Epoch 110/150] train MSE = 1.555849e-04
# [Epoch 111/150] train MSE = 1.556591e-04
# [Epoch 112/150] train MSE = 1.556962e-04
# [Epoch 113/150] train MSE = 1.556552e-04
# [Epoch 114/150] train MSE = 1.555407e-04
# [Epoch 115/150] train MSE = 1.555672e-04
# [Epoch 116/150] train MSE = 1.554992e-04
# [Epoch 117/150] train MSE = 1.556373e-04
# [Epoch 118/150] train MSE = 1.555740e-04
# [Epoch 119/150] train MSE = 1.558251e-04
# [Epoch 120/150] train MSE = 1.555390e-04
# [Epoch 121/150] train MSE = 1.555982e-04
# [Epoch 122/150] train MSE = 1.555292e-04
# [Epoch 123/150] train MSE = 1.554647e-04
# [Epoch 124/150] train MSE = 1.556778e-04
# [Epoch 125/150] train MSE = 1.556150e-04
# [Epoch 126/150] train MSE = 1.554082e-04
# [Epoch 127/150] train MSE = 1.555506e-04
# [Epoch 128/150] train MSE = 1.555183e-04
# [Epoch 129/150] train MSE = 1.554674e-04
# [Epoch 130/150] train MSE = 1.557743e-04
# [Epoch 131/150] train MSE = 1.554776e-04
# [Epoch 132/150] train MSE = 1.555486e-04
# [Epoch 133/150] train MSE = 1.555271e-04
# [Epoch 134/150] train MSE = 1.554283e-04
# [Epoch 135/150] train MSE = 1.556214e-04
# [Epoch 136/150] train MSE = 1.558074e-04
# [Epoch 137/150] train MSE = 1.554988e-04
# [Epoch 138/150] train MSE = 1.554738e-04
# [Epoch 139/150] train MSE = 1.555622e-04
# [Epoch 140/150] train MSE = 1.555358e-04
# [Epoch 141/150] train MSE = 1.555509e-04
# [Epoch 142/150] train MSE = 1.556061e-04
# [Epoch 143/150] train MSE = 1.553563e-04
# [Epoch 144/150] train MSE = 1.552795e-04
# [Epoch 145/150] train MSE = 1.553432e-04
# [Epoch 146/150] train MSE = 1.555062e-04
# [Epoch 147/150] train MSE = 1.553033e-04
# [Epoch 148/150] train MSE = 1.554481e-04
# [Epoch 149/150] train MSE = 1.552621e-04
# [Epoch 150/150] train MSE = 1.554017e-04

# %%
model_mlp = MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 8.037168e-02
# [Epoch 2/150] train MSE = 4.752756e-03
# [Epoch 3/150] train MSE = 3.269617e-03
# [Epoch 4/150] train MSE = 2.505170e-03
# [Epoch 5/150] train MSE = 2.019082e-03
# [Epoch 6/150] train MSE = 1.680183e-03
# [Epoch 7/150] train MSE = 1.434224e-03
# [Epoch 8/150] train MSE = 1.257344e-03
# [Epoch 9/150] train MSE = 1.109903e-03
# [Epoch 10/150] train MSE = 9.947168e-04
# [Epoch 11/150] train MSE = 9.217072e-04
# [Epoch 12/150] train MSE = 8.229014e-04
# [Epoch 13/150] train MSE = 7.585400e-04
# [Epoch 14/150] train MSE = 7.041347e-04
# [Epoch 15/150] train MSE = 6.586817e-04
# [Epoch 16/150] train MSE = 5.919290e-04
# [Epoch 17/150] train MSE = 5.519953e-04
# [Epoch 18/150] train MSE = 5.218651e-04
# [Epoch 19/150] train MSE = 4.887583e-04
# [Epoch 20/150] train MSE = 4.556097e-04
# [Epoch 21/150] train MSE = 4.333082e-04
# [Epoch 22/150] train MSE = 4.200359e-04
# [Epoch 23/150] train MSE = 3.863004e-04
# [Epoch 24/150] train MSE = 3.847217e-04
# [Epoch 25/150] train MSE = 3.705871e-04
# [Epoch 26/150] train MSE = 3.638005e-04
# [Epoch 27/150] train MSE = 3.698418e-04
# [Epoch 28/150] train MSE = 3.845576e-04
# [Epoch 29/150] train MSE = 3.042062e-04
# [Epoch 30/150] train MSE = 2.961873e-04
# [Epoch 31/150] train MSE = 2.719973e-04
# [Epoch 32/150] train MSE = 2.639582e-04
# [Epoch 33/150] train MSE = 2.843741e-04
# [Epoch 34/150] train MSE = 2.855576e-04
# [Epoch 35/150] train MSE = 2.640279e-04
# [Epoch 36/150] train MSE = 2.774560e-04
# [Epoch 37/150] train MSE = 2.374891e-04
# [Epoch 38/150] train MSE = 2.483353e-04
# [Epoch 39/150] train MSE = 2.568743e-04
# [Epoch 40/150] train MSE = 2.503577e-04
# [Epoch 41/150] train MSE = 2.306698e-04
# [Epoch 42/150] train MSE = 2.505757e-04
# [Epoch 43/150] train MSE = 2.468237e-04
# [Epoch 44/150] train MSE = 2.107419e-04
# [Epoch 45/150] train MSE = 2.929159e-04
# [Epoch 46/150] train MSE = 2.303842e-04
# [Epoch 47/150] train MSE = 2.093898e-04
# [Epoch 48/150] train MSE = 1.934002e-04
# [Epoch 49/150] train MSE = 2.334373e-04
# [Epoch 50/150] train MSE = 2.410334e-04
# [Epoch 51/150] train MSE = 1.983143e-04
# [Epoch 52/150] train MSE = 2.218962e-04
# [Epoch 53/150] train MSE = 1.933489e-04
# [Epoch 54/150] train MSE = 2.012377e-04
# [Epoch 55/150] train MSE = 2.147771e-04
# [Epoch 56/150] train MSE = 2.304703e-04
# [Epoch 57/150] train MSE = 1.909519e-04
# [Epoch 58/150] train MSE = 2.029257e-04
# [Epoch 59/150] train MSE = 2.067613e-04
# [Epoch 60/150] train MSE = 2.045299e-04
# [Epoch 61/150] train MSE = 1.976380e-04
# [Epoch 62/150] train MSE = 1.999604e-04
# [Epoch 63/150] train MSE = 1.803716e-04
# [Epoch 64/150] train MSE = 2.007615e-04
# [Epoch 65/150] train MSE = 1.874395e-04
# [Epoch 66/150] train MSE = 2.153584e-04
# [Epoch 67/150] train MSE = 1.774936e-04
# [Epoch 68/150] train MSE = 1.918778e-04
# [Epoch 69/150] train MSE = 1.791812e-04
# [Epoch 70/150] train MSE = 1.980170e-04
# [Epoch 71/150] train MSE = 1.717061e-04
# [Epoch 72/150] train MSE = 1.865060e-04
# [Epoch 73/150] train MSE = 2.096827e-04
# [Epoch 74/150] train MSE = 2.277246e-04
# [Epoch 75/150] train MSE = 1.712079e-04
# [Epoch 76/150] train MSE = 1.718407e-04
# [Epoch 77/150] train MSE = 1.903167e-04
# [Epoch 78/150] train MSE = 1.842479e-04
# [Epoch 79/150] train MSE = 1.794052e-04
# [Epoch 80/150] train MSE = 2.209633e-04
# [Epoch 81/150] train MSE = 1.895766e-04
# [Epoch 82/150] train MSE = 1.663548e-04
# [Epoch 83/150] train MSE = 1.821427e-04
# [Epoch 84/150] train MSE = 1.675604e-04
# [Epoch 85/150] train MSE = 1.808367e-04
# [Epoch 86/150] train MSE = 1.844174e-04
# [Epoch 87/150] train MSE = 1.912693e-04
# [Epoch 88/150] train MSE = 1.650026e-04
# [Epoch 89/150] train MSE = 1.705420e-04
# [Epoch 90/150] train MSE = 1.831687e-04
# [Epoch 91/150] train MSE = 1.878442e-04
# [Epoch 92/150] train MSE = 1.911431e-04
# [Epoch 93/150] train MSE = 1.793768e-04
# [Epoch 94/150] train MSE = 1.622678e-04
# [Epoch 95/150] train MSE = 1.614989e-04
# [Epoch 96/150] train MSE = 1.745216e-04
# [Epoch 97/150] train MSE = 1.729140e-04
# [Epoch 98/150] train MSE = 1.904233e-04
# [Epoch 99/150] train MSE = 1.740355e-04
# [Epoch 100/150] train MSE = 1.835600e-04
# [Epoch 101/150] train MSE = 1.857839e-04
# [Epoch 102/150] train MSE = 1.671360e-04
# [Epoch 103/150] train MSE = 1.763916e-04
# [Epoch 104/150] train MSE = 1.807463e-04
# [Epoch 105/150] train MSE = 1.750151e-04
# [Epoch 106/150] train MSE = 1.541592e-04
# [Epoch 107/150] train MSE = 1.753075e-04
# [Epoch 108/150] train MSE = 1.642073e-04
# [Epoch 109/150] train MSE = 1.879497e-04
# [Epoch 110/150] train MSE = 1.722510e-04
# [Epoch 111/150] train MSE = 1.811342e-04
# [Epoch 112/150] train MSE = 1.847377e-04
# [Epoch 113/150] train MSE = 1.768700e-04
# [Epoch 114/150] train MSE = 1.615999e-04
# [Epoch 115/150] train MSE = 1.665597e-04
# [Epoch 116/150] train MSE = 1.578548e-04
# [Epoch 117/150] train MSE = 1.567947e-04
# [Epoch 118/150] train MSE = 1.969583e-04
# [Epoch 119/150] train MSE = 1.765982e-04
# [Epoch 120/150] train MSE = 1.670147e-04
# [Epoch 121/150] train MSE = 1.671089e-04
# [Epoch 122/150] train MSE = 1.708165e-04
# [Epoch 123/150] train MSE = 1.641654e-04
# [Epoch 124/150] train MSE = 1.594757e-04
# [Epoch 125/150] train MSE = 1.680311e-04
# [Epoch 126/150] train MSE = 1.597998e-04
# [Epoch 127/150] train MSE = 1.631889e-04
# [Epoch 128/150] train MSE = 1.839312e-04
# [Epoch 129/150] train MSE = 1.581055e-04
# [Epoch 130/150] train MSE = 1.760593e-04
# [Epoch 131/150] train MSE = 1.587114e-04
# [Epoch 132/150] train MSE = 1.559717e-04
# [Epoch 133/150] train MSE = 1.695595e-04
# [Epoch 134/150] train MSE = 1.909161e-04
# [Epoch 135/150] train MSE = 1.600414e-04
# [Epoch 136/150] train MSE = 1.621294e-04
# [Epoch 137/150] train MSE = 1.511791e-04
# [Epoch 138/150] train MSE = 1.551629e-04
# [Epoch 139/150] train MSE = 1.667499e-04
# [Epoch 140/150] train MSE = 1.868520e-04
# [Epoch 141/150] train MSE = 1.504805e-04
# [Epoch 142/150] train MSE = 1.535540e-04
# [Epoch 143/150] train MSE = 1.584051e-04
# [Epoch 144/150] train MSE = 1.674730e-04
# [Epoch 145/150] train MSE = 1.526337e-04
# [Epoch 146/150] train MSE = 1.518142e-04
# [Epoch 147/150] train MSE = 1.642841e-04
# [Epoch 148/150] train MSE = 1.790001e-04
# [Epoch 149/150] train MSE = 1.558732e-04
# [Epoch 150/150] train MSE = 1.599417e-04

# %%
# Evaluate models
print("Evaluating Linear Model:")
test_loss_lin = eval_integrator_B(model_lin, data, R, k)

print("\nEvaluating MLP Model:")
test_loss_mlp = eval_integrator_B(model_mlp, data, R, k)
# Out:
# Evaluating Linear Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 1.588292e-04
#
# Evaluating MLP Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 1.736612e-04

# %%
# Visualize comparison
visualize_B_compare_models(data, model_lin, model_mlp, R=R, k=k)
# Out:
# C:\Users\amt35\AppData\Local\Temp\ipykernel_39032\736158891.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Plot training losses
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
# Save models
u_scale = np.max(np.abs(data)) + 1e-8
config_lin = {"k": k, "R": R, "u_scale": u_scale}
config_mlp = {"k": k, "R": R, "hidden": 128, "num_layers": 3, "u_scale": u_scale}

save_integrator_model(model_lin, "linear", "diffusion_advection_linear_model.pt", config_lin)
save_integrator_model(model_mlp, "mlp", "diffusion_advection_mlp_model.pt", config_mlp)

print("Models saved successfully!")
# Out:
# Models saved successfully!
