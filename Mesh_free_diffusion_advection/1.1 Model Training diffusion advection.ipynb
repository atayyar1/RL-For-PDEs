# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate diffusion-advection data (Dirichlet BC)
# -----------------------
def diffusion_advection_solver_dirichlet(u0, nu=0.01, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D diffusion-advection (Dirichlet BCs u(0,t)=u(1,t)=0).
    
    Solves: ∂u/∂t + c * ∂u/∂x = ν * ∂²u/∂x²
    Uses upwind scheme for advection: if c > 0, backward difference
    Uses central difference for diffusion
    """
    u = u0.copy()
    Nx = len(u)
    traj = [u.copy()]
    
    for _ in range(n_steps):
        un = u.copy()
        
        # Diffusion term: ν * ∂²u/∂x² (central difference)
        # Laplacian on interior points
        lap = (un[2:] - 2*un[1:-1] + un[:-2]) / dx**2
        diffusion = nu * lap
        
        # Advection term: c * ∂u/∂x (upwind scheme)
        if c > 0:
            # Backward difference for c > 0
            advection = c * (un[1:-1] - un[:-2]) / dx
        else:
            # Forward difference for c < 0
            advection = c * (un[2:] - un[1:-1]) / dx
        
        # Combine: ∂u/∂t = -c * ∂u/∂x + ν * ∂²u/∂x²
        u[1:-1] = un[1:-1] + dt * (-advection + diffusion)
        
        # Dirichlet boundaries
        u[0] = 0.0
        u[-1] = 0.0
        
        traj.append(u.copy())
    return np.stack(traj)  # shape (T, Nx)

def generate_diffusion_advection_data(Nx=128, nu=0.01, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)
    
    # initial condition compatible with Dirichlet BC
    u0 = np.sin(2*np.pi * x)   # = 0 at x=0 and x=1
    
    data = diffusion_advection_solver_dirichlet(u0, nu, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
nu = 0.017  # diffusion coefficient
c = 0.4    # advection velocity
n_steps = 5000

x, data = generate_diffusion_advection_data(Nx, nu, c, dt0, n_steps)

# %%
t_plot = n_steps  # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Diffusion-Advection: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) / true * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
def save_integrator_model(model, model_type, path, config):
    """
    Save a trained integrator model.

    Args:
        model: trained torch.nn.Module
        model_type: str ("linear" or "mlp")
        config: dict with required hyperparameters
    """
    torch.save(
        {
            "model_type": model_type,
            "model_state_dict": model.state_dict(),
            "config": config,
        },
        path,
    )

# %%
def load_integrator_model(path):
    """
    Load a saved integrator model.
    """
    device = "cuda"
    checkpoint = torch.load(path, map_location=device)

    model_type = checkpoint["model_type"]
    config = checkpoint["config"]

    if model_type == "linear":
        model = LinearIntegrator(k=config["k"])
    elif model_type == "mlp":
        model = MLPIntegrator(
            k=config["k"],
            hidden=config["hidden"],
            num_layers=config["num_layers"],
        )
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(checkpoint["model_state_dict"])
    model = model.to(device)
    model.eval()

    return model, config

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.438003e+00
# [Epoch 2/150] train MSE = 7.661336e-01
# [Epoch 3/150] train MSE = 4.090231e-01
# [Epoch 4/150] train MSE = 2.125574e-01
# [Epoch 5/150] train MSE = 1.065333e-01
# [Epoch 6/150] train MSE = 5.087217e-02
# [Epoch 7/150] train MSE = 2.298678e-02
# [Epoch 8/150] train MSE = 9.775377e-03
# [Epoch 9/150] train MSE = 3.945343e-03
# [Epoch 10/150] train MSE = 1.558440e-03
# [Epoch 11/150] train MSE = 6.567187e-04
# [Epoch 12/150] train MSE = 3.428194e-04
# [Epoch 13/150] train MSE = 2.419185e-04
# [Epoch 14/150] train MSE = 2.120683e-04
# [Epoch 15/150] train MSE = 2.038983e-04
# [Epoch 16/150] train MSE = 2.018497e-04
# [Epoch 17/150] train MSE = 2.013587e-04
# [Epoch 18/150] train MSE = 2.012521e-04
# [Epoch 19/150] train MSE = 2.012518e-04
# [Epoch 20/150] train MSE = 2.011552e-04
# [Epoch 21/150] train MSE = 2.011212e-04
# [Epoch 22/150] train MSE = 2.011060e-04
# [Epoch 23/150] train MSE = 2.010699e-04
# [Epoch 24/150] train MSE = 2.010693e-04
# [Epoch 25/150] train MSE = 2.010109e-04
# [Epoch 26/150] train MSE = 2.009581e-04
# [Epoch 27/150] train MSE = 2.009530e-04
# [Epoch 28/150] train MSE = 2.009126e-04
# [Epoch 29/150] train MSE = 2.008891e-04
# [Epoch 30/150] train MSE = 2.008311e-04
# [Epoch 31/150] train MSE = 2.008014e-04
# [Epoch 32/150] train MSE = 2.007516e-04
# [Epoch 33/150] train MSE = 2.007062e-04
# [Epoch 34/150] train MSE = 2.006479e-04
# [Epoch 35/150] train MSE = 2.005790e-04
# [Epoch 36/150] train MSE = 2.005462e-04
# [Epoch 37/150] train MSE = 2.005081e-04
# [Epoch 38/150] train MSE = 2.004557e-04
# [Epoch 39/150] train MSE = 2.004087e-04
# [Epoch 40/150] train MSE = 2.004867e-04
# [Epoch 41/150] train MSE = 2.003042e-04
# [Epoch 42/150] train MSE = 2.002613e-04
# [Epoch 43/150] train MSE = 2.001493e-04
# [Epoch 44/150] train MSE = 2.001347e-04
# [Epoch 45/150] train MSE = 2.000427e-04
# [Epoch 46/150] train MSE = 1.999775e-04
# [Epoch 47/150] train MSE = 1.999069e-04
# [Epoch 48/150] train MSE = 1.998617e-04
# [Epoch 49/150] train MSE = 1.997732e-04
# [Epoch 50/150] train MSE = 1.997350e-04
# [Epoch 51/150] train MSE = 1.996929e-04
# [Epoch 52/150] train MSE = 1.995804e-04
# [Epoch 53/150] train MSE = 1.995581e-04
# [Epoch 54/150] train MSE = 1.994767e-04
# [Epoch 55/150] train MSE = 1.993404e-04
# [Epoch 56/150] train MSE = 1.992980e-04
# [Epoch 57/150] train MSE = 1.991591e-04
# [Epoch 58/150] train MSE = 1.990834e-04
# [Epoch 59/150] train MSE = 1.990763e-04
# [Epoch 60/150] train MSE = 1.990685e-04
# [Epoch 61/150] train MSE = 1.988581e-04
# [Epoch 62/150] train MSE = 1.987977e-04
# [Epoch 63/150] train MSE = 1.986380e-04
# [Epoch 64/150] train MSE = 1.985250e-04
# [Epoch 65/150] train MSE = 1.984726e-04
# [Epoch 66/150] train MSE = 1.983419e-04
# [Epoch 67/150] train MSE = 1.982041e-04
# [Epoch 68/150] train MSE = 1.980778e-04
# [Epoch 69/150] train MSE = 1.979821e-04
# [Epoch 70/150] train MSE = 1.978481e-04
# [Epoch 71/150] train MSE = 1.977459e-04
# [Epoch 72/150] train MSE = 1.976934e-04
# [Epoch 73/150] train MSE = 1.974722e-04
# [Epoch 74/150] train MSE = 1.974810e-04
# [Epoch 75/150] train MSE = 1.973129e-04
# [Epoch 76/150] train MSE = 1.971269e-04
# [Epoch 77/150] train MSE = 1.970382e-04
# [Epoch 78/150] train MSE = 1.969783e-04
# [Epoch 79/150] train MSE = 1.970069e-04
# [Epoch 80/150] train MSE = 1.966297e-04
# [Epoch 81/150] train MSE = 1.968354e-04
# [Epoch 82/150] train MSE = 1.963790e-04
# [Epoch 83/150] train MSE = 1.962693e-04
# [Epoch 84/150] train MSE = 1.960920e-04
# [Epoch 85/150] train MSE = 1.958429e-04
# [Epoch 86/150] train MSE = 1.957753e-04
# [Epoch 87/150] train MSE = 1.955249e-04
# [Epoch 88/150] train MSE = 1.952521e-04
# [Epoch 89/150] train MSE = 1.954105e-04
# [Epoch 90/150] train MSE = 1.953435e-04
# [Epoch 91/150] train MSE = 1.949876e-04
# [Epoch 92/150] train MSE = 1.949033e-04
# [Epoch 93/150] train MSE = 1.946203e-04
# [Epoch 94/150] train MSE = 1.944102e-04
# [Epoch 95/150] train MSE = 1.942051e-04
# [Epoch 96/150] train MSE = 1.938618e-04
# [Epoch 97/150] train MSE = 1.938504e-04
# [Epoch 98/150] train MSE = 1.936146e-04
# [Epoch 99/150] train MSE = 1.932080e-04
# [Epoch 100/150] train MSE = 1.931891e-04
# [Epoch 101/150] train MSE = 1.928827e-04
# [Epoch 102/150] train MSE = 1.928326e-04
# [Epoch 103/150] train MSE = 1.925857e-04
# [Epoch 104/150] train MSE = 1.922312e-04
# [Epoch 105/150] train MSE = 1.920311e-04
# [Epoch 106/150] train MSE = 1.917376e-04
# [Epoch 107/150] train MSE = 1.920593e-04
# [Epoch 108/150] train MSE = 1.913641e-04
# [Epoch 109/150] train MSE = 1.911950e-04
# [Epoch 110/150] train MSE = 1.910211e-04
# [Epoch 111/150] train MSE = 1.906286e-04
# [Epoch 112/150] train MSE = 1.902507e-04
# [Epoch 113/150] train MSE = 1.898564e-04
# [Epoch 114/150] train MSE = 1.894393e-04
# [Epoch 115/150] train MSE = 1.893356e-04
# [Epoch 116/150] train MSE = 1.894107e-04
# [Epoch 117/150] train MSE = 1.891711e-04
# [Epoch 118/150] train MSE = 1.885869e-04
# [Epoch 119/150] train MSE = 1.882955e-04
# [Epoch 120/150] train MSE = 1.881300e-04
# [Epoch 121/150] train MSE = 1.875632e-04
# [Epoch 122/150] train MSE = 1.874613e-04
# [Epoch 123/150] train MSE = 1.869053e-04
# [Epoch 124/150] train MSE = 1.865648e-04
# [Epoch 125/150] train MSE = 1.865395e-04
# [Epoch 126/150] train MSE = 1.860941e-04
# [Epoch 127/150] train MSE = 1.855717e-04
# [Epoch 128/150] train MSE = 1.854282e-04
# [Epoch 129/150] train MSE = 1.850079e-04
# [Epoch 130/150] train MSE = 1.846508e-04
# [Epoch 131/150] train MSE = 1.847982e-04
# [Epoch 132/150] train MSE = 1.840501e-04
# [Epoch 133/150] train MSE = 1.836433e-04
# [Epoch 134/150] train MSE = 1.835493e-04
# [Epoch 135/150] train MSE = 1.826588e-04
# [Epoch 136/150] train MSE = 1.828791e-04
# [Epoch 137/150] train MSE = 1.818373e-04
# [Epoch 138/150] train MSE = 1.815073e-04
# [Epoch 139/150] train MSE = 1.810961e-04
# [Epoch 140/150] train MSE = 1.808620e-04
# [Epoch 141/150] train MSE = 1.805486e-04
# [Epoch 142/150] train MSE = 1.800424e-04
# [Epoch 143/150] train MSE = 1.797361e-04
# [Epoch 144/150] train MSE = 1.794905e-04
# [Epoch 145/150] train MSE = 1.786193e-04
# [Epoch 146/150] train MSE = 1.788299e-04
# [Epoch 147/150] train MSE = 1.787917e-04
# [Epoch 148/150] train MSE = 1.775010e-04
# [Epoch 149/150] train MSE = 1.771327e-04
# [Epoch 150/150] train MSE = 1.768098e-04

# %%
model_mlp = MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 7.288379e-02
# [Epoch 2/150] train MSE = 5.822421e-03
# [Epoch 3/150] train MSE = 3.830764e-03
# [Epoch 4/150] train MSE = 2.899651e-03
# [Epoch 5/150] train MSE = 2.310412e-03
# [Epoch 6/150] train MSE = 1.898486e-03
# [Epoch 7/150] train MSE = 1.595857e-03
# [Epoch 8/150] train MSE = 1.360330e-03
# [Epoch 9/150] train MSE = 1.185536e-03
# [Epoch 10/150] train MSE = 1.071216e-03
# [Epoch 11/150] train MSE = 9.760339e-04
# [Epoch 12/150] train MSE = 8.371397e-04
# [Epoch 13/150] train MSE = 7.667052e-04
# [Epoch 14/150] train MSE = 7.187301e-04
# [Epoch 15/150] train MSE = 6.526704e-04
# [Epoch 16/150] train MSE = 5.955463e-04
# [Epoch 17/150] train MSE = 6.332090e-04
# [Epoch 18/150] train MSE = 5.193495e-04
# [Epoch 19/150] train MSE = 5.161400e-04
# [Epoch 20/150] train MSE = 4.838195e-04
# [Epoch 21/150] train MSE = 4.412623e-04
# [Epoch 22/150] train MSE = 4.287382e-04
# [Epoch 23/150] train MSE = 4.121194e-04
# [Epoch 24/150] train MSE = 3.735845e-04
# [Epoch 25/150] train MSE = 3.530217e-04
# [Epoch 26/150] train MSE = 3.585255e-04
# [Epoch 27/150] train MSE = 3.422380e-04
# [Epoch 28/150] train MSE = 3.836853e-04
# [Epoch 29/150] train MSE = 3.139583e-04
# [Epoch 30/150] train MSE = 2.934433e-04
# [Epoch 31/150] train MSE = 3.047604e-04
# [Epoch 32/150] train MSE = 3.046279e-04
# [Epoch 33/150] train MSE = 2.824479e-04
# [Epoch 34/150] train MSE = 2.937869e-04
# [Epoch 35/150] train MSE = 2.929967e-04
# [Epoch 36/150] train MSE = 2.887782e-04
# [Epoch 37/150] train MSE = 2.706655e-04
# [Epoch 38/150] train MSE = 2.817496e-04
# [Epoch 39/150] train MSE = 2.431127e-04
# [Epoch 40/150] train MSE = 2.308113e-04
# [Epoch 41/150] train MSE = 2.508364e-04
# [Epoch 42/150] train MSE = 3.181329e-04
# [Epoch 43/150] train MSE = 2.325434e-04
# [Epoch 44/150] train MSE = 2.241351e-04
# [Epoch 45/150] train MSE = 2.272503e-04
# [Epoch 46/150] train MSE = 2.711607e-04
# [Epoch 47/150] train MSE = 2.273117e-04
# [Epoch 48/150] train MSE = 2.082397e-04
# [Epoch 49/150] train MSE = 2.134913e-04
# [Epoch 50/150] train MSE = 2.189126e-04
# [Epoch 51/150] train MSE = 2.304817e-04
# [Epoch 52/150] train MSE = 2.267064e-04
# [Epoch 53/150] train MSE = 2.113296e-04
# [Epoch 54/150] train MSE = 1.929985e-04
# [Epoch 55/150] train MSE = 2.125843e-04
# [Epoch 56/150] train MSE = 2.374961e-04
# [Epoch 57/150] train MSE = 2.214343e-04
# [Epoch 58/150] train MSE = 2.001935e-04
# [Epoch 59/150] train MSE = 1.879344e-04
# [Epoch 60/150] train MSE = 2.567988e-04
# [Epoch 61/150] train MSE = 2.123656e-04
# [Epoch 62/150] train MSE = 1.797151e-04
# [Epoch 63/150] train MSE = 1.858399e-04
# [Epoch 64/150] train MSE = 2.018888e-04
# [Epoch 65/150] train MSE = 1.967263e-04
# [Epoch 66/150] train MSE = 2.185305e-04
# [Epoch 67/150] train MSE = 2.084490e-04
# [Epoch 68/150] train MSE = 2.072822e-04
# [Epoch 69/150] train MSE = 2.015275e-04
# [Epoch 70/150] train MSE = 1.820682e-04
# [Epoch 71/150] train MSE = 1.943528e-04
# [Epoch 72/150] train MSE = 1.958992e-04
# [Epoch 73/150] train MSE = 2.227867e-04
# [Epoch 74/150] train MSE = 1.970739e-04
# [Epoch 75/150] train MSE = 1.803382e-04
# [Epoch 76/150] train MSE = 1.780516e-04
# [Epoch 77/150] train MSE = 1.792146e-04
# [Epoch 78/150] train MSE = 1.874002e-04
# [Epoch 79/150] train MSE = 2.013350e-04
# [Epoch 80/150] train MSE = 2.205301e-04
# [Epoch 81/150] train MSE = 1.860230e-04
# [Epoch 82/150] train MSE = 1.781540e-04
# [Epoch 83/150] train MSE = 1.742739e-04
# [Epoch 84/150] train MSE = 2.179087e-04
# [Epoch 85/150] train MSE = 1.689493e-04
# [Epoch 86/150] train MSE = 1.778614e-04
# [Epoch 87/150] train MSE = 1.799729e-04
# [Epoch 88/150] train MSE = 1.740466e-04
# [Epoch 89/150] train MSE = 1.838644e-04
# [Epoch 90/150] train MSE = 1.849544e-04
# [Epoch 91/150] train MSE = 1.895084e-04
# [Epoch 92/150] train MSE = 1.876207e-04
# [Epoch 93/150] train MSE = 1.877297e-04
# [Epoch 94/150] train MSE = 1.965198e-04
# [Epoch 95/150] train MSE = 1.788731e-04
# [Epoch 96/150] train MSE = 2.109904e-04
# [Epoch 97/150] train MSE = 1.700830e-04
# [Epoch 98/150] train MSE = 1.746289e-04
# [Epoch 99/150] train MSE = 1.887937e-04
# [Epoch 100/150] train MSE = 1.671081e-04
# [Epoch 101/150] train MSE = 1.870846e-04
# [Epoch 102/150] train MSE = 1.736706e-04
# [Epoch 103/150] train MSE = 1.630548e-04
# [Epoch 104/150] train MSE = 1.719484e-04
# [Epoch 105/150] train MSE = 1.722588e-04
# [Epoch 106/150] train MSE = 1.931923e-04
# [Epoch 107/150] train MSE = 1.738581e-04
# [Epoch 108/150] train MSE = 1.805777e-04
# [Epoch 109/150] train MSE = 1.657715e-04
# [Epoch 110/150] train MSE = 1.620885e-04
# [Epoch 111/150] train MSE = 2.083158e-04
# [Epoch 112/150] train MSE = 1.692505e-04
# [Epoch 113/150] train MSE = 1.636710e-04
# [Epoch 114/150] train MSE = 1.651450e-04
# [Epoch 115/150] train MSE = 1.646515e-04
# [Epoch 116/150] train MSE = 1.757137e-04
# [Epoch 117/150] train MSE = 1.621001e-04
# [Epoch 118/150] train MSE = 1.735002e-04
# [Epoch 119/150] train MSE = 1.644438e-04
# [Epoch 120/150] train MSE = 1.624313e-04
# [Epoch 121/150] train MSE = 1.866524e-04
# [Epoch 122/150] train MSE = 1.785083e-04
# [Epoch 123/150] train MSE = 1.608716e-04
# [Epoch 124/150] train MSE = 1.843039e-04
# [Epoch 125/150] train MSE = 1.666691e-04
# [Epoch 126/150] train MSE = 1.585846e-04
# [Epoch 127/150] train MSE = 1.702730e-04
# [Epoch 128/150] train MSE = 1.765252e-04
# [Epoch 129/150] train MSE = 1.792273e-04
# [Epoch 130/150] train MSE = 1.650077e-04
# [Epoch 131/150] train MSE = 1.696803e-04
# [Epoch 132/150] train MSE = 1.811297e-04
# [Epoch 133/150] train MSE = 1.568272e-04
# [Epoch 134/150] train MSE = 1.609784e-04
# [Epoch 135/150] train MSE = 1.730664e-04
# [Epoch 136/150] train MSE = 1.571797e-04
# [Epoch 137/150] train MSE = 1.601349e-04
# [Epoch 138/150] train MSE = 1.808064e-04
# [Epoch 139/150] train MSE = 1.663106e-04
# [Epoch 140/150] train MSE = 1.574366e-04
# [Epoch 141/150] train MSE = 1.583716e-04
# [Epoch 142/150] train MSE = 1.668509e-04
# [Epoch 143/150] train MSE = 2.109274e-04
# [Epoch 144/150] train MSE = 1.587857e-04
# [Epoch 145/150] train MSE = 1.520751e-04
# [Epoch 146/150] train MSE = 1.640490e-04
# [Epoch 147/150] train MSE = 1.586264e-04
# [Epoch 148/150] train MSE = 1.521826e-04
# [Epoch 149/150] train MSE = 1.587541e-04
# [Epoch 150/150] train MSE = 1.760641e-04

# %%
# Evaluate models
print("Evaluating Linear Model:")
test_loss_lin = eval_integrator_B(model_lin, data, R, k)

print("\nEvaluating MLP Model:")
test_loss_mlp = eval_integrator_B(model_mlp, data, R, k)
# Out:
# Evaluating Linear Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 1.784744e-04
#
# Evaluating MLP Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 2.072300e-04

# %%
# ===== Load model =====

ckpt = torch.load("diffusion_advection_mlp_model.pt", map_location="cuda")

if ckpt["model_type"] == "linear":
    model = LinearIntegrator(k=ckpt["config"]["k"])
elif ckpt["model_type"] == "mlp":
    model = MLPIntegrator(
        k=ckpt["config"]["k"],
        hidden=ckpt["config"]["hidden"],
        num_layers=ckpt["config"]["num_layers"],
    )
else:
    raise ValueError("Unknown model type")

model.load_state_dict(ckpt["state_dict"])
model = model.to("cuda")
model.eval()

print(f"Loaded {ckpt['model_type']} model with config:")
print(ckpt["config"])

# %%
# Visualize comparison
visualize_B_compare_models(data, model_lin, model_mlp, R=R, k=k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Visualize comparison
# ----> 2 visualize_B_compare_models(data, model_lin, model_mlp, R=R, k=k)
#
# NameError: name 'model_lin' is not defined

# %%
# Plot training losses
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
# Save models
u_scale = np.max(np.abs(data)) + 1e-8
config_lin = {"k": k, "R": R, "u_scale": u_scale}
config_mlp = {"k": k, "R": R, "hidden": 128, "num_layers": 3, "u_scale": u_scale}

save_integrator_model(model_lin, "linear", "diffusion_advection_linear_model.pt", config_lin)
save_integrator_model(model_mlp, "mlp", "diffusion_advection_mlp_model.pt", config_mlp)

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
# Cumulative test error comparison
n_points = 10000
step =500
n_steps = n_points // step

test_ds = BDataset(data, N_samples=n_points, R=R, k=k, seed=456, pregenerate=True)
loader = DataLoader(test_ds, batch_size=step, shuffle=False, num_workers=0, pin_memory=True)

loss_fn = nn.MSELoss()
cum_err_lin, cum_err_mlp = [], []
total_lin, total_mlp = 0.0, 0.0

model_lin.eval()
model_mlp.eval()
with torch.no_grad():
    for i, (feats, target) in enumerate(loader):
        feats = feats.to(device)
        target = target.to(device)
        
        pred_lin = model_lin(feats)
        pred_mlp = model_mlp(feats)
        
        loss_lin = loss_fn(pred_lin, target).item()
        loss_mlp = loss_fn(pred_mlp, target).item()
        
        total_lin += loss_lin * step
        total_mlp += loss_mlp * step
        
        cum_err_lin.append(total_lin    )
        cum_err_mlp.append(total_mlp )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Cumulative error
x = np.arange(step, n_points + 1, step)
ax1.semilogy(x, cum_err_lin, 'o-', label='Linear', color='C0', markersize=4)
ax1.semilogy(x, cum_err_mlp, 's-', label='MLP', color='C1', markersize=4)
ax1.set_xlabel('Number of test points')
ax1.set_ylabel('Cumulative MSE')
ax1.set_title('Cumulative Test Error')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Error ratio
ratio = np.array(cum_err_mlp) / np.array(cum_err_lin)
ax2.plot(x, ratio, 'k-', linewidth=2)
ax2.axhline(1, color='r', linestyle='--', alpha=0.5, label='Equal')
ax2.set_xlabel('Number of test points')
ax2.set_ylabel('MLP / Linear')
ax2.set_title('Error Ratio (MLP/Linear)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
