# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate diffusion-advection data (Dirichlet BC)
# -----------------------
def diffusion_advection_solver_dirichlet(u0, nu=0.01, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D diffusion-advection (Dirichlet BCs u(0,t)=u(1,t)=0).
    
    Solves: ∂u/∂t + c * ∂u/∂x = ν * ∂²u/∂x²
    Uses upwind scheme for advection: if c > 0, backward difference
    Uses central difference for diffusion
    """
    u = u0.copy()
    Nx = len(u)
    traj = [u.copy()]
    
    for _ in range(n_steps):
        un = u.copy()
        
        # Diffusion term: ν * ∂²u/∂x² (central difference)
        # Laplacian on interior points
        lap = (un[2:] - 2*un[1:-1] + un[:-2]) / dx**2
        diffusion = nu * lap
        
        # Advection term: c * ∂u/∂x (upwind scheme)
        if c > 0:
            # Backward difference for c > 0
            advection = c * (un[1:-1] - un[:-2]) / dx
        else:
            # Forward difference for c < 0
            advection = c * (un[2:] - un[1:-1]) / dx
        
        # Combine: ∂u/∂t = -c * ∂u/∂x + ν * ∂²u/∂x²
        u[1:-1] = un[1:-1] + dt * (-advection + diffusion)
        
        # Dirichlet boundaries
        u[0] = 0.0
        u[-1] = 0.0
        
        traj.append(u.copy())
    return np.stack(traj)  # shape (T, Nx)

def generate_diffusion_advection_data(Nx=128, nu=0.01, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)
    
    # initial condition compatible with Dirichlet BC
    u0 = np.sin(2*np.pi * x)   # = 0 at x=0 and x=1
    
    data = diffusion_advection_solver_dirichlet(u0, nu, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
nu = 0.017  # diffusion coefficient
c = 0.4    # advection velocity
n_steps = 5000

x, data = generate_diffusion_advection_data(Nx, nu, c, dt0, n_steps)

# %%
t_plot = n_steps  # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Diffusion-Advection: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) / true * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
def save_integrator_model(model, model_type, path, config):
    """
    Save a trained integrator model.

    Args:
        model: trained torch.nn.Module
        model_type: str ("linear" or "mlp")
        config: dict with required hyperparameters
    """
    torch.save(
        {
            "model_type": model_type,
            "model_state_dict": model.state_dict(),
            "config": config,
        },
        path,
    )

# %%
def load_integrator_model(path):
    """
    Load a saved integrator model.
    """
    device = "cuda"
    checkpoint = torch.load(path, map_location=device)

    model_type = checkpoint["model_type"]
    config = checkpoint["config"]

    if model_type == "linear":
        model = LinearIntegrator(k=config["k"])
    elif model_type == "mlp":
        model = MLPIntegrator(
            k=config["k"],
            hidden=config["hidden"],
            num_layers=config["num_layers"],
        )
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(checkpoint["model_state_dict"])
    model = model.to(device)
    model.eval()

    return model, config

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 2.018004e+00
# [Epoch 2/150] train MSE = 1.096835e+00
# [Epoch 3/150] train MSE = 5.828424e-01
# [Epoch 4/150] train MSE = 3.038402e-01
# [Epoch 5/150] train MSE = 1.537054e-01
# [Epoch 6/150] train MSE = 7.436807e-02
# [Epoch 7/150] train MSE = 3.414965e-02
# [Epoch 8/150] train MSE = 1.482028e-02
# [Epoch 9/150] train MSE = 6.107639e-03
# [Epoch 10/150] train MSE = 2.427363e-03
# [Epoch 11/150] train MSE = 9.744725e-04
# [Epoch 12/150] train MSE = 4.395101e-04
# [Epoch 13/150] train MSE = 2.551549e-04
# [Epoch 14/150] train MSE = 1.958422e-04
# [Epoch 15/150] train MSE = 1.780748e-04
# [Epoch 16/150] train MSE = 1.730734e-04
# [Epoch 17/150] train MSE = 1.717735e-04
# [Epoch 18/150] train MSE = 1.714358e-04
# [Epoch 19/150] train MSE = 1.713273e-04
# [Epoch 20/150] train MSE = 1.712468e-04
# [Epoch 21/150] train MSE = 1.712042e-04
# [Epoch 22/150] train MSE = 1.711812e-04
# [Epoch 23/150] train MSE = 1.711206e-04
# [Epoch 24/150] train MSE = 1.710525e-04
# [Epoch 25/150] train MSE = 1.710071e-04
# [Epoch 26/150] train MSE = 1.709791e-04
# [Epoch 27/150] train MSE = 1.709194e-04
# [Epoch 28/150] train MSE = 1.708438e-04
# [Epoch 29/150] train MSE = 1.707978e-04
# [Epoch 30/150] train MSE = 1.707345e-04
# [Epoch 31/150] train MSE = 1.706455e-04
# [Epoch 32/150] train MSE = 1.705899e-04
# [Epoch 33/150] train MSE = 1.705317e-04
# [Epoch 34/150] train MSE = 1.704812e-04
# [Epoch 35/150] train MSE = 1.704630e-04
# [Epoch 36/150] train MSE = 1.703135e-04
# [Epoch 37/150] train MSE = 1.702840e-04
# [Epoch 38/150] train MSE = 1.701872e-04
# [Epoch 39/150] train MSE = 1.701185e-04
# [Epoch 40/150] train MSE = 1.700546e-04
# [Epoch 41/150] train MSE = 1.699593e-04
# [Epoch 42/150] train MSE = 1.698534e-04
# [Epoch 43/150] train MSE = 1.698153e-04
# [Epoch 44/150] train MSE = 1.697289e-04
# [Epoch 45/150] train MSE = 1.696216e-04
# [Epoch 46/150] train MSE = 1.695221e-04
# [Epoch 47/150] train MSE = 1.694406e-04
# [Epoch 48/150] train MSE = 1.693336e-04
# [Epoch 49/150] train MSE = 1.692394e-04
# [Epoch 50/150] train MSE = 1.691345e-04
# [Epoch 51/150] train MSE = 1.690169e-04
# [Epoch 52/150] train MSE = 1.689285e-04
# [Epoch 53/150] train MSE = 1.688435e-04
# [Epoch 54/150] train MSE = 1.687540e-04
# [Epoch 55/150] train MSE = 1.686166e-04
# [Epoch 56/150] train MSE = 1.684791e-04
# [Epoch 57/150] train MSE = 1.684380e-04
# [Epoch 58/150] train MSE = 1.682892e-04
# [Epoch 59/150] train MSE = 1.682266e-04
# [Epoch 60/150] train MSE = 1.680833e-04
# [Epoch 61/150] train MSE = 1.679722e-04
# [Epoch 62/150] train MSE = 1.677719e-04
# [Epoch 63/150] train MSE = 1.676758e-04
# [Epoch 64/150] train MSE = 1.675477e-04
# [Epoch 65/150] train MSE = 1.673995e-04
# [Epoch 66/150] train MSE = 1.673370e-04
# [Epoch 67/150] train MSE = 1.671741e-04
# [Epoch 68/150] train MSE = 1.669982e-04
# [Epoch 69/150] train MSE = 1.668955e-04
# [Epoch 70/150] train MSE = 1.668095e-04
# [Epoch 71/150] train MSE = 1.666131e-04
# [Epoch 72/150] train MSE = 1.664477e-04
# [Epoch 73/150] train MSE = 1.662971e-04
# [Epoch 74/150] train MSE = 1.661330e-04
# [Epoch 75/150] train MSE = 1.660581e-04
# [Epoch 76/150] train MSE = 1.658140e-04
# [Epoch 77/150] train MSE = 1.658255e-04
# [Epoch 78/150] train MSE = 1.655240e-04
# [Epoch 79/150] train MSE = 1.654187e-04
# [Epoch 80/150] train MSE = 1.652198e-04
# [Epoch 81/150] train MSE = 1.650620e-04
# [Epoch 82/150] train MSE = 1.648533e-04
# [Epoch 83/150] train MSE = 1.647520e-04
# [Epoch 84/150] train MSE = 1.645594e-04
# [Epoch 85/150] train MSE = 1.643287e-04
# [Epoch 86/150] train MSE = 1.642084e-04
# [Epoch 87/150] train MSE = 1.640663e-04
# [Epoch 88/150] train MSE = 1.638575e-04
# [Epoch 89/150] train MSE = 1.636456e-04
# [Epoch 90/150] train MSE = 1.634479e-04
# [Epoch 91/150] train MSE = 1.632687e-04
# [Epoch 92/150] train MSE = 1.631983e-04
# [Epoch 93/150] train MSE = 1.629166e-04
# [Epoch 94/150] train MSE = 1.628365e-04
# [Epoch 95/150] train MSE = 1.625993e-04
# [Epoch 96/150] train MSE = 1.624598e-04
# [Epoch 97/150] train MSE = 1.623904e-04
# [Epoch 98/150] train MSE = 1.620215e-04
# [Epoch 99/150] train MSE = 1.618867e-04
# [Epoch 100/150] train MSE = 1.615936e-04
# [Epoch 101/150] train MSE = 1.614697e-04
# [Epoch 102/150] train MSE = 1.612356e-04
# [Epoch 103/150] train MSE = 1.612111e-04
# [Epoch 104/150] train MSE = 1.608633e-04
# [Epoch 105/150] train MSE = 1.606561e-04
# [Epoch 106/150] train MSE = 1.607246e-04
# [Epoch 107/150] train MSE = 1.603084e-04
# [Epoch 108/150] train MSE = 1.603134e-04
# [Epoch 109/150] train MSE = 1.598982e-04
# [Epoch 110/150] train MSE = 1.596811e-04
# [Epoch 111/150] train MSE = 1.594801e-04
# [Epoch 112/150] train MSE = 1.594736e-04
# [Epoch 113/150] train MSE = 1.592920e-04
# [Epoch 114/150] train MSE = 1.591531e-04
# [Epoch 115/150] train MSE = 1.588584e-04
# [Epoch 116/150] train MSE = 1.584971e-04
# [Epoch 117/150] train MSE = 1.584806e-04
# [Epoch 118/150] train MSE = 1.582973e-04
# [Epoch 119/150] train MSE = 1.581343e-04
# [Epoch 120/150] train MSE = 1.577961e-04
# [Epoch 121/150] train MSE = 1.579468e-04
# [Epoch 122/150] train MSE = 1.578209e-04
# [Epoch 123/150] train MSE = 1.576115e-04
# [Epoch 124/150] train MSE = 1.572052e-04
# [Epoch 125/150] train MSE = 1.570356e-04
# [Epoch 126/150] train MSE = 1.573067e-04
# [Epoch 127/150] train MSE = 1.569100e-04
# [Epoch 128/150] train MSE = 1.565543e-04
# [Epoch 129/150] train MSE = 1.563886e-04
# [Epoch 130/150] train MSE = 1.564979e-04
# [Epoch 131/150] train MSE = 1.562123e-04
# [Epoch 132/150] train MSE = 1.559663e-04
# [Epoch 133/150] train MSE = 1.558822e-04
# [Epoch 134/150] train MSE = 1.555342e-04
# [Epoch 135/150] train MSE = 1.557282e-04
# [Epoch 136/150] train MSE = 1.554891e-04
# [Epoch 137/150] train MSE = 1.553605e-04
# [Epoch 138/150] train MSE = 1.551081e-04
# [Epoch 139/150] train MSE = 1.550801e-04
# [Epoch 140/150] train MSE = 1.551432e-04
# [Epoch 141/150] train MSE = 1.550731e-04
# [Epoch 142/150] train MSE = 1.548918e-04
# [Epoch 143/150] train MSE = 1.548314e-04
# [Epoch 144/150] train MSE = 1.548418e-04
# [Epoch 145/150] train MSE = 1.543359e-04
# [Epoch 146/150] train MSE = 1.542477e-04
# [Epoch 147/150] train MSE = 1.553298e-04
# [Epoch 148/150] train MSE = 1.545352e-04
# [Epoch 149/150] train MSE = 1.540552e-04
# [Epoch 150/150] train MSE = 1.542017e-04

# %%
model_mlp = MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.052380e-01
# [Epoch 2/150] train MSE = 5.741615e-03
# [Epoch 3/150] train MSE = 3.923124e-03
# [Epoch 4/150] train MSE = 3.034035e-03
# [Epoch 5/150] train MSE = 2.435628e-03
# [Epoch 6/150] train MSE = 2.027706e-03
# [Epoch 7/150] train MSE = 1.726687e-03
# [Epoch 8/150] train MSE = 1.502730e-03
# [Epoch 9/150] train MSE = 1.323165e-03
# [Epoch 10/150] train MSE = 1.185319e-03
# [Epoch 11/150] train MSE = 1.073397e-03
# [Epoch 12/150] train MSE = 9.789672e-04
# [Epoch 13/150] train MSE = 8.870077e-04
# [Epoch 14/150] train MSE = 8.170272e-04
# [Epoch 15/150] train MSE = 7.577815e-04
# [Epoch 16/150] train MSE = 7.076486e-04
# [Epoch 17/150] train MSE = 6.544255e-04
# [Epoch 18/150] train MSE = 6.172208e-04
# [Epoch 19/150] train MSE = 5.821991e-04
# [Epoch 20/150] train MSE = 5.559305e-04
# [Epoch 21/150] train MSE = 5.127216e-04
# [Epoch 22/150] train MSE = 4.924131e-04
# [Epoch 23/150] train MSE = 4.546236e-04
# [Epoch 24/150] train MSE = 4.345544e-04
# [Epoch 25/150] train MSE = 4.122173e-04
# [Epoch 26/150] train MSE = 3.968747e-04
# [Epoch 27/150] train MSE = 3.778223e-04
# [Epoch 28/150] train MSE = 3.641305e-04
# [Epoch 29/150] train MSE = 3.540599e-04
# [Epoch 30/150] train MSE = 3.298436e-04
# [Epoch 31/150] train MSE = 3.172205e-04
# [Epoch 32/150] train MSE = 3.091677e-04
# [Epoch 33/150] train MSE = 3.025679e-04
# [Epoch 34/150] train MSE = 2.969058e-04
# [Epoch 35/150] train MSE = 2.803271e-04
# [Epoch 36/150] train MSE = 2.884980e-04
# [Epoch 37/150] train MSE = 2.872514e-04
# [Epoch 38/150] train MSE = 2.525896e-04
# [Epoch 39/150] train MSE = 2.847228e-04
# [Epoch 40/150] train MSE = 2.637977e-04
# [Epoch 41/150] train MSE = 2.574194e-04
# [Epoch 42/150] train MSE = 2.406421e-04
# [Epoch 43/150] train MSE = 2.391025e-04
# [Epoch 44/150] train MSE = 2.441359e-04
# [Epoch 45/150] train MSE = 2.243120e-04
# [Epoch 46/150] train MSE = 2.380457e-04
# [Epoch 47/150] train MSE = 2.703721e-04
# [Epoch 48/150] train MSE = 2.366698e-04
# [Epoch 49/150] train MSE = 2.176262e-04
# [Epoch 50/150] train MSE = 2.044133e-04
# [Epoch 51/150] train MSE = 2.309994e-04
# [Epoch 52/150] train MSE = 2.401884e-04
# [Epoch 53/150] train MSE = 2.347361e-04
# [Epoch 54/150] train MSE = 2.011048e-04
# [Epoch 55/150] train MSE = 2.021204e-04
# [Epoch 56/150] train MSE = 1.979215e-04
# [Epoch 57/150] train MSE = 2.291863e-04
# [Epoch 58/150] train MSE = 2.000261e-04
# [Epoch 59/150] train MSE = 2.271572e-04
# [Epoch 60/150] train MSE = 2.028842e-04
# [Epoch 61/150] train MSE = 1.956524e-04
# [Epoch 62/150] train MSE = 2.184393e-04
# [Epoch 63/150] train MSE = 1.969371e-04
# [Epoch 64/150] train MSE = 1.970749e-04
# [Epoch 65/150] train MSE = 1.747795e-04
# [Epoch 66/150] train MSE = 2.199046e-04
# [Epoch 67/150] train MSE = 2.348887e-04
# [Epoch 68/150] train MSE = 1.865941e-04
# [Epoch 69/150] train MSE = 1.743180e-04
# [Epoch 70/150] train MSE = 1.803132e-04
# [Epoch 71/150] train MSE = 2.074995e-04
# [Epoch 72/150] train MSE = 1.716958e-04
# [Epoch 73/150] train MSE = 2.046926e-04
# [Epoch 74/150] train MSE = 1.710550e-04
# [Epoch 75/150] train MSE = 1.852823e-04
# [Epoch 76/150] train MSE = 1.938648e-04
# [Epoch 77/150] train MSE = 1.845150e-04
# [Epoch 78/150] train MSE = 1.828444e-04
# [Epoch 79/150] train MSE = 1.937738e-04
# [Epoch 80/150] train MSE = 1.702470e-04
# [Epoch 81/150] train MSE = 2.382425e-04
# [Epoch 82/150] train MSE = 1.685220e-04
# [Epoch 83/150] train MSE = 1.741935e-04
# [Epoch 84/150] train MSE = 1.730124e-04
# [Epoch 85/150] train MSE = 2.147518e-04
# [Epoch 86/150] train MSE = 1.836378e-04
# [Epoch 87/150] train MSE = 1.766041e-04
# [Epoch 88/150] train MSE = 1.864349e-04
# [Epoch 89/150] train MSE = 1.732564e-04
# [Epoch 90/150] train MSE = 1.841884e-04
# [Epoch 91/150] train MSE = 1.840862e-04
# [Epoch 92/150] train MSE = 1.715213e-04
# [Epoch 93/150] train MSE = 1.757132e-04
# [Epoch 94/150] train MSE = 1.708441e-04
# [Epoch 95/150] train MSE = 1.698775e-04
# [Epoch 96/150] train MSE = 1.793275e-04
# [Epoch 97/150] train MSE = 2.042943e-04
# [Epoch 98/150] train MSE = 1.652206e-04
# [Epoch 99/150] train MSE = 1.923764e-04
# [Epoch 100/150] train MSE = 1.694228e-04
# [Epoch 101/150] train MSE = 1.630439e-04
# [Epoch 102/150] train MSE = 1.858019e-04
# [Epoch 103/150] train MSE = 1.695477e-04
# [Epoch 104/150] train MSE = 1.928420e-04
# [Epoch 105/150] train MSE = 1.804481e-04
# [Epoch 106/150] train MSE = 1.653344e-04
# [Epoch 107/150] train MSE = 1.682368e-04
# [Epoch 108/150] train MSE = 1.794293e-04
# [Epoch 109/150] train MSE = 1.827387e-04
# [Epoch 110/150] train MSE = 1.801771e-04
# [Epoch 111/150] train MSE = 1.623864e-04
# [Epoch 112/150] train MSE = 1.612893e-04
# [Epoch 113/150] train MSE = 1.718294e-04
# [Epoch 114/150] train MSE = 1.746291e-04
# [Epoch 115/150] train MSE = 1.709104e-04
# [Epoch 116/150] train MSE = 1.640772e-04
# [Epoch 117/150] train MSE = 1.652897e-04
# [Epoch 118/150] train MSE = 1.668192e-04
# [Epoch 119/150] train MSE = 1.705220e-04
# [Epoch 120/150] train MSE = 1.645401e-04
# [Epoch 121/150] train MSE = 2.089731e-04
# [Epoch 122/150] train MSE = 1.620830e-04
# [Epoch 123/150] train MSE = 1.660884e-04
# [Epoch 124/150] train MSE = 1.682638e-04
# [Epoch 125/150] train MSE = 1.720875e-04
# [Epoch 126/150] train MSE = 1.559024e-04
# [Epoch 127/150] train MSE = 1.654052e-04
# [Epoch 128/150] train MSE = 1.700576e-04
# [Epoch 129/150] train MSE = 1.707240e-04
# [Epoch 130/150] train MSE = 1.617392e-04
# [Epoch 131/150] train MSE = 1.584922e-04
# [Epoch 132/150] train MSE = 1.903927e-04
# [Epoch 133/150] train MSE = 1.598976e-04
# [Epoch 134/150] train MSE = 1.552751e-04
# [Epoch 135/150] train MSE = 1.761613e-04
# [Epoch 136/150] train MSE = 1.575840e-04
# [Epoch 137/150] train MSE = 1.664897e-04
# [Epoch 138/150] train MSE = 1.573232e-04
# [Epoch 139/150] train MSE = 1.597211e-04
# [Epoch 140/150] train MSE = 1.687855e-04
# [Epoch 141/150] train MSE = 1.651650e-04
# [Epoch 142/150] train MSE = 1.594840e-04
# [Epoch 143/150] train MSE = 1.616002e-04
# [Epoch 144/150] train MSE = 1.803617e-04
# [Epoch 145/150] train MSE = 1.631603e-04
# [Epoch 146/150] train MSE = 1.639289e-04
# [Epoch 147/150] train MSE = 1.589952e-04
# [Epoch 148/150] train MSE = 1.679230e-04
# [Epoch 149/150] train MSE = 1.585458e-04
# [Epoch 150/150] train MSE = 1.551748e-04

# %%
# Evaluate models
print("Evaluating Linear Model:")
test_loss_lin = eval_integrator_B(model_lin, data, R, k)

print("\nEvaluating MLP Model:")
test_loss_mlp = eval_integrator_B(model_mlp, data, R, k)
# Out:
# Evaluating Linear Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 1.515255e-04
#
# Evaluating MLP Model:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
# [Eval] MSE = 1.573240e-04

# %%
# Visualize comparison
visualize_B_compare_models(data, model_lin, model_mlp, R=R, k=k)
# Out:
# C:\Users\amt35\AppData\Local\Temp\ipykernel_11020\736158891.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Plot training losses
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
# Save models
u_scale = np.max(np.abs(data)) + 1e-8
config_lin = {"k": k, "R": R, "u_scale": u_scale}
config_mlp = {"k": k, "R": R, "hidden": 128, "num_layers": 3, "u_scale": u_scale}

save_integrator_model(model_lin, "linear", "diffusion_advection_linear_model.pt", config_lin)
save_integrator_model(model_mlp, "mlp", "diffusion_advection_mlp_model.pt", config_mlp)

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %%
# Cumulative test error comparison
n_points = 10000
step =500
n_steps = n_points // step

test_ds = BDataset(data, N_samples=n_points, R=R, k=k, seed=456, pregenerate=True)
loader = DataLoader(test_ds, batch_size=step, shuffle=False, num_workers=0, pin_memory=True)

loss_fn = nn.MSELoss()
cum_err_lin, cum_err_mlp = [], []
total_lin, total_mlp = 0.0, 0.0

model_lin.eval()
model_mlp.eval()
with torch.no_grad():
    for i, (feats, target) in enumerate(loader):
        feats = feats.to(device)
        target = target.to(device)
        
        pred_lin = model_lin(feats)
        pred_mlp = model_mlp(feats)
        
        loss_lin = loss_fn(pred_lin, target).item()
        loss_mlp = loss_fn(pred_mlp, target).item()
        
        total_lin += loss_lin * step
        total_mlp += loss_mlp * step
        
        cum_err_lin.append(total_lin    )
        cum_err_mlp.append(total_mlp )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Cumulative error
x = np.arange(step, n_points + 1, step)
ax1.semilogy(x, cum_err_lin, 'o-', label='Linear', color='C0', markersize=4)
ax1.semilogy(x, cum_err_mlp, 's-', label='MLP', color='C1', markersize=4)
ax1.set_xlabel('Number of test points')
ax1.set_ylabel('Cumulative MSE')
ax1.set_title('Cumulative Test Error')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Error ratio
ratio = np.array(cum_err_mlp) / np.array(cum_err_lin)
ax2.plot(x, ratio, 'k-', linewidth=2)
ax2.axhline(1, color='r', linestyle='--', alpha=0.5, label='Equal')
ax2.set_xlabel('Number of test points')
ax2.set_ylabel('MLP / Linear')
ax2.set_title('Error Ratio (MLP/Linear)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
