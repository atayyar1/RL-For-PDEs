# %% [markdown]
# # Burgers Rollout With Picard GFDM
#
# Space-time GFDM rollout for Burgers' equation: `u_t + u u_x = alpha u_xx`.
#
# The nonlinear advection speed is Picard-linearized locally as the mean of neighbor `u` values.

# %%
# Rollout_burgers_picard.py
# Solves Burgers' equation: ut + u*ux = alpha*uxx
# Method: Picard linearization — local advection speed c_local = mean(u_neighbors)
# Analytical solution via Hopf-Cole transformation with Fourier cosine series

"""
Design
- FD grid is used as a coordinate scaffold only. Candidate points are
  drawn from FD grid coordinates so coverage is always dense.
- u values at interior points are computed by PDE-informed interpolation,
  NOT copied from FD. FD is used only for error measurement.
- Stopping criterion: max_points successfully computed interior points.
- KDTree for O(log N) neighbour queries.
- O(1) candidate removal via swap-and-pop.
"""

import time
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator

# %% [markdown]
# ## Parameters
#
# Set the Burgers viscosity and final time.

# %%
alpha = 0.1
T     = 0.5

# %% [markdown]
# ## Analytical Solution
#
# Hopf-Cole analytical reference, precomputed once with a Fourier cosine series.

# %%
# Precompute coefficients once
_xq = np.linspace(0.0, 1.0, 20001)
_phi0 = np.exp(-(1 - np.cos(np.pi * _xq)) / (2 * alpha * np.pi))

_N_SERIES = 200
_a = np.zeros(_N_SERIES + 1)
_a[0] = np.trapezoid(_phi0, _xq)
for n in range(1, _N_SERIES + 1):
    _a[n] = 2.0 * np.trapezoid(_phi0 * np.cos(n * np.pi * _xq), _xq)

_n_arr = np.arange(1, _N_SERIES + 1)
_an = _a[1:]
_lam_hc = -alpha * (_n_arr * np.pi) ** 2

def u_true(x, t):
    x = np.asarray(x, dtype=float)
    scalar = x.ndim == 0
    x = np.atleast_1d(x)
    cos_nx = np.cos(np.pi * np.outer(x, _n_arr))
    sin_nx = np.sin(np.pi * np.outer(x, _n_arr))
    exp_t = np.exp(_lam_hc * t)
    phi = _a[0] + (cos_nx * (_an * exp_t)).sum(axis=-1)
    phi_x = -(sin_nx * (_an * _n_arr * np.pi * exp_t)).sum(axis=-1)
    result = -2 * alpha * phi_x / phi
    return float(result[0]) if scalar else result

# %% [markdown]
# ## FD Reference Grid
#
# The FD grid provides coordinates and a reference solution for error checks.

# %%
# -- FD r/eference grid --------------------------------------------------------?
nx_fd = 100
x_fd  = np.linspace(0.0, 1.0, nx_fd)
dx_fd = x_fd[1] - x_fd[0]

# Compute nt_fd from CFL ? never touch this manually
dt_cfl = min(0.9 * dx_fd / 1.0,
             0.45 * dx_fd**2 / alpha)
nt_fd  = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt_fd)
dt_fd  = t_fd[1] - t_fd[0]


def build_fd_reference():
    """Explicit upwind FD solve. Returns (u_fd, interpolant)."""
    u = np.zeros((nx_fd, nt_fd))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt_fd / dx_fd**2

    for it in range(nt_fd - 1):
        un = u[:, it]
        r_adv_local = un * dt_fd / dx_fd
        u[1:-1, it+1] = (un[1:-1]
                         - r_adv_local[1:-1] * (un[1:-1] - un[:-2])
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,  it+1] = 0.0
        u[-1, it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
        bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ## Rollout Settings
#
# These are the same rollout controls from the working solver.

# %%
# -- Integrator hyperparameters ------------------------------------------------
max_points    = 100000   # stopping criterion
u_bound = 1.1
n_neighbours  = 5     # stencil size (3 equations, 5 unknowns → underdetermined)
cond_max      = 1e4
isotropy_max  = 50.0
w_max_factor  = 3.0     # reject if max|w_j| > w_max_factor / n
w_min_floor   = -1.0

# Spawn box in FD grid steps
spawn_nx      = 5       # ? x steps around a newly solved point
spawn_nt      = 3       # + t steps forward

# Neighbour search box in normalised units (x/dx_fd, t/dt_fd)
box_n0        = 2.0     # initial half-width
box_grow      = 1.5
box_nmax      = 15.0

max_candidates = 6000   # cap on candidate list length (for memory and speed)

# %% [markdown]
# ## Visited Points
#
# KDTree-backed storage for accepted `(x, t, u)` points.

# %%
# -- KDTree-backed visited set ------------------------------------------------?
class VisitedSet:
    """
    Stores (x, t, u) points. KDTree is in normalised (x/dx_fd, t/dt_fd)
    space so both axes are commensurate during neighbour search.
    Rebuilt lazily every rebuild_every insertions.
    """
    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
    def add(self, x, t, u):
        self._pts.append((x, t, u))
        self._norm.append((x / dx_fd, t / dt_fd))   # add this
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))   # change this
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()

    def find_neighbours(self, x_star, t_star):
        self._ensure()
        xn = x_star / dx_fd
        tn = t_star / dt_fd
        bn = box_n0
        while True:
            idxs = self._tree.query_ball_point([xn, tn], r=bn, p=np.inf)
            nb = [
                self._pts[i] for i in idxs
                if abs(self._pts[i][0] - x_star) <= bn * dx_fd
                and 0 < (t_star - self._pts[i][1]) <= bn * dt_fd
            ]
            if len(nb) >= n_neighbours:
                nb.sort(key=lambda p: (p[0]-x_star)**2 + (p[1]-t_star)**2)
                return nb[:n_neighbours]
            bn = min(bn * box_grow, box_nmax)
            if bn >= box_nmax:
                return None
    def __len__(self):
        return len(self._pts)

# %% [markdown]
# ## Stencil And Picard Weights
#
# The local advection speed is `mean(u_neighbors)` before solving weights.

# %%
# -- Stencil geometry check ----------------------------------------------------
def stencil_is_good(dx_i, dt_i):
    if np.min(dx_i) * np.max(dx_i) > 0:          # two-sided coverage
        return False
    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)
    pts = np.column_stack([dx_i / h, dt_i / tau])
    return True


# -- Weight solver ------------------------------------------------------------?
def solve_weights(dx_i, dt_i, u_nb):
    """
    Min-norm lstsq on the 3?n PDE-informed system.
    Returns (w, cond) or (None, cond).
    """
    c_local = float(np.mean(u_nb))

    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
         (dx_i - c_local * dt_i)              / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ]) 
    b = np.array([1 , 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > cond_max:
        return None,    cond

    w = np.linalg.lstsq(A, b, rcond=None)[0]


    # Additional weight checks to prevent error explosion ? these are somewhat ad-hoc and may be tuned or removed based on your needs.
    if np.max(np.abs(w)) > w_max_factor / len(dx_i):   # no dominant weight
        return None, cond
    if np.min(w) < w_min_floor:                         # no extreme negatives
        return None, cond

    return w, cond

## Add L2 instead of L1

# %% [markdown]
# ## Main Rollout
#
# This is the candidate-driven GFDM integrator.

# %%
# -- Main integrator ----------------------------------------------------------?
def run_integrator(seed=None):
    t_wall = time.time()
    if seed is not None:
        np.random.seed(seed)

    print("Building FD reference...", flush=True)
    _, fd_interp = build_fd_reference()
    print(f"  dx={dx_fd:.4f}  dt={dt_fd:.5f}", flush=True)

    # IC + BC into visited set
    visited = VisitedSet()
    for ix in range(nx_fd):
        visited.add(x_fd[ix], 0.0, u_true(x_fd[ix], 0.0))
    for it in range(1, nt_fd):
        visited.add(0.0,  t_fd[it], 0.0)
        visited.add(1.0,  t_fd[it], 0.0)
    print(f"  IC+BC points: {len(visited)}", flush=True)

    # Candidate pool ? integer (ix, it) keys for O(1) deduplication
    cand_keys = set()
    cand_list = []   # list of (x, t)

    def push(ix, it):
        if (ix, it) not in cand_keys:
            cand_keys.add((ix, it))
            cand_list.append((x_fd[ix], t_fd[it]))

    # Seed from IC
    for ix in range(1, nx_fd - 1):
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix, nit = ix + dix, dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

    print(f"  Initial candidates: {len(cand_list)}", flush=True)
    print(f"  Stopping at {max_points} computed points\n", flush=True)

    rej        = dict(proximity=0, no_nb=0, geometry=0, cond=0, weights=0)
    point_data = []

    while cand_list and len(point_data) < max_points:

        # Trim if candidate list is over budget
        protect_candidates = 500

        if len(cand_list) > max_candidates:
            target_size = max(max_candidates, protect_candidates)
            n_remove = len(cand_list) - target_size
            if n_remove > 0:
                del cand_list[:n_remove]

        # ── O(1) swap-and-pop ───────────────────────────────
        idx            = np.random.randint(len(cand_list))
        x_star, t_star = cand_list[idx]
        cand_list[idx] = cand_list[-1]
        cand_list.pop()
        ix_s = int(round(x_star / dx_fd))
        it_s = int(round(t_star / dt_fd))
        cand_keys.discard((ix_s, it_s))
        

        nb = visited.find_neighbours(x_star, t_star)
        if nb is None:
            rej['no_nb'] += 1
            continue

        nb_pts = np.array(nb)
        dx_i   = nb_pts[:, 0] - x_star
        dt_i   = nb_pts[:, 1] - t_star   # negative: neighbours are in the past

        if not stencil_is_good(dx_i, dt_i):
            rej['geometry'] += 1
            continue

        w, cond = solve_weights(dx_i, dt_i, nb_pts[:, 2])
        if w is None:
            rej['cond' if cond > cond_max else 'weights'] += 1
            continue

        # Accept point  
        u_hat = float(w @ nb_pts[:, 2])

        # Break the error cascade - u is bounded by IC amplitude + margin
        if abs(u_hat) > u_bound:
            rej['bounds'] = rej.get('bounds', 0) + 1
            continue

        visited.add(x_star, t_star, u_hat)

        # Spawn new candidates in the FD grid box around this point
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix = ix_s + dix
                nit = it_s + dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

        u_fd_ref = float(fd_interp([[x_star, t_star]])[0])
        u_true_ref = float(u_true(x_star, t_star))
 
        point_data.append({
            'x':     x_star,
            't':     t_star,
            'u':     u_hat,
            'u_true': u_true_ref,
            'u_fd':   u_fd_ref,
            'err_true': abs(u_hat - u_true_ref),
            'err_fd':   abs(u_hat - u_fd_ref),
            'err':   abs(u_hat - u_true_ref),   # use true error for stats and plotting
            'cond':  cond,
            'w1':    float(np.sum(np.abs(w))),
            'box_x': float(np.max(np.abs(dx_i))),   # add this
            'box_t': float(np.max(np.abs(dt_i))),   # add this
            'nb_x':  nb_pts[:, 0].copy(),            # add
            'nb_t':  nb_pts[:, 1].copy(),            # add
            'nb_u':  nb_pts[:, 2].copy(),            # add
        })

        if len(point_data) % 500 == 0:
            errs = [p['err'] for p in point_data]
            t_max = max(p['t'] for p in point_data)
            print(f"  {len(point_data):5d} pts | "
                  f"mean={np.mean(errs):.2e} | "
                  f"max={np.max(errs):.2e} | "
                  f"t_max={t_max:.3f} | "
                  f"cands={len(cand_list):5d} | "
                  f"wall={time.time()-t_wall:.1f}s",
                  flush=True)

    # Summary
    errs = np.array([p['err'] for p in point_data])
    print(f"\n{'─'*56}")
    print(f"  Computed  : {len(point_data)} points")
    print(f"  Mean err  : {errs.mean():.3e}")
    print(f"  Max  err  : {errs.max():.3e}")
    print(f"  Wall time : {time.time()-t_wall:.1f}s")
    total = sum(rej.values()) + len(point_data)
    print(f"\n  Rejections (total attempts: {total})")
    for r, n in rej.items():
        print(f"    {r:10s}: {n:6d}  ({100*n/total:.1f}%)")

    return visited, point_data, fd_interp

# %% [markdown]
# ## Run
#
# Run the full rollout. For a quick test, set `max_points` to a smaller number first.

# %%
# Uncomment for a quick test before the full run:
# max_points = 1000

visited, point_data, fd_interp = run_integrator(seed=None)
# Out:
# Building FD reference...
#   dx=0.0101  dt=0.00046
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 100000 computed points
#
#     500 pts | mean=5.67e-05 | max=1.07e-03 | t_max=0.011 | cands= 1681 | wall=0.1s
#    1000 pts | mean=7.77e-05 | max=1.07e-03 | t_max=0.013 | cands= 2457 | wall=0.2s
#    1500 pts | mean=8.69e-05 | max=1.07e-03 | t_max=0.018 | cands= 3166 | wall=0.4s
#    2000 pts | mean=1.01e-04 | max=1.07e-03 | t_max=0.023 | cands= 3714 | wall=0.5s
#    2500 pts | mean=1.19e-04 | max=1.37e-03 | t_max=0.027 | cands= 4415 | wall=0.6s
#    3000 pts | mean=1.29e-04 | max=1.37e-03 | t_max=0.030 | cands= 4988 | wall=0.7s
#    3500 pts | mean=1.37e-04 | max=1.37e-03 | t_max=0.034 | cands= 5253 | wall=0.9s
#    4000 pts | mean=1.45e-04 | max=1.37e-03 | t_max=0.035 | cands= 5570 | wall=1.0s
#    4500 pts | mean=1.50e-04 | max=1.37e-03 | t_max=0.036 | cands= 5601 | wall=1.1s
#    5000 pts | mean=1.56e-04 | max=1.37e-03 | t_max=0.036 | cands= 5676 | wall=1.3s
#    5500 pts | mean=1.60e-04 | max=1.37e-03 | t_max=0.036 | cands= 5853 | wall=1.5s
#    6000 pts | mean=1.65e-04 | max=1.40e-03 | t_max=0.038 | cands= 5913 | wall=1.6s
#    6500 pts | mean=1.72e-04 | max=1.40e-03 | t_max=0.038 | cands= 5988 | wall=1.8s
#    7000 pts | mean=1.75e-04 | max=1.40e-03 | t_max=0.039 | cands= 5986 | wall=1.9s
#    7500 pts | mean=1.80e-04 | max=1.40e-03 | t_max=0.043 | cands= 6002 | wall=2.1s
#    8000 pts | mean=1.85e-04 | max=1.40e-03 | t_max=0.046 | cands= 6001 | wall=2.3s
#    8500 pts | mean=1.89e-04 | max=1.40e-03 | t_max=0.046 | cands= 5989 | wall=2.5s
#    9000 pts | mean=1.93e-04 | max=1.40e-03 | t_max=0.047 | cands= 5979 | wall=2.7s
#    9500 pts | mean=1.96e-04 | max=1.40e-03 | t_max=0.049 | cands= 5999 | wall=2.9s
#   10000 pts | mean=2.01e-04 | max=1.40e-03 | t_max=0.052 | cands= 5994 | wall=3.0s
#   10500 pts | mean=2.08e-04 | max=2.26e-03 | t_max=0.055 | cands= 5967 | wall=3.2s
#   11000 pts | mean=2.14e-04 | max=2.64e-03 | t_max=0.056 | cands= 6004 | wall=3.4s
#   11500 pts | mean=2.23e-04 | max=2.64e-03 | t_max=0.057 | cands= 5964 | wall=3.6s
#   12000 pts | mean=2.32e-04 | max=2.64e-03 | t_max=0.058 | cands= 5938 | wall=3.8s
#   12500 pts | mean=2.41e-04 | max=2.64e-03 | t_max=0.061 | cands= 5982 | wall=4.0s
#   13000 pts | mean=2.49e-04 | max=2.64e-03 | t_max=0.061 | cands= 5985 | wall=4.2s
#   13500 pts | mean=2.54e-04 | max=2.64e-03 | t_max=0.061 | cands= 5957 | wall=4.4s
#   14000 pts | mean=2.60e-04 | max=2.64e-03 | t_max=0.062 | cands= 5994 | wall=4.6s
#   14500 pts | mean=2.64e-04 | max=2.64e-03 | t_max=0.064 | cands= 5931 | wall=4.8s
#   15000 pts | mean=2.68e-04 | max=2.64e-03 | t_max=0.066 | cands= 5941 | wall=5.0s
#   15500 pts | mean=2.73e-04 | max=2.64e-03 | t_max=0.069 | cands= 5990 | wall=5.2s
#   16000 pts | mean=2.75e-04 | max=2.64e-03 | t_max=0.071 | cands= 5872 | wall=5.5s
#   16500 pts | mean=2.79e-04 | max=2.64e-03 | t_max=0.074 | cands= 5981 | wall=5.7s
#   17000 pts | mean=2.81e-04 | max=2.64e-03 | t_max=0.077 | cands= 5929 | wall=5.9s
#   17500 pts | mean=2.84e-04 | max=2.64e-03 | t_max=0.079 | cands= 5884 | wall=6.1s
#   18000 pts | mean=2.86e-04 | max=2.64e-03 | t_max=0.079 | cands= 5831 | wall=6.4s
#   18500 pts | mean=2.89e-04 | max=2.64e-03 | t_max=0.079 | cands= 5983 | wall=6.6s
#   19000 pts | mean=2.92e-04 | max=2.64e-03 | t_max=0.079 | cands= 5945 | wall=6.9s
#   19500 pts | mean=2.97e-04 | max=2.64e-03 | t_max=0.079 | cands= 5947 | wall=7.1s
#   20000 pts | mean=3.00e-04 | max=2.64e-03 | t_max=0.079 | cands= 5944 | wall=7.4s
#   20500 pts | mean=3.04e-04 | max=2.64e-03 | t_max=0.079 | cands= 5956 | wall=7.6s
#   21000 pts | mean=3.07e-04 | max=2.64e-03 | t_max=0.079 | cands= 5960 | wall=7.9s
#   21500 pts | mean=3.11e-04 | max=2.64e-03 | t_max=0.079 | cands= 5893 | wall=8.2s
#   22000 pts | mean=3.15e-04 | max=2.64e-03 | t_max=0.079 | cands= 5819 | wall=8.5s
#   22500 pts | mean=3.19e-04 | max=2.64e-03 | t_max=0.079 | cands= 5800 | wall=8.7s
#   23000 pts | mean=3.23e-04 | max=2.64e-03 | t_max=0.079 | cands= 5786 | wall=9.0s
#   23500 pts | mean=3.26e-04 | max=2.64e-03 | t_max=0.079 | cands= 5863 | wall=9.3s
#   24000 pts | mean=3.29e-04 | max=2.64e-03 | t_max=0.079 | cands= 5835 | wall=9.7s
#   24500 pts | mean=3.32e-04 | max=2.64e-03 | t_max=0.079 | cands= 5798 | wall=10.0s
#   25000 pts | mean=3.36e-04 | max=2.64e-03 | t_max=0.079 | cands= 5990 | wall=10.3s
#   25500 pts | mean=3.39e-04 | max=2.64e-03 | t_max=0.079 | cands= 5754 | wall=10.7s
#   26000 pts | mean=3.42e-04 | max=2.64e-03 | t_max=0.079 | cands= 5993 | wall=11.0s
#   26500 pts | mean=3.46e-04 | max=2.64e-03 | t_max=0.079 | cands= 5937 | wall=11.3s
#   27000 pts | mean=3.49e-04 | max=2.64e-03 | t_max=0.079 | cands= 5989 | wall=11.7s
#   27500 pts | mean=3.53e-04 | max=2.64e-03 | t_max=0.079 | cands= 5999 | wall=12.0s
#   28000 pts | mean=3.57e-04 | max=2.64e-03 | t_max=0.079 | cands= 5839 | wall=12.4s
#   28500 pts | mean=3.61e-04 | max=2.64e-03 | t_max=0.079 | cands= 5940 | wall=12.7s
#   29000 pts | mean=3.64e-04 | max=2.64e-03 | t_max=0.081 | cands= 5838 | wall=13.1s
#   29500 pts | mean=3.68e-04 | max=2.64e-03 | t_max=0.085 | cands= 5979 | wall=13.4s
#   30000 pts | mean=3.71e-04 | max=2.64e-03 | t_max=0.089 | cands= 5926 | wall=13.7s
#   30500 pts | mean=3.74e-04 | max=2.64e-03 | t_max=0.092 | cands= 5955 | wall=14.0s
#   31000 pts | mean=3.77e-04 | max=2.64e-03 | t_max=0.092 | cands= 5912 | wall=14.3s
#   31500 pts | mean=3.80e-04 | max=2.64e-03 | t_max=0.092 | cands= 5973 | wall=14.6s
#   32000 pts | mean=3.83e-04 | max=2.64e-03 | t_max=0.093 | cands= 5863 | wall=14.9s
#   32500 pts | mean=3.86e-04 | max=2.64e-03 | t_max=0.095 | cands= 5892 | wall=15.2s
#   33000 pts | mean=3.90e-04 | max=2.64e-03 | t_max=0.097 | cands= 5953 | wall=15.5s
#   33500 pts | mean=3.93e-04 | max=2.64e-03 | t_max=0.100 | cands= 5904 | wall=15.8s
#   34000 pts | mean=3.96e-04 | max=2.65e-03 | t_max=0.100 | cands= 5902 | wall=16.1s
#   34500 pts | mean=4.00e-04 | max=2.65e-03 | t_max=0.100 | cands= 5928 | wall=16.5s
#   35000 pts | mean=4.02e-04 | max=2.65e-03 | t_max=0.101 | cands= 5911 | wall=16.8s
#   35500 pts | mean=4.06e-04 | max=2.65e-03 | t_max=0.101 | cands= 5829 | wall=17.1s
#   36000 pts | mean=4.11e-04 | max=2.65e-03 | t_max=0.101 | cands= 5844 | wall=17.5s
#   36500 pts | mean=4.15e-04 | max=2.74e-03 | t_max=0.101 | cands= 5998 | wall=17.8s
#   37000 pts | mean=4.20e-04 | max=2.74e-03 | t_max=0.106 | cands= 5990 | wall=18.1s
#   37500 pts | mean=4.24e-04 | max=2.74e-03 | t_max=0.108 | cands= 5997 | wall=18.4s
#   38000 pts | mean=4.30e-04 | max=2.74e-03 | t_max=0.108 | cands= 5975 | wall=18.7s
#   38500 pts | mean=4.35e-04 | max=2.74e-03 | t_max=0.108 | cands= 5856 | wall=19.1s
#   39000 pts | mean=4.40e-04 | max=2.74e-03 | t_max=0.112 | cands= 5820 | wall=19.4s
#   39500 pts | mean=4.46e-04 | max=2.81e-03 | t_max=0.114 | cands= 5886 | wall=19.7s
#   40000 pts | mean=4.51e-04 | max=3.40e-03 | t_max=0.116 | cands= 5945 | wall=20.1s
#   40500 pts | mean=4.56e-04 | max=3.40e-03 | t_max=0.118 | cands= 5865 | wall=20.4s
#   41000 pts | mean=4.62e-04 | max=3.75e-03 | t_max=0.119 | cands= 5840 | wall=20.8s
#   41500 pts | mean=4.68e-04 | max=4.23e-03 | t_max=0.119 | cands= 5921 | wall=21.1s
#   42000 pts | mean=4.75e-04 | max=4.23e-03 | t_max=0.119 | cands= 5764 | wall=21.5s
#   42500 pts | mean=4.81e-04 | max=4.23e-03 | t_max=0.119 | cands= 5765 | wall=21.8s
#   43000 pts | mean=4.89e-04 | max=4.23e-03 | t_max=0.120 | cands= 5812 | wall=22.3s
#   43500 pts | mean=4.95e-04 | max=4.23e-03 | t_max=0.125 | cands= 5961 | wall=22.6s
#   44000 pts | mean=5.02e-04 | max=4.23e-03 | t_max=0.127 | cands= 5943 | wall=23.0s
#   44500 pts | mean=5.09e-04 | max=4.23e-03 | t_max=0.127 | cands= 5718 | wall=23.4s
#   45000 pts | mean=5.15e-04 | max=4.23e-03 | t_max=0.127 | cands= 5824 | wall=23.9s
#   45500 pts | mean=5.21e-04 | max=4.23e-03 | t_max=0.127 | cands= 5672 | wall=24.3s
#   46000 pts | mean=5.26e-04 | max=4.23e-03 | t_max=0.127 | cands= 5703 | wall=24.7s
#   46500 pts | mean=5.32e-04 | max=4.23e-03 | t_max=0.127 | cands= 5616 | wall=25.1s
#   47000 pts | mean=5.37e-04 | max=4.23e-03 | t_max=0.127 | cands= 5475 | wall=25.6s
#   47500 pts | mean=5.43e-04 | max=4.23e-03 | t_max=0.127 | cands= 5354 | wall=26.0s
#   48000 pts | mean=5.48e-04 | max=4.23e-03 | t_max=0.127 | cands= 5508 | wall=26.5s
#   48500 pts | mean=5.53e-04 | max=4.23e-03 | t_max=0.127 | cands= 5524 | wall=27.0s
#   49000 pts | mean=5.59e-04 | max=4.23e-03 | t_max=0.127 | cands= 5597 | wall=27.4s
#   49500 pts | mean=5.65e-04 | max=4.23e-03 | t_max=0.127 | cands= 5799 | wall=27.9s
#   50000 pts | mean=5.71e-04 | max=4.23e-03 | t_max=0.131 | cands= 5951 | wall=28.3s
#   50500 pts | mean=5.78e-04 | max=4.23e-03 | t_max=0.131 | cands= 5843 | wall=28.8s
#   51000 pts | mean=5.83e-04 | max=4.23e-03 | t_max=0.133 | cands= 5865 | wall=29.2s
#   51500 pts | mean=5.89e-04 | max=4.23e-03 | t_max=0.134 | cands= 6001 | wall=29.7s
#   52000 pts | mean=5.96e-04 | max=4.23e-03 | t_max=0.135 | cands= 5713 | wall=30.2s
#   52500 pts | mean=6.02e-04 | max=4.23e-03 | t_max=0.138 | cands= 5716 | wall=30.7s
#   53000 pts | mean=6.07e-04 | max=4.23e-03 | t_max=0.138 | cands= 5777 | wall=31.2s
#   53500 pts | mean=6.12e-04 | max=4.23e-03 | t_max=0.138 | cands= 5704 | wall=31.7s
#   54000 pts | mean=6.17e-04 | max=4.23e-03 | t_max=0.138 | cands= 5791 | wall=32.3s
#   54500 pts | mean=6.22e-04 | max=4.23e-03 | t_max=0.140 | cands= 5907 | wall=32.8s
#   55000 pts | mean=6.27e-04 | max=4.23e-03 | t_max=0.141 | cands= 5799 | wall=33.4s
#   55500 pts | mean=6.31e-04 | max=4.23e-03 | t_max=0.141 | cands= 5795 | wall=33.9s
#   56000 pts | mean=6.36e-04 | max=4.23e-03 | t_max=0.141 | cands= 5934 | wall=34.4s
#   56500 pts | mean=6.40e-04 | max=4.23e-03 | t_max=0.144 | cands= 5816 | wall=35.0s
#   57000 pts | mean=6.44e-04 | max=4.23e-03 | t_max=0.146 | cands= 5703 | wall=35.6s
#   57500 pts | mean=6.48e-04 | max=4.23e-03 | t_max=0.147 | cands= 5689 | wall=36.1s
#   58000 pts | mean=6.52e-04 | max=4.23e-03 | t_max=0.148 | cands= 5543 | wall=36.7s
#   58500 pts | mean=6.56e-04 | max=4.23e-03 | t_max=0.148 | cands= 5568 | wall=37.2s
#   59000 pts | mean=6.60e-04 | max=4.23e-03 | t_max=0.148 | cands= 5787 | wall=37.8s
#   59500 pts | mean=6.64e-04 | max=4.23e-03 | t_max=0.148 | cands= 5755 | wall=38.4s
#   60000 pts | mean=6.67e-04 | max=4.23e-03 | t_max=0.148 | cands= 5501 | wall=39.0s
#   60500 pts | mean=6.71e-04 | max=4.23e-03 | t_max=0.148 | cands= 5557 | wall=39.6s
#   61000 pts | mean=6.74e-04 | max=4.23e-03 | t_max=0.148 | cands= 5722 | wall=40.2s
#   61500 pts | mean=6.78e-04 | max=4.23e-03 | t_max=0.148 | cands= 5667 | wall=40.8s
#   62000 pts | mean=6.81e-04 | max=4.23e-03 | t_max=0.148 | cands= 5498 | wall=41.4s
#   62500 pts | mean=6.84e-04 | max=4.23e-03 | t_max=0.148 | cands= 5344 | wall=42.0s
#   63000 pts | mean=6.87e-04 | max=4.23e-03 | t_max=0.148 | cands= 5518 | wall=42.6s
#   63500 pts | mean=6.90e-04 | max=4.23e-03 | t_max=0.148 | cands= 5380 | wall=43.2s
#   64000 pts | mean=6.94e-04 | max=4.23e-03 | t_max=0.148 | cands= 5346 | wall=43.8s
#   64500 pts | mean=6.97e-04 | max=4.23e-03 | t_max=0.148 | cands= 5341 | wall=44.4s
#   65000 pts | mean=7.00e-04 | max=4.23e-03 | t_max=0.148 | cands= 5470 | wall=45.1s
#   65500 pts | mean=7.04e-04 | max=4.23e-03 | t_max=0.148 | cands= 5440 | wall=45.7s
#   66000 pts | mean=7.07e-04 | max=4.23e-03 | t_max=0.148 | cands= 5473 | wall=46.4s
#   66500 pts | mean=7.09e-04 | max=4.23e-03 | t_max=0.148 | cands= 5248 | wall=47.1s
#   67000 pts | mean=7.12e-04 | max=4.23e-03 | t_max=0.148 | cands= 5425 | wall=47.8s
#   67500 pts | mean=7.15e-04 | max=4.23e-03 | t_max=0.148 | cands= 5567 | wall=48.4s
#   68000 pts | mean=7.18e-04 | max=4.23e-03 | t_max=0.148 | cands= 5349 | wall=49.0s
#   68500 pts | mean=7.22e-04 | max=4.23e-03 | t_max=0.148 | cands= 5326 | wall=49.7s
#   69000 pts | mean=7.25e-04 | max=4.23e-03 | t_max=0.148 | cands= 5487 | wall=50.4s
#   69500 pts | mean=7.27e-04 | max=4.23e-03 | t_max=0.148 | cands= 5399 | wall=51.2s
#   70000 pts | mean=7.30e-04 | max=4.23e-03 | t_max=0.148 | cands= 5256 | wall=52.0s
#   70500 pts | mean=7.33e-04 | max=4.23e-03 | t_max=0.148 | cands= 5197 | wall=52.8s
#   71000 pts | mean=7.36e-04 | max=4.23e-03 | t_max=0.148 | cands= 5288 | wall=53.6s
#   71500 pts | mean=7.39e-04 | max=4.23e-03 | t_max=0.148 | cands= 5331 | wall=54.3s
#   72000 pts | mean=7.41e-04 | max=4.23e-03 | t_max=0.148 | cands= 5208 | wall=55.0s
#   72500 pts | mean=7.44e-04 | max=4.23e-03 | t_max=0.148 | cands= 4998 | wall=55.8s
#   73000 pts | mean=7.47e-04 | max=4.23e-03 | t_max=0.148 | cands= 5082 | wall=56.5s
#   73500 pts | mean=7.51e-04 | max=4.23e-03 | t_max=0.148 | cands= 5399 | wall=57.2s
#   74000 pts | mean=7.53e-04 | max=4.23e-03 | t_max=0.148 | cands= 5246 | wall=58.1s
#   74500 pts | mean=7.56e-04 | max=4.23e-03 | t_max=0.148 | cands= 5198 | wall=58.8s
#   75000 pts | mean=7.59e-04 | max=4.23e-03 | t_max=0.148 | cands= 5168 | wall=59.6s
#   75500 pts | mean=7.62e-04 | max=4.23e-03 | t_max=0.148 | cands= 5287 | wall=60.2s
#   76000 pts | mean=7.64e-04 | max=4.23e-03 | t_max=0.148 | cands= 5399 | wall=61.0s
#   76500 pts | mean=7.66e-04 | max=4.23e-03 | t_max=0.148 | cands= 5173 | wall=61.7s
#   77000 pts | mean=7.69e-04 | max=4.23e-03 | t_max=0.148 | cands= 5151 | wall=62.4s
#   77500 pts | mean=7.72e-04 | max=4.23e-03 | t_max=0.148 | cands= 5113 | wall=63.1s
#   78000 pts | mean=7.75e-04 | max=4.23e-03 | t_max=0.148 | cands= 5074 | wall=63.9s
#   78500 pts | mean=7.78e-04 | max=4.23e-03 | t_max=0.148 | cands= 5077 | wall=64.7s
#   79000 pts | mean=7.80e-04 | max=4.23e-03 | t_max=0.148 | cands= 4995 | wall=65.5s
#   79500 pts | mean=7.83e-04 | max=4.23e-03 | t_max=0.148 | cands= 4880 | wall=66.4s
#   80000 pts | mean=7.85e-04 | max=4.23e-03 | t_max=0.148 | cands= 4862 | wall=67.2s
#   80500 pts | mean=7.88e-04 | max=4.23e-03 | t_max=0.148 | cands= 4810 | wall=68.0s
#   81000 pts | mean=7.91e-04 | max=4.23e-03 | t_max=0.148 | cands= 5028 | wall=68.8s
#   81500 pts | mean=7.93e-04 | max=4.23e-03 | t_max=0.148 | cands= 5073 | wall=69.6s
#   82000 pts | mean=7.96e-04 | max=4.23e-03 | t_max=0.148 | cands= 5107 | wall=70.5s
#   82500 pts | mean=7.99e-04 | max=4.23e-03 | t_max=0.148 | cands= 5080 | wall=71.4s
#   83000 pts | mean=8.01e-04 | max=4.23e-03 | t_max=0.148 | cands= 5089 | wall=72.3s
#   83500 pts | mean=8.04e-04 | max=4.23e-03 | t_max=0.148 | cands= 4994 | wall=73.2s
#   84000 pts | mean=8.06e-04 | max=4.23e-03 | t_max=0.148 | cands= 4899 | wall=74.0s
#   84500 pts | mean=8.09e-04 | max=4.23e-03 | t_max=0.148 | cands= 5034 | wall=74.9s
#   85000 pts | mean=8.11e-04 | max=4.23e-03 | t_max=0.148 | cands= 5032 | wall=75.9s
#   85500 pts | mean=8.13e-04 | max=4.23e-03 | t_max=0.148 | cands= 4910 | wall=76.8s
#   86000 pts | mean=8.16e-04 | max=4.23e-03 | t_max=0.148 | cands= 4845 | wall=77.7s
#   86500 pts | mean=8.18e-04 | max=4.23e-03 | t_max=0.148 | cands= 4900 | wall=78.5s
#   87000 pts | mean=8.21e-04 | max=4.23e-03 | t_max=0.148 | cands= 4833 | wall=79.3s
#   87500 pts | mean=8.23e-04 | max=4.23e-03 | t_max=0.148 | cands= 4743 | wall=80.1s
#   88000 pts | mean=8.25e-04 | max=4.23e-03 | t_max=0.148 | cands= 4817 | wall=81.0s
#   88500 pts | mean=8.28e-04 | max=4.23e-03 | t_max=0.148 | cands= 4790 | wall=81.7s
#   89000 pts | mean=8.30e-04 | max=4.23e-03 | t_max=0.148 | cands= 4889 | wall=82.6s
#   89500 pts | mean=8.32e-04 | max=4.23e-03 | t_max=0.148 | cands= 4582 | wall=83.4s
#   90000 pts | mean=8.35e-04 | max=4.23e-03 | t_max=0.148 | cands= 4534 | wall=84.4s
#   90500 pts | mean=8.38e-04 | max=4.23e-03 | t_max=0.148 | cands= 4608 | wall=85.3s
#   91000 pts | mean=8.40e-04 | max=4.23e-03 | t_max=0.148 | cands= 4468 | wall=86.3s
#   91500 pts | mean=8.42e-04 | max=4.23e-03 | t_max=0.148 | cands= 4438 | wall=87.2s
#   92000 pts | mean=8.44e-04 | max=4.23e-03 | t_max=0.148 | cands= 4617 | wall=88.1s
#   92500 pts | mean=8.47e-04 | max=4.23e-03 | t_max=0.148 | cands= 4730 | wall=88.9s
#   93000 pts | mean=8.49e-04 | max=4.23e-03 | t_max=0.148 | cands= 4524 | wall=89.9s
#   93500 pts | mean=8.51e-04 | max=4.23e-03 | t_max=0.148 | cands= 4604 | wall=90.7s
#   94000 pts | mean=8.53e-04 | max=4.23e-03 | t_max=0.148 | cands= 4475 | wall=91.7s
#   94500 pts | mean=8.55e-04 | max=4.23e-03 | t_max=0.148 | cands= 4309 | wall=92.6s
#   95000 pts | mean=8.58e-04 | max=4.23e-03 | t_max=0.148 | cands= 4508 | wall=93.5s
#   95500 pts | mean=8.60e-04 | max=4.23e-03 | t_max=0.148 | cands= 4394 | wall=94.5s
#   96000 pts | mean=8.62e-04 | max=4.23e-03 | t_max=0.148 | cands= 4210 | wall=95.4s
#   96500 pts | mean=8.64e-04 | max=4.23e-03 | t_max=0.148 | cands= 4485 | wall=96.3s
#   97000 pts | mean=8.66e-04 | max=4.23e-03 | t_max=0.148 | cands= 4224 | wall=97.3s
#   97500 pts | mean=8.68e-04 | max=4.23e-03 | t_max=0.148 | cands= 4459 | wall=98.2s
#   98000 pts | mean=8.70e-04 | max=4.23e-03 | t_max=0.148 | cands= 4349 | wall=99.2s
#   98500 pts | mean=8.72e-04 | max=4.23e-03 | t_max=0.148 | cands= 4333 | wall=100.2s
#   99000 pts | mean=8.75e-04 | max=4.23e-03 | t_max=0.148 | cands= 4296 | wall=101.2s
#   99500 pts | mean=8.77e-04 | max=4.23e-03 | t_max=0.148 | cands= 4283 | wall=102.2s
#   100000 pts | mean=8.79e-04 | max=4.23e-03 | t_max=0.148 | cands= 4308 | wall=103.3s
#
# ────────────────────────────────────────────────────────
#   Computed  : 100000 points
#   Mean err  : 8.789e-04
#   Max  err  : 4.227e-03
#   Wall time : 103.4s
#
#   Rejections (total attempts: 578775)
#     proximity :      0  (0.0%)
#     no_nb     :    132  (0.0%)
#     geometry  :  63202  (10.9%)
#     cond      : 304989  (52.7%)
#     weights   : 110452  (19.1%)

# %% [markdown]
# ## Optional Plots
#
# Run this after the rollout if your existing `Plots` helpers are available.

# %%
# %matplotlib widget
import importlib
from Plots import interactive_plot as interactive_plot_module
from Plots import error_analysis as error_analysis_module

importlib.reload(interactive_plot_module)
importlib.reload(error_analysis_module)

interactive_plot = interactive_plot_module.interactive_plot
error_analysis = error_analysis_module.error_analysis

# Extract IC and BC coordinates from visited._pts
ic_x = np.array([p[0] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])
ic_t = np.array([p[1] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])

bc_x = np.array([p[0] for p in visited._pts if p[0] in [0.0, 1.0]])
bc_t = np.array([p[1] for p in visited._pts if p[0] in [0.0, 1.0]])

interactive_plot(
    point_data,
    visited._pts,   # pass the raw list so the plot code sees (x, t, u) tuples
    u_true,
    fd_interp,
    T,
    dt_fd,          # was dt_sc
    ic_x,
    ic_t,
    bc_x,
    bc_t
)

error_analysis(point_data, u_true=u_true, fd_interp=fd_interp)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
