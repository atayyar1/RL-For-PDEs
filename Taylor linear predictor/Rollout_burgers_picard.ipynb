# %% [markdown]
# # Burgers Rollout With Picard GFDM
#
# Space-time GFDM rollout for Burgers' equation: `u_t + u u_x = alpha u_xx`.
#
# The nonlinear advection speed is Picard-linearized locally as the mean of neighbor `u` values.

# %%
# Rollout_burgers_picard.py
# Solves Burgers' equation: ut + u*ux = alpha*uxx
# Method: Picard linearization — local advection speed c_local = mean(u_neighbors)
# Analytical solution via Hopf-Cole transformation with Fourier cosine series

"""
Design
- FD grid is used as a coordinate scaffold only. Candidate points are
  drawn from FD grid coordinates so coverage is always dense.
- u values at interior points are computed by PDE-informed interpolation,
  NOT copied from FD. FD is used only for error measurement.
- Stopping criterion: max_points successfully computed interior points.
- KDTree for O(log N) neighbour queries.
- O(1) candidate removal via swap-and-pop.
"""

import time
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator

# %% [markdown]
# ## Parameters
#
# Set the Burgers viscosity and final time.

# %%
alpha = 0.1
T     = 0.5

# %% [markdown]
# ## Analytical Solution
#
# Hopf-Cole analytical reference, precomputed once with a Fourier cosine series.

# %%
# Precompute coefficients once
_xq = np.linspace(0.0, 1.0, 20001)
_phi0 = np.exp(-(1 - np.cos(np.pi * _xq)) / (2 * alpha * np.pi))

_N_SERIES = 200
_a = np.zeros(_N_SERIES + 1)
_a[0] = np.trapezoid(_phi0, _xq)
for n in range(1, _N_SERIES + 1):
    _a[n] = 2.0 * np.trapezoid(_phi0 * np.cos(n * np.pi * _xq), _xq)

_n_arr = np.arange(1, _N_SERIES + 1)
_an = _a[1:]
_lam_hc = -alpha * (_n_arr * np.pi) ** 2

def u_true(x, t):
    x = np.asarray(x, dtype=float)
    scalar = x.ndim == 0
    x = np.atleast_1d(x)
    cos_nx = np.cos(np.pi * np.outer(x, _n_arr))
    sin_nx = np.sin(np.pi * np.outer(x, _n_arr))
    exp_t = np.exp(_lam_hc * t)
    phi = _a[0] + (cos_nx * (_an * exp_t)).sum(axis=-1)
    phi_x = -(sin_nx * (_an * _n_arr * np.pi * exp_t)).sum(axis=-1)
    result = -2 * alpha * phi_x / phi
    return float(result[0]) if scalar else result

# %% [markdown]
# ## FD Reference Grid
#
# The FD grid provides coordinates and a reference solution for error checks.

# %%
# -- FD r/eference grid --------------------------------------------------------?
nx_fd = 100
x_fd  = np.linspace(0.0, 1.0, nx_fd)
dx_fd = x_fd[1] - x_fd[0]

# Compute nt_fd from CFL ? never touch this manually
dt_cfl = min(0.9 * dx_fd / 1.0,
             0.45 * dx_fd**2 / alpha)
nt_fd  = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt_fd)
dt_fd  = t_fd[1] - t_fd[0]


def build_fd_reference():
    """Explicit upwind FD solve. Returns (u_fd, interpolant)."""
    u = np.zeros((nx_fd, nt_fd))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt_fd / dx_fd**2

    for it in range(nt_fd - 1):
        un = u[:, it]
        r_adv_local = un * dt_fd / dx_fd
        u[1:-1, it+1] = (un[1:-1]
                         - r_adv_local[1:-1] * (un[1:-1] - un[:-2])
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,  it+1] = 0.0
        u[-1, it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
        bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ## Rollout Settings
#
# These are the same rollout controls from the working solver.

# %%
# -- Integrator hyperparameters ------------------------------------------------
max_points    = 100000   # stopping criterion
u_bound = 1.1
n_neighbours  = 5     # stencil size (3 equations, 5 unknowns → underdetermined)
cond_max      = 1e4
isotropy_max  = 50.0
w_max_factor  = 3.0     # reject if max|w_j| > w_max_factor / n
w_min_floor   = -1.0

# Spawn box in FD grid steps
spawn_nx      = 5       # ? x steps around a newly solved point
spawn_nt      = 3       # + t steps forward

# Neighbour search box in normalised units (x/dx_fd, t/dt_fd)
box_n0        = 2.0     # initial half-width
box_grow      = 1.5
box_nmax      = 15.0

max_candidates = 6000   # cap on candidate list length (for memory and speed)

# %% [markdown]
# ## Visited Points
#
# KDTree-backed storage for accepted `(x, t, u)` points.

# %%
# -- KDTree-backed visited set ------------------------------------------------?
class VisitedSet:
    """
    Stores (x, t, u) points. KDTree is in normalised (x/dx_fd, t/dt_fd)
    space so both axes are commensurate during neighbour search.
    Rebuilt lazily every rebuild_every insertions.
    """
    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
    def add(self, x, t, u):
        self._pts.append((x, t, u))
        self._norm.append((x / dx_fd, t / dt_fd))   # add this
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))   # change this
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()

    def find_neighbours(self, x_star, t_star):
        self._ensure()
        xn = x_star / dx_fd
        tn = t_star / dt_fd
        bn = box_n0
        while True:
            idxs = self._tree.query_ball_point([xn, tn], r=bn, p=np.inf)
            nb = [
                self._pts[i] for i in idxs
                if abs(self._pts[i][0] - x_star) <= bn * dx_fd
                and 0 < (t_star - self._pts[i][1]) <= bn * dt_fd
            ]
            if len(nb) >= n_neighbours:
                nb.sort(key=lambda p: (p[0]-x_star)**2 + (p[1]-t_star)**2)
                return nb[:n_neighbours]
            bn = min(bn * box_grow, box_nmax)
            if bn >= box_nmax:
                return None
    def __len__(self):
        return len(self._pts)

# %% [markdown]
# ## Stencil And Picard Weights
#
# The local advection speed is `mean(u_neighbors)` before solving weights.

# %%
# -- Stencil geometry check ----------------------------------------------------
def stencil_is_good(dx_i, dt_i):
    if np.min(dx_i) * np.max(dx_i) > 0:          # two-sided coverage
        return False
    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)
    pts = np.column_stack([dx_i / h, dt_i / tau])
    return True


# -- Weight solver ------------------------------------------------------------?
def solve_weights(dx_i, dt_i, u_nb):
    """
    Min-norm lstsq on the 3?n PDE-informed system.
    Returns (w, cond) or (None, cond).
    """
    c_local = float(np.mean(u_nb))

    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
         (dx_i - c_local * dt_i)              / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ]) 
    b = np.array([1 , 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > cond_max:
        return None,    cond

    w = np.linalg.lstsq(A, b, rcond=None)[0]


    # Additional weight checks to prevent error explosion ? these are somewhat ad-hoc and may be tuned or removed based on your needs.
    if np.max(np.abs(w)) > w_max_factor / len(dx_i):   # no dominant weight
        return None, cond
    if np.min(w) < w_min_floor:                         # no extreme negatives
        return None, cond

    return w, cond

## Add L2 instead of L1

# %% [markdown]
# ## Main Rollout
#
# This is the candidate-driven GFDM integrator.

# %%
# -- Main integrator ----------------------------------------------------------?
def run_integrator(seed=None):
    t_wall = time.time()
    if seed is not None:
        np.random.seed(seed)

    print("Building FD reference...", flush=True)
    _, fd_interp = build_fd_reference()
    print(f"  dx={dx_fd:.4f}  dt={dt_fd:.5f}", flush=True)

    # IC + BC into visited set
    visited = VisitedSet()
    for ix in range(nx_fd):
        visited.add(x_fd[ix], 0.0, u_true(x_fd[ix], 0.0))
    for it in range(1, nt_fd):
        visited.add(0.0,  t_fd[it], 0.0)
        visited.add(1.0,  t_fd[it], 0.0)
    print(f"  IC+BC points: {len(visited)}", flush=True)

    # Candidate pool ? integer (ix, it) keys for O(1) deduplication
    cand_keys = set()
    cand_list = []   # list of (x, t)

    def push(ix, it):
        if (ix, it) not in cand_keys:
            cand_keys.add((ix, it))
            cand_list.append((x_fd[ix], t_fd[it]))

    # Seed from IC
    for ix in range(1, nx_fd - 1):
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix, nit = ix + dix, dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

    print(f"  Initial candidates: {len(cand_list)}", flush=True)
    print(f"  Stopping at {max_points} computed points\n", flush=True)

    rej        = dict(proximity=0, no_nb=0, geometry=0, cond=0, weights=0)
    point_data = []

    while cand_list and len(point_data) < max_points:

        # Trim if candidate list is over budget
        protect_candidates = 500

        if len(cand_list) > max_candidates:
            target_size = max(max_candidates, protect_candidates)
            n_remove = len(cand_list) - target_size
            if n_remove > 0:
                del cand_list[:n_remove]

        # ── O(1) swap-and-pop ───────────────────────────────
        idx            = np.random.randint(len(cand_list))
        x_star, t_star = cand_list[idx]
        cand_list[idx] = cand_list[-1]
        cand_list.pop()
        ix_s = int(round(x_star / dx_fd))
        it_s = int(round(t_star / dt_fd))
        cand_keys.discard((ix_s, it_s))
        

        nb = visited.find_neighbours(x_star, t_star)
        if nb is None:
            rej['no_nb'] += 1
            continue

        nb_pts = np.array(nb)
        dx_i   = nb_pts[:, 0] - x_star
        dt_i   = nb_pts[:, 1] - t_star   # negative: neighbours are in the past

        if not stencil_is_good(dx_i, dt_i):
            rej['geometry'] += 1
            continue

        w, cond = solve_weights(dx_i, dt_i, nb_pts[:, 2])
        if w is None:
            rej['cond' if cond > cond_max else 'weights'] += 1
            continue

        # Accept point  
        u_hat = float(w @ nb_pts[:, 2])

        # Break the error cascade - u is bounded by IC amplitude + margin
        if abs(u_hat) > u_bound:
            rej['bounds'] = rej.get('bounds', 0) + 1
            continue

        visited.add(x_star, t_star, u_hat)

        # Spawn new candidates in the FD grid box around this point
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix = ix_s + dix
                nit = it_s + dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

        u_fd_ref = float(fd_interp([[x_star, t_star]])[0])
        u_true_ref = float(u_true(x_star, t_star))
 
        point_data.append({
            'x':     x_star,
            't':     t_star,
            'u':     u_hat,
            'u_true': u_true_ref,
            'u_fd':   u_fd_ref,
            'err_true': abs(u_hat - u_true_ref),
            'err_fd':   abs(u_hat - u_fd_ref),
            'err':   abs(u_hat - u_true_ref),   # use true error for stats and plotting
            'cond':  cond,
            'w1':    float(np.sum(np.abs(w))),
            'box_x': float(np.max(np.abs(dx_i))),   # add this
            'box_t': float(np.max(np.abs(dt_i))),   # add this
            'nb_x':  nb_pts[:, 0].copy(),            # add
            'nb_t':  nb_pts[:, 1].copy(),            # add
            'nb_u':  nb_pts[:, 2].copy(),            # add
        })

        if len(point_data) % 500 == 0:
            errs = [p['err'] for p in point_data]
            t_max = max(p['t'] for p in point_data)
            print(f"  {len(point_data):5d} pts | "
                  f"mean={np.mean(errs):.2e} | "
                  f"max={np.max(errs):.2e} | "
                  f"t_max={t_max:.3f} | "
                  f"cands={len(cand_list):5d} | "
                  f"wall={time.time()-t_wall:.1f}s",
                  flush=True)

    # Summary
    errs = np.array([p['err'] for p in point_data])
    print(f"\n{'─'*56}")
    print(f"  Computed  : {len(point_data)} points")
    print(f"  Mean err  : {errs.mean():.3e}")
    print(f"  Max  err  : {errs.max():.3e}")
    print(f"  Wall time : {time.time()-t_wall:.1f}s")
    total = sum(rej.values()) + len(point_data)
    print(f"\n  Rejections (total attempts: {total})")
    for r, n in rej.items():
        print(f"    {r:10s}: {n:6d}  ({100*n/total:.1f}%)")

    return visited, point_data, fd_interp

# %% [markdown]
# ## Run
#
# Run the full rollout. For a quick test, set `max_points` to a smaller number first.

# %%
# Uncomment for a quick test before the full run:
# max_points = 1000

visited, point_data, fd_interp = run_integrator(seed=None)
# Out:
# Building FD reference...
#   dx=0.0101  dt=0.00046
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 100000 computed points
#
#     500 pts | mean=3.97e-05 | max=5.73e-04 | t_max=0.009 | cands= 1553 | wall=0.1s
#    1000 pts | mean=8.15e-05 | max=2.11e-03 | t_max=0.017 | cands= 2590 | wall=0.3s
#    1500 pts | mean=9.91e-05 | max=2.21e-03 | t_max=0.022 | cands= 3401 | wall=0.4s
#    2000 pts | mean=1.03e-04 | max=2.21e-03 | t_max=0.022 | cands= 3684 | wall=0.5s
#    2500 pts | mean=1.09e-04 | max=2.21e-03 | t_max=0.026 | cands= 3972 | wall=0.7s
#    3000 pts | mean=1.14e-04 | max=2.21e-03 | t_max=0.026 | cands= 4209 | wall=0.8s
#    3500 pts | mean=1.19e-04 | max=2.21e-03 | t_max=0.028 | cands= 4446 | wall=1.0s
#    4000 pts | mean=1.24e-04 | max=2.21e-03 | t_max=0.033 | cands= 5000 | wall=1.1s
#    4500 pts | mean=1.29e-04 | max=2.21e-03 | t_max=0.037 | cands= 5456 | wall=1.3s
#    5000 pts | mean=1.36e-04 | max=2.21e-03 | t_max=0.039 | cands= 5694 | wall=1.4s
#    5500 pts | mean=1.42e-04 | max=2.21e-03 | t_max=0.040 | cands= 5959 | wall=1.6s
#    6000 pts | mean=1.48e-04 | max=2.21e-03 | t_max=0.042 | cands= 5982 | wall=1.7s
#    6500 pts | mean=1.56e-04 | max=2.21e-03 | t_max=0.043 | cands= 6000 | wall=1.9s
#    7000 pts | mean=1.62e-04 | max=2.21e-03 | t_max=0.046 | cands= 5999 | wall=2.1s
#    7500 pts | mean=1.69e-04 | max=2.21e-03 | t_max=0.048 | cands= 5991 | wall=2.2s
#    8000 pts | mean=1.77e-04 | max=2.21e-03 | t_max=0.048 | cands= 6001 | wall=2.4s
#    8500 pts | mean=1.83e-04 | max=2.21e-03 | t_max=0.048 | cands= 5996 | wall=2.6s
#    9000 pts | mean=1.91e-04 | max=2.21e-03 | t_max=0.053 | cands= 5994 | wall=2.8s
#    9500 pts | mean=1.97e-04 | max=2.21e-03 | t_max=0.055 | cands= 5993 | wall=3.0s
#   10000 pts | mean=2.04e-04 | max=2.21e-03 | t_max=0.055 | cands= 5993 | wall=3.1s
#   10500 pts | mean=2.10e-04 | max=2.21e-03 | t_max=0.055 | cands= 5957 | wall=3.3s
#   11000 pts | mean=2.16e-04 | max=2.21e-03 | t_max=0.055 | cands= 5999 | wall=3.5s
#   11500 pts | mean=2.22e-04 | max=2.21e-03 | t_max=0.055 | cands= 5972 | wall=3.7s
#   12000 pts | mean=2.27e-04 | max=2.21e-03 | t_max=0.055 | cands= 5982 | wall=3.9s
#   12500 pts | mean=2.35e-04 | max=2.21e-03 | t_max=0.055 | cands= 5941 | wall=4.1s
#   13000 pts | mean=2.42e-04 | max=2.21e-03 | t_max=0.056 | cands= 5984 | wall=4.3s
#   13500 pts | mean=2.49e-04 | max=2.24e-03 | t_max=0.058 | cands= 5983 | wall=4.5s
#   14000 pts | mean=2.55e-04 | max=2.24e-03 | t_max=0.059 | cands= 5921 | wall=4.8s
#   14500 pts | mean=2.61e-04 | max=2.24e-03 | t_max=0.064 | cands= 5998 | wall=5.0s
#   15000 pts | mean=2.67e-04 | max=2.24e-03 | t_max=0.065 | cands= 5938 | wall=5.2s
#   15500 pts | mean=2.73e-04 | max=2.24e-03 | t_max=0.068 | cands= 5962 | wall=5.4s
#   16000 pts | mean=2.78e-04 | max=2.24e-03 | t_max=0.068 | cands= 5898 | wall=5.7s
#   16500 pts | mean=2.83e-04 | max=2.24e-03 | t_max=0.068 | cands= 5939 | wall=5.9s
#   17000 pts | mean=2.88e-04 | max=2.24e-03 | t_max=0.068 | cands= 5998 | wall=6.2s
#   17500 pts | mean=2.93e-04 | max=2.24e-03 | t_max=0.068 | cands= 5822 | wall=6.5s
#   18000 pts | mean=2.97e-04 | max=2.24e-03 | t_max=0.068 | cands= 5877 | wall=6.8s
#   18500 pts | mean=3.01e-04 | max=2.24e-03 | t_max=0.068 | cands= 5970 | wall=7.0s
#   19000 pts | mean=3.07e-04 | max=2.24e-03 | t_max=0.069 | cands= 5999 | wall=7.3s
#   19500 pts | mean=3.13e-04 | max=2.24e-03 | t_max=0.069 | cands= 5917 | wall=7.6s
#   20000 pts | mean=3.20e-04 | max=2.24e-03 | t_max=0.069 | cands= 5989 | wall=7.9s
#   20500 pts | mean=3.28e-04 | max=2.35e-03 | t_max=0.070 | cands= 5980 | wall=8.2s
#   21000 pts | mean=3.38e-04 | max=2.35e-03 | t_max=0.074 | cands= 5994 | wall=8.5s
#   21500 pts | mean=3.47e-04 | max=2.38e-03 | t_max=0.075 | cands= 5966 | wall=8.7s
#   22000 pts | mean=3.56e-04 | max=2.38e-03 | t_max=0.075 | cands= 5908 | wall=9.0s
#   22500 pts | mean=3.64e-04 | max=2.38e-03 | t_max=0.075 | cands= 5976 | wall=9.3s
#   23000 pts | mean=3.71e-04 | max=2.38e-03 | t_max=0.078 | cands= 5907 | wall=9.6s
#   23500 pts | mean=3.78e-04 | max=2.38e-03 | t_max=0.078 | cands= 5804 | wall=9.9s
#   24000 pts | mean=3.84e-04 | max=2.38e-03 | t_max=0.079 | cands= 5914 | wall=10.2s
#   24500 pts | mean=3.90e-04 | max=2.38e-03 | t_max=0.079 | cands= 5937 | wall=10.6s
#   25000 pts | mean=3.97e-04 | max=2.38e-03 | t_max=0.079 | cands= 6007 | wall=10.9s
#   25500 pts | mean=4.04e-04 | max=2.38e-03 | t_max=0.080 | cands= 5992 | wall=11.2s
#   26000 pts | mean=4.11e-04 | max=2.38e-03 | t_max=0.081 | cands= 5989 | wall=11.5s
#   26500 pts | mean=4.17e-04 | max=2.38e-03 | t_max=0.082 | cands= 5905 | wall=11.8s
#   27000 pts | mean=4.24e-04 | max=2.38e-03 | t_max=0.087 | cands= 5996 | wall=12.1s
#   27500 pts | mean=4.30e-04 | max=2.38e-03 | t_max=0.092 | cands= 5865 | wall=12.4s
#   28000 pts | mean=4.37e-04 | max=2.38e-03 | t_max=0.092 | cands= 5981 | wall=12.7s
#   28500 pts | mean=4.42e-04 | max=2.38e-03 | t_max=0.092 | cands= 5982 | wall=13.0s
#   29000 pts | mean=4.45e-04 | max=2.38e-03 | t_max=0.092 | cands= 5980 | wall=13.3s
#   29500 pts | mean=4.50e-04 | max=2.38e-03 | t_max=0.092 | cands= 5999 | wall=13.6s
#   30000 pts | mean=4.53e-04 | max=2.38e-03 | t_max=0.092 | cands= 5974 | wall=13.9s
#   30500 pts | mean=4.56e-04 | max=2.38e-03 | t_max=0.092 | cands= 5955 | wall=14.2s
#   31000 pts | mean=4.58e-04 | max=2.38e-03 | t_max=0.093 | cands= 5996 | wall=14.5s
#   31500 pts | mean=4.61e-04 | max=2.38e-03 | t_max=0.096 | cands= 5964 | wall=14.8s
#   32000 pts | mean=4.64e-04 | max=2.38e-03 | t_max=0.100 | cands= 5987 | wall=15.1s
#   32500 pts | mean=4.66e-04 | max=2.38e-03 | t_max=0.101 | cands= 6001 | wall=15.4s
#   33000 pts | mean=4.68e-04 | max=2.38e-03 | t_max=0.101 | cands= 5922 | wall=15.8s
#   33500 pts | mean=4.71e-04 | max=2.38e-03 | t_max=0.101 | cands= 5905 | wall=16.1s
#   34000 pts | mean=4.73e-04 | max=2.38e-03 | t_max=0.104 | cands= 5841 | wall=16.5s
#   34500 pts | mean=4.75e-04 | max=2.38e-03 | t_max=0.104 | cands= 5929 | wall=16.8s
#   35000 pts | mean=4.78e-04 | max=2.38e-03 | t_max=0.104 | cands= 5933 | wall=17.1s
#   35500 pts | mean=4.80e-04 | max=2.38e-03 | t_max=0.105 | cands= 5972 | wall=17.4s
#   36000 pts | mean=4.83e-04 | max=2.38e-03 | t_max=0.105 | cands= 5962 | wall=17.8s
#   36500 pts | mean=4.86e-04 | max=2.38e-03 | t_max=0.105 | cands= 5953 | wall=18.1s
#   37000 pts | mean=4.90e-04 | max=2.38e-03 | t_max=0.105 | cands= 5924 | wall=18.5s
#   37500 pts | mean=4.93e-04 | max=2.38e-03 | t_max=0.105 | cands= 5907 | wall=18.8s
#   38000 pts | mean=4.96e-04 | max=2.38e-03 | t_max=0.106 | cands= 5915 | wall=19.2s
#   38500 pts | mean=4.99e-04 | max=2.38e-03 | t_max=0.106 | cands= 5875 | wall=19.5s
#   39000 pts | mean=5.02e-04 | max=2.38e-03 | t_max=0.108 | cands= 5761 | wall=19.9s
#   39500 pts | mean=5.04e-04 | max=2.38e-03 | t_max=0.111 | cands= 5968 | wall=20.3s
#   40000 pts | mean=5.06e-04 | max=2.38e-03 | t_max=0.111 | cands= 5999 | wall=20.7s
#   40500 pts | mean=5.07e-04 | max=2.38e-03 | t_max=0.111 | cands= 5977 | wall=21.1s
#   41000 pts | mean=5.09e-04 | max=2.38e-03 | t_max=0.111 | cands= 5844 | wall=21.4s
#   41500 pts | mean=5.11e-04 | max=2.38e-03 | t_max=0.111 | cands= 5965 | wall=21.8s
#   42000 pts | mean=5.12e-04 | max=2.38e-03 | t_max=0.111 | cands= 6001 | wall=22.2s
#   42500 pts | mean=5.13e-04 | max=2.38e-03 | t_max=0.111 | cands= 5996 | wall=22.5s
#   43000 pts | mean=5.14e-04 | max=2.38e-03 | t_max=0.112 | cands= 5904 | wall=22.9s
#   43500 pts | mean=5.15e-04 | max=2.38e-03 | t_max=0.114 | cands= 5991 | wall=23.3s
#   44000 pts | mean=5.16e-04 | max=2.38e-03 | t_max=0.118 | cands= 5977 | wall=23.6s
#   44500 pts | mean=5.18e-04 | max=2.38e-03 | t_max=0.120 | cands= 5903 | wall=24.0s
#   45000 pts | mean=5.19e-04 | max=2.38e-03 | t_max=0.120 | cands= 5947 | wall=24.4s
#   45500 pts | mean=5.20e-04 | max=2.38e-03 | t_max=0.122 | cands= 5999 | wall=24.7s
#   46000 pts | mean=5.21e-04 | max=2.38e-03 | t_max=0.122 | cands= 5984 | wall=25.1s
#   46500 pts | mean=5.22e-04 | max=2.38e-03 | t_max=0.122 | cands= 6006 | wall=25.5s
#   47000 pts | mean=5.23e-04 | max=2.38e-03 | t_max=0.122 | cands= 5968 | wall=25.8s
#   47500 pts | mean=5.24e-04 | max=2.38e-03 | t_max=0.122 | cands= 5993 | wall=26.1s
#   48000 pts | mean=5.25e-04 | max=2.38e-03 | t_max=0.123 | cands= 5946 | wall=26.5s
#   48500 pts | mean=5.26e-04 | max=2.38e-03 | t_max=0.125 | cands= 5988 | wall=26.8s
#   49000 pts | mean=5.27e-04 | max=2.38e-03 | t_max=0.126 | cands= 5965 | wall=27.2s
#   49500 pts | mean=5.29e-04 | max=2.38e-03 | t_max=0.129 | cands= 5975 | wall=27.5s
#   50000 pts | mean=5.31e-04 | max=2.38e-03 | t_max=0.132 | cands= 5998 | wall=27.8s
#   50500 pts | mean=5.33e-04 | max=2.38e-03 | t_max=0.136 | cands= 5955 | wall=28.1s
#   51000 pts | mean=5.35e-04 | max=2.38e-03 | t_max=0.139 | cands= 5964 | wall=28.5s
#   51500 pts | mean=5.37e-04 | max=2.38e-03 | t_max=0.140 | cands= 5877 | wall=28.8s
#   52000 pts | mean=5.38e-04 | max=2.38e-03 | t_max=0.142 | cands= 5982 | wall=29.2s
#   52500 pts | mean=5.40e-04 | max=2.38e-03 | t_max=0.147 | cands= 5905 | wall=29.5s
#   53000 pts | mean=5.41e-04 | max=2.38e-03 | t_max=0.150 | cands= 5993 | wall=29.8s
#   53500 pts | mean=5.43e-04 | max=2.38e-03 | t_max=0.150 | cands= 5908 | wall=30.2s
#   54000 pts | mean=5.45e-04 | max=2.62e-03 | t_max=0.150 | cands= 5923 | wall=30.5s
#   54500 pts | mean=5.47e-04 | max=2.62e-03 | t_max=0.150 | cands= 5989 | wall=30.9s
#   55000 pts | mean=5.50e-04 | max=2.62e-03 | t_max=0.151 | cands= 6000 | wall=31.2s
#   55500 pts | mean=5.53e-04 | max=4.35e-03 | t_max=0.151 | cands= 5991 | wall=31.6s
#   56000 pts | mean=5.56e-04 | max=4.35e-03 | t_max=0.151 | cands= 5883 | wall=31.9s
#   56500 pts | mean=5.60e-04 | max=4.35e-03 | t_max=0.151 | cands= 5954 | wall=32.3s
#   57000 pts | mean=5.65e-04 | max=4.35e-03 | t_max=0.152 | cands= 5999 | wall=32.7s
#   57500 pts | mean=5.69e-04 | max=4.35e-03 | t_max=0.153 | cands= 5911 | wall=33.0s
#   58000 pts | mean=5.74e-04 | max=4.35e-03 | t_max=0.155 | cands= 5897 | wall=33.4s

# %% [markdown]
# ## Optional Plots
#
# Run this after the rollout if your existing `Plots` helpers are available.

# %%
# %matplotlib widget
import importlib
from Plots import interactive_plot as interactive_plot_module
from Plots import error_analysis as error_analysis_module

importlib.reload(interactive_plot_module)
importlib.reload(error_analysis_module)

interactive_plot = interactive_plot_module.interactive_plot
error_analysis = error_analysis_module.error_analysis

# Extract IC and BC coordinates from visited._pts
ic_x = np.array([p[0] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])
ic_t = np.array([p[1] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])

bc_x = np.array([p[0] for p in visited._pts if p[0] in [0.0, 1.0]])
bc_t = np.array([p[1] for p in visited._pts if p[0] in [0.0, 1.0]])

interactive_plot(
    point_data,
    visited._pts,   # pass the raw list so the plot code sees (x, t, u) tuples
    u_true,
    fd_interp,
    T,
    dt_fd,          # was dt_sc
    ic_x,
    ic_t,
    bc_x,
    bc_t
)

error_analysis(point_data, u_true=u_true, fd_interp=fd_interp)
