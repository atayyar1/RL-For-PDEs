# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE 
alpha = 0.05

#   FD reference grid   
nx    = 30
T     = 0.6
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

#  True solution; Analytical diffusion solution

def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# ### FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()               
        self.rejected_history = []  # (x, t) per rejected move
    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))  
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()
    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0
    def contains(self, x, t):                    
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None
            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)
            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None
            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]
            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# ### GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    #if cond > 1e4:
    #    return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### PDEEnvironment

# %%
class PDEEnvironment(gym.Env):
    # only allow up
    #ACTIONS = {0 :(0,1), 1: (0,2) }  
    # can go diagonally up-left, up, or up-right
    ACTIONS = {0: (-1, 1),   # up-left
               1: ( 0, 1),   # straight forward
               2: ( 1, 1),   # up-right
             }
    def __init__(self, t_star_steps=2, N_particles=27, lam=0.001, beta=100.0, K_max=500 ):
        super().__init__()

        #   PDE constants  
        self.alpha = alpha

        #G6id variables  
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T
 
        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = K_max
        self.lam    = lam
        self.beta = beta

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions  ────────────────────────────────────────────
        self.N = N_particles

        mid    = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets= [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(3 * self.N + 2,), dtype=np.float32
        )
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))



    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_set = set()
        return self._build_obs(), {}


    def _build_obs(self):
        return np.array([
            *self.walker_x,
            *self.walker_t,
            *self.walker_u,
            self.x_star,
            self.t_star
        ], dtype=np.float32)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        #if not (np.min(dx_i) < 0 < np.max(dx_i)):
        #    return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'
    def step(self, action):

            self.step_count += 1
            done   = False
            reward = 0.0

            i              = int(action) // len(self.ACTIONS)
            j              = int(action) % len(self.ACTIONS)
            dx_idx, dt_idx = self.ACTIONS[j]
            dx_move = dx_idx * self.dx
            dt_move = dt_idx * self.dt

            info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

            x_new = self.walker_x[i] + dx_move
            t_new = self.walker_t[i] + dt_move

            if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
                info['rejected'] = 'bounds'

            elif self.visited.contains(x_new, t_new):
                info['rejected'] = 'collision'

            else:
                u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
                if not success:
                    info['rejected'] = reason
                    self.gfdm_rejected_set.add(int(action))
                    
                else:
                    self.gfdm_rejected_set.clear()
                    self.visited.add(x_new, t_new, u_hat)
                    self.walker_x[i] = x_new
                    self.walker_t[i] = t_new
                    self.walker_u[i] = u_hat
                    self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                    info['accepted'] = True

                    if (abs(x_new - self.x_star) < self.eps_x and
                        abs(t_new - self.t_star) < self.eps_t):
                        done = True
                        info['reached'] = True

            # ── track rejected positions ──────────────────────────────────────────
            if not info['accepted']:
                self.rejected_history.append((x_new, t_new, info['rejected']))
            # ─────────────────────────────────────────────────────────────────────

            if done:
                u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
                u_ref           = u_true(self.x_star, self.t_star)

                if u_pred is None:
                    reward        = -1.0
                    info['error'] = None
                else:
                    reward = -(self.beta * abs(u_pred - u_ref) + self.lam * self.step_count)
                    info['u_pred'] = u_pred
                    info['u_ref']  = u_ref
                    info['error']  = abs(u_pred - u_ref)
                    info['k_term'] = self.step_count

            elif self.step_count >= self.K_max:
                done = True
                reward = -1.0 - self.lam * self.step_count
                info['timeout'] = True

            return self._build_obs(), reward, done, False, info
    def action_masks(self) -> np.ndarray:
        mask = np.ones(self.N * len(self.ACTIONS), dtype=bool)
        for i in range(self.N):
            for j in range(len(self.ACTIONS)):
                dx_idx, dt_idx = self.ACTIONS[j]
                x_new = self.walker_x[i] + dx_idx * self.dx
                t_new = self.walker_t[i] + dt_idx * self.dt
                if not (0.0 <= x_new <= 1.0 and
                        0.0 < t_new <= self.T and
                        not self.visited.contains(x_new, t_new)):
                    mask[i * len(self.ACTIONS) + j] = False
        for a in self.gfdm_rejected_set:
            mask[a] = False
        if not mask.any():
            mask[:] = True
        return mask

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
t_star_steps = 10  # ← change this to test different targets
env      = PDEEnvironment(t_star_steps=t_star_steps)
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()
    state, reward, done, _, info = env.step(action)



    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts
               if t > 0.0 and 0.0 < x < 1.0]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")

for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")
# walker distribution check — tells you if one walker is dominating
walker_counts = {}
for i, traj in trajectories.items():
    walker_counts[i] = len(traj) - 1  # subtract starting position
print("\nAccepted moves per walker:")
for i, count in sorted(walker_counts.items()):
    print(f"  Walker {i:d}: {count}")

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          500
# Reward:         -1.500000
# Reached:        False
# Timeout:        True
# Total accepted: 310
# Total rejected: 190
# Rejection reasons:
#   collision : 190
#
# Accepted moves per walker:
#   Walker 0: 18
#   Walker 1: 6
#   Walker 2: 23
#   Walker 3: 14
#   Walker 4: 6
#   Walker 5: 18
#   Walker 6: 7
#   Walker 7: 28
#   Walker 8: 16
#   Walker 9: 1
#   Walker 10: 15
#   Walker 11: 13
#   Walker 12: 13
#   Walker 13: 4
#   Walker 14: 20
#   Walker 15: 23
#   Walker 16: 9
#   Walker 17: 3
#   Walker 18: 0
#   Walker 19: 9
#   Walker 20: 14
#   Walker 21: 9
#   Walker 22: 6
#   Walker 23: 4
#   Walker 24: 8
#   Walker 25: 22
#   Walker 26: 1

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps,N_particles, save=True, timestep=None,
                      img_dir=".", label=None):
    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1)

    # ── Rejected positions ───────────────────────────────────────────────────
    rej_colors = {
        'bounds':    'blue',
        'collision': 'orange',
        'cond':      'purple',
        'weights':   'brown',
        'geometry':  'red',
        None:        'gray',
    }
    if env.rejected_history:
        from collections import defaultdict
        by_reason = defaultdict(list)
        for (rx, rt, reason) in env.rejected_history:
            by_reason[reason].append((rx, rt))
        for reason, pts in by_reason.items():
            ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                       s=6, alpha=0.08, linewidths=0, zorder=1,
                       color=rej_colors.get(reason, 'gray'),
                       label=f'rej:{reason} ({len(pts)})')
    # ─────────────────────────────────────────────────────────────────────────

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, color=colors[i], zorder=2)
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4)

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'

    # ── Stencil at z* ────────────────────────────────────────────────────────
    if reached:
        _, success, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star)
        if success and nb_coords is not None:
            for (nx_, nt_) in nb_coords:
                ax.plot([env.x_star, nx_], [env.t_star, nt_],
                        '--', color='red', linewidth=0.8,
                        alpha=0.7, zorder=5)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1],
                       s=40, color='red', zorder=6, alpha=0.7)

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=7)
    ax.set_xlabel('x')
    ax.set_ylabel('t')

    title = f't_star={t_star_steps}·dt  |  {outcome}'
    if timestep is not None:
        title += f'  |  step {timestep:,}'
    ax.set_title(title)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)

    if env.rejected_history:
        ax.legend(fontsize=6, loc='upper left', markerscale=2)

    plt.tight_layout()

    if save:
        if label is not None:
            fname = f'traj_t{t_star_steps}dt_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120)

    plt.close(fig)

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps,N_particles, plot_freq=50_000, img_dir=".", verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles = N_particles
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles, save=True,
                              timestep=self.num_timesteps, img_dir=self.img_dir)
        return True


def make_env(t_star_steps, N_particles, lam, beta, K_max):
    def _init():
        env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles, lam=lam, beta=beta, K_max=K_max)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
# ── Run configuration ────────────────────────────────────────────────────────
N_particles     = 25
curriculum      = [15]
seeds           = [4]
lam             = 0.001
beta            = 1000
K_max           = 500
n_envs          = 15
n_steps         = 2048 // n_envs
total_timesteps = 6_000_000

# ── Run directory ────────────────────────────────────────────────────────────
day      = date.today().day
stages_str = "-".join(str(s) for s in curriculum)
run_name = f"t{stages_str}_lam{lam}_beta{beta}_K{K_max}_N{N_particles}"
run_dir  = os.path.join(f"runs{day}", run_name)

print(f"Run: {run_dir}")
for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    vec_env = SubprocVecEnv([make_env(curriculum[0], N_particles, lam, beta, K_max)
                             for _ in range(n_envs)])
    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=5e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=60,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    for t_star_steps in curriculum:
        print(f"\n{'='*50}")
        print(f"Stage: t* = {t_star_steps}·dt = {t_star_steps * dt:.4f}  |  budget: {total_timesteps//1000}k steps")
        print(f"{'='*50}")

        vec_env = SubprocVecEnv([make_env(t_star_steps, N_particles, lam, beta, K_max)
                                 for _ in range(n_envs)])
        model.set_env(vec_env)

        model.learn(
            total_timesteps=total_timesteps,
            reset_num_timesteps=False,
            tb_log_name=f"seed{seed}",
            log_interval=10,
            callback=[
                ReachedRateCallback(),
                PlotCallback(t_star_steps, N_particles, plot_freq=100_000, img_dir=img_dir),
                CheckpointCallback(
                    save_freq=100_000,
                    save_path=os.path.join(ckpt_dir, f"tstar{t_star_steps}"),
                    name_prefix=f"tstar{t_star_steps}"
                ),
            ],
        )

        model.save(os.path.join(ckpt_dir, f"tstar{t_star_steps}_final"))

        plot_trajectories(
            model, t_star_steps, N_particles,
            save=True, timestep=None, img_dir=img_dir, label="final")

        make_trajectory_video(model, PDEEnvironment, t_star_steps, N_particles, img_dir=img_dir)
        make_training_progress_video(img_dir=img_dir,t_star_steps=t_star_steps,fps=3)
# Out:
# Run: runs7\t10_lam0.001_beta1000_K500_N25
#
# ##################################################
# SEED 4
# ##################################################
# Using cpu device
#
# ==================================================
# Stage: t* = 10·dt = 0.1053  |  budget: 4000k steps
# ==================================================
# Logging to runs7\t10_lam0.001_beta1000_K500_N25\seed4\logs\seed4_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | -0.758      |
# |    mean_error_on_reach  | 0.000275    |
# |    mean_kterm_on_reach  | 202         |
# |    reached_rate         | 0.726       |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.005742181 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0469     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 0.0289      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 309          |
# |    ep_rew_mean          | -1.02        |
# |    mean_error_on_reach  | 0.00047      |
# |    mean_kterm_on_reach  | 202          |
# |    reached_rate         | 0.64         |
# | time/                   |              |
# |    fps                  | 1940         |
# |    iterations           | 20           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 40800        |
# | train/                  |              |
# |    approx_kl            | 0.0073882956 |
# |    clip_fraction        | 0.372        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0602      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0237      |
# |    value_loss           | 0.0171       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 351         |
# |    ep_rew_mean          | -1.09       |
# |    mean_error_on_reach  | 0.000473    |
# |    mean_kterm_on_reach  | 225         |
# |    reached_rate         | 0.57        |
# | time/                   |             |
# |    fps                  | 1967        |
# |    iterations           | 30          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 61200       |
# | train/                  |             |
# |    approx_kl            | 0.008305994 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0512     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 0.00967     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 395          |
# |    ep_rew_mean          | -1.23        |
# |    mean_error_on_reach  | 0.000613     |
# |    mean_kterm_on_reach  | 234          |
# |    reached_rate         | 0.46         |
# | time/                   |              |
# |    fps                  | 1978         |
# |    iterations           | 40           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 81600        |
# | train/                  |              |
# |    approx_kl            | 0.0076396037 |
# |    clip_fraction        | 0.379        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.35        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0492      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0199      |
# |    value_loss           | 0.019        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 425          |
# |    ep_rew_mean          | -1.51        |
# |    mean_error_on_reach  | 0.000813     |
# |    mean_kterm_on_reach  | 255          |
# |    reached_rate         | 0.36         |
# | time/                   |              |
# |    fps                  | 1960         |
# |    iterations           | 50           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 102000       |
# | train/                  |              |
# |    approx_kl            | 0.0075963587 |
# |    clip_fraction        | 0.33         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0516      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 0.0175       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | -1.68       |
# |    mean_error_on_reach  | 0.000959    |
# |    mean_kterm_on_reach  | 277         |
# |    reached_rate         | 0.34        |
# | time/                   |             |
# |    fps                  | 1965        |
# |    iterations           | 60          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 122400      |
# | train/                  |             |
# |    approx_kl            | 0.009493144 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0503     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.00603     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 425         |
# |    ep_rew_mean          | -1.47       |
# |    mean_error_on_reach  | 0.000959    |
# |    mean_kterm_on_reach  | 294         |
# |    reached_rate         | 0.36        |
# | time/                   |             |
# |    fps                  | 1975        |
# |    iterations           | 70          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 142800      |
# | train/                  |             |
# |    approx_kl            | 0.009871859 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0648     |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 420         |
# |    ep_rew_mean          | -1.95       |
# |    mean_error_on_reach  | 0.0017      |
# |    mean_kterm_on_reach  | 292         |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1971        |
# |    iterations           | 80          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.005991865 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.067       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0222      |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 3           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | -7.18       |
# |    mean_error_on_reach  | 0.00695     |
# |    mean_kterm_on_reach  | 284         |
# |    reached_rate         | 0.46        |
# | time/                   |             |
# |    fps                  | 1978        |
# |    iterations           | 90          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.006558256 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.00619     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00719    |
# |    value_loss           | 663         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | -7.2        |
# |    mean_error_on_reach  | 0.00775     |
# |    mean_kterm_on_reach  | 260         |
# |    reached_rate         | 0.57        |
# | time/                   |             |
# |    fps                  | 1975        |
# |    iterations           | 100         |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 204000      |
# | train/                  |             |
# |    approx_kl            | 0.011085392 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0263     |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.138       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | -2.26        |
# |    mean_error_on_reach  | 0.00778      |
# |    mean_kterm_on_reach  | 255          |
# |    reached_rate         | 0.51         |
# | time/                   |              |
# |    fps                  | 1979         |
# |    iterations           | 110          |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 224400       |
# | train/                  |              |
# |    approx_kl            | 0.0139210075 |
# |    clip_fraction        | 0.363        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0578      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.0155      |
# |    value_loss           | 0.025        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | -2.3        |
# |    mean_error_on_reach  | 0.00769     |
# |    mean_kterm_on_reach  | 245         |
# |    reached_rate         | 0.42        |
# | time/                   |             |
# |    fps                  | 1984        |
# |    iterations           | 120         |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 244800      |
# | train/                  |             |
# |    approx_kl            | 0.010973432 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0237     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.0284      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | -2.56       |
# |    mean_error_on_reach  | 0.00365     |
# |    mean_kterm_on_reach  | 243         |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1990        |
# |    iterations           | 130         |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 265200      |
# | train/                  |             |
# |    approx_kl            | 0.010271459 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0631     |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | -2.12       |
# |    mean_error_on_reach  | 0.00322     |
# |    mean_kterm_on_reach  | 227         |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1993        |
# |    iterations           | 140         |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.011147476 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0479     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | -1.68       |
# |    mean_error_on_reach  | 0.00274     |
# |    mean_kterm_on_reach  | 203         |
# |    reached_rate         | 0.4         |
# | time/                   |             |
# |    fps                  | 1986        |
# |    iterations           | 150         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.009196296 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0445     |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0207      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 365         |
# |    ep_rew_mean          | -1.88       |
# |    mean_error_on_reach  | 0.00298     |
# |    mean_kterm_on_reach  | 189         |
# |    reached_rate         | 0.38        |
# | time/                   |             |
# |    fps                  | 1985        |
# |    iterations           | 160         |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 326400      |
# | train/                  |             |
# |    approx_kl            | 0.011467694 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.041      |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | -1.78       |
# |    mean_error_on_reach  | 0.00232     |
# |    mean_kterm_on_reach  | 180         |
# |    reached_rate         | 0.33        |
# | time/                   |             |
# |    fps                  | 1988        |
# |    iterations           | 170         |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 346800      |
# | train/                  |             |
# |    approx_kl            | 0.009045168 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0737     |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | -1.24       |
# |    mean_error_on_reach  | 0.00165     |
# |    mean_kterm_on_reach  | 177         |
# |    reached_rate         | 0.39        |
# | time/                   |             |
# |    fps                  | 1990        |
# |    iterations           | 180         |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 367200      |
# | train/                  |             |
# |    approx_kl            | 0.011339802 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0652     |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | -1.46       |
# |    mean_error_on_reach  | 0.00153     |
# |    mean_kterm_on_reach  | 171         |
# |    reached_rate         | 0.45        |
# | time/                   |             |
# |    fps                  | 1992        |
# |    iterations           | 190         |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 387600      |
# | train/                  |             |
# |    approx_kl            | 0.009546349 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0403     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 0.00137     |
# |    mean_kterm_on_reach  | 181         |
# |    reached_rate         | 0.47        |
# | time/                   |             |
# |    fps                  | 1987        |
# |    iterations           | 200         |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 408000      |
# | train/                  |             |
# |    approx_kl            | 0.012444491 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0547     |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.00096     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | -1.29       |
# |    mean_error_on_reach  | 0.000929    |
# |    mean_kterm_on_reach  | 188         |
# |    reached_rate         | 0.35        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 210         |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 428400      |
# | train/                  |             |
# |    approx_kl            | 0.009669031 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0694     |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | -0.948      |
# |    mean_error_on_reach  | 0.000776    |
# |    mean_kterm_on_reach  | 167         |
# |    reached_rate         | 0.53        |
# | time/                   |             |
# |    fps                  | 1992        |
# |    iterations           | 220         |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 448800      |
# | train/                  |             |
# |    approx_kl            | 0.009969389 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0372     |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.00693     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | -0.866      |
# |    mean_error_on_reach  | 0.000353    |
# |    mean_kterm_on_reach  | 144         |
# |    reached_rate         | 0.65        |
# | time/                   |             |
# |    fps                  | 1993        |
# |    iterations           | 230         |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 469200      |
# | train/                  |             |
# |    approx_kl            | 0.012816389 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0466     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00234     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | -0.997      |
# |    mean_error_on_reach  | 0.000457    |
# |    mean_kterm_on_reach  | 146         |
# |    reached_rate         | 0.6         |
# | time/                   |             |
# |    fps                  | 1996        |
# |    iterations           | 240         |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 489600      |
# | train/                  |             |
# |    approx_kl            | 0.012352457 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0603     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | -0.994      |
# |    mean_error_on_reach  | 0.000466    |
# |    mean_kterm_on_reach  | 157         |
# |    reached_rate         | 0.55        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 250         |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 510000      |
# | train/                  |             |
# |    approx_kl            | 0.011729782 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0445     |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -0.516      |
# |    mean_error_on_reach  | 0.000227    |
# |    mean_kterm_on_reach  | 116         |
# |    reached_rate         | 0.84        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 260         |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 530400      |
# | train/                  |             |
# |    approx_kl            | 0.010641433 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0381     |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00374     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -0.82       |
# |    mean_error_on_reach  | 0.000392    |
# |    mean_kterm_on_reach  | 122         |
# |    reached_rate         | 0.74        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 270         |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 550800      |
# | train/                  |             |
# |    approx_kl            | 0.010337586 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0579     |
# |    n_updates            | 2690        |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00837     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 331        |
# |    ep_rew_mean          | -3.26      |
# |    mean_error_on_reach  | 0.0027     |
# |    mean_kterm_on_reach  | 151        |
# |    reached_rate         | 0.54       |
# | time/                   |            |
# |    fps                  | 1991       |
# |    iterations           | 280        |
# |    time_elapsed         | 286        |
# |    total_timesteps      | 571200     |
# | train/                  |            |
# |    approx_kl            | 0.01093686 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0412    |
# |    n_updates            | 2790       |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 0.00529    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 381          |
# |    ep_rew_mean          | -3.42        |
# |    mean_error_on_reach  | 0.00277      |
# |    mean_kterm_on_reach  | 168          |
# |    reached_rate         | 0.41         |
# | time/                   |              |
# |    fps                  | 1994         |
# |    iterations           | 290          |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 591600       |
# | train/                  |              |
# |    approx_kl            | 0.0116137685 |
# |    clip_fraction        | 0.424        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0608      |
# |    n_updates            | 2890         |
# |    policy_gradient_loss | -0.0209      |
# |    value_loss           | 0.000963     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 368         |
# |    ep_rew_mean          | -1.27       |
# |    mean_error_on_reach  | 0.00279     |
# |    mean_kterm_on_reach  | 187         |
# |    reached_rate         | 0.42        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 300         |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 612000      |
# | train/                  |             |
# |    approx_kl            | 0.009502452 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0503     |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00647     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 265       |
# |    ep_rew_mean          | -1.09     |
# |    mean_error_on_reach  | 0.00075   |
# |    mean_kterm_on_reach  | 162       |
# |    reached_rate         | 0.67      |
# | time/                   |           |
# |    fps                  | 1982      |
# |    iterations           | 310       |
# |    time_elapsed         | 318       |
# |    total_timesteps      | 632400    |
# | train/                  |           |
# |    approx_kl            | 0.0113229 |
# |    clip_fraction        | 0.379     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -2.6      |
# |    explained_variance   | 0.798     |
# |    learning_rate        | 0.0005    |
# |    loss                 | -0.0253   |
# |    n_updates            | 3090      |
# |    policy_gradient_loss | -0.0135   |
# |    value_loss           | 0.0113    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 277         |
# |    ep_rew_mean          | -1.2        |
# |    mean_error_on_reach  | 0.000855    |
# |    mean_kterm_on_reach  | 156         |
# |    reached_rate         | 0.67        |
# | time/                   |             |
# |    fps                  | 1973        |
# |    iterations           | 320         |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 652800      |
# | train/                  |             |
# |    approx_kl            | 0.011073679 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0769     |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.00415     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | -1.09        |
# |    mean_error_on_reach  | 0.000763     |
# |    mean_kterm_on_reach  | 171          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 1968         |
# |    iterations           | 330          |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 673200       |
# | train/                  |              |
# |    approx_kl            | 0.0126784565 |
# |    clip_fraction        | 0.429        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0511      |
# |    n_updates            | 3290         |
# |    policy_gradient_loss | -0.0206      |
# |    value_loss           | 0.00251      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | -0.687      |
# |    mean_error_on_reach  | 0.000386    |
# |    mean_kterm_on_reach  | 125         |
# |    reached_rate         | 0.81        |
# | time/                   |             |
# |    fps                  | 1962        |
# |    iterations           | 340         |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 693600      |
# | train/                  |             |
# |    approx_kl            | 0.009631382 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0496     |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.00612     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 275          |
# |    ep_rew_mean          | -10.2        |
# |    mean_error_on_reach  | 0.00963      |
# |    mean_kterm_on_reach  | 127          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 1955         |
# |    iterations           | 350          |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 714000       |
# | train/                  |              |
# |    approx_kl            | 0.0026882957 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | -0.000419    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 693          |
# |    n_updates            | 3490         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 661          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | -28.4       |
# |    mean_error_on_reach  | 0.0278      |
# |    mean_kterm_on_reach  | 149         |
# |    reached_rate         | 0.58        |
# | time/                   |             |
# |    fps                  | 1950        |
# |    iterations           | 360         |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.014541442 |
# |    clip_fraction        | 0.486       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0251     |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.00965    |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | -0.826      |
# |    mean_error_on_reach  | 0.0112      |
# |    mean_kterm_on_reach  | 139         |
# |    reached_rate         | 0.69        |
# | time/                   |             |
# |    fps                  | 1946        |
# |    iterations           | 370         |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 754800      |
# | train/                  |             |
# |    approx_kl            | 0.016750202 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0575     |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.00774     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | -0.827      |
# |    mean_error_on_reach  | 0.000442    |
# |    mean_kterm_on_reach  | 113         |
# |    reached_rate         | 0.72        |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 380         |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 775200      |
# | train/                  |             |
# |    approx_kl            | 0.008336474 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00142     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0429      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 261        |
# |    ep_rew_mean          | -0.942     |
# |    mean_error_on_reach  | 0.000456   |
# |    mean_kterm_on_reach  | 130        |
# |    reached_rate         | 0.67       |
# | time/                   |            |
# |    fps                  | 1936       |
# |    iterations           | 390        |
# |    time_elapsed         | 410        |
# |    total_timesteps      | 795600     |
# | train/                  |            |
# |    approx_kl            | 0.01038041 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0378    |
# |    n_updates            | 3890       |
# |    policy_gradient_loss | -0.0129    |
# |    value_loss           | 0.00564    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | -1.1        |
# |    mean_error_on_reach  | 0.000486    |
# |    mean_kterm_on_reach  | 143         |
# |    reached_rate         | 0.46        |
# | time/                   |             |
# |    fps                  | 1932        |
# |    iterations           | 400         |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 816000      |
# | train/                  |             |
# |    approx_kl            | 0.009500755 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0559     |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | -1.1        |
# |    mean_error_on_reach  | 0.000461    |
# |    mean_kterm_on_reach  | 159         |
# |    reached_rate         | 0.46        |
# | time/                   |             |
# |    fps                  | 1928        |
# |    iterations           | 410         |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 836400      |
# | train/                  |             |
# |    approx_kl            | 0.013490694 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0103      |
# |    n_updates            | 4090        |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.00072     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | -1.13       |
# |    mean_error_on_reach  | 0.000529    |
# |    mean_kterm_on_reach  | 167         |
# |    reached_rate         | 0.52        |
# | time/                   |             |
# |    fps                  | 1924        |
# |    iterations           | 420         |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 856800      |
# | train/                  |             |
# |    approx_kl            | 0.012751174 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0457     |
# |    n_updates            | 4190        |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 350         |
# |    ep_rew_mean          | -1.16       |
# |    mean_error_on_reach  | 0.000593    |
# |    mean_kterm_on_reach  | 177         |
# |    reached_rate         | 0.51        |
# | time/                   |             |
# |    fps                  | 1920        |
# |    iterations           | 430         |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 877200      |
# | train/                  |             |
# |    approx_kl            | 0.012319426 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0603     |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.00564     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | -1.09       |
# |    mean_error_on_reach  | 0.000625    |
# |    mean_kterm_on_reach  | 193         |
# |    reached_rate         | 0.52        |
# | time/                   |             |
# |    fps                  | 1915        |
# |    iterations           | 440         |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 897600      |
# | train/                  |             |
# |    approx_kl            | 0.015794583 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0555     |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.00462     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | -1.14       |
# |    mean_error_on_reach  | 0.000568    |
# |    mean_kterm_on_reach  | 199         |
# |    reached_rate         | 0.51        |
# | time/                   |             |
# |    fps                  | 1909        |
# |    iterations           | 450         |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 918000      |
# | train/                  |             |
# |    approx_kl            | 0.010470176 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0316     |
# |    n_updates            | 4490        |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 0.0209      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -0.801      |
# |    mean_error_on_reach  | 0.000572    |
# |    mean_kterm_on_reach  | 113         |
# |    reached_rate         | 0.86        |
# | time/                   |             |
# |    fps                  | 1903        |
# |    iterations           | 460         |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 938400      |
# | train/                  |             |
# |    approx_kl            | 0.010315785 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0314     |
# |    n_updates            | 4590        |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.0321      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -0.521      |
# |    mean_error_on_reach  | 0.000368    |
# |    mean_kterm_on_reach  | 94.1        |
# |    reached_rate         | 0.94        |
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 470         |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 958800      |
# | train/                  |             |
# |    approx_kl            | 0.010099252 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0454     |
# |    n_updates            | 4690        |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 0.00768     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# ...
# | train/                  |             |
# |    approx_kl            | 0.021570379 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0614     |
# |    n_updates            | 18090       |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.000421    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | -0.117      |
# |    mean_error_on_reach  | 9.12e-05    |
# |    mean_kterm_on_reach  | 26.1        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1962        |
# |    iterations           | 1820        |
# |    time_elapsed         | 1891        |
# |    total_timesteps      | 3712800     |
# | train/                  |             |
# |    approx_kl            | 0.008663716 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0158     |
# |    n_updates            | 18190       |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 0.00421     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | -0.0977     |
# |    mean_error_on_reach  | 5.3e-05     |
# |    mean_kterm_on_reach  | 30.5        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 1963        |
# |    iterations           | 1830        |
# |    time_elapsed         | 1901        |
# |    total_timesteps      | 3733200     |
# | train/                  |             |
# |    approx_kl            | 0.012477972 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0272     |
# |    n_updates            | 18290       |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 0.00354     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.6        |
# |    ep_rew_mean          | -0.0826     |
# |    mean_error_on_reach  | 5.6e-05     |
# |    mean_kterm_on_reach  | 26.6        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1963        |
# |    iterations           | 1840        |
# |    time_elapsed         | 1911        |
# |    total_timesteps      | 3753600     |
# | train/                  |             |
# |    approx_kl            | 0.009818581 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0167     |
# |    n_updates            | 18390       |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.1       |
# |    ep_rew_mean          | -0.0625    |
# |    mean_error_on_reach  | 3.74e-05   |
# |    mean_kterm_on_reach  | 25.1       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1964       |
# |    iterations           | 1850       |
# |    time_elapsed         | 1921       |
# |    total_timesteps      | 3774000    |
# | train/                  |            |
# |    approx_kl            | 0.01427632 |
# |    clip_fraction        | 0.422      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.021     |
# |    n_updates            | 18490      |
# |    policy_gradient_loss | -0.000687  |
# |    value_loss           | 0.00269    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.3        |
# |    ep_rew_mean          | -0.0604     |
# |    mean_error_on_reach  | 3.5e-05     |
# |    mean_kterm_on_reach  | 25.3        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1965        |
# |    iterations           | 1860        |
# |    time_elapsed         | 1930        |
# |    total_timesteps      | 3794400     |
# | train/                  |             |
# |    approx_kl            | 0.014098036 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.0238      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00755    |
# |    n_updates            | 18590       |
# |    policy_gradient_loss | -0.000257   |
# |    value_loss           | 0.000476    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | -0.0811     |
# |    mean_error_on_reach  | 5.22e-05    |
# |    mean_kterm_on_reach  | 28.9        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1965        |
# |    iterations           | 1870        |
# |    time_elapsed         | 1941        |
# |    total_timesteps      | 3814800     |
# | train/                  |             |
# |    approx_kl            | 0.008761109 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0235     |
# |    n_updates            | 18690       |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 0.000253    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | -0.054      |
# |    mean_error_on_reach  | 2.58e-05    |
# |    mean_kterm_on_reach  | 28.2        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1965        |
# |    iterations           | 1880        |
# |    time_elapsed         | 1950        |
# |    total_timesteps      | 3835200     |
# | train/                  |             |
# |    approx_kl            | 0.010073447 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0316     |
# |    n_updates            | 18790       |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 0.00528     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | -0.0533     |
# |    mean_error_on_reach  | 2.62e-05    |
# |    mean_kterm_on_reach  | 27.1        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1966        |
# |    iterations           | 1890        |
# |    time_elapsed         | 1960        |
# |    total_timesteps      | 3855600     |
# | train/                  |             |
# |    approx_kl            | 0.023354424 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0396     |
# |    n_updates            | 18890       |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 0.00739     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.9       |
# |    ep_rew_mean          | -0.197     |
# |    mean_error_on_reach  | 0.000132   |
# |    mean_kterm_on_reach  | 39.9       |
# |    reached_rate         | 0.98       |
# | time/                   |            |
# |    fps                  | 1967       |
# |    iterations           | 1900       |
# |    time_elapsed         | 1970       |
# |    total_timesteps      | 3876000    |
# | train/                  |            |
# |    approx_kl            | 0.01952565 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.735      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0158     |
# |    n_updates            | 18990      |
# |    policy_gradient_loss | -0.00875   |
# |    value_loss           | 0.0752     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | -0.0786     |
# |    mean_error_on_reach  | 4.96e-05    |
# |    mean_kterm_on_reach  | 29          |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1967        |
# |    iterations           | 1910        |
# |    time_elapsed         | 1979        |
# |    total_timesteps      | 3896400     |
# | train/                  |             |
# |    approx_kl            | 0.014512265 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0352     |
# |    n_updates            | 19090       |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.002       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.2         |
# |    ep_rew_mean          | -0.0871      |
# |    mean_error_on_reach  | 5.69e-05     |
# |    mean_kterm_on_reach  | 30.2         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1968         |
# |    iterations           | 1920         |
# |    time_elapsed         | 1989         |
# |    total_timesteps      | 3916800      |
# | train/                  |              |
# |    approx_kl            | 0.0049542747 |
# |    clip_fraction        | 0.342        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | -0.0435      |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0221      |
# |    n_updates            | 19190        |
# |    policy_gradient_loss | 0.00184      |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | -0.0635     |
# |    mean_error_on_reach  | 3.52e-05    |
# |    mean_kterm_on_reach  | 28.3        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1968        |
# |    iterations           | 1930        |
# |    time_elapsed         | 1999        |
# |    total_timesteps      | 3937200     |
# | train/                  |             |
# |    approx_kl            | 0.006457843 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2          |
# |    explained_variance   | -0.0406     |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.02       |
# |    n_updates            | 19290       |
# |    policy_gradient_loss | -0.000345   |
# |    value_loss           | 0.000525    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | -0.107      |
# |    mean_error_on_reach  | 3.26e-05    |
# |    mean_kterm_on_reach  | 30.8        |
# |    reached_rate         | 0.97        |
# | time/                   |             |
# |    fps                  | 1969        |
# |    iterations           | 1940        |
# |    time_elapsed         | 2009        |
# |    total_timesteps      | 3957600     |
# | train/                  |             |
# |    approx_kl            | 0.021028027 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0467     |
# |    n_updates            | 19390       |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.1        |
# |    ep_rew_mean          | -0.0692     |
# |    mean_error_on_reach  | 3.91e-05    |
# |    mean_kterm_on_reach  | 30.1        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1970        |
# |    iterations           | 1950        |
# |    time_elapsed         | 2019        |
# |    total_timesteps      | 3978000     |
# | train/                  |             |
# |    approx_kl            | 0.012643916 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00433    |
# |    n_updates            | 19490       |
# |    policy_gradient_loss | -0.00842    |
# |    value_loss           | 0.0041      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | -0.0578      |
# |    mean_error_on_reach  | 2.97e-05     |
# |    mean_kterm_on_reach  | 28.1         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1970         |
# |    iterations           | 1960         |
# |    time_elapsed         | 2028         |
# |    total_timesteps      | 3998400      |
# | train/                  |              |
# |    approx_kl            | 0.0062421747 |
# |    clip_fraction        | 0.299        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0196      |
# |    n_updates            | 19590        |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 0.000221     |
# ------------------------------------------
# Rollout done: reached, 19 accepted points, 19 total steps.
# Saved video: runs7\t10_lam0.001_beta1000_K500_N25\seed4\images\traj_t10dt_final_reached.mp4
# Found 41 images.
# First frame: traj_t10dt_00100k_timeout.png
# Last frame:  traj_t10dt_final_reached.png
# Saved training progress video: runs7\t10_lam0.001_beta1000_K500_N25\seed4\images\traj_t10dt_training_progress.mp4

# %%
print(img_dir)
# Out:
# runs7\t10_lam0.001_beta1000_K500_N25\seed4\images

# %%
import os
import re
import glob
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()
make_trajectory_video(model, PDEEnvironment, t_star_steps, N_particles, img_dir=img_dir)
make_training_progress_video(img_dir=img_dir,t_star_steps=t_star_steps,fps=3)
# Out:
# Rollout done: reached, 13 accepted points, 13 total steps.
# Saved video: runs3\t5_lam0.001_beta1000_K500_N25\seed4\images\traj_t10dt_final_reached.mp4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[79], line 11
#       7 import matplotlib.animation as animation
#       8 import imageio_ffmpeg
#       9 mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()
#      10 make_trajectory_video(model, PDEEnvironment, t_star_steps, N_particles, img_dir=img_dir)
# ---> 11 make_training_progress_video(img_dir=img_dir,t_star_steps=t_star_steps,fps=3)
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\training_progress_video.py:106, in make_training_progress_video(img_dir, t_star_steps, fps, dpi, outcome_filter, out_name, verbose)
#     103     candidates.append((sort_key, path))
#     105 if not candidates:
# --> 106     raise RuntimeError(
#     107         f"No matching trajectory PNGs found in: {img_dir}\n"
#     108         f"Expected files like:\n"
#     109         f"  traj_t{t_star_steps}dt_10k_reached.png\n"
#     110         f"  traj_t{t_star_steps}dt_20k_timeout.png\n"
#     111         f"  traj_t{t_star_steps}dt_final_reached.png\n"
#     112         f"Check img_dir, t_star_steps, and your saved filenames."
#     113     )
#     115 candidates.sort(key=lambda item: item[0])
#     116 paths_in_order = [path for _, path in candidates]
#
# RuntimeError: No matching trajectory PNGs found in: runs3\t5_lam0.001_beta1000_K500_N25\seed4\images
# Expected files like:
#   traj_t10dt_10k_reached.png
#   traj_t10dt_20k_timeout.png
#   traj_t10dt_final_reached.png
# Check img_dir, t_star_steps, and your saved filenames.
