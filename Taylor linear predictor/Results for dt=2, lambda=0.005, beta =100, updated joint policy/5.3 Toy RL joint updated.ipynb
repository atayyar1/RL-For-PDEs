# %% [markdown]
# Libraries

# %%
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces

# %% [markdown]
# PDE and FD reference Parameters

# %%
# ── PDE ────────────────────────────────────────────────────────
alpha = 0.05

# ── FD reference grid ────────────────────────────────────────── 
nx    = 30
T     = 0.6
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

# %% [markdown]
# Analytical diffusion solution

# %%
def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# __init__

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()                    # NEW

    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))   # NEW
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()
    def contains(self, x, t):                          # NEW
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None

            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)

            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None

            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]

            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > 1e4:
        return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    if np.max(np.abs(w)) > 3.0 / len(dx_i):
        return None, 'weights'
    if np.min(w) < -1.0:
        return None, 'weights'

    return w, 'ok'

# %% [markdown]
# PDEEnvironment

# %%
class PDEEnvironment(gym.Env):

    def __init__(self, t_star_steps=2):
        super().__init__()

        # ── PDE constants ───────────────────────────────────────────────────────
        self.alpha = alpha

        # ── Grid variables ──────────────────────────────────────────────────────
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T

        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = 500
        self.lam    = 0.005
        self.Kx     = 1
        self.Kt     = 1
        self.beta = 100.0

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions ─────────────────────────────────────────────
        self.N = 3

        mid    = self.nx // 2
        margin = 12
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets = [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(3 * self.N + 2,), dtype=np.float32
        )
        self.action_space = spaces.MultiDiscrete([self.N, 3, 2])


    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_init_x])

        self.step_count = 0

        return self._build_obs(), {}


    def _build_obs(self):
        return np.array([
            *self.walker_x,
            *self.walker_t,
            *self.walker_u,
            self.x_star,
            self.t_star
        ], dtype=np.float32)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        if not (np.min(dx_i) < 0 < np.max(dx_i)):
            return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'
        return u_hat, True, nb[:, :2], 'ok'

    def step(self, action):

        self.step_count += 1
        done   = False
        reward = 0.0

        walker_idx, dx_idx, dt_idx = action
        i  = int(walker_idx)
        dx = (int(dx_idx) - self.Kx) * self.dx
        dt = int(dt_idx) * self.dt

        info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

        x_new = self.walker_x[i] + dx
        t_new = self.walker_t[i] + dt

        if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
            info['rejected'] = 'bounds'

        elif self.visited.contains(x_new, t_new):
            info['rejected'] = 'collision'

        else:
            u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
            if not success:
                info['rejected'] = reason
            else:
                self.visited.add(x_new, t_new, u_hat)
                self.walker_x[i] = x_new
                self.walker_t[i] = t_new
                self.walker_u[i] = u_hat
                self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                info['accepted'] = True

                if (abs(x_new - self.x_star) < self.eps_x and
                    abs(t_new - self.t_star) < self.eps_t):
                    done = True
                    info['reached'] = True

        if done:
            u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
            u_ref           = u_true(self.x_star, self.t_star)

            if u_pred is None:
                reward        = -1.0
                info['error'] = None
            else:
                reward = -(self.beta * abs(u_pred - u_ref) + self.lam * self.step_count)
                info['u_pred'] = u_pred
                info['u_ref']  = u_ref
                info['error']  = abs(u_pred - u_ref)
                info['k_term'] = self.step_count

        elif self.step_count >= self.K_max:
            done = True
            reward = -1.0 - self.lam * self.step_count
            info['timeout'] = True

        return self._build_obs(), reward, done, False, info

# %%
env      = PDEEnvironment()
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()                         # MultiDiscrete sample
    state, reward, done, _, info = env.step(action)

    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")
for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")

import matplotlib.pyplot as plt
import matplotlib.cm as cm

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          8
# Reward:         -0.041405
# Reached:        True
# Timeout:        False
# Total accepted: 4
# Total rejected: 4
# Rejection reasons:
#   bounds    : 4

# %%
def plot_trajectories(model, t_star_steps, save=True, title_suffix=""):
    env = PDEEnvironment(t_star_steps=t_star_steps)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=False)
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, zorder=2, color=colors[i])
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4, label=f'Walker {i}')

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=5, label='z*')
    ax.set_xlabel('x')
    ax.set_ylabel('t')
    ax.set_title(f't_star={t_star_steps}·dt  reached={info.get("reached", False)}{title_suffix}')
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)
    plt.tight_layout()

    if save:
        fname = f'trajectories_tstar{t_star_steps}_step{title_suffix.strip()}.png'.replace(" ", "_").replace("—", "")
        fig.savefig(fname, dpi=120)
        print(f"Saved: {fname}")
    plt.close(fig)

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback

class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True


class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, plot_freq=50_000, verbose=0):
        super().__init__(verbose)
        self.t_star_steps  = t_star_steps
        self.plot_freq     = plot_freq
        self.last_plot_at  = 0

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(
                self.model,
                self.t_star_steps,
                save=True,
                title_suffix=f"_step{self.num_timesteps}"
            )
        return True

def make_env(t_star_steps):
    def _init():
        return Monitor(PDEEnvironment(t_star_steps=t_star_steps))
    return _init

t_star_steps = 2
n_envs       = 15
n_steps      = 2048 // n_envs

vec_env = SubprocVecEnv([make_env(t_star_steps) for _ in range(n_envs)])

model = PPO(
    "MlpPolicy",
    vec_env,
    verbose=1,
    gamma=1.0,
    device="cpu",
    n_steps=n_steps,
    batch_size=60,
    tensorboard_log="./logs/",
)

print(f"Training — t_star = {t_star_steps}·dt = {t_star_steps * dt:.4f}")

model.learn(
    total_timesteps=5_000_000,
    reset_num_timesteps=False,
    tb_log_name="joint_policy",
    log_interval=10,
    callback=[
        ReachedRateCallback(),
        PlotCallback(t_star_steps, plot_freq=50_000),
        CheckpointCallback(save_freq=100_000, save_path="./ckpts/"),
    ],
)
model.save(f"checkpoint_tstar{t_star_steps}")
# Out:
# Using cpu device
# Training — t_star = 2·dt = 0.0211
# Logging to ./logs/joint_policy_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -1.12       |
# |    mean_error_on_reach  | 1.64e-05    |
# |    mean_kterm_on_reach  | 15.3        |
# |    reached_rate         | 0.697       |
# | time/                   |             |
# |    fps                  | 2679        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.010371233 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0312      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 0.0579      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | -1.55       |
# |    mean_error_on_reach  | 1.4e-05     |
# |    mean_kterm_on_reach  | 15.4        |
# |    reached_rate         | 0.57        |
# | time/                   |             |
# |    fps                  | 2535        |
# |    iterations           | 20          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 40800       |
# | train/                  |             |
# |    approx_kl            | 0.007981259 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0978      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 0.0887      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step50010.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 210         |
# |    ep_rew_mean          | -1.43       |
# |    mean_error_on_reach  | 1.38e-05    |
# |    mean_kterm_on_reach  | 26          |
# |    reached_rate         | 0.62        |
# | time/                   |             |
# |    fps                  | 2433        |
# |    iterations           | 30          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 61200       |
# | train/                  |             |
# |    approx_kl            | 0.008835174 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0227      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -1.5         |
# |    mean_error_on_reach  | 1.58e-05     |
# |    mean_kterm_on_reach  | 47.4         |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 2457         |
# |    iterations           | 40           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 81600        |
# | train/                  |              |
# |    approx_kl            | 0.0072913775 |
# |    clip_fraction        | 0.0971       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0391       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 0.0596       |
# ------------------------------------------
# Saved: trajectories_tstar2_step_step100020.png
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 232        |
# |    ep_rew_mean          | -1.5       |
# |    mean_error_on_reach  | 1.55e-05   |
# |    mean_kterm_on_reach  | 79.8       |
# |    reached_rate         | 0.66       |
# | time/                   |            |
# |    fps                  | 2458       |
# |    iterations           | 50         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 102000     |
# | train/                  |            |
# |    approx_kl            | 0.01697224 |
# |    clip_fraction        | 0.0974     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.01      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0173     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00504   |
# |    value_loss           | 0.0671     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | -1.91       |
# |    mean_error_on_reach  | 1.64e-05    |
# |    mean_kterm_on_reach  | 83.4        |
# |    reached_rate         | 0.51        |
# | time/                   |             |
# |    fps                  | 2462        |
# |    iterations           | 60          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 122400      |
# | train/                  |             |
# |    approx_kl            | 0.013254723 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | -2.66       |
# |    mean_error_on_reach  | 1.62e-05    |
# |    mean_kterm_on_reach  | 91          |
# |    reached_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 2467        |
# |    iterations           | 70          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 142800      |
# | train/                  |             |
# |    approx_kl            | 0.007937648 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0517      |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 0.104       |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step150030.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | -3.19       |
# |    mean_error_on_reach  | 1.62e-05    |
# |    mean_kterm_on_reach  | 91          |
# |    reached_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 2463        |
# |    iterations           | 80          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.009813741 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.000925   |
# |    value_loss           | 0.0479      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 1.62e-05    |
# |    mean_kterm_on_reach  | 91          |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2474        |
# |    iterations           | 90          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.006402656 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0245      |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 0.0238      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step200040.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 1.62e-05    |
# |    mean_kterm_on_reach  | 91          |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2468        |
# |    iterations           | 100         |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 204000      |
# | train/                  |             |
# |    approx_kl            | 0.012545078 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0284      |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 1.62e-05    |
# |    mean_kterm_on_reach  | 91          |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2485        |
# |    iterations           | 110         |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 224400      |
# | train/                  |             |
# |    approx_kl            | 0.009414803 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00371     |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 0.0048      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -3.45       |
# |    mean_error_on_reach  | 1.55e-05    |
# |    mean_kterm_on_reach  | 99.6        |
# |    reached_rate         | 0.03        |
# | time/                   |             |
# |    fps                  | 2497        |
# |    iterations           | 120         |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 244800      |
# | train/                  |             |
# |    approx_kl            | 0.006956859 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0809      |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.000393   |
# |    value_loss           | 0.0339      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step250050.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -3.21       |
# |    mean_error_on_reach  | 1.66e-05    |
# |    mean_kterm_on_reach  | 109         |
# |    reached_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 2487        |
# |    iterations           | 130         |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 265200      |
# | train/                  |             |
# |    approx_kl            | 0.012331515 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 0.0567      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | -3.15       |
# |    mean_error_on_reach  | 1.66e-05    |
# |    mean_kterm_on_reach  | 115         |
# |    reached_rate         | 0.15        |
# | time/                   |             |
# |    fps                  | 2498        |
# |    iterations           | 140         |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.013860671 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00699     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step300060.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -3.23       |
# |    mean_error_on_reach  | 1.66e-05    |
# |    mean_kterm_on_reach  | 119         |
# |    reached_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 2498        |
# |    iterations           | 150         |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.009123872 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.021       |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 0.00544     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -3.23       |
# |    mean_error_on_reach  | 1.67e-05    |
# |    mean_kterm_on_reach  | 127         |
# |    reached_rate         | 0.11        |
# | time/                   |             |
# |    fps                  | 2494        |
# |    iterations           | 160         |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 326400      |
# | train/                  |             |
# |    approx_kl            | 0.014758371 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0747      |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 0.0821      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -1.28       |
# |    mean_error_on_reach  | 1.31e-05    |
# |    mean_kterm_on_reach  | 119         |
# |    reached_rate         | 0.71        |
# | time/                   |             |
# |    fps                  | 2494        |
# |    iterations           | 170         |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 346800      |
# | train/                  |             |
# |    approx_kl            | 0.008539612 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0446      |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 0.1         |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step350070.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | -0.953       |
# |    mean_error_on_reach  | 7.77e-06     |
# |    mean_kterm_on_reach  | 47.3         |
# |    reached_rate         | 0.78         |
# | time/                   |              |
# |    fps                  | 2494         |
# |    iterations           | 180          |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 367200       |
# | train/                  |              |
# |    approx_kl            | 0.0067876847 |
# |    clip_fraction        | 0.088        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0196       |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.0777       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -0.899      |
# |    mean_error_on_reach  | 3.28e-06    |
# |    mean_kterm_on_reach  | 59.6        |
# |    reached_rate         | 0.82        |
# | time/                   |             |
# |    fps                  | 2495        |
# |    iterations           | 190         |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 387600      |
# | train/                  |             |
# |    approx_kl            | 0.009054205 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0027      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step400080.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | -1.72        |
# |    mean_error_on_reach  | 3.42e-06     |
# |    mean_kterm_on_reach  | 73.1         |
# |    reached_rate         | 0.58         |
# | time/                   |              |
# |    fps                  | 2492         |
# |    iterations           | 200          |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 408000       |
# | train/                  |              |
# |    approx_kl            | 0.0027081924 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0628       |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 0.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -2.73        |
# |    mean_error_on_reach  | 3.42e-06     |
# |    mean_kterm_on_reach  | 83.6         |
# |    reached_rate         | 0.27         |
# | time/                   |              |
# |    fps                  | 2498         |
# |    iterations           | 210          |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 428400       |
# | train/                  |              |
# |    approx_kl            | 0.0035464303 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | -0.0189      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0832       |
# |    n_updates            | 2090         |
# |    policy_gradient_loss | -2.45e-05    |
# |    value_loss           | 0.0934       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 457         |
# |    ep_rew_mean          | -3.11       |
# |    mean_error_on_reach  | 3.42e-06    |
# |    mean_kterm_on_reach  | 109         |
# |    reached_rate         | 0.18        |
# | time/                   |             |
# |    fps                  | 2504        |
# |    iterations           | 220         |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 448800      |
# | train/                  |             |
# |    approx_kl            | 0.008658867 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0828      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00542     |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | 0.00326     |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step450090.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 459         |
# |    ep_rew_mean          | -3.13       |
# |    mean_error_on_reach  | 3.48e-06    |
# |    mean_kterm_on_reach  | 112         |
# |    reached_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 2506        |
# |    iterations           | 230         |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 469200      |
# | train/                  |             |
# |    approx_kl            | 0.010687591 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00728     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 0.0285      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 463         |
# |    ep_rew_mean          | -3.18       |
# |    mean_error_on_reach  | 4.47e-06    |
# |    mean_kterm_on_reach  | 118         |
# |    reached_rate         | 0.13        |
# | time/                   |             |
# |    fps                  | 2511        |
# |    iterations           | 240         |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 489600      |
# | train/                  |             |
# |    approx_kl            | 0.008119626 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00809    |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 0.0562      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step500100.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | -2.66       |
# |    mean_error_on_reach  | 8.46e-06    |
# |    mean_kterm_on_reach  | 127         |
# |    reached_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 2509        |
# |    iterations           | 250         |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 510000      |
# | train/                  |             |
# |    approx_kl            | 0.006391962 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00785    |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 0.0406      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | -2.19       |
# |    mean_error_on_reach  | 1.37e-05    |
# |    mean_kterm_on_reach  | 119         |
# |    reached_rate         | 0.41        |
# | time/                   |             |
# |    fps                  | 2510        |
# |    iterations           | 260         |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 530400      |
# | train/                  |             |
# |    approx_kl            | 0.007940934 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00186     |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 0.0638      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step550110.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | -2.13        |
# |    mean_error_on_reach  | 1.55e-05     |
# |    mean_kterm_on_reach  | 106          |
# |    reached_rate         | 0.43         |
# | time/                   |              |
# |    fps                  | 2508         |
# |    iterations           | 270          |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 550800       |
# | train/                  |              |
# |    approx_kl            | 0.0076700817 |
# |    clip_fraction        | 0.0828       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0325       |
# |    n_updates            | 2690         |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 0.041        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -2.28        |
# |    mean_error_on_reach  | 1.65e-05     |
# |    mean_kterm_on_reach  | 72.7         |
# |    reached_rate         | 0.4          |
# | time/                   |              |
# |    fps                  | 2509         |
# |    iterations           | 280          |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 571200       |
# | train/                  |              |
# |    approx_kl            | 0.0030945672 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00444     |
# |    n_updates            | 2790         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 0.0282       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | -2.11       |
# |    mean_error_on_reach  | 1.27e-05    |
# |    mean_kterm_on_reach  | 76.6        |
# |    reached_rate         | 0.45        |
# | time/                   |             |
# |    fps                  | 2510        |
# |    iterations           | 290         |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 591600      |
# | train/                  |             |
# |    approx_kl            | 0.022527074 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0119      |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 0.0272      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step600120.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | -1.09       |
# |    mean_error_on_reach  | 6.07e-06    |
# |    mean_kterm_on_reach  | 58.7        |
# |    reached_rate         | 0.74        |
# | time/                   |             |
# |    fps                  | 2506        |
# |    iterations           | 300         |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 612000      |
# | train/                  |             |
# |    approx_kl            | 0.005992172 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0484      |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 0.0953      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.6        |
# |    ep_rew_mean          | -0.473      |
# |    mean_error_on_reach  | 2.76e-06    |
# |    mean_kterm_on_reach  | 19.6        |
# |    reached_rate         | 0.89        |
# | time/                   |             |
# |    fps                  | 2505        |
# |    iterations           | 310         |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 632400      |
# | train/                  |             |
# |    approx_kl            | 0.005766487 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0498      |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 0.0976      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step650130.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | -0.301      |
# |    mean_error_on_reach  | 2.07e-06    |
# |    mean_kterm_on_reach  | 19.1        |
# |    reached_rate         | 0.94        |
# | time/                   |             |
# |    fps                  | 2493        |
# |    iterations           | 320         |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 652800      |
# | train/                  |             |
# |    approx_kl            | 0.005168784 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0708      |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | 0.000689    |
# |    value_loss           | 0.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | -0.271      |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 12.9        |
# |    reached_rate         | 0.94        |
# | time/                   |             |
# |    fps                  | 2490        |
# |    iterations           | 330         |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 673200      |
# | train/                  |             |
# |    approx_kl            | 0.009116065 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 0.0845      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.7        |
# |    ep_rew_mean          | -0.103      |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 13.8        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 2484        |
# |    iterations           | 340         |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 693600      |
# | train/                  |             |
# |    approx_kl            | 0.029088715 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00525    |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 0.00835     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step700140.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.95        |
# |    ep_rew_mean          | -0.0499     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 9.95        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 2468        |
# |    iterations           | 350         |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 714000      |
# | train/                  |             |
# |    approx_kl            | 0.010841447 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0936      |
# |    n_updates            | 3490        |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.82        |
# |    ep_rew_mean          | -0.0442     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 8.82        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 2459        |
# |    iterations           | 360         |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.012935155 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | 0.00157     |
# |    value_loss           | 0.00548     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step750150.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | -0.186      |
# |    mean_error_on_reach  | 1.55e-06    |
# |    mean_kterm_on_reach  | 9.58        |
# |    reached_rate         | 0.96        |
# | time/                   |             |
# |    fps                  | 2450        |
# |    iterations           | 370         |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 754800      |
# | train/                  |             |
# |    approx_kl            | 0.011805241 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.9        |
# |    ep_rew_mean          | -0.0945     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 11.9        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 2446        |
# |    iterations           | 380         |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 775200      |
# | train/                  |             |
# |    approx_kl            | 0.052355465 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0171     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 0.0393      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.9         |
# |    ep_rew_mean          | -0.355       |
# |    mean_error_on_reach  | 1.3e-06      |
# |    mean_kterm_on_reach  | 8.72         |
# |    reached_rate         | 0.91         |
# | time/                   |              |
# |    fps                  | 2445         |
# |    iterations           | 390          |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 795600       |
# | train/                  |              |
# |    approx_kl            | 0.0040609064 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0426       |
# |    n_updates            | 3890         |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 0.0974       |
# ------------------------------------------
# Saved: trajectories_tstar2_step_step800160.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | -0.0744     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 7.96        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 2443        |
# |    iterations           | 400         |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 816000      |
# | train/                  |             |
# |    approx_kl            | 0.014618609 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 0.00496     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | -0.875       |
# |    mean_error_on_reach  | 1.55e-06     |
# |    mean_kterm_on_reach  | 8.74         |
# |    reached_rate         | 0.76         |
# | time/                   |              |
# |    fps                  | 2442         |
# |    iterations           | 410          |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 836400       |
# | train/                  |              |
# |    approx_kl            | 0.0053522494 |
# |    clip_fraction        | 0.0847       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0368       |
# |    n_updates            | 4090         |
# |    policy_gradient_loss | 0.00138      |
# |    value_loss           | 0.0909       |
# ------------------------------------------
# Saved: trajectories_tstar2_step_step850170.png
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.5       |
# |    ep_rew_mean          | -0.0825    |
# |    mean_error_on_reach  | 1.3e-06    |
# |    mean_kterm_on_reach  | 9.56       |
# |    reached_rate         | 0.99       |
# | time/                   |            |
# |    fps                  | 2440       |
# |    iterations           | 420        |
# |    time_elapsed         | 351        |
# |    total_timesteps      | 856800     |
# | train/                  |            |
# |    approx_kl            | 0.05134109 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.65      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00523   |
# |    n_updates            | 4190       |
# |    policy_gradient_loss | 0.00121    |
# |    value_loss           | 0.0121     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.83        |
# |    ep_rew_mean          | -0.0393     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 7.83        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 2438        |
# |    iterations           | 430         |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 877200      |
# | train/                  |             |
# |    approx_kl            | 0.012799345 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | -0.0664     |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 6.31        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 2435        |
# |    iterations           | 440         |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 897600      |
# | train/                  |             |
# |    approx_kl            | 0.014956907 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0577      |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 0.0329      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step900180.png
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.8       |
# |    ep_rew_mean          | -0.309     |
# |    mean_error_on_reach  | 1.3e-06    |
# |    mean_kterm_on_reach  | 6.32       |
# |    reached_rate         | 0.92       |
# | time/                   |            |
# |    fps                  | 2432       |
# |    iterations           | 450        |
# |    time_elapsed         | 377        |
# |    total_timesteps      | 918000     |
# | train/                  |            |
# |    approx_kl            | 0.08396544 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.591     |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.29       |
# |    n_updates            | 4490       |
# |    policy_gradient_loss | 0.0146     |
# |    value_loss           | 0.0326     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | -0.171      |
# |    mean_error_on_reach  | 1.3e-06     |
# |    mean_kterm_on_reach  | 6.37        |
# |    reached_rate         | 0.96        |
# | time/                   |             |
# |    fps                  | 2432        |
# |    iterations           | 460         |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 938400      |
# | train/                  |             |
# |    approx_kl            | 0.014732039 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0607      |
# |    n_updates            | 4590        |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 0.137       |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step950190.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.8         |
# |    ep_rew_mean          | -0.239       |
# |    mean_error_on_reach  | 1.3e-06      |
# |    mean_kterm_on_reach  | 6.18         |
# |    reached_rate         | 0.94         |
# | time/                   |              |
# |    fps                  | 2430         |
# |    iterations           | 470          |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 958800       |
# ...
# |    total_timesteps      | 4692000     |
# | train/                  |             |
# |    approx_kl            | 0.010238524 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 6.5e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00869     |
# |    n_updates            | 22990       |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 1.15e-05    |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step4700940.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2255        |
# |    iterations           | 2310        |
# |    time_elapsed         | 2089        |
# |    total_timesteps      | 4712400     |
# | train/                  |             |
# |    approx_kl            | 0.011381372 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 2.56e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00779     |
# |    n_updates            | 23090       |
# |    policy_gradient_loss | -0.000747   |
# |    value_loss           | 5.8e-06     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -3.5       |
# |    mean_error_on_reach  | 4.24e-06   |
# |    mean_kterm_on_reach  | 21.2       |
# |    reached_rate         | 0          |
# | time/                   |            |
# |    fps                  | 2256       |
# |    iterations           | 2320       |
# |    time_elapsed         | 2097       |
# |    total_timesteps      | 4732800    |
# | train/                  |            |
# |    approx_kl            | 0.01854327 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | -1.55e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.42e-09   |
# |    n_updates            | 23190      |
# |    policy_gradient_loss | -0.00172   |
# |    value_loss           | 8.74e-07   |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step4750950.png
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -3.5       |
# |    mean_error_on_reach  | 4.24e-06   |
# |    mean_kterm_on_reach  | 21.2       |
# |    reached_rate         | 0          |
# | time/                   |            |
# |    fps                  | 2256       |
# |    iterations           | 2330       |
# |    time_elapsed         | 2106       |
# |    total_timesteps      | 4753200    |
# | train/                  |            |
# |    approx_kl            | 0.01633621 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 3.76e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0115     |
# |    n_updates            | 23290      |
# |    policy_gradient_loss | -0.0082    |
# |    value_loss           | 1.6e-05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -3.5         |
# |    mean_error_on_reach  | 4.24e-06     |
# |    mean_kterm_on_reach  | 21.2         |
# |    reached_rate         | 0            |
# | time/                   |              |
# |    fps                  | 2257         |
# |    iterations           | 2340         |
# |    time_elapsed         | 2114         |
# |    total_timesteps      | 4773600      |
# | train/                  |              |
# |    approx_kl            | 0.0073836786 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 1.78e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0104      |
# |    n_updates            | 23390        |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 7.25e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2258        |
# |    iterations           | 2350        |
# |    time_elapsed         | 2122        |
# |    total_timesteps      | 4794000     |
# | train/                  |             |
# |    approx_kl            | 0.009894937 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00282    |
# |    n_updates            | 23490       |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 6.43e-06    |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step4800960.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2259        |
# |    iterations           | 2360        |
# |    time_elapsed         | 2130        |
# |    total_timesteps      | 4814400     |
# | train/                  |             |
# |    approx_kl            | 0.015312726 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.34e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 23590       |
# |    policy_gradient_loss | 0.00105     |
# |    value_loss           | 1.51e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -3.5         |
# |    mean_error_on_reach  | 4.24e-06     |
# |    mean_kterm_on_reach  | 21.2         |
# |    reached_rate         | 0            |
# | time/                   |              |
# |    fps                  | 2260         |
# |    iterations           | 2370         |
# |    time_elapsed         | 2138         |
# |    total_timesteps      | 4834800      |
# | train/                  |              |
# |    approx_kl            | 0.0064177825 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 9.78e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0149       |
# |    n_updates            | 23690        |
# |    policy_gradient_loss | -0.000623    |
# |    value_loss           | 7.92e-06     |
# ------------------------------------------
# Saved: trajectories_tstar2_step_step4850970.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2261        |
# |    iterations           | 2380        |
# |    time_elapsed         | 2146        |
# |    total_timesteps      | 4855200     |
# | train/                  |             |
# |    approx_kl            | 0.015792996 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -2.55e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 23790       |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 3.87e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2262        |
# |    iterations           | 2390        |
# |    time_elapsed         | 2154        |
# |    total_timesteps      | 4875600     |
# | train/                  |             |
# |    approx_kl            | 0.007865095 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -2.74e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00852     |
# |    n_updates            | 23890       |
# |    policy_gradient_loss | 0.000932    |
# |    value_loss           | 2.53e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2264        |
# |    iterations           | 2400        |
# |    time_elapsed         | 2162        |
# |    total_timesteps      | 4896000     |
# | train/                  |             |
# |    approx_kl            | 0.006162954 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -8.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00543    |
# |    n_updates            | 23990       |
# |    policy_gradient_loss | 0.000897    |
# |    value_loss           | 4.09e-06    |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step4900980.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2265        |
# |    iterations           | 2410        |
# |    time_elapsed         | 2170        |
# |    total_timesteps      | 4916400     |
# | train/                  |             |
# |    approx_kl            | 0.013508349 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -1.66e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0269     |
# |    n_updates            | 24090       |
# |    policy_gradient_loss | -0.000762   |
# |    value_loss           | 7.53e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2266        |
# |    iterations           | 2420        |
# |    time_elapsed         | 2178        |
# |    total_timesteps      | 4936800     |
# | train/                  |             |
# |    approx_kl            | 0.009457856 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0138      |
# |    n_updates            | 24190       |
# |    policy_gradient_loss | -0.000162   |
# |    value_loss           | 2.35e-06    |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step4950990.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2267        |
# |    iterations           | 2430        |
# |    time_elapsed         | 2186        |
# |    total_timesteps      | 4957200     |
# | train/                  |             |
# |    approx_kl            | 0.010856751 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 3.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 24290       |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 1.27e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -3.5        |
# |    mean_error_on_reach  | 4.24e-06    |
# |    mean_kterm_on_reach  | 21.2        |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 2268        |
# |    iterations           | 2440        |
# |    time_elapsed         | 2194        |
# |    total_timesteps      | 4977600     |
# | train/                  |             |
# |    approx_kl            | 0.004604157 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00799    |
# |    n_updates            | 24390       |
# |    policy_gradient_loss | 0.000237    |
# |    value_loss           | 3.52e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -3.5         |
# |    mean_error_on_reach  | 4.24e-06     |
# |    mean_kterm_on_reach  | 21.2         |
# |    reached_rate         | 0            |
# | time/                   |              |
# |    fps                  | 2269         |
# |    iterations           | 2450         |
# |    time_elapsed         | 2202         |
# |    total_timesteps      | 4998000      |
# | train/                  |              |
# |    approx_kl            | 0.0069546737 |
# |    clip_fraction        | 0.0825       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000216     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000283     |
# |    n_updates            | 24490        |
# |    policy_gradient_loss | 0.00116      |
# |    value_loss           | 6.4e-07      |
# ------------------------------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
obs, _ = env.reset()
trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, info = env.step(action)
    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))
        
visited_log = [(x, t) for (x, t, _) in env.visited._pts]
fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = cm.tab10.colors
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    ax.plot(xs, ts, '-',  linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# ── Use logged stencils instead of post-hoc reconstruction ───────────────────
stencils = {key: coords for key, coords in env.stencil_log.items()}

# ── Build plot ───────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 7))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors     = cm.tab10.colors
all_points = []

for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    ax.plot(xs, ts, '-',  linewidth=1.5, zorder=2)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^',
               zorder=4, label=f'Walker {i}')
    for (x, t) in traj[1:]:
        ax.scatter(x, t, s=60, color=colors[i], zorder=3)
        all_points.append((x, t, i))

ax.scatter(env.x_star, env.t_star, s=200, color='red',
           marker='*', zorder=5, label='z*')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Click any walker point to see its GFDM stencil')
ax.legend()
plt.tight_layout()

active_lines = []

def on_click(event):
    global active_lines

    if event.inaxes != ax or not all_points:
        return

    cx, ct  = event.xdata, event.ydata
    best_pt = min(all_points,
                  key=lambda p: ((p[0]-cx)/env.dx)**2 + ((p[1]-ct)/env.dt)**2)
    x, t, i = best_pt
    key     = (round(x, 8), round(t, 8))

    for line in active_lines:
        line.remove()
    active_lines = []

    if key in stencils:
        for (nx, nt) in stencils[key]:
            colors = plt.cm.viridis(np.linspace(0, 1, env.N))
            line, = ax.plot([x, nx], [t, nt], '--' , alpha=0.75,
                            linewidth=2, zorder=2)
            active_lines.append(line)

        dot, = ax.plot(x, t, 'o',
                       markersize=10, markeredgecolor='black',
                       markeredgewidth=1.5, zorder=6)
        active_lines.append(dot)

    fig.canvas.draw_idle()

fig.canvas.mpl_connect('button_press_event', on_click)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
env = PDEEnvironment()
env.reset()

# Force specific known actions and check they decode correctly
test_actions = [
    [0, 0, 1],   # walker 0, dx=-dx, dt=+dt  — should move left+forward
    [0, 2, 1],   # walker 0, dx=+dx, dt=+dt  — should move right+forward
    [0, 1, 0],   # walker 0, dx=0,   dt=0    — always rejected (no-op)
    [5, 2, 1],   # walker 5, dx=+dx, dt=+dt
]

for a in test_actions:
    env.reset()
    obs, reward, done, _, info = env.step(a)
    print(f"action={a} | walker={info['walker']} | accepted={info['accepted']} | rejected={info['rejected']}")
    if info['accepted']:
        i = info['walker']
        print(f"  → walker {i} now at x={env.walker_x[i]:.4f}, t={env.walker_t[i]:.4f}")
# Out:
# action=[0, 0, 1] | walker=0 | accepted=True | rejected=None
#   → walker 0 now at x=0.4828, t=0.0105
# action=[0, 2, 1] | walker=0 | accepted=True | rejected=None
#   → walker 0 now at x=0.5517, t=0.0105
# action=[0, 1, 0] | walker=0 | accepted=False | rejected=bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 14
#      12 for a in test_actions:
#      13     env.reset()
# ---> 14     obs, reward, done, _, info = env.step(a)
#      15     print(f"action={a} | walker={info['walker']} | accepted={info['accepted']} | rejected={info['rejected']}")
#      16     if info['accepted']:
#
# Cell In[29], line 143, in PDEEnvironment.step(self, action)
#     139 dt = int(dt_idx) * self.dt
#     141 info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}
# --> 143 x_new = self.walker_x[i] + dx
#     144 t_new = self.walker_t[i] + dt
#     146 if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
#
# IndexError: index 5 is out of bounds for axis 0 with size 3
