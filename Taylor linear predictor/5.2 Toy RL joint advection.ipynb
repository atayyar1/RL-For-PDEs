# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE
alpha = 0.05
c     = 0.5          # advection velocity

#   FD reference grid   
nx    = 20
T     = 0.6
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = min(0.45 * dx**2 / alpha, 0.9 * dx / abs(c))   # diffusive AND advective CFL
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

#  True solution; analytical advection-diffusion via exponential shift + Fourier sine series
_lam_shift = c / (2 * alpha)      # NOTE: named _lam_shift, not `beta` — cell 18 defines
_N_SERIES  = 200                  #       beta=1000 for the RL reward; reusing that name
                                   #       here would get silently overwritten at call time
_xq = np.linspace(0.0, 1.0, 20001)
_b  = np.zeros(_N_SERIES + 1)
for n in range(1, _N_SERIES + 1):
    integrand = np.exp(-_lam_shift * _xq) * np.sin(np.pi * _xq) * np.sin(n * np.pi * _xq)
    _b[n] = 2.0 * np.trapezoid(integrand, _xq)   # use np.trapz instead if numpy < 2.0

_n_arr = np.arange(1, _N_SERIES + 1)
_bn    = _b[1:]
_decay = -alpha * (_n_arr * np.pi) ** 2

def u_true(x, t):
    x = np.asarray(x, dtype=float)
    scalar = x.ndim == 0
    x = np.atleast_1d(x)
    sin_nx = np.sin(np.pi * np.outer(x, _n_arr))
    exp_t  = np.exp(_decay * t)
    s      = (sin_nx * (_bn * exp_t)).sum(axis=-1)
    result = np.exp(_lam_shift * x - (c**2 / (4 * alpha)) * t) * s
    return float(result[0]) if scalar else result

# %% [markdown]
# ### FD For advection

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2
    r_adv  = c     * dt / dx        # <-- was missing

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         - r_adv  * (un[1:-1] - un[:-2])   # <-- upwind advection term (correct for c>0)
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
        bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ## Solve Weights Advection

# %%
# NOTE (jo-exploration): corrected u_xx row. Substituting u_t = alpha u_xx - c u_x
# RECURSIVELY also reduces u_xt and u_tt to x-derivatives, contributing
# -c dx dt + 0.5 c^2 dt^2. The exact u_xx coefficient is therefore
#     0.5*(dx - c dt)^2 + alpha*dt      [ = 0.5*xi^2 + alpha*dt, xi = dx - c dt ]
# The previous row 0.5*dx^2 + alpha*dt drops both terms. Harmless when |c dt|<<|dx|,
# but it cannot express a 2nd-order advection scheme: with the correction the
# 3-point centred stencil is exactly Lax-Wendroff; without it, FTCS-central
# (unconditionally unstable). Verified symbolically.
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        (dx_i - c * dt_i) / h,      # <-- was dx_i / h
        (0.5 * (dx_i - c * dt_i)**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])
    w = np.linalg.lstsq(A, b, rcond=None)[0]
    if abs(w.sum() - 1.0) > 1e-6:       # jo-exploration: rank-deficient A
        return None, 'inconsistent'
 

    cond = np.linalg.cond(A)
    #if cond > 1e4:
    #    return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()               
        self.rejected_history = []  # (x, t) per rejected move
    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))  
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()
    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0
    def contains(self, x, t):                    
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None
            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)
            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None
            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]
            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# ### PDEEnvironment

# %%
class PDEEnvironment(gym.Env):
    # only allow up
    #ACTIONS = {0 :(0,1), 1: (0,2) }  
    # can go diagonally up-left, up, or up-right
    ACTIONS = {0: (-1, 1),   # up-left
 
               1: ( 0, 1),   # straight forward
 
               2: ( 1, 1),   # up-right
              }
    def __init__(self, t_star_steps=2, N_particles=27, lam=0.001, beta=100.0, K_max=500 ):
        super().__init__()

        #   PDE constants  
        self.alpha = alpha

        #G6id variables  
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T
 
        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = K_max
        self.lam    = lam
        self.beta = beta

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions  ────────────────────────────────────────────
        self.N = N_particles

        mid    = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets= [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(3 * self.N + 2,), dtype=np.float32
        )
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))



    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_set = set()
        return self._build_obs(), {}


    def _build_obs(self):
        return np.array([
            *self.walker_x,
            *self.walker_t,
            *self.walker_u,
            self.x_star,
            self.t_star
        ], dtype=np.float32)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        if not (np.min(dx_i) < 0 < np.max(dx_i)):
            return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'
    def step(self, action):

            self.step_count += 1
            done   = False
            reward = 0.0

            i              = int(action) // len(self.ACTIONS)
            j              = int(action) % len(self.ACTIONS)
            dx_idx, dt_idx = self.ACTIONS[j]
            dx_move = dx_idx * self.dx
            dt_move = dt_idx * self.dt

            info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

            x_new = self.walker_x[i] + dx_move
            t_new = self.walker_t[i] + dt_move

            if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
                info['rejected'] = 'bounds'

            elif self.visited.contains(x_new, t_new):
                info['rejected'] = 'collision'

            else:
                u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
                if not success:
                    info['rejected'] = reason
                    self.gfdm_rejected_set.add(int(action))
                    
                else:
                    self.gfdm_rejected_set.clear()
                    self.visited.add(x_new, t_new, u_hat)
                    self.walker_x[i] = x_new
                    self.walker_t[i] = t_new
                    self.walker_u[i] = u_hat
                    self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                    info['accepted'] = True

                    if (abs(x_new - self.x_star) < self.eps_x and
                        abs(t_new - self.t_star) < self.eps_t):
                        done = True
                        info['reached'] = True

            # ── track rejected positions ──────────────────────────────────────────
            if not info['accepted']:
                self.rejected_history.append((x_new, t_new, info['rejected']))
            # ─────────────────────────────────────────────────────────────────────

            if done:
                u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
                u_ref           = u_true(self.x_star, self.t_star)

                if u_pred is None:
                    reward        = -1.0
                    info['error'] = None
                else:
                    reward = -(self.beta * abs(u_pred - u_ref) + self.lam * self.step_count)
                    info['u_pred'] = u_pred
                    info['u_ref']  = u_ref
                    info['error']  = abs(u_pred - u_ref)
                    info['k_term'] = self.step_count

            elif self.step_count >= self.K_max:
                done = True
                reward = -1.0 - self.lam * self.step_count
                info['timeout'] = True

            return self._build_obs(), reward, done, False, info
    def action_masks(self) -> np.ndarray:
        mask = np.ones(self.N * len(self.ACTIONS), dtype=bool)
        for i in range(self.N):
            for j in range(len(self.ACTIONS)):
                dx_idx, dt_idx = self.ACTIONS[j]
                x_new = self.walker_x[i] + dx_idx * self.dx
                t_new = self.walker_t[i] + dt_idx * self.dt
                if not (0.0 <= x_new <= 1.0 and
                        0.0 < t_new <= 1.5 * self.t_star and
                        not self.visited.contains(x_new, t_new)):
                    mask[i * len(self.ACTIONS) + j] = False
        for a in self.gfdm_rejected_set:
            mask[a] = False
        if not mask.any():
            mask[:] = True
        return mask

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
t_star_steps = 15  # ← change this to test different targets
env      = PDEEnvironment(t_star_steps=t_star_steps)
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()
    state, reward, done, _, info = env.step(action)



    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts
               if t > 0.0 and 0.0 < x < 1.0]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")

for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")
# walker distribution check — tells you if one walker is dominating
walker_counts = {}
for i, traj in trajectories.items():
    walker_counts[i] = len(traj) - 1  # subtract starting position
print("\nAccepted moves per walker:")
for i, count in sorted(walker_counts.items()):
    print(f"  Walker {i:d}: {count}")

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          500
# Reward:         -1.500000
# Reached:        False
# Timeout:        True
# Total accepted: 168
# Total rejected: 332
# Rejection reasons:
#   collision : 285
#   geometry  : 47
#
# Accepted moves per walker:
#   Walker 0: 0
#   Walker 1: 20
#   Walker 2: 15
#   Walker 3: 0
#   Walker 4: 0
#   Walker 5: 1
#   Walker 6: 15
#   Walker 7: 9
#   Walker 8: 0
#   Walker 9: 0
#   Walker 10: 13
#   Walker 11: 7
#   Walker 12: 6
#   Walker 13: 14
#   Walker 14: 0
#   Walker 15: 4
#   Walker 16: 10
#   Walker 17: 0
#   Walker 18: 4
#   Walker 19: 13
#   Walker 20: 0
#   Walker 21: 10
#   Walker 22: 9
#   Walker 23: 9
#   Walker 24: 1
#   Walker 25: 0
#   Walker 26: 8

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps,N_particles, save=True, timestep=None,
                      img_dir=".", label=None):
    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1)

    # ── Rejected positions ───────────────────────────────────────────────────
    rej_colors = {
        'bounds':    'blue',
        'collision': 'orange',
        'cond':      'purple',
        'weights':   'brown',
        'geometry':  'red',
        None:        'gray',
    }
    if env.rejected_history:
        from collections import defaultdict
        by_reason = defaultdict(list)
        for (rx, rt, reason) in env.rejected_history:
            by_reason[reason].append((rx, rt))
        for reason, pts in by_reason.items():
            ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                       s=6, alpha=0.08, linewidths=0, zorder=1,
                       color=rej_colors.get(reason, 'gray'),
                       label=f'rej:{reason} ({len(pts)})')
    # ─────────────────────────────────────────────────────────────────────────

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, color=colors[i], zorder=2)
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4)

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'

    # ── Stencil at z* ────────────────────────────────────────────────────────
    if reached:
        _, success, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star)
        if success and nb_coords is not None:
            for (nx_, nt_) in nb_coords:
                ax.plot([env.x_star, nx_], [env.t_star, nt_],
                        '--', color='red', linewidth=0.8,
                        alpha=0.7, zorder=5)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1],
                       s=40, color='red', zorder=6, alpha=0.7)

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=7)
    ax.set_xlabel('x')
    ax.set_ylabel('t')

    title = f't_star={t_star_steps}·dt  |  {outcome}'
    if timestep is not None:
        title += f'  |  step {timestep:,}'
    ax.set_title(title)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)

    if env.rejected_history:
        ax.legend(fontsize=6, loc='upper left', markerscale=2)

    plt.tight_layout()

    if save:
        if label is not None:
            fname = f'traj_t{t_star_steps}dt_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120)

    plt.close(fig)

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps,N_particles, plot_freq=50_000, img_dir=".", verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles = N_particles
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles, save=True,
                              timestep=self.num_timesteps, img_dir=self.img_dir)
        return True


def make_env(t_star_steps, N_particles, lam, beta, K_max):
    def _init():
        env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles, lam=lam, beta=beta, K_max=K_max)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
# ── Run configuration ────────────────────────────────────────────────────────
N_particles     = 25
curriculum      = [10]
seeds           = [6,7]
lam             = 0.001
beta            = 1000
K_max           = 500
n_envs          = 15
n_steps         = 2048 // n_envs
total_timesteps = 5_000_000

# ── Run directory ────────────────────────────────────────────────────────────
day      = date.today().day
stages_str = "-".join(str(s) for s in curriculum)
run_name = f"t{stages_str}_lam{lam}_beta{beta}_K{K_max}_N{N_particles},geometry_constrained"
run_dir  = os.path.join(f"runs_adv{day}", run_name)

print(f"Run: {run_dir}")
for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    vec_env = SubprocVecEnv([make_env(curriculum[0], N_particles, lam, beta, K_max)
                             for _ in range(n_envs)])
    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=5e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=60,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    for t_star_steps in curriculum:
        print(f"\n{'='*50}")
        print(f"Stage: t* = {t_star_steps}·dt = {t_star_steps * dt:.4f}  |  budget: {total_timesteps//1000}k steps")
        print(f"{'='*50}")

        vec_env = SubprocVecEnv([make_env(t_star_steps, N_particles, lam, beta, K_max)
                                 for _ in range(n_envs)])
        model.set_env(vec_env)

        model.learn(
            total_timesteps=total_timesteps,
            reset_num_timesteps=False,
            tb_log_name=f"seed{seed}",
            log_interval=10,
            callback=[
                ReachedRateCallback(),
                PlotCallback(t_star_steps, N_particles, plot_freq=100_000, img_dir=img_dir),
                CheckpointCallback(
                    save_freq=100_000,
                    save_path=os.path.join(ckpt_dir, f"tstar{t_star_steps}"),
                    name_prefix=f"tstar{t_star_steps}"
                ),
            ],
        )

        model.save(os.path.join(ckpt_dir, f"tstar{t_star_steps}_final"))

        plot_trajectories(
            model, t_star_steps, N_particles,
            save=True, timestep=None, img_dir=img_dir, label="final")

        make_trajectory_video(model, PDEEnvironment, t_star_steps, N_particles, img_dir=img_dir)
        make_training_progress_video(img_dir=img_dir,t_star_steps=t_star_steps,fps=3)
# Out:
# Run: runs_adv8\t5_lam0.001_beta1000_K400_N25,geometry_constrained
#
# ##################################################
# SEED 6
# ##################################################
# Using cpu device
#
# ==================================================
# Stage: t* = 5·dt = 0.1200  |  budget: 1000k steps
# ==================================================
# Logging to runs_adv8\t5_lam0.001_beta1000_K400_N25,geometry_constrained\seed6\logs\seed6_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 168         |
# |    ep_rew_mean          | -4.2        |
# |    mean_error_on_reach  | 0.00553     |
# |    mean_kterm_on_reach  | 72.1        |
# |    reached_rate         | 0.71        |
# | time/                   |             |
# |    fps                  | 1937        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.005229093 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0376      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.289       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 189        |
# |    ep_rew_mean          | -3.67      |
# |    mean_error_on_reach  | 0.00513    |
# |    mean_kterm_on_reach  | 74.6       |
# |    reached_rate         | 0.66       |
# | time/                   |            |
# |    fps                  | 1907       |
# |    iterations           | 20         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 40800      |
# | train/                  |            |
# |    approx_kl            | 0.00719237 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0711    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0224    |
# |    value_loss           | 0.0506     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | -3.43        |
# |    mean_error_on_reach  | 0.00518      |
# |    mean_kterm_on_reach  | 79.5         |
# |    reached_rate         | 0.54         |
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 30           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 61200        |
# | train/                  |              |
# |    approx_kl            | 0.0068127466 |
# |    clip_fraction        | 0.322        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.39        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0248      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0188      |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 247        |
# |    ep_rew_mean          | -3.07      |
# |    mean_error_on_reach  | 0.00491    |
# |    mean_kterm_on_reach  | 84         |
# |    reached_rate         | 0.49       |
# | time/                   |            |
# |    fps                  | 1911       |
# |    iterations           | 40         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 81600      |
# | train/                  |            |
# |    approx_kl            | 0.00906506 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | 0.672      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0379    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 0.0638     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | -3.35        |
# |    mean_error_on_reach  | 0.00577      |
# |    mean_kterm_on_reach  | 84.8         |
# |    reached_rate         | 0.39         |
# | time/                   |              |
# |    fps                  | 1908         |
# |    iterations           | 50           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 102000       |
# | train/                  |              |
# |    approx_kl            | 0.0058711558 |
# |    clip_fraction        | 0.285        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0283       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.359        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -3.27        |
# |    mean_error_on_reach  | 0.00558      |
# |    mean_kterm_on_reach  | 87.9         |
# |    reached_rate         | 0.52         |
# | time/                   |              |
# |    fps                  | 1905         |
# |    iterations           | 60           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 122400       |
# | train/                  |              |
# |    approx_kl            | 0.0061225793 |
# |    clip_fraction        | 0.297        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.518        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0135       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0169      |
# |    value_loss           | 0.339        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | -3.28       |
# |    mean_error_on_reach  | 0.00588     |
# |    mean_kterm_on_reach  | 88.9        |
# |    reached_rate         | 0.43        |
# | time/                   |             |
# |    fps                  | 1906        |
# |    iterations           | 70          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 142800      |
# | train/                  |             |
# |    approx_kl            | 0.008288734 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0334     |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.0661      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | -2.64       |
# |    mean_error_on_reach  | 0.00589     |
# |    mean_kterm_on_reach  | 86.7        |
# |    reached_rate         | 0.32        |
# | time/                   |             |
# |    fps                  | 1907        |
# |    iterations           | 80          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.008085118 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0202     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -2.34       |
# |    mean_error_on_reach  | 0.00514     |
# |    mean_kterm_on_reach  | 87.3        |
# |    reached_rate         | 0.32        |
# | time/                   |             |
# |    fps                  | 1908        |
# |    iterations           | 90          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.004836863 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.022       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0151     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.604       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | -2.53       |
# |    mean_error_on_reach  | 0.00505     |
# |    mean_kterm_on_reach  | 87.8        |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1900        |
# |    iterations           | 100         |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 204000      |
# | train/                  |             |
# |    approx_kl            | 0.007864386 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0384     |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | -2.68       |
# |    mean_error_on_reach  | 0.00517     |
# |    mean_kterm_on_reach  | 89.3        |
# |    reached_rate         | 0.35        |
# | time/                   |             |
# |    fps                  | 1896        |
# |    iterations           | 110         |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 224400      |
# | train/                  |             |
# |    approx_kl            | 0.009285201 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0416     |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.0685      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 290         |
# |    ep_rew_mean          | -2.56       |
# |    mean_error_on_reach  | 0.00484     |
# |    mean_kterm_on_reach  | 91.4        |
# |    reached_rate         | 0.36        |
# | time/                   |             |
# |    fps                  | 1893        |
# |    iterations           | 120         |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 244800      |
# | train/                  |             |
# |    approx_kl            | 0.009132951 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0525     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.0436      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | -2.56       |
# |    mean_error_on_reach  | 0.00502     |
# |    mean_kterm_on_reach  | 91.9        |
# |    reached_rate         | 0.38        |
# | time/                   |             |
# |    fps                  | 1884        |
# |    iterations           | 130         |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 265200      |
# | train/                  |             |
# |    approx_kl            | 0.019959878 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0477     |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 257         |
# |    ep_rew_mean          | -4.23       |
# |    mean_error_on_reach  | 0.0064      |
# |    mean_kterm_on_reach  | 87.5        |
# |    reached_rate         | 0.45        |
# | time/                   |             |
# |    fps                  | 1882        |
# |    iterations           | 140         |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.007113155 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.15        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.549       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | -4.9        |
# |    mean_error_on_reach  | 0.00792     |
# |    mean_kterm_on_reach  | 84.5        |
# |    reached_rate         | 0.6         |
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 150         |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.011348091 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0169     |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.0908      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | -4.01       |
# |    mean_error_on_reach  | 0.00799     |
# |    mean_kterm_on_reach  | 78.9        |
# |    reached_rate         | 0.4         |
# | time/                   |             |
# |    fps                  | 1880        |
# |    iterations           | 160         |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 326400      |
# | train/                  |             |
# |    approx_kl            | 0.011356726 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0546     |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00496     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | -2.34       |
# |    mean_error_on_reach  | 0.00675     |
# |    mean_kterm_on_reach  | 75.6        |
# |    reached_rate         | 0.4         |
# | time/                   |             |
# |    fps                  | 1882        |
# |    iterations           | 170         |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 346800      |
# | train/                  |             |
# |    approx_kl            | 0.008116755 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0478     |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.0337      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | -2.5        |
# |    mean_error_on_reach  | 0.00603     |
# |    mean_kterm_on_reach  | 80.8        |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1883        |
# |    iterations           | 180         |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 367200      |
# | train/                  |             |
# |    approx_kl            | 0.009457707 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0464     |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 290         |
# |    ep_rew_mean          | -3.13       |
# |    mean_error_on_reach  | 0.00558     |
# |    mean_kterm_on_reach  | 87          |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1884        |
# |    iterations           | 190         |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 387600      |
# | train/                  |             |
# |    approx_kl            | 0.010037605 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0168     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.0889      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | -4.06       |
# |    mean_error_on_reach  | 0.00599     |
# |    mean_kterm_on_reach  | 86.7        |
# |    reached_rate         | 0.38        |
# | time/                   |             |
# |    fps                  | 1882        |
# |    iterations           | 200         |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 408000      |
# | train/                  |             |
# |    approx_kl            | 0.007445132 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.282       |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.966       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -3.46       |
# |    mean_error_on_reach  | 0.00649     |
# |    mean_kterm_on_reach  | 85.8        |
# |    reached_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1884        |
# |    iterations           | 210         |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 428400      |
# | train/                  |             |
# |    approx_kl            | 0.005763654 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0215      |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 0.741       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | -2.06       |
# |    mean_error_on_reach  | 0.0066      |
# |    mean_kterm_on_reach  | 86.4        |
# |    reached_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 1884        |
# |    iterations           | 220         |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 448800      |
# | train/                  |             |
# |    approx_kl            | 0.006882715 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | -0.247      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0388     |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.000559    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | -2.06        |
# |    mean_error_on_reach  | 0.00696      |
# |    mean_kterm_on_reach  | 83.3         |
# |    reached_rate         | 0.19         |
# | time/                   |              |
# |    fps                  | 1882         |
# |    iterations           | 230          |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 469200       |
# | train/                  |              |
# |    approx_kl            | 0.0075272135 |
# |    clip_fraction        | 0.312        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.038       |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00553     |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 56
#      52         vec_env = SubprocVecEnv([make_env(t_star_steps, N_particles, lam, beta, K_max)
#      53                                  for _ in range(n_envs)])
#      54         model.set_env(vec_env)
#      55
# ---> 56         model.learn(
#      57             total_timesteps=total_timesteps,
#      58             reset_num_timesteps=False,
#      59             tb_log_name=f"seed{seed}",
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\sb3_contrib\ppo_mask\ppo_mask.py:465, in MaskablePPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, use_masking, progress_bar)
#     462     if log_interval is not None and iteration % log_interval == 0:
#     463         self.dump_logs(iteration)
# --> 465     self.train()
#     467 callback.on_training_end()
#     469 return self
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\sb3_contrib\ppo_mask\ppo_mask.py:408, in MaskablePPO.train(self)
#     406     # Clip grad norm
#     407     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 408     self.policy.optimizer.step()
#     410 self._n_updates += 1
#     411 if not continue_training:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\optimizer.py:535, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     530             raise RuntimeError(
#     531                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     532             )
#     534 # pyrefly: ignore [invalid-param-spec]
# --> 535 out = func(*args, **kwargs)
#     536 self._optimizer_step_code()
#     538 # call optimizer step post hooks
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\optimizer.py:80, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      78     torch.set_grad_enabled(self.defaults["differentiable"])
#      79     torch._dynamo.graph_break()
# ---> 80     ret = func(*args, **kwargs)
#      81 finally:
#      82     torch._dynamo.graph_break()
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\optimizer.py:148, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     146     return disabled_func(*args, **kwargs)
#     147 else:
# --> 148     return func(*args, **kwargs)
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\torch\optim\adam.py:475, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     471         exp_avg_sq.mul_(beta2).addcmul_(
#     472             grad, grad, value=cast(float, 1 - beta2)
#     473         )
#     474 else:
# --> 475     exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)  # type: ignore[arg-type]
#     477 if capturable or differentiable:
#     478     step = step_t
#
# KeyboardInterrupt:
