# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from trajectory_video2 import make_trajectory_video1
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE 
alpha = 0.05

#   FD reference grid   
nx    = 100
T     = 1
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

#  True solution; Analytical diffusion solution

def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# ### FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()               
        self.rejected_history = []  # (x, t) per rejected move
    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))  
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()
    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0
    def contains(self, x, t):                    
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None
            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)
            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None
            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]
            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# ### GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    #cond = np.linalg.cond(A)
    #if cond > 1e4:
    #    return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### PDEEnvironment

# %%
class PDEEnvironment(gym.Env):
    # only allow up
    #ACTIONS = {0 :(0,1), 1: (0,2) }  
    # can go diagonally up-left, up, or up-right
    ACTIONS = {0: (-1, 1),   # up-left
               1: ( -1, 2),   # up up left
               2: (-1, 3),   # up up up left


               3: ( 0, 1),   # straight forward
               4: ( 0, 2),   # straight forward forward
               5: ( 0, 3),   # straight forward forward forward

               6: ( 1, 1),   # up-right
               7: ( 1, 2),   # up-right-right
               8: ( 1, 3),   # up-right-right-right
             }
    def __init__(self, t_star_schedule=None, t_star_steps=2, N_particles=27,
                 lam=0.001, beta=100.0, K_max=500, c_shape=0.0,
                 x_star_idx=None, x_star_schedule=None):
        super().__init__()

        #   PDE constants  
        self.alpha = alpha
        self.c_shape = c_shape

        #G6id variables  
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T
 
        # ── t* schedule: dict {t_star_steps: K_max}. None → fixed single t*. ─────
        # When set, t* (and its matched K_max) is resampled every reset().
        self.t_star_schedule = dict(t_star_schedule) if t_star_schedule else None

        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star_steps = t_star_steps          # provisional; reset() may override
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = K_max
        self.lam    = lam
        self.beta = beta

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions  ────────────────────────────────────────────
        self.N = N_particles

        mid    = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets= [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(2 * self.N+1,), dtype=np.float32
        )
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))



    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        # ── Resample t* (and matched K_max) per episode if a schedule is set ─────
        if self.t_star_schedule is not None:
            choices = list(self.t_star_schedule.keys())
            self.t_star_steps = int(self.np_random.choice(choices))
            self.t_star = self.t_star_steps * self.dt
            self.K_max  = self.t_star_schedule[self.t_star_steps]
            
        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_set = set()
        self._phi_prev = self._potential()
        
        return self._build_obs(), {}


    def _build_obs(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        t_star_norm = self.t_star / self.dt   # = t_star_steps, horizon length in step units
        return np.array([
            *dx_rel,
            *dt_rel,
            t_star_norm,
        ], dtype=np.float32)
    
    def _potential(self):
        """Φ(s) = -c * mean normalized distance of walkers to z*.
        Uses the SAME normalization as _build_obs."""
        if self.c_shape == 0.0:
            return 0.0
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        d = np.sqrt(dx_rel**2 + dt_rel**2)
        return -self.c_shape * float(np.mean(d))

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        #if not (np.min(dx_i) < 0 < np.max(dx_i)):
        #    return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'
    def step(self, action):

            self.step_count += 1
            done   = False
            reward = 0.0

            i              = int(action) // len(self.ACTIONS)
            j              = int(action) % len(self.ACTIONS)
            dx_idx, dt_idx = self.ACTIONS[j]
            dx_move = dx_idx * self.dx
            dt_move = dt_idx * self.dt

            info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

            x_new = self.walker_x[i] + dx_move
            t_new = self.walker_t[i] + dt_move

            if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
                info['rejected'] = 'bounds'

            elif self.visited.contains(x_new, t_new):
                info['rejected'] = 'collision'

            else:
                u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
                if not success:
                    info['rejected'] = reason
                    self.gfdm_rejected_set.add(int(action))
                    
                else:
                    self.gfdm_rejected_set.clear()
                    self.visited.add(x_new, t_new, u_hat)
                    self.walker_x[i] = x_new
                    self.walker_t[i] = t_new
                    self.walker_u[i] = u_hat
                    self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                    info['accepted'] = True

                    if (abs(x_new - self.x_star) < self.eps_x and
                        abs(t_new - self.t_star) < self.eps_t):
                        done = True
                        info['reached'] = True

            # ── track rejected positions ──────────────────────────────────────────
            if not info['accepted']:
                self.rejected_history.append((x_new, t_new, info['rejected']))
            # ─────────────────────────────────────────────────────────────────────

            if done:
                u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
                u_ref           = u_true(self.x_star, self.t_star)

                worst_case_timeout = -1 - self.lam * self.K_max

                if u_pred is None:
                    reward        = worst_case_timeout 
                    info['error'] = None
                else:
                    reward = -(self.beta * abs(u_pred - u_ref) + self.lam * self.step_count)
                    info['u_pred'] = u_pred
                    info['u_ref']  = u_ref
                    info['error']  = abs(u_pred - u_ref)
                    info['k_term'] = self.step_count

            elif self.step_count >= self.K_max:
                done = True
                reward = -1 - self.lam * self.step_count
                info['timeout'] = True

            # ── PBRS shaping: Φ(terminal) ≡ 0 (Ng et al. 1999), γ = 1 ────────────
            phi_new = 0.0 if done else self._potential()
            shaping = phi_new - self._phi_prev
            self._phi_prev = phi_new
            reward += shaping
            info['shaping'] = shaping
            info['phi'] = phi_new

            return self._build_obs(), reward, done, False, info
    def action_masks(self) -> np.ndarray:
        mask = np.ones(self.N * len(self.ACTIONS), dtype=bool)
        for i in range(self.N):
            for j in range(len(self.ACTIONS)):
                dx_idx, dt_idx = self.ACTIONS[j]
                x_new = self.walker_x[i] + dx_idx * self.dx
                t_new = self.walker_t[i] + dt_idx * self.dt
                if not (0.0 <= x_new <= 1.0 and
                        0.0 < t_new <= 1.5 * self.t_star and
                        not self.visited.contains(x_new, t_new)):
                    mask[i * len(self.ACTIONS) + j] = False
        for a in self.gfdm_rejected_set:
            mask[a] = False
        if not mask.any():
            mask[:] = True
        return mask

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
t_star_steps = 50  # ← change this to test different targets
env      = PDEEnvironment(t_star_steps=t_star_steps)
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()
    state, reward, done, _, info = env.step(action)



    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts
               if t > 0.0 and 0.0 < x < 1.0]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")

for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")
# walker distribution check — tells you if one walker is dominating
walker_counts = {}
for i, traj in trajectories.items():
    walker_counts[i] = len(traj) - 1  # subtract starting position
print("\nAccepted moves per walker:")
for i, count in sorted(walker_counts.items()):
    print(f"  Walker {i:d}: {count}")

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          500
# Reward:         -1.500000
# Reached:        False
# Timeout:        True
# Total accepted: 487
# Total rejected: 13
# Rejection reasons:
#   collision : 9
#   bounds    : 4
#
# Accepted moves per walker:
#   Walker 0: 14
#   Walker 1: 15
#   Walker 2: 13
#   Walker 3: 12
#   Walker 4: 21
#   Walker 5: 20
#   Walker 6: 23
#   Walker 7: 22
#   Walker 8: 14
#   Walker 9: 15
#   Walker 10: 12
#   Walker 11: 15
#   Walker 12: 12
#   Walker 13: 23
#   Walker 14: 29
#   Walker 15: 25
#   Walker 16: 19
#   Walker 17: 15
#   Walker 18: 18
#   Walker 19: 21
#   Walker 20: 17
#   Walker 21: 15
#   Walker 22: 29
#   Walker 23: 20
#   Walker 24: 20
#   Walker 25: 17
#   Walker 26: 11

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps, N_particles, lam, beta, K_max, c_shape,
                       save=True, timestep=None, img_dir=".", label=None):
    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles,
                          lam=lam, beta=beta, K_max=K_max, c_shape=c_shape)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1)

    # ── Rejected positions ───────────────────────────────────────────────────
    rej_colors = {
        'bounds':    'blue',
        'collision': 'orange',
        'cond':      'purple',
        'weights':   'brown',
        'geometry':  'red',
        None:        'gray',
    }
    if env.rejected_history:
        from collections import defaultdict
        by_reason = defaultdict(list)
        for (rx, rt, reason) in env.rejected_history:
            by_reason[reason].append((rx, rt))
        for reason, pts in by_reason.items():
            ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                       s=6, alpha=0.08, linewidths=0, zorder=1,
                       color=rej_colors.get(reason, 'gray'),
                       label=f'rej:{reason} ({len(pts)})')
    # ─────────────────────────────────────────────────────────────────────────

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, color=colors[i], zorder=2)
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4)

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'

    # ── Stencil at z* ────────────────────────────────────────────────────────
    if reached:
        _, success, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star)
        if success and nb_coords is not None:
            for (nx_, nt_) in nb_coords:
                ax.plot([env.x_star, nx_], [env.t_star, nt_],
                        '--', color='red', linewidth=0.8,
                        alpha=0.7, zorder=5)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1],
                       s=40, color='red', zorder=6, alpha=0.7)

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=7)
    ax.set_xlabel('x')
    ax.set_ylabel('t')

    title = f't_star={t_star_steps}·dt  |  {outcome}'
    if timestep is not None:
        title += f'  |  step {timestep:,}'
    if reached and info.get('error') is not None:
        title += f'  |  err={info["error"]:.2e}  |  k={info["k_term"]}'
    ax.set_title(title)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)

    if env.rejected_history:
        ax.legend(fontsize=6, loc='upper left', markerscale=2)

    plt.tight_layout()

    if save:
        if label is not None:
            fname = f'traj_t{t_star_steps}dt_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120)
        plt.close(fig)
    else:
        plt.show()

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, N_particles, lam, beta, K_max, c_shape,
                 plot_freq=50_000, img_dir=".", verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles  = N_particles
        self.lam          = lam
        self.beta         = beta
        self.K_max        = K_max
        self.c_shape      = c_shape
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles,
                              self.lam, self.beta, self.K_max, self.c_shape,
                              save=True, timestep=self.num_timesteps,
                              img_dir=self.img_dir)
        return True


def make_env(t_star_schedule, N_particles, lam, beta, K_max, c_shape):
    def _init():
        env = PDEEnvironment(t_star_schedule=t_star_schedule, N_particles=N_particles,
                             lam=lam, beta=beta, K_max=K_max, c_shape=c_shape)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
# ── Run configuration ────────────────────────────────────────────────────────
N_particles     = 30
t_star_schedule = {5: 50} #, 7: 140, 10: 200, 15: 300}   # {t_star_steps: K_max}
seeds           = [5]
lam             = 0.01
beta            = 100000
n_envs          = 15
n_steps         = 2048 // n_envs
total_timesteps = 1_000_000
c_shape         = 0.1

# representative t* used ONLY for periodic plots/videos (policy trains on all keys)
plot_tstar   =5
plot_K_max   = t_star_schedule[plot_tstar]

# ── Run directory ────────────────────────────────────────────────────────────
day        = date.today().day
stages_str = "-".join(str(s) for s in t_star_schedule.keys())
run_name   = f"t{stages_str}_lam{lam}_beta{beta}_N{N_particles}_c{c_shape}"
run_dir    = os.path.join(f"runs{day}", run_name)

print(f"Run: {run_dir}")
print(f"Training jointly on t*={list(t_star_schedule.keys())}  "
      f"(periodic plots shown at t*={plot_tstar})")

for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    # every subprocess gets the SAME schedule and resamples t* per episode in reset()
    vec_env = SubprocVecEnv([
        make_env(t_star_schedule, N_particles, lam, beta, K_max=None, c_shape=c_shape)
        for _ in range(n_envs)
    ])

    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=2e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=60,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    print(f"\n{'='*50}")
    print(f"Joint training over t* schedule: {t_star_schedule}")
    print(f"budget: {total_timesteps//1000}k steps")
    print(f"{'='*50}")

    model.learn(
        total_timesteps=total_timesteps,
        reset_num_timesteps=False,
        tb_log_name=f"seed{seed}",
        log_interval=10,
        callback=[
            ReachedRateCallback(),
            PlotCallback(plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                            plot_freq=100_000, img_dir=img_dir),
            CheckpointCallback(
                save_freq=100_000,
                save_path=os.path.join(ckpt_dir, "sched"),
                name_prefix="sched"
            ),
        ],
    )

    model.save(os.path.join(ckpt_dir, "sched_final"))

    # final plots/videos at the representative t*
    plot_trajectories(model, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                      save=True, timestep=None, img_dir=img_dir, label="final")
    make_training_progress_video(img_dir, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                                 label="final", fps=5)
    make_trajectory_video1(
    model, PDEEnvironment, t_star_steps, N_particles,
    img_dir=img_dir, label="final",
    )
# Out:
# Run: runs21\t5_lam0.01_beta100000_N30_c0.1
# Training jointly on t*=[5]  (periodic plots shown at t*=5)
#
# ##################################################
# SEED 5
# ##################################################
# Using cpu device
#
# ==================================================
# Joint training over t* schedule: {5: 50}
# budget: 1000k steps
# ==================================================
# Logging to runs21\t5_lam0.01_beta100000_N30_c0.1\seed5\logs\seed5_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | 1.04        |
# |    mean_error_on_reach  | 8.63e-07    |
# |    mean_kterm_on_reach  | 35.7        |
# |    reached_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.005374048 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | -0.144      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.095      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | 1.08        |
# |    mean_error_on_reach  | 1.19e-06    |
# |    mean_kterm_on_reach  | 31.3        |
# |    reached_rate         | 0.08        |
# | time/                   |             |
# |    fps                  | 1134        |
# |    iterations           | 20          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 40800       |
# | train/                  |             |
# |    approx_kl            | 0.005537451 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0604     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.5         |
# |    ep_rew_mean          | 1.13         |
# |    mean_error_on_reach  | 1.18e-06     |
# |    mean_kterm_on_reach  | 28.6         |
# |    reached_rate         | 0.12         |
# | time/                   |              |
# |    fps                  | 1092         |
# |    iterations           | 30           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 61200        |
# | train/                  |              |
# |    approx_kl            | 0.0055849575 |
# |    clip_fraction        | 0.299        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0228      |
# |    value_loss           | 0.0188       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.6         |
# |    ep_rew_mean          | 1.14         |
# |    mean_error_on_reach  | 1.1e-06      |
# |    mean_kterm_on_reach  | 23           |
# |    reached_rate         | 0.14         |
# | time/                   |              |
# |    fps                  | 1089         |
# |    iterations           | 40           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 81600        |
# | train/                  |              |
# |    approx_kl            | 0.0067654965 |
# |    clip_fraction        | 0.299        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.33        |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0729      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0214      |
# |    value_loss           | 0.0228       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.6        |
# |    ep_rew_mean          | 1.37        |
# |    mean_error_on_reach  | 1.24e-06    |
# |    mean_kterm_on_reach  | 16.7        |
# |    reached_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 50          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 102000      |
# | train/                  |             |
# |    approx_kl            | 0.005830359 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0651     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 0.0554      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.8         |
# |    ep_rew_mean          | 1.75         |
# |    mean_error_on_reach  | 1.02e-06     |
# |    mean_kterm_on_reach  | 15.1         |
# |    reached_rate         | 0.61         |
# | time/                   |              |
# |    fps                  | 1076         |
# |    iterations           | 60           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 122400       |
# | train/                  |              |
# |    approx_kl            | 0.0060139657 |
# |    clip_fraction        | 0.339        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.19        |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0319      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0302      |
# |    value_loss           | 0.0983       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.89        |
# |    ep_rew_mean          | 2.24        |
# |    mean_error_on_reach  | 8.08e-07    |
# |    mean_kterm_on_reach  | 4.79        |
# |    reached_rate         | 0.91        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 70          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 142800      |
# | train/                  |             |
# |    approx_kl            | 0.007247376 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0193     |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 0.0817      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.67        |
# |    ep_rew_mean          | 2.39        |
# |    mean_error_on_reach  | 7.01e-07    |
# |    mean_kterm_on_reach  | 2.67        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 80          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.009313003 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0308     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.0179      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.76        |
# |    ep_rew_mean          | 2.41        |
# |    mean_error_on_reach  | 4.79e-07    |
# |    mean_kterm_on_reach  | 2.76        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 90          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.017515391 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0284     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00369     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31        |
# |    ep_rew_mean          | 2.43        |
# |    mean_error_on_reach  | 2.47e-07    |
# |    mean_kterm_on_reach  | 3.31        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 100         |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 204000      |
# | train/                  |             |
# |    approx_kl            | 0.026095077 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | -4.7        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0275     |
# |    n_updates            | 990         |
# |    policy_gradient_loss | 0.000782    |
# |    value_loss           | 0.000487    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.59        |
# |    ep_rew_mean          | 2.43        |
# |    mean_error_on_reach  | 1.77e-07    |
# |    mean_kterm_on_reach  | 3.13        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 110         |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 224400      |
# | train/                  |             |
# |    approx_kl            | 0.007378175 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.038      |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.13       |
# |    ep_rew_mean          | 2.44       |
# |    mean_error_on_reach  | 1.49e-07   |
# |    mean_kterm_on_reach  | 3.13       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 832        |
# |    iterations           | 120        |
# |    time_elapsed         | 293        |
# |    total_timesteps      | 244800     |
# | train/                  |            |
# |    approx_kl            | 0.03708285 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | -2.42      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0114    |
# |    n_updates            | 1190       |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.000464   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.55        |
# |    ep_rew_mean          | 2.45        |
# |    mean_error_on_reach  | 8.78e-08    |
# |    mean_kterm_on_reach  | 3.55        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 130         |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 265200      |
# | train/                  |             |
# |    approx_kl            | 0.015797043 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0334     |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.29        |
# |    ep_rew_mean          | 2.45        |
# |    mean_error_on_reach  | 9.7e-08     |
# |    mean_kterm_on_reach  | 3.29        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 140         |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.010655011 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.296      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00266     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 0.000372    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.42        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.17e-07    |
# |    mean_kterm_on_reach  | 3.42        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 150         |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.010727252 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.474      |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0109     |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 4.2e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.34         |
# |    ep_rew_mean          | 2.45         |
# |    mean_error_on_reach  | 9.06e-08     |
# |    mean_kterm_on_reach  | 3.34         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 160          |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 326400       |
# | train/                  |              |
# |    approx_kl            | 0.0027216808 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00616     |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | 0.00357      |
# |    value_loss           | 5.21e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.86       |
# |    ep_rew_mean          | 2.44       |
# |    mean_error_on_reach  | 9.51e-08   |
# |    mean_kterm_on_reach  | 3.86       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 762        |
# |    iterations           | 170        |
# |    time_elapsed         | 455        |
# |    total_timesteps      | 346800     |
# | train/                  |            |
# |    approx_kl            | 0.08028316 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.429     |
# |    explained_variance   | 0.0775     |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0301    |
# |    n_updates            | 1690       |
# |    policy_gradient_loss | -0.0232    |
# |    value_loss           | 0.000139   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.93        |
# |    ep_rew_mean          | 2.36        |
# |    mean_error_on_reach  | 1.87e-07    |
# |    mean_kterm_on_reach  | 3.59        |
# |    reached_rate         | 0.95        |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 180         |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 367200      |
# | train/                  |             |
# |    approx_kl            | 0.012701391 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0353     |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.0709      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.44        |
# |    ep_rew_mean          | 2.45        |
# |    mean_error_on_reach  | 9.7e-08     |
# |    mean_kterm_on_reach  | 3.44        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 190         |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 387600      |
# | train/                  |             |
# |    approx_kl            | 0.049083646 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0236     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.74      |
# |    ep_rew_mean          | 2.27      |
# |    mean_error_on_reach  | 1.3e-07   |
# |    mean_kterm_on_reach  | 3.12      |
# |    reached_rate         | 0.88      |
# | time/                   |           |
# |    fps                  | 730       |
# |    iterations           | 200       |
# |    time_elapsed         | 558       |
# |    total_timesteps      | 408000    |
# | train/                  |           |
# |    approx_kl            | 0.0360325 |
# |    clip_fraction        | 0.428     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.299    |
# |    explained_variance   | 0.472     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0568   |
# |    n_updates            | 1990      |
# |    policy_gradient_loss | -0.042    |
# |    value_loss           | 3.54e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.53       |
# |    ep_rew_mean          | 2.45       |
# |    mean_error_on_reach  | 7.88e-08   |
# |    mean_kterm_on_reach  | 3.53       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 210        |
# |    time_elapsed         | 590        |
# |    total_timesteps      | 428400     |
# | train/                  |            |
# |    approx_kl            | 0.32190257 |
# |    clip_fraction        | 0.484      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.331     |
# |    explained_variance   | 0.00563    |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0185    |
# |    n_updates            | 2090       |
# |    policy_gradient_loss | 0.00622    |
# |    value_loss           | 0.000211   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.1       |
# |    ep_rew_mean          | 2.18       |
# |    mean_error_on_reach  | 1.14e-07   |
# |    mean_kterm_on_reach  | 5.68       |
# |    reached_rate         | 0.83       |
# | time/                   |            |
# |    fps                  | 721        |
# |    iterations           | 220        |
# |    time_elapsed         | 621        |
# |    total_timesteps      | 448800     |
# | train/                  |            |
# |    approx_kl            | 0.16782154 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.352     |
# |    explained_variance   | -2.9       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0331    |
# |    n_updates            | 2190       |
# |    policy_gradient_loss | 0.183      |
# |    value_loss           | 0.000669   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.29         |
# |    ep_rew_mean          | 2.45         |
# |    mean_error_on_reach  | 1.03e-07     |
# |    mean_kterm_on_reach  | 3.29         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 230          |
# |    time_elapsed         | 655          |
# |    total_timesteps      | 469200       |
# | train/                  |              |
# |    approx_kl            | 0.0105022155 |
# |    clip_fraction        | 0.176        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00305     |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | 0.0257       |
# |    value_loss           | 8.56e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.25        |
# |    ep_rew_mean          | 2.45        |
# |    mean_error_on_reach  | 1e-07       |
# |    mean_kterm_on_reach  | 3.25        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 240         |
# |    time_elapsed         | 688         |
# |    total_timesteps      | 489600      |
# | train/                  |             |
# |    approx_kl            | 0.004396247 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0267     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00929    |
# |    value_loss           | 0.0055      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.08       |
# |    ep_rew_mean          | 2.38       |
# |    mean_error_on_reach  | 1.73e-07   |
# |    mean_kterm_on_reach  | 3.2        |
# |    reached_rate         | 0.96       |
# | time/                   |            |
# |    fps                  | 707        |
# |    iterations           | 250        |
# |    time_elapsed         | 721        |
# |    total_timesteps      | 510000     |
# | train/                  |            |
# |    approx_kl            | 0.08678708 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.323     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0566    |
# |    n_updates            | 2490       |
# |    policy_gradient_loss | -0.0391    |
# |    value_loss           | 7.32e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.86        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 2.02e-07    |
# |    mean_kterm_on_reach  | 2.86        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 260         |
# |    time_elapsed         | 754         |
# |    total_timesteps      | 530400      |
# | train/                  |             |
# |    approx_kl            | 0.017823622 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.0175      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.029      |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 0.000503    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.51         |
# |    ep_rew_mean          | 2.44         |
# |    mean_error_on_reach  | 1.06e-07     |
# |    mean_kterm_on_reach  | 3.51         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 270          |
# |    time_elapsed         | 787          |
# |    total_timesteps      | 550800       |
# | train/                  |              |
# |    approx_kl            | 0.0066584162 |
# |    clip_fraction        | 0.224        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0258      |
# |    n_updates            | 2690         |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.00525      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.1       |
# |    ep_rew_mean          | 2.27       |
# |    mean_error_on_reach  | 1.94e-07   |
# |    mean_kterm_on_reach  | 8.49       |
# |    reached_rate         | 0.92       |
# | time/                   |            |
# |    fps                  | 697        |
# |    iterations           | 280        |
# |    time_elapsed         | 819        |
# |    total_timesteps      | 571200     |
# | train/                  |            |
# |    approx_kl            | 0.00854025 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -3.78      |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 0.0344     |
# |    n_updates            | 2790       |
# |    policy_gradient_loss | -0.00268   |
# |    value_loss           | 0.111      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.66        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.31e-07    |
# |    mean_kterm_on_reach  | 3.66        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 290         |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 591600      |
# | train/                  |             |
# |    approx_kl            | 0.010593083 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.0265      |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.00714     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.74        |
# |    ep_rew_mean          | 2.43        |
# |    mean_error_on_reach  | 3.17e-07    |
# |    mean_kterm_on_reach  | 2.74        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 300         |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 612000      |
# | train/                  |             |
# |    approx_kl            | 0.025123823 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0391     |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.28        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.44e-07    |
# |    mean_kterm_on_reach  | 3.28        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 310         |
# |    time_elapsed         | 916         |
# |    total_timesteps      | 632400      |
# | train/                  |             |
# |    approx_kl            | 0.010590696 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.122       |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.32         |
# |    ep_rew_mean          | 2.44         |
# |    mean_error_on_reach  | 1.2e-07      |
# |    mean_kterm_on_reach  | 3.32         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 687          |
# |    iterations           | 320          |
# |    time_elapsed         | 949          |
# |    total_timesteps      | 652800       |
# | train/                  |              |
# |    approx_kl            | 0.0069269678 |
# |    clip_fraction        | 0.262        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.663       |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0107      |
# |    n_updates            | 3190         |
# |    policy_gradient_loss | -0.00997     |
# |    value_loss           | 0.000327     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.43         |
# |    ep_rew_mean          | 2.44         |
# |    mean_error_on_reach  | 1.16e-07     |
# |    mean_kterm_on_reach  | 3.43         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 684          |
# |    iterations           | 330          |
# |    time_elapsed         | 983          |
# |    total_timesteps      | 673200       |
# | train/                  |              |
# |    approx_kl            | 0.0050940984 |
# |    clip_fraction        | 0.228        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.688        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0279      |
# |    n_updates            | 3290         |
# |    policy_gradient_loss | -0.00946     |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.06       |
# |    ep_rew_mean          | 2.44       |
# |    mean_error_on_reach  | 1.45e-07   |
# |    mean_kterm_on_reach  | 3.06       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 681        |
# |    iterations           | 340        |
# |    time_elapsed         | 1017       |
# |    total_timesteps      | 693600     |
# | train/                  |            |
# |    approx_kl            | 0.00770378 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.425     |
# |    explained_variance   | -1.06      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.00115   |
# |    n_updates            | 3390       |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 0.000563   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.04        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 7.57e-08    |
# |    mean_kterm_on_reach  | 4.04        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 350         |
# |    time_elapsed         | 1051        |
# |    total_timesteps      | 714000      |
# | train/                  |             |
# |    approx_kl            | 0.006299123 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0123     |
# |    n_updates            | 3490        |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.000721    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.89        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1e-07       |
# |    mean_kterm_on_reach  | 3.89        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 360         |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.005084793 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.867      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0251     |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.000142    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.12      |
# |    ep_rew_mean          | 2.45      |
# |    mean_error_on_reach  | 1.11e-07  |
# |    mean_kterm_on_reach  | 3.12      |
# |    reached_rate         | 1         |
# | time/                   |           |
# |    fps                  | 674       |
# |    iterations           | 370       |
# |    time_elapsed         | 1119      |
# |    total_timesteps      | 754800    |
# | train/                  |           |
# |    approx_kl            | 0.0109175 |
# |    clip_fraction        | 0.171     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.262    |
# |    explained_variance   | 0.745     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0121   |
# |    n_updates            | 3690      |
# |    policy_gradient_loss | -0.0134   |
# |    value_loss           | 3.04e-05  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.26        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 6.17e-08    |
# |    mean_kterm_on_reach  | 4.26        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 380         |
# |    time_elapsed         | 1151        |
# |    total_timesteps      | 775200      |
# | train/                  |             |
# |    approx_kl            | 0.005207854 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.0233      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0244     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 0.000199    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.21        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 7.16e-08    |
# |    mean_kterm_on_reach  | 4.21        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 390         |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 795600      |
# | train/                  |             |
# |    approx_kl            | 0.027717603 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0391     |
# |    n_updates            | 3890        |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 0.000131    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.59       |
# |    ep_rew_mean          | 2.31       |
# |    mean_error_on_reach  | 3.86e-07   |
# |    mean_kterm_on_reach  | 2.85       |
# |    reached_rate         | 0.92       |
# | time/                   |            |
# |    fps                  | 670        |
# |    iterations           | 400        |
# |    time_elapsed         | 1216       |
# |    total_timesteps      | 816000     |
# | train/                  |            |
# |    approx_kl            | 0.52428275 |
# |    clip_fraction        | 0.794      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.582     |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0663    |
# |    n_updates            | 3990       |
# |    policy_gradient_loss | 1.97       |
# |    value_loss           | 1.8e-05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.61         |
# |    ep_rew_mean          | 2.44         |
# |    mean_error_on_reach  | 8.92e-08     |
# |    mean_kterm_on_reach  | 3.61         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 668          |
# |    iterations           | 410          |
# |    time_elapsed         | 1250         |
# |    total_timesteps      | 836400       |
# | train/                  |              |
# |    approx_kl            | 0.0051398096 |
# |    clip_fraction        | 0.194        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.43         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0156      |
# |    n_updates            | 4090         |
# |    policy_gradient_loss | -0.00619     |
# |    value_loss           | 7.23e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.57         |
# |    ep_rew_mean          | 2.45         |
# |    mean_error_on_reach  | 7.97e-08     |
# |    mean_kterm_on_reach  | 3.57         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 420          |
# |    time_elapsed         | 1283         |
# |    total_timesteps      | 856800       |
# | train/                  |              |
# |    approx_kl            | 0.0025715309 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.403       |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0128       |
# |    n_updates            | 4190         |
# |    policy_gradient_loss | 0.00223      |
# |    value_loss           | 0.000494     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.27         |
# |    ep_rew_mean          | 2.45         |
# |    mean_error_on_reach  | 9.69e-08     |
# |    mean_kterm_on_reach  | 3.27         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 430          |
# |    time_elapsed         | 1318         |
# |    total_timesteps      | 877200       |
# | train/                  |              |
# |    approx_kl            | 0.0076786927 |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.002        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0298       |
# |    n_updates            | 4290         |
# |    policy_gradient_loss | 0.00277      |
# |    value_loss           | 9.41e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.37        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.77e-07    |
# |    mean_kterm_on_reach  | 3.37        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 440         |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 897600      |
# | train/                  |             |
# |    approx_kl            | 0.009830769 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0217     |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 3.33e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.27         |
# |    ep_rew_mean          | 2.45         |
# |    mean_error_on_reach  | 9.96e-08     |
# |    mean_kterm_on_reach  | 3.27         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 661          |
# |    iterations           | 450          |
# |    time_elapsed         | 1386         |
# |    total_timesteps      | 918000       |
# | train/                  |              |
# |    approx_kl            | 0.0075740535 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0104      |
# |    n_updates            | 4490         |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 5.48e-05     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 17        |
# |    ep_rew_mean          | 2         |
# |    mean_error_on_reach  | 4.72e-07  |
# |    mean_kterm_on_reach  | 3.83      |
# |    reached_rate         | 0.72      |
# | time/                   |           |
# |    fps                  | 661       |
# |    iterations           | 460       |
# |    time_elapsed         | 1418      |
# |    total_timesteps      | 938400    |
# | train/                  |           |
# |    approx_kl            | 1.0097921 |
# |    clip_fraction        | 0.583     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -1.56     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.067    |
# |    n_updates            | 4590      |
# |    policy_gradient_loss | 0.368     |
# |    value_loss           | 2.26e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.92      |
# |    ep_rew_mean          | 2.38      |
# |    mean_error_on_reach  | 6.62e-07  |
# |    mean_kterm_on_reach  | 2.44      |
# |    reached_rate         | 0.99      |
# | time/                   |           |
# |    fps                  | 662       |
# |    iterations           | 470       |
# |    time_elapsed         | 1447      |
# |    total_timesteps      | 958800    |
# | train/                  |           |
# |    approx_kl            | 0.0313536 |
# |    clip_fraction        | 0.393     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -1.43     |
# |    explained_variance   | 0.894     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0121   |
# |    n_updates            | 4690      |
# |    policy_gradient_loss | -0.00397  |
# |    value_loss           | 0.0222    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.91e-07    |
# |    mean_kterm_on_reach  | 2.92        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 480         |
# |    time_elapsed         | 1482        |
# |    total_timesteps      | 979200      |
# | train/                  |             |
# |    approx_kl            | 0.010594957 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.272      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0205     |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | 0.0844      |
# |    value_loss           | 5.91e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.06        |
# |    ep_rew_mean          | 2.44        |
# |    mean_error_on_reach  | 1.15e-07    |
# |    mean_kterm_on_reach  | 4.06        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 490         |
# |    time_elapsed         | 1515        |
# |    total_timesteps      | 999600      |
# | train/                  |             |
# |    approx_kl            | 0.010420275 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0127     |
# |    n_updates            | 4890        |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.00743     |
# -----------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 85
#      81
#      82     # final plots/videos at the representative t*
#      83     plot_trajectories(model, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
#      84                       save=True, timestep=None, img_dir=img_dir, label="final")
# ---> 85     make_training_progress_video(img_dir, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
#      86                                  label="final", fps=5)
#      87     make_trajectory_video1(
#      88     model, PDEEnvironment, t_star_steps, N_particles,
#
# TypeError: make_training_progress_video() got an unexpected keyword argument 'label'
