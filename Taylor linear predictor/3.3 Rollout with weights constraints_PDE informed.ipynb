# %% [markdown]
# ## Scattered integrator — advection-diffusion PDE:
#     u_t + c * u_x = alpha * u_xx,   x in [0,1],  t in [0,T]

# %%
"""
Design
- FD grid is used as a coordinate scaffold only. Candidate points are
  drawn from FD grid coordinates so coverage is always dense.
- u values at interior points are computed by PDE-informed interpolation,
  NOT copied from FD. FD is used only for error measurement.
- Stopping criterion: max_points successfully computed interior points.
- KDTree for O(log N) neighbour queries.
- O(1) candidate removal via swap-and-pop.
"""

import time
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator

alpha = 0.05
c     = 0.5
T     = 0.5
import numpy as np

alpha = 0.05
c = 0.5

beta = c / (2 * alpha)
_N_SERIES = 200

# Precompute coefficients once
_xq = np.linspace(0.0, 1.0, 20001)
_b = np.zeros(_N_SERIES + 1)

for n in range(1, _N_SERIES + 1):
    integrand = np.exp(-beta * _xq) * np.sin(np.pi * _xq) * np.sin(n * np.pi * _xq)
    _b[n] = 2.0 * np.trapezoid(integrand, _xq)

_n_arr = np.arange(1, _N_SERIES + 1)
_bn    = _b[1:]
_lam   = -alpha * (_n_arr * np.pi) ** 2

def u_true(x, t):
    x = np.asarray(x, dtype=float)
    scalar = x.ndim == 0
    x = np.atleast_1d(x)
    sin_nx = np.sin(np.pi * np.outer(x, _n_arr))
    exp_t  = np.exp(_lam * t)
    s      = (sin_nx * (_bn * exp_t)).sum(axis=-1)
    result = np.exp(beta * x - (c**2 / (4 * alpha)) * t) * s
    return float(result[0]) if scalar else result

# ── FD r/eference grid ─────────────────────────────────────────────────────────
nx_fd = 100
x_fd  = np.linspace(0.0, 1.0, nx_fd)
dx_fd = x_fd[1] - x_fd[0]

# Compute nt_fd from CFL — never touch this manually
dt_cfl = min(0.9  * dx_fd / c,
             0.45 * dx_fd**2 / alpha)
nt_fd  = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt_fd)
dt_fd  = t_fd[1] - t_fd[0]



def build_fd_reference():
    """Explicit upwind FD solve. Returns (u_fd, interpolant)."""
    u = np.zeros((nx_fd, nt_fd))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt_fd / dx_fd**2
    r_adv  = c     * dt_fd / dx_fd

    for it in range(nt_fd - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         - r_adv  * (un[1:-1] - un[:-2])
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,  it+1] = 0.0
        u[-1, it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
        bounds_error=False, fill_value=None
    )
    return u, interp


# ── Integrator hyperparameters ────────────────────────────────────────────────
max_points    = 100000   # stopping criterion
u_bound = 1.1
n_neighbours  = 5     # stencil size (3 equations, 5 unknowns → underdetermined)
cond_max      = 1e4
isotropy_max  = 50.0
w_max_factor  = 3.0     # reject if max|w_j| > w_max_factor / n
w_min_floor   = -1.0

# Spawn box in FD grid steps
spawn_nx      = 5       # ± x steps around a newly solved point
spawn_nt      = 3       # + t steps forward

# Neighbour search box in normalised units (x/dx_fd, t/dt_fd)
box_n0        = 2.0     # initial half-width
box_grow      = 1.5
box_nmax      = 15.0

max_candidates = 6000   # cap on candidate list length (for memory and speed)


# ── KDTree-backed visited set ─────────────────────────────────────────────────
class VisitedSet:
    """
    Stores (x, t, u) points. KDTree is in normalised (x/dx_fd, t/dt_fd)
    space so both axes are commensurate during neighbour search.
    Rebuilt lazily every rebuild_every insertions.
    """
    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
    def add(self, x, t, u):
        self._pts.append((x, t, u))
        self._norm.append((x / dx_fd, t / dt_fd))   # add this
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))   # change this
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()

    def find_neighbours(self, x_star, t_star):
        self._ensure()
        xn = x_star / dx_fd
        tn = t_star / dt_fd
        bn = box_n0
        while True:
            idxs = self._tree.query_ball_point([xn, tn], r=bn, p=np.inf)
            nb = [
                self._pts[i] for i in idxs
                if abs(self._pts[i][0] - x_star) <= bn * dx_fd
                and 0 < (t_star - self._pts[i][1]) <= bn * dt_fd
            ]
            if len(nb) >= n_neighbours:
                nb.sort(key=lambda p: (p[0]-x_star)**2 + (p[1]-t_star)**2)
                return nb[:n_neighbours]
            bn = min(bn * box_grow, box_nmax)
            if bn >= box_nmax:
                return None
    def __len__(self):
        return len(self._pts)


# ── Stencil geometry check ────────────────────────────────────────────────────
def stencil_is_good(dx_i, dt_i):
    if np.min(dx_i) * np.max(dx_i) > 0:          # two-sided coverage
        return False
    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)
    pts = np.column_stack([dx_i / h, dt_i / tau])
    return True


# ── Weight solver ─────────────────────────────────────────────────────────────
def solve_weights(dx_i, dt_i):
    """
    Min-norm lstsq on the 3×n PDE-informed system.
    Returns (w, cond) or (None, cond).
    """
    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
         (dx_i - c * dt_i)              / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ]) 
    b = np.array([1 , 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > cond_max:
        return None,    cond

    w = np.linalg.lstsq(A, b, rcond=None)[0]


    # Additional weight checks to prevent error explosion — these are somewhat ad-hoc and may be tuned or removed based on your needs.
    if np.max(np.abs(w)) > w_max_factor / len(dx_i):   # no dominant weight
        return None, cond
    if np.min(w) < w_min_floor:                         # no extreme negatives
        return None, cond

    return w, cond

## Add L2 instead of L1

# ── Main integrator ───────────────────────────────────────────────────────────
def run_integrator(seed=None):
    t_wall = time.time()
    if seed is not None:
        np.random.seed(seed)

    print("Building FD reference...", flush=True)
    _, fd_interp = build_fd_reference()
    print(f"  dx={dx_fd:.4f}  dt={dt_fd:.5f}", flush=True)

    # IC + BC into visited set
    visited = VisitedSet()
    for ix in range(nx_fd):
        visited.add(x_fd[ix], 0.0, u_true(x_fd[ix], 0.0))
    for it in range(1, nt_fd):
        visited.add(0.0,  t_fd[it], 0.0)
        visited.add(1.0,  t_fd[it], 0.0)
    print(f"  IC+BC points: {len(visited)}", flush=True)

    # Candidate pool — integer (ix, it) keys for O(1) deduplication
    cand_keys = set()
    cand_list = []   # list of (x, t)

    def push(ix, it):
        if (ix, it) not in cand_keys:
            cand_keys.add((ix, it))
            cand_list.append((x_fd[ix], t_fd[it]))

    # Seed from IC
    for ix in range(1, nx_fd - 1):
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix, nit = ix + dix, dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

    print(f"  Initial candidates: {len(cand_list)}", flush=True)
    print(f"  Stopping at {max_points} computed points\n", flush=True)

    rej        = dict(proximity=0, no_nb=0, geometry=0, cond=0, weights=0)
    point_data = []

    while cand_list and len(point_data) < max_points:

        # Trim if candidate list is over budget
        protect_candidates = 500

        if len(cand_list) > max_candidates:
            target_size = max(max_candidates, protect_candidates)
            n_remove = len(cand_list) - target_size
            if n_remove > 0:
                del cand_list[:n_remove]

        # ── O(1) swap-and-pop ─────────────────────────────────────────────
        idx            = np.random.randint(len(cand_list))
        x_star, t_star = cand_list[idx]
        cand_list[idx] = cand_list[-1]
        cand_list.pop()
        ix_s = int(round(x_star / dx_fd))
        it_s = int(round(t_star / dt_fd))
        cand_keys.discard((ix_s, it_s))
        

        nb = visited.find_neighbours(x_star, t_star)
        if nb is None:
            rej['no_nb'] += 1
            continue

        nb_pts = np.array(nb)
        dx_i   = nb_pts[:, 0] - x_star
        dt_i   = nb_pts[:, 1] - t_star   # negative: neighbours are in the past

        if not stencil_is_good(dx_i, dt_i):
            rej['geometry'] += 1
            continue

        w, cond = solve_weights(dx_i, dt_i)
        if w is None:
            rej['cond' if cond > cond_max else 'weights'] += 1
            continue

        # Accept point  
        u_hat = float(w @ nb_pts[:, 2])

        # Break the error cascade — u is bounded by IC amplitude + margin
        if abs(u_hat) > u_bound:
            rej['bounds'] = rej.get('bounds', 0) + 1
            continue

        visited.add(x_star, t_star, u_hat)

        # Spawn new candidates in the FD grid box around this point
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix = ix_s + dix
                nit = it_s + dit
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push(nix, nit)

        u_fd_ref = float(fd_interp([[x_star, t_star]])[0])
        u_true_ref = float(u_true(x_star, t_star))
 
        point_data.append({
            'x':     x_star,
            't':     t_star,
            'u':     u_hat,
            'u_true': u_true_ref,
            'u_fd':   u_fd_ref,
            'err_true': abs(u_hat - u_true_ref),
            'err_fd':   abs(u_hat - u_fd_ref),
            'err':   abs(u_hat - u_true_ref),   # use true error for stats and plotting
            'cond':  cond,
            'w1':    float(np.sum(np.abs(w))),
            'box_x': float(np.max(np.abs(dx_i))),   # ← add this
            'box_t': float(np.max(np.abs(dt_i))),   # ← add this
            'nb_x':  nb_pts[:, 0].copy(),            # ← add
            'nb_t':  nb_pts[:, 1].copy(),            # ← add
            'nb_u':  nb_pts[:, 2].copy(),            # ← add
        })

        if len(point_data) % 500 == 0:
            errs = [p['err'] for p in point_data]
            t_max = max(p['t'] for p in point_data)
            print(f"  {len(point_data):5d} pts | "
                  f"mean={np.mean(errs):.2e} | "
                  f"max={np.max(errs):.2e} | "
                  f"t_max={t_max:.3f} | "
                  f"cands={len(cand_list):5d} | "
                  f"wall={time.time()-t_wall:.1f}s",
                  flush=True)

    # Summary
    errs = np.array([p['err'] for p in point_data])
    print(f"\n{'─'*56}")
    print(f"  Computed  : {len(point_data)} points")
    print(f"  Mean err  : {errs.mean():.3e}")
    print(f"  Max  err  : {errs.max():.3e}")
    print(f"  Wall time : {time.time()-t_wall:.1f}s")
    total = sum(rej.values()) + len(point_data)
    print(f"\n  Rejections (total attempts: {total})")
    for r, n in rej.items():
        print(f"    {r:10s}: {n:6d}  ({100*n/total:.1f}%)")

    return visited, point_data, fd_interp


if __name__ == '__main__':
    visited, point_data, fd_interp = run_integrator()
# Out:
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 1190
#   Initial candidates: 294
#   Stopping at 100000 computed points
#
#     500 pts | mean=4.12e-05 | max=1.75e-03 | t_max=0.015 | cands= 1334 | wall=1.1s
#    1000 pts | mean=5.95e-05 | max=1.75e-03 | t_max=0.027 | cands= 2257 | wall=2.4s
#    1500 pts | mean=7.93e-05 | max=1.75e-03 | t_max=0.040 | cands= 3205 | wall=3.7s
#    2000 pts | mean=9.98e-05 | max=1.75e-03 | t_max=0.048 | cands= 3784 | wall=4.7s
#    2500 pts | mean=1.12e-04 | max=2.34e-03 | t_max=0.057 | cands= 4283 | wall=6.1s
#    3000 pts | mean=1.24e-04 | max=2.34e-03 | t_max=0.064 | cands= 4638 | wall=6.9s
#    3500 pts | mean=1.37e-04 | max=3.50e-03 | t_max=0.071 | cands= 5065 | wall=7.6s
#    4000 pts | mean=1.49e-04 | max=3.50e-03 | t_max=0.076 | cands= 5398 | wall=8.4s
#    4500 pts | mean=1.57e-04 | max=3.50e-03 | t_max=0.083 | cands= 5674 | wall=9.2s
#    5000 pts | mean=1.65e-04 | max=4.29e-03 | t_max=0.086 | cands= 5872 | wall=9.9s
#    5500 pts | mean=1.73e-04 | max=4.47e-03 | t_max=0.089 | cands= 5987 | wall=10.6s
#    6000 pts | mean=1.78e-04 | max=4.47e-03 | t_max=0.090 | cands= 5927 | wall=11.4s
#    6500 pts | mean=1.87e-04 | max=4.47e-03 | t_max=0.091 | cands= 5999 | wall=12.2s
#    7000 pts | mean=1.94e-04 | max=4.47e-03 | t_max=0.091 | cands= 5958 | wall=13.0s
#    7500 pts | mean=2.01e-04 | max=4.47e-03 | t_max=0.091 | cands= 5972 | wall=14.0s
#    8000 pts | mean=2.08e-04 | max=4.47e-03 | t_max=0.091 | cands= 5988 | wall=14.9s
#    8500 pts | mean=2.14e-04 | max=4.47e-03 | t_max=0.093 | cands= 5973 | wall=15.7s
#    9000 pts | mean=2.19e-04 | max=4.47e-03 | t_max=0.093 | cands= 5989 | wall=16.6s
#    9500 pts | mean=2.24e-04 | max=4.47e-03 | t_max=0.105 | cands= 5974 | wall=17.5s
#   10000 pts | mean=2.30e-04 | max=4.47e-03 | t_max=0.105 | cands= 5826 | wall=18.6s
#   10500 pts | mean=2.35e-04 | max=4.47e-03 | t_max=0.107 | cands= 5868 | wall=19.6s
#   11000 pts | mean=2.38e-04 | max=4.47e-03 | t_max=0.107 | cands= 5998 | wall=20.5s
#   11500 pts | mean=2.41e-04 | max=4.47e-03 | t_max=0.107 | cands= 5857 | wall=21.8s
#   12000 pts | mean=2.43e-04 | max=4.47e-03 | t_max=0.107 | cands= 5845 | wall=23.2s
#   12500 pts | mean=2.47e-04 | max=4.47e-03 | t_max=0.107 | cands= 5941 | wall=24.4s
#   13000 pts | mean=2.49e-04 | max=4.47e-03 | t_max=0.107 | cands= 5892 | wall=25.6s
#   13500 pts | mean=2.51e-04 | max=4.47e-03 | t_max=0.107 | cands= 5973 | wall=26.8s
#   14000 pts | mean=2.53e-04 | max=4.47e-03 | t_max=0.107 | cands= 5877 | wall=28.0s
#   14500 pts | mean=2.56e-04 | max=4.47e-03 | t_max=0.107 | cands= 5959 | wall=29.3s
#   15000 pts | mean=2.59e-04 | max=4.47e-03 | t_max=0.107 | cands= 6001 | wall=30.4s
#   15500 pts | mean=2.62e-04 | max=4.47e-03 | t_max=0.107 | cands= 5890 | wall=31.4s
#   16000 pts | mean=2.65e-04 | max=4.47e-03 | t_max=0.107 | cands= 5978 | wall=32.4s
#   16500 pts | mean=2.68e-04 | max=4.47e-03 | t_max=0.107 | cands= 5899 | wall=33.4s
#   17000 pts | mean=2.72e-04 | max=4.47e-03 | t_max=0.117 | cands= 5959 | wall=34.6s
#   17500 pts | mean=2.77e-04 | max=4.47e-03 | t_max=0.122 | cands= 5989 | wall=35.8s
#   18000 pts | mean=2.82e-04 | max=4.47e-03 | t_max=0.129 | cands= 5942 | wall=36.9s
#   18500 pts | mean=2.87e-04 | max=4.47e-03 | t_max=0.129 | cands= 6007 | wall=37.9s
#   19000 pts | mean=2.92e-04 | max=4.47e-03 | t_max=0.134 | cands= 5981 | wall=38.6s
#   19500 pts | mean=2.96e-04 | max=4.47e-03 | t_max=0.135 | cands= 6001 | wall=39.7s
#   20000 pts | mean=3.00e-04 | max=4.47e-03 | t_max=0.141 | cands= 5982 | wall=40.6s
#   20500 pts | mean=3.04e-04 | max=4.47e-03 | t_max=0.141 | cands= 5965 | wall=41.6s
#   21000 pts | mean=3.08e-04 | max=4.47e-03 | t_max=0.143 | cands= 5988 | wall=42.5s
#   21500 pts | mean=3.12e-04 | max=4.47e-03 | t_max=0.147 | cands= 5972 | wall=43.5s
#   22000 pts | mean=3.18e-04 | max=4.47e-03 | t_max=0.155 | cands= 5934 | wall=44.3s
#   22500 pts | mean=3.23e-04 | max=4.47e-03 | t_max=0.164 | cands= 5987 | wall=45.2s
#   23000 pts | mean=3.28e-04 | max=4.47e-03 | t_max=0.167 | cands= 5948 | wall=46.2s
#   23500 pts | mean=3.32e-04 | max=4.47e-03 | t_max=0.169 | cands= 6002 | wall=47.1s
#   24000 pts | mean=3.37e-04 | max=4.47e-03 | t_max=0.169 | cands= 5900 | wall=48.1s
#   24500 pts | mean=3.42e-04 | max=4.47e-03 | t_max=0.169 | cands= 5993 | wall=49.1s
#   25000 pts | mean=3.46e-04 | max=4.47e-03 | t_max=0.169 | cands= 5990 | wall=50.1s
#   25500 pts | mean=3.50e-04 | max=4.47e-03 | t_max=0.169 | cands= 5975 | wall=51.3s
#   26000 pts | mean=3.53e-04 | max=4.47e-03 | t_max=0.169 | cands= 6007 | wall=52.3s
#   26500 pts | mean=3.57e-04 | max=4.47e-03 | t_max=0.169 | cands= 5970 | wall=53.4s
#   27000 pts | mean=3.59e-04 | max=4.47e-03 | t_max=0.169 | cands= 5954 | wall=54.7s
#   27500 pts | mean=3.62e-04 | max=4.47e-03 | t_max=0.169 | cands= 5955 | wall=56.0s
#   28000 pts | mean=3.64e-04 | max=4.47e-03 | t_max=0.169 | cands= 5951 | wall=57.2s
#   28500 pts | mean=3.67e-04 | max=4.47e-03 | t_max=0.169 | cands= 5958 | wall=58.5s
#   29000 pts | mean=3.69e-04 | max=4.47e-03 | t_max=0.173 | cands= 5993 | wall=59.7s
#   29500 pts | mean=3.73e-04 | max=4.47e-03 | t_max=0.175 | cands= 5911 | wall=60.9s
#   30000 pts | mean=3.76e-04 | max=4.47e-03 | t_max=0.181 | cands= 6001 | wall=62.2s
#   30500 pts | mean=3.79e-04 | max=4.47e-03 | t_max=0.181 | cands= 5945 | wall=63.7s
#   31000 pts | mean=3.82e-04 | max=4.47e-03 | t_max=0.185 | cands= 5987 | wall=65.4s
#   31500 pts | mean=3.85e-04 | max=4.47e-03 | t_max=0.186 | cands= 5994 | wall=67.0s
#   32000 pts | mean=3.88e-04 | max=4.47e-03 | t_max=0.194 | cands= 5998 | wall=68.4s
#   32500 pts | mean=3.91e-04 | max=4.47e-03 | t_max=0.194 | cands= 5868 | wall=69.8s
#   33000 pts | mean=3.94e-04 | max=4.47e-03 | t_max=0.196 | cands= 5980 | wall=71.0s
#   33500 pts | mean=3.97e-04 | max=4.47e-03 | t_max=0.196 | cands= 5988 | wall=72.2s
#   34000 pts | mean=4.00e-04 | max=4.47e-03 | t_max=0.198 | cands= 5955 | wall=73.5s
#   34500 pts | mean=4.04e-04 | max=4.47e-03 | t_max=0.207 | cands= 5979 | wall=74.7s
#   35000 pts | mean=4.08e-04 | max=4.47e-03 | t_max=0.215 | cands= 5946 | wall=75.9s
#   35500 pts | mean=4.13e-04 | max=4.47e-03 | t_max=0.218 | cands= 5922 | wall=77.2s
#   36000 pts | mean=4.17e-04 | max=4.47e-03 | t_max=0.222 | cands= 5971 | wall=78.3s
#   36500 pts | mean=4.21e-04 | max=7.27e-03 | t_max=0.229 | cands= 5960 | wall=79.6s
#   37000 pts | mean=4.25e-04 | max=7.27e-03 | t_max=0.230 | cands= 5916 | wall=80.7s
#   37500 pts | mean=4.30e-04 | max=7.27e-03 | t_max=0.230 | cands= 5876 | wall=82.1s
#   38000 pts | mean=4.34e-04 | max=7.27e-03 | t_max=0.231 | cands= 5893 | wall=83.5s
#   38500 pts | mean=4.37e-04 | max=7.27e-03 | t_max=0.231 | cands= 5921 | wall=85.0s
#   39000 pts | mean=4.40e-04 | max=7.27e-03 | t_max=0.231 | cands= 5761 | wall=86.5s
#   39500 pts | mean=4.43e-04 | max=7.27e-03 | t_max=0.235 | cands= 5808 | wall=88.0s
#   40000 pts | mean=4.47e-04 | max=7.27e-03 | t_max=0.242 | cands= 5652 | wall=89.6s
#   40500 pts | mean=4.50e-04 | max=7.27e-03 | t_max=0.244 | cands= 5593 | wall=91.2s
#   41000 pts | mean=4.53e-04 | max=7.27e-03 | t_max=0.244 | cands= 5342 | wall=92.9s
#   41500 pts | mean=4.56e-04 | max=7.27e-03 | t_max=0.244 | cands= 5337 | wall=94.6s
#   42000 pts | mean=4.58e-04 | max=7.27e-03 | t_max=0.244 | cands= 5263 | wall=96.3s
#   42500 pts | mean=4.61e-04 | max=7.27e-03 | t_max=0.244 | cands= 5232 | wall=98.1s
#   43000 pts | mean=4.64e-04 | max=7.27e-03 | t_max=0.244 | cands= 5202 | wall=99.8s
#   43500 pts | mean=4.66e-04 | max=7.27e-03 | t_max=0.244 | cands= 5006 | wall=101.8s
#   44000 pts | mean=4.67e-04 | max=7.27e-03 | t_max=0.244 | cands= 5121 | wall=103.5s
#   44500 pts | mean=4.69e-04 | max=7.27e-03 | t_max=0.244 | cands= 4932 | wall=105.4s
#   45000 pts | mean=4.71e-04 | max=7.27e-03 | t_max=0.244 | cands= 5138 | wall=107.2s
#   45500 pts | mean=4.73e-04 | max=7.27e-03 | t_max=0.244 | cands= 5103 | wall=109.0s
#   46000 pts | mean=4.75e-04 | max=7.27e-03 | t_max=0.244 | cands= 5135 | wall=110.8s
#   46500 pts | mean=4.76e-04 | max=7.27e-03 | t_max=0.244 | cands= 5082 | wall=112.6s
#   47000 pts | mean=4.78e-04 | max=7.27e-03 | t_max=0.244 | cands= 5335 | wall=114.3s
#   47500 pts | mean=4.79e-04 | max=7.27e-03 | t_max=0.244 | cands= 5287 | wall=116.0s
#   48000 pts | mean=4.81e-04 | max=7.27e-03 | t_max=0.244 | cands= 5428 | wall=117.7s
#   48500 pts | mean=4.83e-04 | max=7.27e-03 | t_max=0.244 | cands= 5508 | wall=119.5s
#   49000 pts | mean=4.84e-04 | max=7.27e-03 | t_max=0.244 | cands= 5717 | wall=121.0s
#   49500 pts | mean=4.86e-04 | max=7.27e-03 | t_max=0.244 | cands= 5638 | wall=122.8s
#   50000 pts | mean=4.87e-04 | max=7.27e-03 | t_max=0.244 | cands= 5586 | wall=124.5s
#   50500 pts | mean=4.88e-04 | max=7.27e-03 | t_max=0.244 | cands= 5795 | wall=126.2s
#   51000 pts | mean=4.90e-04 | max=7.27e-03 | t_max=0.244 | cands= 5944 | wall=127.7s
#   51500 pts | mean=4.91e-04 | max=7.27e-03 | t_max=0.250 | cands= 5854 | wall=129.4s
#   52000 pts | mean=4.92e-04 | max=7.27e-03 | t_max=0.252 | cands= 5858 | wall=130.9s
#   52500 pts | mean=4.94e-04 | max=7.27e-03 | t_max=0.254 | cands= 5923 | wall=132.6s
#   53000 pts | mean=4.95e-04 | max=7.27e-03 | t_max=0.256 | cands= 5928 | wall=134.4s
#   53500 pts | mean=4.96e-04 | max=7.27e-03 | t_max=0.258 | cands= 5953 | wall=136.0s
#   54000 pts | mean=4.98e-04 | max=7.27e-03 | t_max=0.258 | cands= 5785 | wall=137.7s
#   54500 pts | mean=4.99e-04 | max=7.27e-03 | t_max=0.258 | cands= 5687 | wall=139.7s
#   55000 pts | mean=5.00e-04 | max=7.27e-03 | t_max=0.258 | cands= 5581 | wall=141.7s
#   55500 pts | mean=5.01e-04 | max=7.27e-03 | t_max=0.266 | cands= 5623 | wall=143.6s
#   56000 pts | mean=5.02e-04 | max=7.27e-03 | t_max=0.266 | cands= 5424 | wall=145.6s
#   56500 pts | mean=5.03e-04 | max=7.27e-03 | t_max=0.266 | cands= 5559 | wall=147.6s
#   57000 pts | mean=5.04e-04 | max=7.27e-03 | t_max=0.268 | cands= 5577 | wall=149.5s
#   57500 pts | mean=5.05e-04 | max=7.27e-03 | t_max=0.273 | cands= 5779 | wall=151.6s
#   58000 pts | mean=5.06e-04 | max=7.27e-03 | t_max=0.276 | cands= 5598 | wall=153.7s
#   58500 pts | mean=5.07e-04 | max=7.27e-03 | t_max=0.280 | cands= 5612 | wall=155.8s
#   59000 pts | mean=5.08e-04 | max=7.27e-03 | t_max=0.280 | cands= 5553 | wall=157.7s
#   59500 pts | mean=5.09e-04 | max=7.27e-03 | t_max=0.281 | cands= 5495 | wall=160.0s
#   60000 pts | mean=5.10e-04 | max=7.27e-03 | t_max=0.281 | cands= 5403 | wall=162.4s
#   60500 pts | mean=5.11e-04 | max=7.27e-03 | t_max=0.281 | cands= 5313 | wall=164.8s
#   61000 pts | mean=5.12e-04 | max=7.27e-03 | t_max=0.281 | cands= 5236 | wall=167.1s
#   61500 pts | mean=5.13e-04 | max=7.27e-03 | t_max=0.281 | cands= 5345 | wall=169.3s
#   62000 pts | mean=5.14e-04 | max=7.27e-03 | t_max=0.281 | cands= 5277 | wall=171.4s
#   62500 pts | mean=5.15e-04 | max=7.27e-03 | t_max=0.281 | cands= 5128 | wall=173.6s
#   63000 pts | mean=5.16e-04 | max=7.27e-03 | t_max=0.281 | cands= 5193 | wall=175.7s
#   63500 pts | mean=5.17e-04 | max=7.27e-03 | t_max=0.281 | cands= 4936 | wall=178.1s
#   64000 pts | mean=5.18e-04 | max=7.27e-03 | t_max=0.281 | cands= 5018 | wall=180.3s
#   64500 pts | mean=5.19e-04 | max=7.27e-03 | t_max=0.281 | cands= 5037 | wall=182.5s
#   65000 pts | mean=5.21e-04 | max=7.27e-03 | t_max=0.281 | cands= 5100 | wall=184.7s
#   65500 pts | mean=5.21e-04 | max=7.27e-03 | t_max=0.281 | cands= 5088 | wall=186.9s
#   66000 pts | mean=5.23e-04 | max=7.27e-03 | t_max=0.281 | cands= 4801 | wall=189.2s
#   66500 pts | mean=5.24e-04 | max=7.27e-03 | t_max=0.281 | cands= 4846 | wall=191.6s
#   67000 pts | mean=5.25e-04 | max=7.27e-03 | t_max=0.281 | cands= 4896 | wall=193.7s
#   67500 pts | mean=5.26e-04 | max=7.27e-03 | t_max=0.281 | cands= 4794 | wall=196.2s
#   68000 pts | mean=5.26e-04 | max=7.27e-03 | t_max=0.281 | cands= 4774 | wall=198.5s
#   68500 pts | mean=5.27e-04 | max=7.27e-03 | t_max=0.281 | cands= 4904 | wall=200.9s
#   69000 pts | mean=5.28e-04 | max=7.27e-03 | t_max=0.281 | cands= 4789 | wall=203.2s
#   69500 pts | mean=5.29e-04 | max=7.27e-03 | t_max=0.281 | cands= 4739 | wall=205.7s
#   70000 pts | mean=5.30e-04 | max=7.27e-03 | t_max=0.281 | cands= 4944 | wall=208.0s
#   70500 pts | mean=5.31e-04 | max=7.27e-03 | t_max=0.281 | cands= 4811 | wall=211.0s
#   71000 pts | mean=5.33e-04 | max=7.27e-03 | t_max=0.281 | cands= 4672 | wall=213.6s
#   71500 pts | mean=5.34e-04 | max=7.27e-03 | t_max=0.281 | cands= 4646 | wall=216.1s
#   72000 pts | mean=5.35e-04 | max=7.27e-03 | t_max=0.281 | cands= 4736 | wall=218.5s
#   72500 pts | mean=5.36e-04 | max=7.27e-03 | t_max=0.281 | cands= 4511 | wall=221.2s
#   73000 pts | mean=5.36e-04 | max=7.27e-03 | t_max=0.281 | cands= 4627 | wall=224.9s
#   73500 pts | mean=5.37e-04 | max=7.27e-03 | t_max=0.281 | cands= 4600 | wall=229.3s
#   74000 pts | mean=5.38e-04 | max=7.27e-03 | t_max=0.281 | cands= 4433 | wall=233.7s
#   74500 pts | mean=5.39e-04 | max=7.27e-03 | t_max=0.281 | cands= 4120 | wall=237.9s
#   75000 pts | mean=5.40e-04 | max=7.27e-03 | t_max=0.281 | cands= 4271 | wall=241.7s
#   75500 pts | mean=5.41e-04 | max=7.27e-03 | t_max=0.281 | cands= 4369 | wall=245.7s
#   76000 pts | mean=5.41e-04 | max=7.27e-03 | t_max=0.281 | cands= 4207 | wall=249.5s
#   76500 pts | mean=5.42e-04 | max=7.27e-03 | t_max=0.281 | cands= 4300 | wall=253.5s
#   77000 pts | mean=5.43e-04 | max=7.27e-03 | t_max=0.281 | cands= 4285 | wall=257.6s
#   77500 pts | mean=5.44e-04 | max=7.27e-03 | t_max=0.281 | cands= 4358 | wall=260.5s
#   78000 pts | mean=5.45e-04 | max=7.27e-03 | t_max=0.281 | cands= 4447 | wall=263.2s
#   78500 pts | mean=5.46e-04 | max=7.27e-03 | t_max=0.281 | cands= 4405 | wall=266.0s
#   79000 pts | mean=5.46e-04 | max=7.27e-03 | t_max=0.281 | cands= 4351 | wall=268.7s
#   79500 pts | mean=5.47e-04 | max=7.27e-03 | t_max=0.281 | cands= 4280 | wall=271.5s
#   80000 pts | mean=5.48e-04 | max=7.27e-03 | t_max=0.281 | cands= 4182 | wall=274.3s
#   80500 pts | mean=5.49e-04 | max=7.27e-03 | t_max=0.281 | cands= 4175 | wall=277.3s
#   81000 pts | mean=5.50e-04 | max=7.27e-03 | t_max=0.281 | cands= 4066 | wall=280.3s
#   81500 pts | mean=5.51e-04 | max=7.27e-03 | t_max=0.281 | cands= 4163 | wall=283.2s
#   82000 pts | mean=5.51e-04 | max=7.27e-03 | t_max=0.281 | cands= 4192 | wall=286.0s
#   82500 pts | mean=5.52e-04 | max=7.27e-03 | t_max=0.281 | cands= 4118 | wall=289.0s
#   83000 pts | mean=5.53e-04 | max=7.27e-03 | t_max=0.281 | cands= 4031 | wall=292.0s
#   83500 pts | mean=5.54e-04 | max=7.27e-03 | t_max=0.281 | cands= 4089 | wall=295.0s
#   84000 pts | mean=5.55e-04 | max=7.27e-03 | t_max=0.281 | cands= 4099 | wall=297.9s
#   84500 pts | mean=5.56e-04 | max=7.27e-03 | t_max=0.281 | cands= 3920 | wall=301.1s
#   85000 pts | mean=5.56e-04 | max=7.27e-03 | t_max=0.281 | cands= 3882 | wall=304.0s
#   85500 pts | mean=5.57e-04 | max=7.27e-03 | t_max=0.281 | cands= 3863 | wall=307.2s
#   86000 pts | mean=5.58e-04 | max=7.27e-03 | t_max=0.281 | cands= 3946 | wall=310.1s
#   86500 pts | mean=5.58e-04 | max=7.27e-03 | t_max=0.281 | cands= 3945 | wall=313.1s
#   87000 pts | mean=5.59e-04 | max=7.27e-03 | t_max=0.281 | cands= 3949 | wall=316.1s
#   87500 pts | mean=5.60e-04 | max=7.27e-03 | t_max=0.281 | cands= 3909 | wall=319.4s
#   88000 pts | mean=5.61e-04 | max=7.27e-03 | t_max=0.281 | cands= 3807 | wall=322.8s
#   88500 pts | mean=5.62e-04 | max=7.27e-03 | t_max=0.281 | cands= 3617 | wall=326.1s
#   89000 pts | mean=5.62e-04 | max=7.27e-03 | t_max=0.281 | cands= 3771 | wall=329.1s
#   89500 pts | mean=5.63e-04 | max=7.27e-03 | t_max=0.281 | cands= 3673 | wall=332.4s
#   90000 pts | mean=5.64e-04 | max=7.27e-03 | t_max=0.281 | cands= 3431 | wall=335.7s
#   90500 pts | mean=5.65e-04 | max=7.27e-03 | t_max=0.281 | cands= 3493 | wall=339.0s
#   91000 pts | mean=5.66e-04 | max=7.27e-03 | t_max=0.281 | cands= 3487 | wall=342.3s
#   91500 pts | mean=5.66e-04 | max=7.27e-03 | t_max=0.281 | cands= 3558 | wall=345.6s
#   92000 pts | mean=5.67e-04 | max=7.27e-03 | t_max=0.281 | cands= 3605 | wall=348.9s
#   92500 pts | mean=5.67e-04 | max=7.27e-03 | t_max=0.281 | cands= 3580 | wall=352.3s
#   93000 pts | mean=5.68e-04 | max=7.27e-03 | t_max=0.281 | cands= 3594 | wall=355.5s
#   93500 pts | mean=5.69e-04 | max=7.27e-03 | t_max=0.281 | cands= 3482 | wall=358.9s
#   94000 pts | mean=5.70e-04 | max=7.27e-03 | t_max=0.281 | cands= 3325 | wall=362.2s
#   94500 pts | mean=5.71e-04 | max=7.27e-03 | t_max=0.281 | cands= 3208 | wall=365.6s
#   95000 pts | mean=5.72e-04 | max=7.27e-03 | t_max=0.281 | cands= 3372 | wall=368.8s
#   95500 pts | mean=5.72e-04 | max=7.27e-03 | t_max=0.281 | cands= 3273 | wall=372.3s
#   96000 pts | mean=5.73e-04 | max=7.27e-03 | t_max=0.281 | cands= 3356 | wall=375.5s
#   96500 pts | mean=5.74e-04 | max=7.27e-03 | t_max=0.281 | cands= 3347 | wall=379.0s
#   97000 pts | mean=5.74e-04 | max=7.27e-03 | t_max=0.281 | cands= 3187 | wall=382.4s
#   97500 pts | mean=5.75e-04 | max=7.27e-03 | t_max=0.281 | cands= 3165 | wall=385.9s
#   98000 pts | mean=5.76e-04 | max=7.27e-03 | t_max=0.281 | cands= 2945 | wall=389.4s
#   98500 pts | mean=5.76e-04 | max=7.27e-03 | t_max=0.281 | cands= 3018 | wall=392.9s
#   99000 pts | mean=5.77e-04 | max=7.27e-03 | t_max=0.281 | cands= 2989 | wall=396.3s
#   99500 pts | mean=5.77e-04 | max=7.27e-03 | t_max=0.281 | cands= 2854 | wall=399.9s
#   100000 pts | mean=5.78e-04 | max=7.27e-03 | t_max=0.281 | cands= 2751 | wall=403.4s
#
# ────────────────────────────────────────────────────────
#   Computed  : 100000 points
#   Mean err  : 5.780e-04
#   Max  err  : 7.269e-03
#   Wall time : 403.4s
#
#   Rejections (total attempts: 614906)
#     proximity :      0  (0.0%)
#     no_nb     :    138  (0.0%)
#     geometry  :  64932  (10.6%)
#     cond      : 296138  (48.2%)
#     weights   : 153698  (25.0%)

# %%
# %matplotlib widget
import importlib
from Plots import interactive_plot as interactive_plot_module
from Plots import error_analysis as error_analysis_module

importlib.reload(interactive_plot_module)
importlib.reload(error_analysis_module)

interactive_plot = interactive_plot_module.interactive_plot
error_analysis = error_analysis_module.error_analysis

# Extract IC and BC coordinates from visited._pts
ic_x = np.array([p[0] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])
ic_t = np.array([p[1] for p in visited._pts if p[1] == 0.0 and 0 < p[0] < 1.0])

bc_x = np.array([p[0] for p in visited._pts if p[0] in [0.0, 1.0]])
bc_t = np.array([p[1] for p in visited._pts if p[0] in [0.0, 1.0]])

interactive_plot(
    point_data,
    visited._pts,   # pass the raw list so the plot code sees (x, t, u) tuples
    u_true,
    fd_interp,
    T,
    dt_fd,          # was dt_sc
    ic_x,
    ic_t,
    bc_x,
    bc_t
)

error_analysis(point_data, u_true=u_true, fd_interp=fd_interp)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Convergence study
# ## Fix a fine reference grid, sweep candidate spacing via stride.

# %%
import numpy as np
import matplotlib.pyplot as plt

T             = 1
n_max         = 5000
strides       = [1, 2, 4,8]    # ← added 8
nx_fd_cv      = 400
max_points_cv = 2_000
cv_seed       = 42

# Save original globals so we can restore after the study
_orig = {k: globals()[k] for k in
         ['nx_fd','x_fd','dx_fd','nt_fd','t_fd','dt_fd','max_points']}

# ── Local stencil check that accepts coarser span_ref ────────────────────────
def stencil_is_good_cv(dx_i, dt_i, span_ref):
    if np.min(dx_i) * np.max(dx_i) > 0:
        return False
    if np.max(dx_i) - np.min(dx_i) < 0.9 * span_ref:   # uses effective dx
        return False
    h   = max(np.max(np.abs(dx_i)), 1e-12)
    tau = max(np.max(np.abs(dt_i)), 1e-12)
    pts = np.column_stack([dx_i / h, dt_i / tau])
    ev  = np.linalg.eigvalsh(pts.T @ pts)
    if ev[0] < 1e-14 or ev[1] / ev[0] > isotropy_max:
        return False
    return True

# ── Fix reference grid ────────────────────────────────────────────────────────
nx_fd  = nx_fd_cv
x_fd   = np.linspace(0.0, 1.0, nx_fd)
dx_fd  = x_fd[1] - x_fd[0]
dt_cfl = min(0.9 * dx_fd / c, 0.45 * dx_fd**2 / alpha)
nt_fd  = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt_fd)
dt_fd  = t_fd[1] - t_fd[0]
max_points = max_points_cv

print(f"Reference grid: nx={nx_fd}, nt={nt_fd}, dx={dx_fd:.4f}, dt={dt_fd:.5f}")
print(f"CFL — advection: {c*dt_fd/dx_fd:.3f}, diffusion: {alpha*dt_fd/dx_fd**2:.3f}\n")

cv_results = []   # (effective_dx, mean_err, max_err)

for stride in strides:
    eff_dx = stride * dx_fd
    print(f"Stride {stride}  — effective dx={eff_dx:.4f}", flush=True)

    _, fd_interp_cv = build_fd_reference()

    visited_cv = VisitedSet()
    for ix in range(nx_fd):
        visited_cv.add(x_fd[ix], 0.0, u_true(x_fd[ix], 0.0))
    for it in range(1, nt_fd):
        visited_cv.add(0.0, t_fd[it], 0.0)
        visited_cv.add(1.0, t_fd[it], 0.0)

    cand_keys = set()
    cand_list = []

    def push_cv(ix, it):
        if ix % stride != 0 or it % stride != 0:
            return
        if (ix, it) not in cand_keys:
            cand_keys.add((ix, it))
            cand_list.append((x_fd[ix], t_fd[it]))

    np.random.seed(cv_seed)
    for ix in range(stride, nx_fd - 1, stride):
        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix = ix + dix * stride
                nit = dit * stride
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push_cv(nix, nit)

    rej = dict(proximity=0, no_nb=0, geometry=0, cond=0, weights=0, bounds=0)
    point_data_cv = []

    while cand_list and len(point_data_cv) < max_points_cv:
        if len(cand_list) > max_candidates:
            del cand_list[:len(cand_list) - max_candidates]

        idx            = np.random.randint(len(cand_list))
        x_star, t_star = cand_list[idx]
        cand_list[idx] = cand_list[-1]
        cand_list.pop()
        ix_s = int(round(x_star / dx_fd))
        it_s = int(round(t_star / dt_fd))
        cand_keys.discard((ix_s, it_s))

        if visited_cv.is_too_close(x_star, t_star):
            rej['proximity'] += 1
            continue

        nb = visited_cv.find_neighbours(x_star, t_star)
        if nb is None:
            rej['no_nb'] += 1
            continue

        nb_pts = np.array(nb)
        dx_i   = nb_pts[:, 0] - x_star
        dt_i   = nb_pts[:, 1] - t_star

        if not stencil_is_good_cv(dx_i, dt_i, span_ref=eff_dx):   # ← passes eff_dx
            rej['geometry'] += 1
            continue

        w, cond = solve_weights(dx_i, dt_i)
        if w is None:
            rej['cond' if cond > cond_max else 'weights'] += 1
            continue

        u_hat = float(w @ nb_pts[:, 2])
        if abs(u_hat) > u_bound:
            rej['bounds'] += 1
            continue

        visited_cv.add(x_star, t_star, u_hat)

        for dix in range(-spawn_nx, spawn_nx + 1):
            for dit in range(1, spawn_nt + 1):
                nix = ix_s + dix * stride
                nit = it_s + dit * stride
                if 1 <= nix <= nx_fd - 2 and nit < nt_fd:
                    push_cv(nix, nit)

        u_ref = float(fd_interp_cv([[x_star, t_star]])[0])
        point_data_cv.append({'err': abs(u_hat - u_ref)})

    # ── Guard against empty results ───────────────────────────────────────────
    if len(point_data_cv) == 0:
        print(f"  pts=0 — all candidates rejected at this stride")
        cv_results.append((eff_dx, np.nan, np.nan))
        continue

    errs = np.array([p['err'] for p in point_data_cv])
    print(f"  pts={len(point_data_cv)}, mean={errs.mean():.3e}, max={errs.max():.3e}")
    total = sum(rej.values()) + len(point_data_cv)
    for r, n in rej.items():
        if n > 0:
            print(f"    {r:10s}: {n} ({100*n/total:.0f}%)")
    cv_results.append((eff_dx, errs.mean(), errs.max()))

# Restore original globals
for k, v in _orig.items():
    globals()[k] = v

# ── Plot — skip any nan entries ───────────────────────────────────────────────
valid = [(dx, me, mx) for dx, me, mx in cv_results if not np.isnan(me)]

if len(valid) < 2:
    print("Not enough valid strides to plot — check rejection stats above.")
else:
    dxs   = np.array([r[0] for r in valid])
    means = np.array([r[1] for r in valid])
    maxes = np.array([r[2] for r in valid])

    fig, ax = plt.subplots(figsize=(6, 4))
    ax.loglog(dxs, means, 'o-',  label='mean error')
    ax.loglog(dxs, maxes, 's--', label='max error')

    for order, ls, label in [(1, ':', 'O(dx)'), (2, '-.', 'O(dx²)')]:
        ref = means[0] * (dxs / dxs[0])**order
        ax.loglog(dxs, ref, color='gray', linestyle=ls, linewidth=0.8, label=label)

    ax.set_xlabel('Effective dx (your method)')
    ax.set_ylabel('Error vs FD reference')
    ax.set_title('Convergence study')
    ax.legend()
    ax.grid(True, which='both', alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# Reference grid: nx=400, nt=17690, dx=0.0025, dt=0.00006
# CFL — advection: 0.011, diffusion: 0.450
#
# Stride 1  — effective dx=0.0025
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 91
#      88 it_s = int(round(t_star / dt_fd))
#      89 cand_keys.discard((ix_s, it_s))
# ---> 91 if visited_cv.is_too_close(x_star, t_star):
#      92     rej['proximity'] += 1
#      93     continue
#
# AttributeError: 'VisitedSet' object has no attribute 'is_too_close'

# %%
"""
UQ study.
Runs the integrator n_runs times with different seeds, then plots:
  1. Mean error vs u_true per (x,t) bin
  2. Std of error per bin  (high std = RL should focus here)
  3. Visit frequency per bin (coverage reliability)
"""

import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# ── Parameters ────────────────────────────────────────────────────────────────
n_runs        = 5
uq_seeds      = range(n_runs)
uq_max_points = 4_000    # per run — keep modest so total time is reasonable
n_bins_x      = 20       # spatial bins
n_bins_t      = 20       # temporal bins
T= 0.1
# ── Run integrator n_runs times ───────────────────────────────────────────────
print(f"Running {n_runs} integrations ({uq_max_points} pts each)...\n")

_orig_max = max_points
max_points = uq_max_points   # temporarily override stopping criterion

all_point_data = []
for i, seed in enumerate(uq_seeds):
    visited_uq, pd_uq, _ = run_integrator(seed=seed)
    all_point_data.append(pd_uq)
    errs = [p['err'] for p in pd_uq]
    print(f"  run {i+1:2d} | pts={len(pd_uq):4d} | "
          f"mean={np.mean(errs):.2e} | max={np.max(errs):.2e}")

max_points = _orig_max   # restore

# ── Bin setup ─────────────────────────────────────────────────────────────────
x_edges = np.linspace(0.0, 1.0, n_bins_x + 1)
t_edges = np.linspace(0.0, T,   n_bins_t + 1)

# For each bin: collect errors across all runs
# bin_errors[(ix, it)] = list of error values from all runs
bin_errors  = defaultdict(list)
bin_counts  = np.zeros((n_bins_x, n_bins_t))   # how many runs visited this bin

# ── Bin filling — use stored err, not recomputed ──────────────────────
for run_data in all_point_data:
    visited_bins = set()
    for p in run_data:
        ix = min(int(p['x'] / (1.0 / n_bins_x)), n_bins_x - 1)
        it = min(int(p['t'] / (T   / n_bins_t)), n_bins_t - 1)
        bin_errors[(ix, it)].append(p['err'])   # ← was: abs(p['u'] - u_true(...))
        visited_bins.add((ix, it))
    for (ix, it) in visited_bins:
        bin_counts[ix, it] += 1

# Build mean and std arrays
mean_err = np.full((n_bins_x, n_bins_t), np.nan)
std_err  = np.full((n_bins_x, n_bins_t), np.nan)

for (ix, it), errs in bin_errors.items():
    if len(errs) >= 2:
        mean_err[ix, it] = np.mean(errs)
        std_err[ix, it]  = np.std(errs)
    elif len(errs) == 1:
        mean_err[ix, it] = errs[0]

# Visit frequency: fraction of runs that visited each bin
visit_freq = bin_counts / n_runs

# ── Plot ──────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
x_centers = 0.5 * (x_edges[:-1] + x_edges[1:])
t_centers = 0.5 * (t_edges[:-1] + t_edges[1:])

def heatmap(ax, data, title, cmap, label):
    im = ax.pcolormesh(x_edges, t_edges, data.T,
                       cmap=cmap, shading='flat')
    plt.colorbar(im, ax=ax, label=label)
    ax.set_xlabel('x')
    ax.set_ylabel('t')
    ax.set_title(title)

# 1. Mean error vs u_true
heatmap(axes[0], mean_err,
        f'Mean |u - u_true| across {n_runs} runs',
        'Reds', '|u - u_true|')

# 2. Std of error — high = RL should focus here
heatmap(axes[1], std_err,
        'Std of |u - u_true| across runs\n(high = sensitive to random placement)',
        'Oranges', 'std(|u - u_true|)')

# 3. Visit frequency — low = coverage unreliable
heatmap(axes[2], visit_freq,
        'Visit frequency\n(fraction of runs that covered each bin)',
        'Blues', 'fraction of runs')

plt.suptitle(f'UQ across {n_runs} random runs  '
             f'(α={alpha}, c={c}, T={T}, {uq_max_points} pts/run)',
             fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
    
all_errs = [p['err'] for pd in all_point_data for p in pd]  # ← same fix
print(f"\nAcross all {n_runs} runs:")
print(f"  Overall mean error : {np.mean(all_errs):.3e}")
print(f"  Overall std error  : {np.std(all_errs):.3e}")
print(f"  Overall max error  : {np.max(all_errs):.3e}")
print(f"\nBins never visited by any run : "
      f"{np.sum(bin_counts == 0)} / {n_bins_x*n_bins_t}")
print(f"Bins visited by all {n_runs} runs: "
      f"{np.sum(bin_counts == n_runs)} / {n_bins_x*n_bins_t}")
# Out:
# Running 5 integrations (4000 pts each)...
#
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 4000 computed points
#
#     500 pts | mean=1.76e-04 | max=7.56e-04 | t_max=0.028 | cands= 2333 | wall=4.7s
#    1000 pts | mean=2.56e-04 | max=1.32e-03 | t_max=0.039 | cands= 3123 | wall=9.8s
#    1500 pts | mean=3.21e-04 | max=1.72e-03 | t_max=0.051 | cands= 3837 | wall=14.8s
#    2000 pts | mean=3.82e-04 | max=1.78e-03 | t_max=0.058 | cands= 4377 | wall=21.1s
#    2500 pts | mean=4.38e-04 | max=2.12e-03 | t_max=0.063 | cands= 4845 | wall=28.3s
#    3000 pts | mean=4.99e-04 | max=2.16e-03 | t_max=0.073 | cands= 5196 | wall=36.0s
#    3500 pts | mean=5.44e-04 | max=3.05e-03 | t_max=0.092 | cands= 5655 | wall=44.7s
#    4000 pts | mean=5.90e-04 | max=3.05e-03 | t_max=0.096 | cands= 5915 | wall=54.0s
#
# ────────────────────────────────────────────────────────
#   Computed  : 4000 points
#   Mean err  : 5.901e-04
#   Max  err  : 3.046e-03
#   Wall time : 54.1s
#
#   Rejections (total attempts: 10790)
#     proximity :   3995  (37.0%)
#     no_nb     :      1  (0.0%)
#     geometry  :    675  (6.3%)
#     cond      :      0  (0.0%)
#     weights   :   2119  (19.6%)
#   run  1 | pts=4000 | mean=5.90e-04 | max=3.05e-03
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 4000 computed points
#
#     500 pts | mean=2.03e-04 | max=1.14e-03 | t_max=0.028 | cands= 2286 | wall=4.9s
#    1000 pts | mean=2.94e-04 | max=3.34e-03 | t_max=0.035 | cands= 3408 | wall=10.9s
#    1500 pts | mean=3.61e-04 | max=3.34e-03 | t_max=0.050 | cands= 4352 | wall=17.1s
#    2000 pts | mean=4.16e-04 | max=3.34e-03 | t_max=0.057 | cands= 4807 | wall=24.3s
#    2500 pts | mean=4.69e-04 | max=3.34e-03 | t_max=0.065 | cands= 5245 | wall=31.6s
#    3000 pts | mean=5.32e-04 | max=3.34e-03 | t_max=0.076 | cands= 5732 | wall=40.2s
#    3500 pts | mean=6.01e-04 | max=3.34e-03 | t_max=0.084 | cands= 6212 | wall=49.3s
#    4000 pts | mean=6.67e-04 | max=3.83e-03 | t_max=0.096 | cands= 6707 | wall=59.4s
#
# ────────────────────────────────────────────────────────
#   Computed  : 4000 points
#   Mean err  : 6.671e-04
#   Max  err  : 3.827e-03
#   Wall time : 59.4s
#
#   Rejections (total attempts: 9659)
#     proximity :   3212  (33.3%)
#     no_nb     :      2  (0.0%)
#     geometry  :    476  (4.9%)
#     cond      :      0  (0.0%)
#     weights   :   1969  (20.4%)
#   run  2 | pts=4000 | mean=6.67e-04 | max=3.83e-03
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 4000 computed points
#
#     500 pts | mean=1.87e-04 | max=9.59e-04 | t_max=0.027 | cands= 2291 | wall=5.3s
#    1000 pts | mean=2.45e-04 | max=1.00e-03 | t_max=0.037 | cands= 2907 | wall=11.3s
#    1500 pts | mean=3.05e-04 | max=1.24e-03 | t_max=0.048 | cands= 3696 | wall=17.8s
#    2000 pts | mean=3.52e-04 | max=1.53e-03 | t_max=0.054 | cands= 4138 | wall=25.7s
#    2500 pts | mean=3.93e-04 | max=1.53e-03 | t_max=0.062 | cands= 4676 | wall=34.8s
#    3000 pts | mean=4.29e-04 | max=1.88e-03 | t_max=0.064 | cands= 4958 | wall=44.2s
#    3500 pts | mean=4.60e-04 | max=2.07e-03 | t_max=0.066 | cands= 5083 | wall=54.1s
#    4000 pts | mean=4.91e-04 | max=2.07e-03 | t_max=0.067 | cands= 5261 | wall=64.9s
#
# ────────────────────────────────────────────────────────
#   Computed  : 4000 points
#   Mean err  : 4.911e-04
#   Max  err  : 2.074e-03
#   Wall time : 65.0s
#
#   Rejections (total attempts: 11241)
#     proximity :   4472  (39.8%)
#     no_nb     :      1  (0.0%)
#     geometry  :    683  (6.1%)
#     cond      :      0  (0.0%)
#     weights   :   2085  (18.5%)
#   run  3 | pts=4000 | mean=4.91e-04 | max=2.07e-03
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 4000 computed points
#
#     500 pts | mean=1.84e-04 | max=1.12e-03 | t_max=0.028 | cands= 2212 | wall=5.0s
#    1000 pts | mean=2.48e-04 | max=1.44e-03 | t_max=0.038 | cands= 2858 | wall=10.5s
#    1500 pts | mean=2.96e-04 | max=1.44e-03 | t_max=0.040 | cands= 3266 | wall=17.2s
#    2000 pts | mean=3.45e-04 | max=1.44e-03 | t_max=0.052 | cands= 3674 | wall=24.6s
#    2500 pts | mean=3.88e-04 | max=1.54e-03 | t_max=0.058 | cands= 4231 | wall=33.5s
#    3000 pts | mean=4.29e-04 | max=2.06e-03 | t_max=0.065 | cands= 4691 | wall=42.8s
#    3500 pts | mean=4.62e-04 | max=2.06e-03 | t_max=0.069 | cands= 5022 | wall=53.0s
#    4000 pts | mean=4.97e-04 | max=2.06e-03 | t_max=0.071 | cands= 5413 | wall=63.9s
#
# ────────────────────────────────────────────────────────
#   Computed  : 4000 points
#   Mean err  : 4.968e-04
#   Max  err  : 2.059e-03
#   Wall time : 63.9s
#
#   Rejections (total attempts: 12081)
#     proximity :   4908  (40.6%)
#     no_nb     :      2  (0.0%)
#     geometry  :    766  (6.3%)
#     cond      :      0  (0.0%)
#     weights   :   2405  (19.9%)
#   run  4 | pts=4000 | mean=4.97e-04 | max=2.06e-03
# Building FD reference...
#   dx=0.0101  dt=0.00092
#   IC+BC points: 2278
#   Initial candidates: 294
#   Stopping at 4000 computed points
#
#     500 pts | mean=2.53e-04 | max=1.56e-03 | t_max=0.035 | cands= 2449 | wall=5.0s
#    1000 pts | mean=3.29e-04 | max=1.75e-03 | t_max=0.041 | cands= 3061 | wall=10.9s
#    1500 pts | mean=3.64e-04 | max=1.75e-03 | t_max=0.044 | cands= 3701 | wall=17.6s
#    2000 pts | mean=4.10e-04 | max=1.75e-03 | t_max=0.059 | cands= 4310 | wall=25.4s
#    2500 pts | mean=4.56e-04 | max=2.08e-03 | t_max=0.061 | cands= 4880 | wall=33.9s
#    3000 pts | mean=4.96e-04 | max=2.33e-03 | t_max=0.062 | cands= 5128 | wall=43.2s
#    3500 pts | mean=5.42e-04 | max=2.33e-03 | t_max=0.073 | cands= 5574 | wall=53.0s
#    4000 pts | mean=5.87e-04 | max=2.35e-03 | t_max=0.080 | cands= 5880 | wall=64.0s
#
# ────────────────────────────────────────────────────────
#   Computed  : 4000 points
#   Mean err  : 5.866e-04
#   Max  err  : 2.354e-03
#   Wall time : 64.0s
#
#   Rejections (total attempts: 10292)
#     proximity :   3817  (37.1%)
#     no_nb     :      0  (0.0%)
#     geometry  :    552  (5.4%)
#     cond      :      0  (0.0%)
#     weights   :   1923  (18.7%)
#   run  5 | pts=4000 | mean=5.87e-04 | max=2.35e-03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Across all 5 runs:
#   Overall mean error : 5.663e-04
#   Overall std error  : 4.842e-04
#   Overall max error  : 3.827e-03
#
# Bins never visited by any run : 111 / 400
# Bins visited by all 5 runs: 189 / 400
