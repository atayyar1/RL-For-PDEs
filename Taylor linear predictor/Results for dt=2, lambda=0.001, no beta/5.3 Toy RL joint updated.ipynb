# %% [markdown]
# Libraries

# %%
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces

# %% [markdown]
# PDE and FD reference Parameters

# %%
# ── PDE ────────────────────────────────────────────────────────
alpha = 0.05

# ── FD reference grid ────────────────────────────────────────── 
nx    = 30
T     = 0.6
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

# %% [markdown]
# Analytical diffusion solution

# %%
def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# __init__

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()                    # NEW

    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))   # NEW
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()
    def contains(self, x, t):                          # NEW
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None

            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)

            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None

            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]

            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > 1e4:
        return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    if np.max(np.abs(w)) > 3.0 / len(dx_i):
        return None, 'weights'
    if np.min(w) < -1.0:
        return None, 'weights'

    return w, 'ok'

# %% [markdown]
# PDEEnvironment

# %%
class PDEEnvironment(gym.Env):

    def __init__(self, t_star_steps=5):
        super().__init__()

        # ── PDE constants ───────────────────────────────────────────────────────
        self.alpha = alpha

        # ── Grid variables ──────────────────────────────────────────────────────
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T

        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = 500
        self.lam    = 0.001
        self.Kx     = 1
        self.Kt     = 1

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions ─────────────────────────────────────────────
        self.N = 10

        mid    = self.nx // 2
        margin = 1
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets = [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(3 * self.N + 2,), dtype=np.float32
        )
        self.action_space = spaces.MultiDiscrete([self.N, 3, 2])


    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_init_x])

        self.step_count = 0

        return self._build_obs(), {}


    def _build_obs(self):
        return np.array([
            *self.walker_x,
            *self.walker_t,
            *self.walker_u,
            self.x_star,
            self.t_star
        ], dtype=np.float32)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        if not (np.min(dx_i) < 0 < np.max(dx_i)):
            return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        return u_hat, True, nb[:, :2], 'ok'

    def step(self, action):

        self.step_count += 1
        done   = False
        reward = 0.0

        walker_idx, dx_idx, dt_idx = action
        i  = int(walker_idx)
        dx = (int(dx_idx) - self.Kx) * self.dx
        dt = int(dt_idx) * self.dt

        info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

        x_new = self.walker_x[i] + dx
        t_new = self.walker_t[i] + dt

        if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
            info['rejected'] = 'bounds'

        elif self.visited.contains(x_new, t_new):
            info['rejected'] = 'collision'

        else:
            u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
            if not success:
                info['rejected'] = reason
            else:
                self.visited.add(x_new, t_new, u_hat)
                self.walker_x[i] = x_new
                self.walker_t[i] = t_new
                self.walker_u[i] = u_hat
                self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                info['accepted'] = True

                if (abs(x_new - self.x_star) < self.eps_x and
                    abs(t_new - self.t_star) < self.eps_t):
                    done = True
                    info['reached'] = True

        if done:
            u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
            u_ref           = u_true(self.x_star, self.t_star)

            if u_pred is None:
                reward        = -1.0
                info['error'] = None
            else:
                reward         = -abs(u_pred - u_ref) - self.lam * self.step_count
                info['u_pred'] = u_pred
                info['u_ref']  = u_ref
                info['error']  = abs(u_pred - u_ref)
                info['k_term'] = self.step_count

        elif self.step_count >= self.K_max:
            done = True
            reward = -1.0 - self.lam * self.step_count
            info['timeout'] = True

        return self._build_obs(), reward, done, False, info

# %%
env      = PDEEnvironment()
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()                         # MultiDiscrete sample
    state, reward, done, _, info = env.step(action)

    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")
for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")

import matplotlib.pyplot as plt
import matplotlib.cm as cm

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          137
# Reward:         -0.137003
# Reached:        True
# Timeout:        False
# Total accepted: 61
# Total rejected: 76
# Rejection reasons:
#   collision : 43
#   geometry  : 17
#   bounds    : 9
#   weights   : 7

# %%
def plot_trajectories(model, t_star_steps, save=True, title_suffix=""):
    env = PDEEnvironment(t_star_steps=t_star_steps)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=False)
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, zorder=2, color=colors[i])
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4, label=f'Walker {i}')

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=5, label='z*')
    ax.set_xlabel('x')
    ax.set_ylabel('t')
    ax.set_title(f't_star={t_star_steps}·dt  reached={info.get("reached", False)}{title_suffix}')
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)
    plt.tight_layout()

    if save:
        fname = f'trajectories_tstar{t_star_steps}_step{title_suffix.strip()}.png'.replace(" ", "_").replace("—", "")
        fig.savefig(fname, dpi=120)
        print(f"Saved: {fname}")
    plt.close(fig)

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback

class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True


class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, plot_freq=50_000, verbose=0):
        super().__init__(verbose)
        self.t_star_steps  = t_star_steps
        self.plot_freq     = plot_freq
        self.last_plot_at  = 0

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(
                self.model,
                self.t_star_steps,
                save=True,
                title_suffix=f"_step{self.num_timesteps}"
            )
        return True

def make_env(t_star_steps):
    def _init():
        return Monitor(PDEEnvironment(t_star_steps=t_star_steps))
    return _init

t_star_steps = 2
n_envs       = 15
n_steps      = 2048 // n_envs

vec_env = SubprocVecEnv([make_env(t_star_steps) for _ in range(n_envs)])

model = PPO(
    "MlpPolicy",
    vec_env,
    verbose=1,
    gamma=1.0,
    device="cpu",
    n_steps=n_steps,
    batch_size=60,
    tensorboard_log="./logs/",
)

print(f"Training — t_star = {t_star_steps}·dt = {t_star_steps * dt:.4f}")

model.learn(
    total_timesteps=5_000_000,
    reset_num_timesteps=False,
    tb_log_name="joint_policy",
    log_interval=10,
    callback=[
        ReachedRateCallback(),
        PlotCallback(t_star_steps, plot_freq=50_000),
        CheckpointCallback(save_freq=100_000, save_path="./ckpts/"),
    ],
)
model.save(f"checkpoint_tstar{t_star_steps}")
# Out:
# Using cpu device
# Training — t_star = 2·dt = 0.0211
# Logging to ./logs/joint_policy_0
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 225        |
# |    ep_rew_mean          | -0.615     |
# |    mean_error_on_reach  | 2.04e-05   |
# |    mean_kterm_on_reach  | 49.3       |
# |    reached_rate         | 0.61       |
# | time/                   |            |
# |    fps                  | 1714       |
# |    iterations           | 10         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 20400      |
# | train/                  |            |
# |    approx_kl            | 0.01098507 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.86      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00137    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.0106     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 226        |
# |    ep_rew_mean          | -0.536     |
# |    mean_error_on_reach  | 2.02e-05   |
# |    mean_kterm_on_reach  | 83.7       |
# |    reached_rate         | 0.69       |
# | time/                   |            |
# |    fps                  | 1636       |
# |    iterations           | 20         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 40800      |
# | train/                  |            |
# |    approx_kl            | 0.01358735 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00349   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0134    |
# |    value_loss           | 0.00912    |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step50010.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | -0.774      |
# |    mean_error_on_reach  | 2.01e-05    |
# |    mean_kterm_on_reach  | 115         |
# |    reached_rate         | 0.54        |
# | time/                   |             |
# |    fps                  | 1599        |
# |    iterations           | 30          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 61200       |
# | train/                  |             |
# |    approx_kl            | 0.012513458 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0438     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0307      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | -1.19       |
# |    mean_error_on_reach  | 2e-05       |
# |    mean_kterm_on_reach  | 122         |
# |    reached_rate         | 0.25        |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 40          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 81600       |
# | train/                  |             |
# |    approx_kl            | 0.010565681 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step100020.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | -1.4        |
# |    mean_error_on_reach  | 2e-05       |
# |    mean_kterm_on_reach  | 131         |
# |    reached_rate         | 0.09        |
# | time/                   |             |
# |    fps                  | 1614        |
# |    iterations           | 50          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 102000      |
# | train/                  |             |
# |    approx_kl            | 0.006790688 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00129    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00411    |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -1.42       |
# |    mean_error_on_reach  | 2.03e-05    |
# |    mean_kterm_on_reach  | 137         |
# |    reached_rate         | 0.07        |
# | time/                   |             |
# |    fps                  | 1611        |
# |    iterations           | 60          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 122400      |
# | train/                  |             |
# |    approx_kl            | 0.008245708 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0141      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 0.00711     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -1.43       |
# |    mean_error_on_reach  | 2.05e-05    |
# |    mean_kterm_on_reach  | 142         |
# |    reached_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 70          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 142800      |
# | train/                  |             |
# |    approx_kl            | 0.016925946 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 0.00673     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step150030.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -1.46       |
# |    mean_error_on_reach  | 2.05e-05    |
# |    mean_kterm_on_reach  | 142         |
# |    reached_rate         | 0.03        |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 80          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.010123539 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.00502     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 2.05e-05    |
# |    mean_kterm_on_reach  | 142         |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 1630        |
# |    iterations           | 90          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 183600      |
# | train/                  |             |
# |    approx_kl            | 0.006037139 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00107    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.000315   |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step200040.png
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -1.5       |
# |    mean_error_on_reach  | 2.05e-05   |
# |    mean_kterm_on_reach  | 142        |
# |    reached_rate         | 0          |
# | time/                   |            |
# |    fps                  | 1616       |
# |    iterations           | 100        |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 204000     |
# | train/                  |            |
# |    approx_kl            | 0.01927382 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0121    |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.00528   |
# |    value_loss           | 0.000686   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -1.49        |
# |    mean_error_on_reach  | 2.07e-05     |
# |    mean_kterm_on_reach  | 146          |
# |    reached_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 1624         |
# |    iterations           | 110          |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 224400       |
# | train/                  |              |
# |    approx_kl            | 0.0066965185 |
# |    clip_fraction        | 0.0921       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0198      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 0.000434     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.49       |
# |    mean_error_on_reach  | 2.07e-05    |
# |    mean_kterm_on_reach  | 146         |
# |    reached_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 1634        |
# |    iterations           | 120         |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 244800      |
# | train/                  |             |
# |    approx_kl            | 0.013899668 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00248    |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 0.000274    |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step250050.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 2.07e-05    |
# |    mean_kterm_on_reach  | 146         |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 1641        |
# |    iterations           | 130         |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 265200      |
# | train/                  |             |
# |    approx_kl            | 0.014988817 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 4.55e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 2.07e-05    |
# |    mean_kterm_on_reach  | 146         |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 1650        |
# |    iterations           | 140         |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.011983002 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 6.7e-05     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step300060.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 475         |
# |    ep_rew_mean          | -1.35       |
# |    mean_error_on_reach  | 2.01e-05    |
# |    mean_kterm_on_reach  | 175         |
# |    reached_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 1650        |
# |    iterations           | 150         |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.017064447 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000172   |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 0.0073      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | -0.793      |
# |    mean_error_on_reach  | 1.89e-05    |
# |    mean_kterm_on_reach  | 198         |
# |    reached_rate         | 0.53        |
# | time/                   |             |
# |    fps                  | 1652        |
# |    iterations           | 160         |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 326400      |
# | train/                  |             |
# |    approx_kl            | 0.011052789 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0023     |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 0.00574     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | -0.559      |
# |    mean_error_on_reach  | 1.94e-05    |
# |    mean_kterm_on_reach  | 112         |
# |    reached_rate         | 0.67        |
# | time/                   |             |
# |    fps                  | 1647        |
# |    iterations           | 170         |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 346800      |
# | train/                  |             |
# |    approx_kl            | 0.012047805 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 0.00865     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step350070.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | -0.479       |
# |    mean_error_on_reach  | 2.02e-05     |
# |    mean_kterm_on_reach  | 103          |
# |    reached_rate         | 0.73         |
# | time/                   |              |
# |    fps                  | 1639         |
# |    iterations           | 180          |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 367200       |
# | train/                  |              |
# |    approx_kl            | 0.0071053826 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0031       |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 0.0109       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -0.787      |
# |    mean_error_on_reach  | 2.06e-05    |
# |    mean_kterm_on_reach  | 101         |
# |    reached_rate         | 0.51        |
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 190         |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 387600      |
# | train/                  |             |
# |    approx_kl            | 0.013990648 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00997    |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 0.00532     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step400080.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | -1.01       |
# |    mean_error_on_reach  | 2.02e-05    |
# |    mean_kterm_on_reach  | 127         |
# |    reached_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1636        |
# |    iterations           | 200         |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 408000      |
# | train/                  |             |
# |    approx_kl            | 0.010122864 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00498     |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | -1.16        |
# |    mean_error_on_reach  | 2.01e-05     |
# |    mean_kterm_on_reach  | 163          |
# |    reached_rate         | 0.29         |
# | time/                   |              |
# |    fps                  | 1636         |
# |    iterations           | 210          |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 428400       |
# | train/                  |              |
# |    approx_kl            | 0.0104871625 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0238      |
# |    n_updates            | 2090         |
# |    policy_gradient_loss | -0.00677     |
# |    value_loss           | 0.00844      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 458         |
# |    ep_rew_mean          | -1.16       |
# |    mean_error_on_reach  | 1.93e-05    |
# |    mean_kterm_on_reach  | 200         |
# |    reached_rate         | 0.3         |
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 220         |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 448800      |
# | train/                  |             |
# |    approx_kl            | 0.009367885 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 0.00884     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step450090.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | -1.12       |
# |    mean_error_on_reach  | 1.92e-05    |
# |    mean_kterm_on_reach  | 226         |
# |    reached_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1635        |
# |    iterations           | 230         |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 469200      |
# | train/                  |             |
# |    approx_kl            | 0.008076704 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00751    |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000618   |
# |    value_loss           | 0.0043      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 417       |
# |    ep_rew_mean          | -1.05     |
# |    mean_error_on_reach  | 1.93e-05  |
# |    mean_kterm_on_reach  | 262       |
# |    reached_rate         | 0.37      |
# | time/                   |           |
# |    fps                  | 1636      |
# |    iterations           | 240       |
# |    time_elapsed         | 299       |
# |    total_timesteps      | 489600    |
# | train/                  |           |
# |    approx_kl            | 0.0145502 |
# |    clip_fraction        | 0.152     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.39     |
# |    explained_variance   | 0.803     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.017    |
# |    n_updates            | 2390      |
# |    policy_gradient_loss | -0.00879  |
# |    value_loss           | 0.0065    |
# ---------------------------------------
# Saved: trajectories_tstar2_step_step500100.png
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | -0.863       |
# |    mean_error_on_reach  | 1.91e-05     |
# |    mean_kterm_on_reach  | 275          |
# |    reached_rate         | 0.5          |
# | time/                   |              |
# |    fps                  | 1637         |
# |    iterations           | 250          |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 510000       |
# | train/                  |              |
# |    approx_kl            | 0.0147094885 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 0.0154       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 339        |
# |    ep_rew_mean          | -0.829     |
# |    mean_error_on_reach  | 1.92e-05   |
# |    mean_kterm_on_reach  | 237        |
# |    reached_rate         | 0.51       |
# | time/                   |            |
# |    fps                  | 1637       |
# |    iterations           | 260        |
# |    time_elapsed         | 323        |
# |    total_timesteps      | 530400     |
# | train/                  |            |
# |    approx_kl            | 0.01193756 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.42      |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00337    |
# |    n_updates            | 2590       |
# |    policy_gradient_loss | -0.00632   |
# |    value_loss           | 0.00241    |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step550110.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | -1.09       |
# |    mean_error_on_reach  | 1.89e-05    |
# |    mean_kterm_on_reach  | 231         |
# |    reached_rate         | 0.32        |
# | time/                   |             |
# |    fps                  | 1636        |
# |    iterations           | 270         |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 550800      |
# | train/                  |             |
# |    approx_kl            | 0.009111026 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00432     |
# |    n_updates            | 2690        |
# |    policy_gradient_loss | 0.00129     |
# |    value_loss           | 0.0183      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 461         |
# |    ep_rew_mean          | -1.29       |
# |    mean_error_on_reach  | 1.92e-05    |
# |    mean_kterm_on_reach  | 231         |
# |    reached_rate         | 0.17        |
# | time/                   |             |
# |    fps                  | 1634        |
# |    iterations           | 280         |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 571200      |
# | train/                  |             |
# |    approx_kl            | 0.009930507 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00354    |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | 8.9e-05     |
# |    value_loss           | 0.0076      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -1.45       |
# |    mean_error_on_reach  | 1.92e-05    |
# |    mean_kterm_on_reach  | 231         |
# |    reached_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 1634        |
# |    iterations           | 290         |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 591600      |
# | train/                  |             |
# |    approx_kl            | 0.011647061 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 5.9e-06     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step600120.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 1.92e-05    |
# |    mean_kterm_on_reach  | 231         |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 1632        |
# |    iterations           | 300         |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 612000      |
# | train/                  |             |
# |    approx_kl            | 0.007956139 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | 0.000974    |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.49       |
# |    mean_error_on_reach  | 1.91e-05    |
# |    mean_kterm_on_reach  | 232         |
# |    reached_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 1632        |
# |    iterations           | 310         |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 632400      |
# | train/                  |             |
# |    approx_kl            | 0.014432267 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0482     |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step650130.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | -1.42       |
# |    mean_error_on_reach  | 1.89e-05    |
# |    mean_kterm_on_reach  | 235         |
# |    reached_rate         | 0.07        |
# | time/                   |             |
# |    fps                  | 1630        |
# |    iterations           | 320         |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 652800      |
# | train/                  |             |
# |    approx_kl            | 0.010323963 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00224     |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.00877    |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 423         |
# |    ep_rew_mean          | -1.07       |
# |    mean_error_on_reach  | 1.8e-05     |
# |    mean_kterm_on_reach  | 230         |
# |    reached_rate         | 0.35        |
# | time/                   |             |
# |    fps                  | 1628        |
# |    iterations           | 330         |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 673200      |
# | train/                  |             |
# |    approx_kl            | 0.009573121 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | -0.0062     |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -0.782      |
# |    mean_error_on_reach  | 1.57e-05    |
# |    mean_kterm_on_reach  | 218         |
# |    reached_rate         | 0.55        |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 340         |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 693600      |
# | train/                  |             |
# |    approx_kl            | 0.015920069 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 0.013       |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step700140.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | -0.76       |
# |    mean_error_on_reach  | 1.54e-05    |
# |    mean_kterm_on_reach  | 183         |
# |    reached_rate         | 0.55        |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 350         |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 714000      |
# | train/                  |             |
# |    approx_kl            | 0.007099654 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 3490        |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | -0.803      |
# |    mean_error_on_reach  | 1.39e-05    |
# |    mean_kterm_on_reach  | 171         |
# |    reached_rate         | 0.53        |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 360         |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.010871682 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0235      |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 0.00867     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step750150.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | -0.97       |
# |    mean_error_on_reach  | 1.4e-05     |
# |    mean_kterm_on_reach  | 189         |
# |    reached_rate         | 0.42        |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 370         |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 754800      |
# | train/                  |             |
# |    approx_kl            | 0.013235173 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.00989     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | -1          |
# |    mean_error_on_reach  | 1.4e-05     |
# |    mean_kterm_on_reach  | 228         |
# |    reached_rate         | 0.41        |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 380         |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 775200      |
# | train/                  |             |
# |    approx_kl            | 0.010724319 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 0.00993     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | -0.407       |
# |    mean_error_on_reach  | 1.43e-05     |
# |    mean_kterm_on_reach  | 202          |
# |    reached_rate         | 0.83         |
# | time/                   |              |
# |    fps                  | 1624         |
# |    iterations           | 390          |
# |    time_elapsed         | 489          |
# |    total_timesteps      | 795600       |
# | train/                  |              |
# |    approx_kl            | 0.0123711955 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00809      |
# |    n_updates            | 3890         |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 0.00482      |
# ------------------------------------------
# Saved: trajectories_tstar2_step_step800160.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -0.37       |
# |    mean_error_on_reach  | 1.63e-05    |
# |    mean_kterm_on_reach  | 107         |
# |    reached_rate         | 0.81        |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 400         |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 816000      |
# | train/                  |             |
# |    approx_kl            | 0.014669502 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00251     |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 0.00983     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | -0.41       |
# |    mean_error_on_reach  | 1.26e-05    |
# |    mean_kterm_on_reach  | 142         |
# |    reached_rate         | 0.81        |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 410         |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 836400      |
# | train/                  |             |
# |    approx_kl            | 0.018107448 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 4090        |
# |    policy_gradient_loss | 0.000311    |
# |    value_loss           | 0.00898     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step850170.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 292         |
# |    ep_rew_mean          | -0.492      |
# |    mean_error_on_reach  | 1.18e-05    |
# |    mean_kterm_on_reach  | 224         |
# |    reached_rate         | 0.8         |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 420         |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 856800      |
# | train/                  |             |
# |    approx_kl            | 0.009552836 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00211    |
# |    n_updates            | 4190        |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 0.000222    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 372         |
# |    ep_rew_mean          | -0.842      |
# |    mean_error_on_reach  | 1.19e-05    |
# |    mean_kterm_on_reach  | 231         |
# |    reached_rate         | 0.53        |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 430         |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 877200      |
# | train/                  |             |
# |    approx_kl            | 0.006325872 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00814     |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 471        |
# |    ep_rew_mean          | -1.28      |
# |    mean_error_on_reach  | 1.25e-05   |
# |    mean_kterm_on_reach  | 235        |
# |    reached_rate         | 0.19       |
# | time/                   |            |
# |    fps                  | 1625       |
# |    iterations           | 440        |
# |    time_elapsed         | 552        |
# |    total_timesteps      | 897600     |
# | train/                  |            |
# |    approx_kl            | 0.02239394 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0338    |
# |    n_updates            | 4390       |
# |    policy_gradient_loss | -0.00271   |
# |    value_loss           | 0.00476    |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step900180.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -1.45       |
# |    mean_error_on_reach  | 1.25e-05    |
# |    mean_kterm_on_reach  | 235         |
# |    reached_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 450         |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 918000      |
# | train/                  |             |
# |    approx_kl            | 0.012092365 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 4490        |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | -1.48       |
# |    mean_error_on_reach  | 1.25e-05    |
# |    mean_kterm_on_reach  | 235         |
# |    reached_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 460         |
# |    time_elapsed         | 576         |
# |    total_timesteps      | 938400      |
# | train/                  |             |
# |    approx_kl            | 0.008172281 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 4590        |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step950190.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -1.5        |
# |    mean_error_on_reach  | 1.25e-05    |
# |    mean_kterm_on_reach  | 235         |
# |    reached_rate         | 0           |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 470         |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 958800      |
# | train/                  |             |
# |    approx_kl            | 0.008895777 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# ...
# |    fps                  | 1563       |
# |    iterations           | 1410       |
# |    time_elapsed         | 1839       |
# |    total_timesteps      | 2876400    |
# | train/                  |            |
# |    approx_kl            | 0.01572142 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.591     |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.326      |
# |    n_updates            | 14090      |
# |    policy_gradient_loss | 0.00387    |
# |    value_loss           | 0.00245    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17         |
# |    ep_rew_mean          | -0.027     |
# |    mean_error_on_reach  | 2.07e-05   |
# |    mean_kterm_on_reach  | 12.1       |
# |    reached_rate         | 0.99       |
# | time/                   |            |
# |    fps                  | 1562       |
# |    iterations           | 1420       |
# |    time_elapsed         | 1853       |
# |    total_timesteps      | 2896800    |
# | train/                  |            |
# |    approx_kl            | 0.00867016 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00511    |
# |    n_updates            | 14190      |
# |    policy_gradient_loss | -0.00536   |
# |    value_loss           | 0.00996    |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step2900580.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -0.0101     |
# |    mean_error_on_reach  | 2.06e-05    |
# |    mean_kterm_on_reach  | 10          |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1561        |
# |    iterations           | 1430        |
# |    time_elapsed         | 1867        |
# |    total_timesteps      | 2917200     |
# | train/                  |             |
# |    approx_kl            | 0.011243782 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0088     |
# |    n_updates            | 14290       |
# |    policy_gradient_loss | -0.000668   |
# |    value_loss           | 0.00499     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | -0.0119     |
# |    mean_error_on_reach  | 2.07e-05    |
# |    mean_kterm_on_reach  | 11.9        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1560        |
# |    iterations           | 1440        |
# |    time_elapsed         | 1882        |
# |    total_timesteps      | 2937600     |
# | train/                  |             |
# |    approx_kl            | 0.002871601 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00788    |
# |    n_updates            | 14390       |
# |    policy_gradient_loss | -0.000251   |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step2950590.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.3        |
# |    ep_rew_mean          | -0.0153     |
# |    mean_error_on_reach  | 2.05e-05    |
# |    mean_kterm_on_reach  | 15.3        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1560        |
# |    iterations           | 1450        |
# |    time_elapsed         | 1895        |
# |    total_timesteps      | 2958000     |
# | train/                  |             |
# |    approx_kl            | 0.024395332 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0389     |
# |    n_updates            | 14490       |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.000505    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.59        |
# |    ep_rew_mean          | -0.00961    |
# |    mean_error_on_reach  | 2.06e-05    |
# |    mean_kterm_on_reach  | 9.59        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 1460        |
# |    time_elapsed         | 1909        |
# |    total_timesteps      | 2978400     |
# | train/                  |             |
# |    approx_kl            | 0.009400377 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0255      |
# |    n_updates            | 14590       |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 0.000161    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.65       |
# |    ep_rew_mean          | -0.00967   |
# |    mean_error_on_reach  | 2.07e-05   |
# |    mean_kterm_on_reach  | 9.65       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1558       |
# |    iterations           | 1470       |
# |    time_elapsed         | 1923       |
# |    total_timesteps      | 2998800    |
# | train/                  |            |
# |    approx_kl            | 0.04986021 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.942     |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0696     |
# |    n_updates            | 14690      |
# |    policy_gradient_loss | -0.0165    |
# |    value_loss           | 0.0357     |
# ----------------------------------------
# Saved: trajectories_tstar2_step_step3000600.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.2         |
# |    ep_rew_mean          | -0.00922    |
# |    mean_error_on_reach  | 2.07e-05    |
# |    mean_kterm_on_reach  | 9.2         |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 1480        |
# |    time_elapsed         | 1939        |
# |    total_timesteps      | 3019200     |
# | train/                  |             |
# |    approx_kl            | 0.012411847 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 14790       |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.000338    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15          |
# |    ep_rew_mean          | -0.025      |
# |    mean_error_on_reach  | 2.06e-05    |
# |    mean_kterm_on_reach  | 10.1        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 1490        |
# |    time_elapsed         | 1953        |
# |    total_timesteps      | 3039600     |
# | train/                  |             |
# |    approx_kl            | 0.016346416 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 14890       |
# |    policy_gradient_loss | -0.00833    |
# |    value_loss           | 0.00478     |
# -----------------------------------------
# Saved: trajectories_tstar2_step_step3050610.png
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.8        |
# |    ep_rew_mean          | -0.0279     |
# |    mean_error_on_reach  | 2.05e-05    |
# |    mean_kterm_on_reach  | 12.9        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 1500        |
# |    time_elapsed         | 1967        |
# |    total_timesteps      | 3060000     |
# | train/                  |             |
# |    approx_kl            | 0.012592507 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00849    |
# |    n_updates            | 14990       |
# |    policy_gradient_loss | 0.0016      |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64        |
# |    ep_rew_mean          | -0.00866    |
# |    mean_error_on_reach  | 2.06e-05    |
# |    mean_kterm_on_reach  | 8.64        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1554        |
# |    iterations           | 1510        |
# |    time_elapsed         | 1981        |
# |    total_timesteps      | 3080400     |
# | train/                  |             |
# |    approx_kl            | 0.034879126 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0505     |
# |    n_updates            | 15090       |
# |    policy_gradient_loss | 0.0137      |
# |    value_loss           | 2.4e-05     |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[162], line 79
#      66 model = PPO(
#      67     "MlpPolicy",
#      68     vec_env,
#    (...)     74     tensorboard_log="./logs/",
#      75 )
#      77 print(f"Training — t_star = {t_star_steps}·dt = {t_star_steps * dt:.4f}")
# ---> 79 model.learn(
#      80     total_timesteps=5_000_000,
#      81     reset_num_timesteps=False,
#      82     tb_log_name="joint_policy",
#      83     log_interval=10,
#      84     callback=[
#      85         ReachedRateCallback(),
#      86         PlotCallback(t_star_steps, plot_freq=50_000),
#      87         CheckpointCallback(save_freq=100_000, save_path="./ckpts/"),
#      88     ],
#      89 )
#      90 model.save(f"checkpoint_tstar{t_star_steps}")
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:213, in PPO.train(self)
#     209 if isinstance(self.action_space, spaces.Discrete):
#     210     # Convert discrete action from float to long
#     211     actions = rollout_data.actions.long().flatten()
# --> 213 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     214 values = values.flatten()
#     215 # Normalize advantage
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\policies.py:737, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     735     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     736     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 737 distribution = self._get_action_dist_from_latent(latent_pi)
#     738 log_prob = distribution.log_prob(actions)
#     739 values = self.value_net(latent_vf)
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\policies.py:700, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     698 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     699     # Here mean_actions are the flattened logits
# --> 700     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     701 elif isinstance(self.action_dist, BernoulliDistribution):
#     702     # Here mean_actions are the logits (before rounding to get the binary actions)
#     703     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:348, in MultiCategoricalDistribution.proba_distribution(self, action_logits)
#     345 def proba_distribution(
#     346     self: SelfMultiCategoricalDistribution, action_logits: th.Tensor
#     347 ) -> SelfMultiCategoricalDistribution:
# --> 348     self.distribution = [Categorical(logits=split) for split in th.split(action_logits, list(self.action_dims), dim=1)]
#     349     return self
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:348, in <listcomp>(.0)
#     345 def proba_distribution(
#     346     self: SelfMultiCategoricalDistribution, action_logits: th.Tensor
#     347 ) -> SelfMultiCategoricalDistribution:
# --> 348     self.distribution = [Categorical(logits=split) for split in th.split(action_logits, list(self.action_dims), dim=1)]
#     349     return self
#
# File c:\Users\amt35\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\categorical.py:66, in Categorical.__init__(self, probs, logits, validate_args)
#      64         raise ValueError("`logits` parameter must be at least one-dimensional.")
#      65     # Normalize
# ---> 66     self.logits = logits - logits.logsumexp(dim=-1, keepdim=True)
#      67 self._param = self.probs if probs is not None else self.logits
#      68 self._num_events = self._param.size()[-1]
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
obs, _ = env.reset()
trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, info = env.step(action)
    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))
        
visited_log = [(x, t) for (x, t, _) in env.visited._pts]
fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = cm.tab10.colors
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    ax.plot(xs, ts, '-',  linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# ── Use logged stencils instead of post-hoc reconstruction ───────────────────
stencils = {key: coords for key, coords in env.stencil_log.items()}

# ── Build plot ───────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 7))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors     = cm.tab10.colors
all_points = []

for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    ax.plot(xs, ts, '-',  linewidth=1.5, zorder=2)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^',
               zorder=4, label=f'Walker {i}')
    for (x, t) in traj[1:]:
        ax.scatter(x, t, s=60, color=colors[i], zorder=3)
        all_points.append((x, t, i))

ax.scatter(env.x_star, env.t_star, s=200, color='red',
           marker='*', zorder=5, label='z*')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Click any walker point to see its GFDM stencil')
ax.legend()
plt.tight_layout()

active_lines = []

def on_click(event):
    global active_lines

    if event.inaxes != ax or not all_points:
        return

    cx, ct  = event.xdata, event.ydata
    best_pt = min(all_points,
                  key=lambda p: ((p[0]-cx)/env.dx)**2 + ((p[1]-ct)/env.dt)**2)
    x, t, i = best_pt
    key     = (round(x, 8), round(t, 8))

    for line in active_lines:
        line.remove()
    active_lines = []

    if key in stencils:
        for (nx, nt) in stencils[key]:
            colors = plt.cm.viridis(np.linspace(0, 1, env.N))
            line, = ax.plot([x, nx], [t, nt], '--' , alpha=0.75,
                            linewidth=2, zorder=2)
            active_lines.append(line)

        dot, = ax.plot(x, t, 'o',
                       markersize=10, markeredgecolor='black',
                       markeredgewidth=1.5, zorder=6)
        active_lines.append(dot)

    fig.canvas.draw_idle()

fig.canvas.mpl_connect('button_press_event', on_click)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
env = PDEEnvironment()
env.reset()

# Force specific known actions and check they decode correctly
test_actions = [
    [0, 0, 1],   # walker 0, dx=-dx, dt=+dt  — should move left+forward
    [0, 2, 1],   # walker 0, dx=+dx, dt=+dt  — should move right+forward
    [0, 1, 0],   # walker 0, dx=0,   dt=0    — always rejected (no-op)
    [5, 2, 1],   # walker 5, dx=+dx, dt=+dt
]

for a in test_actions:
    env.reset()
    obs, reward, done, _, info = env.step(a)
    print(f"action={a} | walker={info['walker']} | accepted={info['accepted']} | rejected={info['rejected']}")
    if info['accepted']:
        i = info['walker']
        print(f"  → walker {i} now at x={env.walker_x[i]:.4f}, t={env.walker_t[i]:.4f}")
# Out:
# action=[0, 0, 1] | walker=0 | accepted=True | rejected=None
#   → walker 0 now at x=0.4828, t=0.0105
# action=[0, 2, 1] | walker=0 | accepted=True | rejected=None
#   → walker 0 now at x=0.5517, t=0.0105
# action=[0, 1, 0] | walker=0 | accepted=False | rejected=bounds
# action=[5, 2, 1] | walker=5 | accepted=True | rejected=None
#   → walker 5 now at x=0.8276, t=0.0105
