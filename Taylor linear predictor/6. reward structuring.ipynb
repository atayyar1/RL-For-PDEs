# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from trajectory_video2 import make_trajectory_video1
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE 
alpha = 0.05

#   FD reference grid   
nx    = 100
T     = 1
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

#  True solution; Analytical diffusion solution

def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# ### FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()               
        self.rejected_history = []  # (x, t) per rejected move
    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))  
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()
    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0
    def contains(self, x, t):                    
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
        if len(self._pts) < n:
            return None
        pts_arr  = np.asarray(self._pts)
        norm_arr = np.asarray(self._norm)

        # causal filter: neighbours at or before the query time
        mask = pts_arr[:, 1] <= t_star

        # a point can never be its own neighbour: exclude the exact query cell
        same_cell = (np.round(pts_arr[:, 0] / dx) == round(x_star / dx)) & \
                    (np.round(pts_arr[:, 1] / dt) == round(t_star / dt))
        mask &= ~same_cell

        if mask.sum() < n:
            return None
        norm_c = norm_arr[mask]
        pts_c  = pts_arr[mask]
        target = np.array([x_star / dx, t_star / dt])
        d2     = np.sum((norm_c - target) ** 2, axis=1)
        idx = np.argpartition(d2, n - 1)[:n]
        idx = idx[np.argsort(d2[idx])]
        return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# ### GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    #cond = np.linalg.cond(A)
    #if cond > 1e4:
    #    return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### PDEEnvironment

# %%
from matplotlib.pylab import beta


class PDEEnvironment(gym.Env):
    ACTIONS = {0: (-1, 1),
               1: ( 0, 1),
               2: ( 1, 1)}
    
    def __init__(self, t_star_schedule=None, t_star_steps=2, N_particles=27,
             err_tol=1e-3, w_err=0.8, w_time=0.2,
             K_max=5000, c_shape=0.05,
             x_star_schedule=None):          # NEW: list of x* indices to sample
        super().__init__()

        self.alpha = alpha
        self.c_shape = c_shape
        self.ERR_CEIL = 2.2
        self.nx = nx; self.nt = nt
        self.x_fd = x_fd; self.t_fd = t_fd
        self.dx = dx; self.dt = dt; self.T = T

        self.t_star_schedule = dict(t_star_schedule) if t_star_schedule else None

        # ── x* schedule: list of grid indices to sample from. None → fixed center.
        # Store as x_fd values so x* always lands on the grid.
        if x_star_schedule is not None:
            self.x_star_choices = np.array(
                [self.x_fd[int(ix)] for ix in x_star_schedule], dtype=float)
        else:
            self.x_star_choices = None

        # ── Target point (z*) ──
        self.x_star = self.x_fd[self.nx // 2]     # provisional; reset() may override
        self.t_star_steps = t_star_steps
        self.t_star = t_star_steps * dt

        self.K_max = K_max
        self.lam = lam
        self.beta = beta
        self.err_tol = err_tol
        self.w_err = w_err
        self.w_time = w_time
        self.phi_scale = 1.0
        self.n_neighbours = 5
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions: FROZEN to domain center, INDEPENDENT of x* ──
        self.N = N_particles
        mid = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step = (mid - margin) / half_n if half_n > 0 else 0
        offsets = [0]; k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1
        init_idx = np.clip(
            np.round(np.array(offsets[:self.N]) + mid).astype(int),
            margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]   # does NOT depend on x_star

        _, self.fd_interp = build_fd_reference()

        self.visited = None
        self.walker_x = None
        self.walker_t = None
        self.walker_u = None
        self.step_count = 0
        self.stencil_log = {}

        # obs: 2N relative coords + t*_norm + x*_norm  → 2N+2
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(2 * self.N + 2,), dtype=np.float32)
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        
        if self.t_star_schedule is not None:
            choices = list(self.t_star_schedule.keys())
            self.t_star_steps = int(self.np_random.choice(choices))
            self.t_star = self.t_star_steps * self.dt
            self.K_max = self.t_star_schedule[self.t_star_steps]

        # ── Resample x* per episode if a schedule is set ──
        if self.x_star_choices is not None:
            self.x_star = float(self.np_random.choice(self.x_star_choices))

        self.visited = VisitedSet()
        self.stencil_log = {}

        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_set = set()
        self.phi_scale = max(self._mean_target_distance(), 1e-12)
        self._phi_prev = self._potential()

        return self._build_obs(), {}

    def _build_obs(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        t_star_norm = self.t_star / self.dt          # horizon length in step units
        x_star_norm = self.x_star / self.dx          # NEW: absolute x* in dx units
        return np.array([
            *dx_rel,
            *dt_rel,
            t_star_norm,
            x_star_norm,
        ], dtype=np.float32)

    def _mean_target_distance(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        d = np.sqrt(dx_rel**2 + dt_rel**2)
        return float(np.mean(d))

    def _potential(self):
        if self.c_shape == 0.0:
            return 0.0
        return -self.c_shape * self._mean_target_distance() / max(self.phi_scale, 1e-12)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'
        nb = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star
        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason
        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'

    def step(self, action):
        self.step_count += 1
        done = False
        reward = 0.0

        i = int(action) // len(self.ACTIONS)
        j = int(action) % len(self.ACTIONS)
        dx_idx, dt_idx = self.ACTIONS[j]
        dx_move = dx_idx * self.dx
        dt_move = dt_idx * self.dt

        info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

        x_new = self.walker_x[i] + dx_move
        t_new = self.walker_t[i] + dt_move

        if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
            info['rejected'] = 'bounds'
        elif self.visited.contains(x_new, t_new):
            info['rejected'] = 'collision'
        else:
            u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
            if not success:
                info['rejected'] = reason
                self.gfdm_rejected_set.add(int(action))
            else:
                self.gfdm_rejected_set.clear()
                self.visited.add(x_new, t_new, u_hat)
                self.walker_x[i] = x_new
                self.walker_t[i] = t_new
                self.walker_u[i] = u_hat
                self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                info['accepted'] = True
                if (abs(x_new - self.x_star) < self.eps_x and
                        abs(t_new - self.t_star) < self.eps_t):
                    done = True
                    info['reached'] = True

        if not info['accepted']:
            self.rejected_history.append((x_new, t_new, info['rejected']))
        
        if done:
            u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
            u_ref = u_true(self.x_star, self.t_star)
            fail_reward = (-1- self.lam * self.K_max)
            if u_pred is None:
                reward = fail_reward
                info['error'] = None
            else:
                err    = abs(u_pred - u_ref)
                r_acc  = -self.beta * err
                r_eff  = -self.lam * self.step_count
                reward = r_acc + r_eff
                info['u_pred'] = u_pred
                info['u_ref']  = u_ref
                info['error']  = err
                info['k_term'] = self.step_count
                info['r_acc']  = r_acc          # log both terms separately —
                info['r_eff']  = r_eff          # you need them for calibration checks
        elif self.step_count >= self.K_max:
            done = True
            reward = (-1- self.lam * self.K_max
                      )
            info['timeout'] = True

        phi_new = 0.0 if done else self._potential()
        shaping = phi_new - self._phi_prev
        self._phi_prev = phi_new
        reward += shaping
        info['shaping'] = shaping
        info['phi'] = phi_new

        return self._build_obs(), reward, done, False, info

    def action_masks(self) -> np.ndarray:
        mask = np.ones(self.N * len(self.ACTIONS), dtype=bool)
        for i in range(self.N):
            for j in range(len(self.ACTIONS)):
                dx_idx, dt_idx = self.ACTIONS[j]
                x_new = self.walker_x[i] + dx_idx * self.dx
                t_new = self.walker_t[i] + dt_idx * self.dt
                if not (0.0 <= x_new <= 1.0 and
                        0.0 < t_new <= 1.5 * self.t_star and
                        not self.visited.contains(x_new, t_new)):
                    mask[i * len(self.ACTIONS) + j] = False
        for a in self.gfdm_rejected_set:
            mask[a] = False
        if not mask.any():
            mask[:] = True
        return mask

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
K_max= 2000
t_star_steps = 50  # ← change this to test different targets
env      = PDEEnvironment(t_star_steps=t_star_steps, K_max=K_max)
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()
    state, reward, done, _, info = env.step(action)



    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts
               if t > 0.0 and 0.0 < x < 1.0]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")

for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")
# walker distribution check — tells you if one walker is dominating
walker_counts = {}
for i, traj in trajectories.items():
    walker_counts[i] = len(traj) - 1  # subtract starting position
print("\nAccepted moves per walker:")
for i, count in sorted(walker_counts.items()):
    print(f"  Walker {i:d}: {count}")

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          2000
# Reward:         -3.000000
# Reached:        False
# Timeout:        True
# Total accepted: 1750
# Total rejected: 250
# Rejection reasons:
#   collision : 194
#   bounds_u  : 46
#   bounds    : 10
#
# Accepted moves per walker:
#   Walker 0: 39
#   Walker 1: 75
#   Walker 2: 94
#   Walker 3: 28
#   Walker 4: 86
#   Walker 5: 79
#   Walker 6: 66
#   Walker 7: 76
#   Walker 8: 53
#   Walker 9: 64
#   Walker 10: 69
#   Walker 11: 73
#   Walker 12: 52
#   Walker 13: 58
#   Walker 14: 60
#   Walker 15: 62
#   Walker 16: 77
#   Walker 17: 64
#   Walker 18: 61
#   Walker 19: 66
#   Walker 20: 68
#   Walker 21: 79
#   Walker 22: 61
#   Walker 23: 72
#   Walker 24: 77
#   Walker 25: 47
#   Walker 26: 44

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps, N_particles, lam, beta, K_max, c_shape,
                      save=True, timestep=None, img_dir=".", label=None,
                      x_star_steps=None):          # NEW: grid index for x*; None → center
    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles,
                         lam=lam, beta=beta, K_max=K_max, c_shape=c_shape,
                         x_star_schedule=None if x_star_steps is None else [x_star_steps])
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1)

    # ── Rejected positions ───────────────────────────────────────────────────
    rej_colors = {
        'bounds':    'blue',
        'collision': 'orange',
        'cond':      'purple',
        'weights':   'brown',
        'geometry':  'red',
        None:        'gray',
    }
    if env.rejected_history:
        from collections import defaultdict
        by_reason = defaultdict(list)
        for (rx, rt, reason) in env.rejected_history:
            by_reason[reason].append((rx, rt))
        for reason, pts in by_reason.items():
            ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                       s=6, alpha=0.08, linewidths=0, zorder=1,
                       color=rej_colors.get(reason, 'gray'),
                       label=f'rej:{reason} ({len(pts)})')
    # ─────────────────────────────────────────────────────────────────────────

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, color=colors[i], zorder=2)
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4)

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'

    # ── Stencil at z* ────────────────────────────────────────────────────────
    if reached:
        _, success, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star)
        if success and nb_coords is not None:
            for (nx_, nt_) in nb_coords:
                ax.plot([env.x_star, nx_], [env.t_star, nt_],
                        '--', color='red', linewidth=0.8,
                        alpha=0.7, zorder=5)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1],
                       s=40, color='red', zorder=6, alpha=0.7)

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=7)
    ax.set_xlabel('x')
    ax.set_ylabel('t')

    title = f't_star={t_star_steps}·dt  |  x_star={env.x_star:.2f}  |  {outcome}'
    if timestep is not None:
        title += f'  |  step {timestep:,}'
    if reached and info.get('error') is not None:
        title += f'  |  err={info["error"]:.2e}  |  k={info["k_term"]}'
    ax.set_title(title)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)

    if env.rejected_history:
        ax.legend(fontsize=6, loc='upper left', markerscale=2)

    plt.tight_layout()

    if save:
        xtag = "" if x_star_steps is None else f"_x{x_star_steps}"

        if label is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt{xtag}_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120)
        plt.close(fig)
    else:
        plt.show()

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf       = []
        self.kterm_buf = []
        self.err_buf   = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, N_particles, lam, beta, K_max, c_shape,
                 plot_freq=50_000, img_dir=".", verbose=0,
                 x_star_steps=None):              # NEW
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles  = N_particles
        self.lam          = lam
        self.beta         = beta
        self.K_max        = K_max
        self.c_shape      = c_shape
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir
        self.x_star_steps = x_star_steps          # NEW

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles,
                              self.lam, self.beta, self.K_max, self.c_shape,
                              save=True, timestep=self.num_timesteps,
                              img_dir=self.img_dir,
                              x_star_steps=self.x_star_steps)   # NEW
        return True


def make_env(t_star_schedule, N_particles, lam, beta, K_max, c_shape, x_star_schedule):
    def _init():
        env = PDEEnvironment(t_star_schedule=t_star_schedule, N_particles=N_particles,
                             lam=lam, beta=beta, K_max=K_max, c_shape=c_shape,
                             x_star_schedule=x_star_schedule)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
N_particles     = 50
t_star_schedule = {50: 1000}   # multiple t*, K_max ≈ 12·t*
x_star_schedule = [50]                 # 5 interior x*, all reachable at these t*
seeds           = [7]
lam             = 0.005
beta            = 2000
n_envs          = 15
n_steps         = 2048 // n_envs
total_timesteps = 2_000_000
c_shape         = 0.5   

# representative t* used ONLY for periodic plots/videos (policy trains on all keys)
plot_tstar   =50
plot_K_max   = t_star_schedule[plot_tstar]
plot_xstar   = x_star_schedule[0]  # representative x* for plots

# ── Run directory ────────────────────────────────────────────────────────────
day        = date.today().day
stages_str = "-".join(str(s) for s in t_star_schedule.keys())
run_name   = f"t{stages_str}_lam{lam}_beta{beta}_N{N_particles}_c{c_shape}"
run_dir    = os.path.join(f"runs7{day}", run_name)

print(f"Run: {run_dir}")
print(f"Training jointly on t*={list(t_star_schedule.keys())}  "
      f"(periodic plots shown at t*={plot_tstar})")

for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    # every subprocess gets the SAME schedule and resamples t* per episode in reset()
    vec_env = SubprocVecEnv([
        make_env(t_star_schedule, N_particles, lam, beta, K_max=None,
                c_shape=c_shape, x_star_schedule=x_star_schedule)
        for _ in range(n_envs)
    ])

    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=2e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=60,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    print(f"\n{'='*50}")
    print(f"Joint training over t* schedule: {t_star_schedule}")
    print(f"budget: {total_timesteps//1000}k steps")
    print(f"{'='*50}")

    model.learn(
        total_timesteps=total_timesteps,
        reset_num_timesteps=False,
        tb_log_name=f"seed{seed}",
        log_interval=10,
        callback=[
            ReachedRateCallback(),
            PlotCallback(plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                            plot_freq=100_000, img_dir=img_dir, x_star_steps=plot_xstar),
            CheckpointCallback(
                save_freq=100_000,
                save_path=os.path.join(ckpt_dir, "sched"),
                name_prefix="sched"
            ),
        ],
    )

    model.save(os.path.join(ckpt_dir, "sched_final"))

    # final plots/videos at the representative t*
    plot_trajectories(model, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                  save=True, timestep=None, img_dir=img_dir, label="final",
                  x_star_steps=plot_xstar)
    make_training_progress_video(img_dir, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
                                 label="final", fps=5)
    make_trajectory_video1(
        model, PDEEnvironment, plot_tstar, N_particles,
        img_dir=img_dir, label="final",
        x_star_steps=plot_xstar,
    )
# Out:
# Run: runs722\t10_lam0.005_beta20000_N50_c0.5
# Training jointly on t*=[10]  (periodic plots shown at t*=10)
#
# ##################################################
# SEED 7
# ##################################################
# Using cpu device
#
# ==================================================
# Joint training over t* schedule: {10: 1000}
# budget: 2000k steps
# ==================================================
# Logging to runs722\t10_lam0.005_beta20000_N50_c0.5\seed7\logs\seed7_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 716         |
# |    ep_rew_mean          | 9.27        |
# |    mean_error_on_reach  | 5.79e-06    |
# |    mean_kterm_on_reach  | 403         |
# |    reached_rate         | 0.476       |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.004348826 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.294       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.309       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 697         |
# |    ep_rew_mean          | 9.39        |
# |    mean_error_on_reach  | 6.22e-06    |
# |    mean_kterm_on_reach  | 417         |
# |    reached_rate         | 0.519       |
# | time/                   |             |
# |    fps                  | 1190        |
# |    iterations           | 20          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 40800       |
# | train/                  |             |
# |    approx_kl            | 0.007191077 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0263     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 0.0508      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | 9.68        |
# |    mean_error_on_reach  | 6.58e-06    |
# |    mean_kterm_on_reach  | 412         |
# |    reached_rate         | 0.593       |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 30          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 61200       |
# | train/                  |             |
# |    approx_kl            | 0.008310036 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0517     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 628          |
# |    ep_rew_mean          | -91.4        |
# |    mean_error_on_reach  | 0.00724      |
# |    mean_kterm_on_reach  | 402          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 1192         |
# |    iterations           | 40           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 81600        |
# | train/                  |              |
# |    approx_kl            | 0.0036108212 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.00718      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 591          |
# |    ep_rew_mean          | -91.2        |
# |    mean_error_on_reach  | 0.00533      |
# |    mean_kterm_on_reach  | 383          |
# |    reached_rate         | 0.65         |
# | time/                   |              |
# |    fps                  | 1192         |
# |    iterations           | 50           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 102000       |
# | train/                  |              |
# |    approx_kl            | 0.0065407823 |
# |    clip_fraction        | 0.316        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0204      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0155      |
# |    value_loss           | 0.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 529          |
# |    ep_rew_mean          | -149         |
# |    mean_error_on_reach  | 0.00812      |
# |    mean_kterm_on_reach  | 337          |
# |    reached_rate         | 0.68         |
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 60           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 122400       |
# | train/                  |              |
# |    approx_kl            | 0.0033929988 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.08        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.475        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 2.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 498          |
# |    ep_rew_mean          | -50.6        |
# |    mean_error_on_reach  | 0.00812      |
# |    mean_kterm_on_reach  | 306          |
# |    reached_rate         | 0.7          |
# | time/                   |              |
# |    fps                  | 1176         |
# |    iterations           | 70           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 142800       |
# | train/                  |              |
# |    approx_kl            | 0.0067047128 |
# |    clip_fraction        | 0.326        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0378      |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.0211      |
# |    value_loss           | 0.182        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 446         |
# |    ep_rew_mean          | -74.8       |
# |    mean_error_on_reach  | 0.00734     |
# |    mean_kterm_on_reach  | 258         |
# |    reached_rate         | 0.74        |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 80          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 163200      |
# | train/                  |             |
# |    approx_kl            | 0.005791928 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.62        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 6.66        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | -483         |
# |    mean_error_on_reach  | 0.0247       |
# |    mean_kterm_on_reach  | 260          |
# |    reached_rate         | 0.8          |
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 90           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 183600       |
# | train/                  |              |
# |    approx_kl            | 0.0049822386 |
# |    clip_fraction        | 0.241        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.99        |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.65         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0134      |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | -783        |
# |    mean_error_on_reach  | 0.0432      |
# |    mean_kterm_on_reach  | 269         |
# |    reached_rate         | 0.78        |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 100         |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 204000      |
# | train/                  |             |
# |    approx_kl            | 0.005405462 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0002      |
# |    loss                 | 23.8        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 31.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | -561         |
# |    mean_error_on_reach  | 0.0286       |
# |    mean_kterm_on_reach  | 269          |
# |    reached_rate         | 0.84         |
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 110          |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 224400       |
# | train/                  |              |
# |    approx_kl            | 0.0003655393 |
# |    clip_fraction        | 0.00529      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.71        |
# |    explained_variance   | -0.00529     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.1e+04      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.000136    |
# |    value_loss           | 2.71e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 290           |
# |    ep_rew_mean          | -739          |
# |    mean_error_on_reach  | 0.0375        |
# |    mean_kterm_on_reach  | 208           |
# |    reached_rate         | 0.89          |
# | time/                   |               |
# |    fps                  | 1188          |
# |    iterations           | 120           |
# |    time_elapsed         | 205           |
# |    total_timesteps      | 244800        |
# | train/                  |               |
# |    approx_kl            | 0.00033290152 |
# |    clip_fraction        | 0.000833      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.04         |
# |    explained_variance   | -0.0019       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.35e+04      |
# |    n_updates            | 1190          |
# |    policy_gradient_loss | -0.00195      |
# |    value_loss           | 2.94e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 252          |
# |    ep_rew_mean          | -171         |
# |    mean_error_on_reach  | 0.00914      |
# |    mean_kterm_on_reach  | 168          |
# |    reached_rate         | 0.89         |
# | time/                   |              |
# |    fps                  | 1192         |
# |    iterations           | 130          |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 265200       |
# | train/                  |              |
# |    approx_kl            | 0.0003128513 |
# |    clip_fraction        | 0.000392     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.79        |
# |    explained_variance   | 0.0357       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 921          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 3.84e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | -55.2       |
# |    mean_error_on_reach  | 0.00524     |
# |    mean_kterm_on_reach  | 147         |
# |    reached_rate         | 0.84        |
# | time/                   |             |
# |    fps                  | 1196        |
# |    iterations           | 140         |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 285600      |
# | train/                  |             |
# |    approx_kl            | 0.004193074 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 5.46        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 10.8        |
# |    mean_error_on_reach  | 4.6e-05     |
# |    mean_kterm_on_reach  | 158         |
# |    reached_rate         | 0.8         |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 150         |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 306000      |
# | train/                  |             |
# |    approx_kl            | 0.008461766 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.912       |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 10.6        |
# |    mean_error_on_reach  | 5.34e-05    |
# |    mean_kterm_on_reach  | 184         |
# |    reached_rate         | 0.77        |
# | time/                   |             |
# |    fps                  | 1190        |
# |    iterations           | 160         |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 326400      |
# | train/                  |             |
# |    approx_kl            | 0.010774439 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0277     |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.139       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 424           |
# |    ep_rew_mean          | -254          |
# |    mean_error_on_reach  | 0.0132        |
# |    mean_kterm_on_reach  | 213           |
# |    reached_rate         | 0.74          |
# | time/                   |               |
# |    fps                  | 1188          |
# |    iterations           | 170           |
# |    time_elapsed         | 291           |
# |    total_timesteps      | 346800        |
# | train/                  |               |
# |    approx_kl            | 0.00013394764 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.55         |
# |    explained_variance   | 0.0489        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.88e+03      |
# |    n_updates            | 1690          |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 4.45e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 424         |
# |    ep_rew_mean          | -304        |
# |    mean_error_on_reach  | 0.0158      |
# |    mean_kterm_on_reach  | 226         |
# |    reached_rate         | 0.75        |
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 180         |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 367200      |
# | train/                  |             |
# |    approx_kl            | 0.008179772 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.52        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 3.95        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 479          |
# |    ep_rew_mean          | -286         |
# |    mean_error_on_reach  | 0.0159       |
# |    mean_kterm_on_reach  | 232          |
# |    reached_rate         | 0.65         |
# | time/                   |              |
# |    fps                  | 1182         |
# |    iterations           | 190          |
# |    time_elapsed         | 327          |
# |    total_timesteps      | 387600       |
# | train/                  |              |
# |    approx_kl            | 0.0064116423 |
# |    clip_fraction        | 0.279        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.76        |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.56         |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 3.93         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | -9.49       |
# |    mean_error_on_reach  | 0.0167      |
# |    mean_kterm_on_reach  | 224         |
# |    reached_rate         | 0.6         |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 200         |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 408000      |
# | train/                  |             |
# |    approx_kl            | 0.006492187 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.407       |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 3.43        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 540          |
# |    ep_rew_mean          | -9.61        |
# |    mean_error_on_reach  | 0.00352      |
# |    mean_kterm_on_reach  | 237          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 1177         |
# |    iterations           | 210          |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 428400       |
# | train/                  |              |
# |    approx_kl            | 0.0044384883 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.29         |
# |    n_updates            | 2090         |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 1.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 548         |
# |    ep_rew_mean          | -9.46       |
# |    mean_error_on_reach  | 0.00124     |
# |    mean_kterm_on_reach  | 245         |
# |    reached_rate         | 0.61        |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 220         |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 448800      |
# | train/                  |             |
# |    approx_kl            | 0.006805696 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.412       |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.83        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 537          |
# |    ep_rew_mean          | 5.38         |
# |    mean_error_on_reach  | 0.0011       |
# |    mean_kterm_on_reach  | 281          |
# |    reached_rate         | 0.66         |
# | time/                   |              |
# |    fps                  | 1180         |
# |    iterations           | 230          |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 469200       |
# | train/                  |              |
# |    approx_kl            | 0.0064127077 |
# |    clip_fraction        | 0.284        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.33        |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.141        |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 0.487        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 595          |
# |    ep_rew_mean          | 5.01         |
# |    mean_error_on_reach  | 0.000282     |
# |    mean_kterm_on_reach  | 307          |
# |    reached_rate         | 0.61         |
# | time/                   |              |
# |    fps                  | 1177         |
# |    iterations           | 240          |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 489600       |
# | train/                  |              |
# |    approx_kl            | 0.0057376004 |
# |    clip_fraction        | 0.264        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0317      |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 0.128        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 536         |
# |    ep_rew_mean          | 9.76        |
# |    mean_error_on_reach  | 0.000268    |
# |    mean_kterm_on_reach  | 322         |
# |    reached_rate         | 0.69        |
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 250         |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 510000      |
# | train/                  |             |
# |    approx_kl            | 0.008941337 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0439     |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.0359      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 9.51        |
# |    mean_error_on_reach  | 5.5e-05     |
# |    mean_kterm_on_reach  | 336         |
# |    reached_rate         | 0.65        |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 260         |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 530400      |
# | train/                  |             |
# |    approx_kl            | 0.006865902 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0546     |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.0615      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 529        |
# |    ep_rew_mean          | 9.55       |
# |    mean_error_on_reach  | 6.12e-05   |
# |    mean_kterm_on_reach  | 316        |
# |    reached_rate         | 0.68       |
# | time/                   |            |
# |    fps                  | 1170       |
# |    iterations           | 270        |
# |    time_elapsed         | 470        |
# |    total_timesteps      | 550800     |
# | train/                  |            |
# |    approx_kl            | 0.00898959 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -3.58      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0432    |
# |    n_updates            | 2690       |
# |    policy_gradient_loss | -0.0175    |
# |    value_loss           | 0.0376     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 539         |
# |    ep_rew_mean          | 9.45        |
# |    mean_error_on_reach  | 6.77e-05    |
# |    mean_kterm_on_reach  | 325         |
# |    reached_rate         | 0.69        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 280         |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 571200      |
# | train/                  |             |
# |    approx_kl            | 0.006539204 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0334     |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.0537      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 541         |
# |    ep_rew_mean          | 9.36        |
# |    mean_error_on_reach  | 7.68e-05    |
# |    mean_kterm_on_reach  | 329         |
# |    reached_rate         | 0.69        |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 290         |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 591600      |
# | train/                  |             |
# |    approx_kl            | 0.005754024 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0575     |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.0443      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 517          |
# |    ep_rew_mean          | 9.47         |
# |    mean_error_on_reach  | 7.46e-05     |
# |    mean_kterm_on_reach  | 333          |
# |    reached_rate         | 0.72         |
# | time/                   |              |
# |    fps                  | 1162         |
# |    iterations           | 300          |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 612000       |
# | train/                  |              |
# |    approx_kl            | 0.0064380458 |
# |    clip_fraction        | 0.28         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.039       |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 0.0623       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 527         |
# |    ep_rew_mean          | 9.54        |
# |    mean_error_on_reach  | 6.88e-05    |
# |    mean_kterm_on_reach  | 324         |
# |    reached_rate         | 0.69        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 310         |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 632400      |
# | train/                  |             |
# |    approx_kl            | 0.008121722 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0403     |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 0.081       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 9.88        |
# |    mean_error_on_reach  | 6.16e-05    |
# |    mean_kterm_on_reach  | 310         |
# |    reached_rate         | 0.72        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 320         |
# |    time_elapsed         | 563         |
# |    total_timesteps      | 652800      |
# | train/                  |             |
# |    approx_kl            | 0.005959835 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0384     |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.033       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 512         |
# |    ep_rew_mean          | 10          |
# |    mean_error_on_reach  | 4.82e-05    |
# |    mean_kterm_on_reach  | 289         |
# |    reached_rate         | 0.7         |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 330         |
# |    time_elapsed         | 581         |
# |    total_timesteps      | 673200      |
# | train/                  |             |
# |    approx_kl            | 0.008485259 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0502     |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 449          |
# |    ep_rew_mean          | 10.6         |
# |    mean_error_on_reach  | 3.01e-05     |
# |    mean_kterm_on_reach  | 297          |
# |    reached_rate         | 0.77         |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 340          |
# |    time_elapsed         | 600          |
# |    total_timesteps      | 693600       |
# | train/                  |              |
# |    approx_kl            | 0.0060920194 |
# |    clip_fraction        | 0.294        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.3         |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0211      |
# |    n_updates            | 3390         |
# |    policy_gradient_loss | -0.0145      |
# |    value_loss           | 0.0256       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 10.9         |
# |    mean_error_on_reach  | 2.54e-05     |
# |    mean_kterm_on_reach  | 268          |
# |    reached_rate         | 0.82         |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 350          |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 714000       |
# | train/                  |              |
# |    approx_kl            | 0.0056352885 |
# |    clip_fraction        | 0.25         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.67        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0364      |
# |    n_updates            | 3490         |
# |    policy_gradient_loss | -0.013       |
# |    value_loss           | 0.0552       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 361         |
# |    ep_rew_mean          | 11.1        |
# |    mean_error_on_reach  | 2.5e-05     |
# |    mean_kterm_on_reach  | 243         |
# |    reached_rate         | 0.84        |
# | time/                   |             |
# |    fps                  | 1150        |
# |    iterations           | 360         |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 734400      |
# | train/                  |             |
# |    approx_kl            | 0.005672277 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0239     |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.0419      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 11.8        |
# |    mean_error_on_reach  | 1.45e-05    |
# |    mean_kterm_on_reach  | 190         |
# |    reached_rate         | 0.89        |
# | time/                   |             |
# |    fps                  | 1149        |
# |    iterations           | 370         |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 754800      |
# | train/                  |             |
# |    approx_kl            | 0.008873287 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0449     |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.0228      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 12.4        |
# |    mean_error_on_reach  | 1.06e-05    |
# |    mean_kterm_on_reach  | 125         |
# |    reached_rate         | 0.96        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 380         |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 775200      |
# | train/                  |             |
# |    approx_kl            | 0.007620232 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0512     |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 12.3         |
# |    mean_error_on_reach  | 1.5e-05      |
# |    mean_kterm_on_reach  | 105          |
# |    reached_rate         | 0.94         |
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 390          |
# |    time_elapsed         | 693          |
# |    total_timesteps      | 795600       |
# | train/                  |              |
# |    approx_kl            | 0.0057279887 |
# |    clip_fraction        | 0.254        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0235      |
# |    n_updates            | 3890         |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.0461       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | 12.6         |
# |    mean_error_on_reach  | 7.62e-06     |
# |    mean_kterm_on_reach  | 117          |
# |    reached_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 1143         |
# |    iterations           | 400          |
# |    time_elapsed         | 713          |
# |    total_timesteps      | 816000       |
# | train/                  |              |
# |    approx_kl            | 0.0055830707 |
# |    clip_fraction        | 0.331        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.61        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0493      |
# |    n_updates            | 3990         |
# |    policy_gradient_loss | -0.0157      |
# |    value_loss           | 0.0325       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.6        |
# |    ep_rew_mean          | 12.9        |
# |    mean_error_on_reach  | 5.74e-06    |
# |    mean_kterm_on_reach  | 64.9        |
# |    reached_rate         | 0.98        |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 410         |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 836400      |
# | train/                  |             |
# |    approx_kl            | 0.009062468 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0544     |
# |    n_updates            | 4090        |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.0463      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.4         |
# |    ep_rew_mean          | 13           |
# |    mean_error_on_reach  | 5.24e-06     |
# |    mean_kterm_on_reach  | 44.7         |
# |    reached_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 420          |
# |    time_elapsed         | 754          |
# |    total_timesteps      | 856800       |
# | train/                  |              |
# |    approx_kl            | 0.0061665736 |
# |    clip_fraction        | 0.252        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0299      |
# |    n_updates            | 4190         |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.7        |
# |    ep_rew_mean          | 13.2        |
# |    mean_error_on_reach  | 3.47e-06    |
# |    mean_kterm_on_reach  | 30.7        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1131        |
# |    iterations           | 430         |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 877200      |
# | train/                  |             |
# |    approx_kl            | 0.007992593 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.045      |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.1         |
# |    ep_rew_mean          | 13.2         |
# |    mean_error_on_reach  | 3.71e-06     |
# |    mean_kterm_on_reach  | 27.1         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1126         |
# |    iterations           | 440          |
# |    time_elapsed         | 796          |
# |    total_timesteps      | 897600       |
# | train/                  |              |
# |    approx_kl            | 0.0062808786 |
# |    clip_fraction        | 0.224        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0247      |
# |    n_updates            | 4390         |
# |    policy_gradient_loss | -0.00865     |
# |    value_loss           | 0.00989      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 13.2        |
# |    mean_error_on_reach  | 3.65e-06    |
# |    mean_kterm_on_reach  | 22.8        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1121        |
# |    iterations           | 450         |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 918000      |
# | train/                  |             |
# |    approx_kl            | 0.008692754 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0329     |
# |    n_updates            | 4490        |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00989     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.4         |
# |    ep_rew_mean          | 13.3         |
# |    mean_error_on_reach  | 2.22e-06     |
# |    mean_kterm_on_reach  | 25.4         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1116         |
# |    iterations           | 460          |
# |    time_elapsed         | 840          |
# |    total_timesteps      | 938400       |
# | train/                  |              |
# |    approx_kl            | 0.0062505035 |
# |    clip_fraction        | 0.299        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0272      |
# |    n_updates            | 4590         |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.00414      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 2.1e-06     |
# |    mean_kterm_on_reach  | 20.9        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 470         |
# |    time_elapsed         | 862         |
# |    total_timesteps      | 958800      |
# | train/                  |             |
# |    approx_kl            | 0.010904089 |
# |    clip_fraction        | 0.243       |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 20.4        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 1.75e-06    |
# |    mean_kterm_on_reach  | 20.4        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 840         |
# |    time_elapsed         | 1689        |
# |    total_timesteps      | 1713600     |
# | train/                  |             |
# |    approx_kl            | 0.013280198 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00616     |
# |    n_updates            | 8390        |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 0.000718    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.3        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 2.13e-06    |
# |    mean_kterm_on_reach  | 19.3        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1012        |
# |    iterations           | 850         |
# |    time_elapsed         | 1711        |
# |    total_timesteps      | 1734000     |
# | train/                  |             |
# |    approx_kl            | 0.004604688 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00496    |
# |    n_updates            | 8490        |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 13.3         |
# |    mean_error_on_reach  | 1.48e-06     |
# |    mean_kterm_on_reach  | 20.8         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1011         |
# |    iterations           | 860          |
# |    time_elapsed         | 1733         |
# |    total_timesteps      | 1754400      |
# | train/                  |              |
# |    approx_kl            | 0.0057318173 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0241      |
# |    n_updates            | 8590         |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 0.00145      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 12.6        |
# |    mean_error_on_reach  | 7.32e-06    |
# |    mean_kterm_on_reach  | 94.8        |
# |    reached_rate         | 0.96        |
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 870         |
# |    time_elapsed         | 1751        |
# |    total_timesteps      | 1774800     |
# | train/                  |             |
# |    approx_kl            | 0.007236367 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0493     |
# |    n_updates            | 8690        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0347      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38           |
# |    ep_rew_mean          | 13.2         |
# |    mean_error_on_reach  | 1.67e-06     |
# |    mean_kterm_on_reach  | 28.2         |
# |    reached_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 1014         |
# |    iterations           | 880          |
# |    time_elapsed         | 1770         |
# |    total_timesteps      | 1795200      |
# | train/                  |              |
# |    approx_kl            | 0.0054973513 |
# |    clip_fraction        | 0.267        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0278      |
# |    n_updates            | 8790         |
# |    policy_gradient_loss | -0.009       |
# |    value_loss           | 0.0321       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.3        |
# |    ep_rew_mean          | 13.2        |
# |    mean_error_on_reach  | 2.71e-06    |
# |    mean_kterm_on_reach  | 24.5        |
# |    reached_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 890         |
# |    time_elapsed         | 1791        |
# |    total_timesteps      | 1815600     |
# | train/                  |             |
# |    approx_kl            | 0.006794051 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.106       |
# |    n_updates            | 8890        |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 0.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 1.8e-06     |
# |    mean_kterm_on_reach  | 23.8        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1012        |
# |    iterations           | 900         |
# |    time_elapsed         | 1812        |
# |    total_timesteps      | 1836000     |
# | train/                  |             |
# |    approx_kl            | 0.004679475 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0177     |
# |    n_updates            | 8990        |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 0.00578     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.2         |
# |    ep_rew_mean          | 13.3         |
# |    mean_error_on_reach  | 1.77e-06     |
# |    mean_kterm_on_reach  | 24.2         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1011         |
# |    iterations           | 910          |
# |    time_elapsed         | 1835         |
# |    total_timesteps      | 1856400      |
# | train/                  |              |
# |    approx_kl            | 0.0070760655 |
# |    clip_fraction        | 0.315        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | -0.341       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0231      |
# |    n_updates            | 9090         |
# |    policy_gradient_loss | -0.00783     |
# |    value_loss           | 0.00937      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 1.73e-06    |
# |    mean_kterm_on_reach  | 21.9        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 920         |
# |    time_elapsed         | 1857        |
# |    total_timesteps      | 1876800     |
# | train/                  |             |
# |    approx_kl            | 0.010550673 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00787     |
# |    n_updates            | 9190        |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 0.00307     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24           |
# |    ep_rew_mean          | 13.3         |
# |    mean_error_on_reach  | 1.78e-06     |
# |    mean_kterm_on_reach  | 24           |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1009         |
# |    iterations           | 930          |
# |    time_elapsed         | 1879         |
# |    total_timesteps      | 1897200      |
# | train/                  |              |
# |    approx_kl            | 0.0052228435 |
# |    clip_fraction        | 0.251        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | -0.559       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0382       |
# |    n_updates            | 9290         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 0.027        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31          |
# |    ep_rew_mean          | 13.2        |
# |    mean_error_on_reach  | 1.71e-06    |
# |    mean_kterm_on_reach  | 31          |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 940         |
# |    time_elapsed         | 1899        |
# |    total_timesteps      | 1917600     |
# | train/                  |             |
# |    approx_kl            | 0.010253093 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0276     |
# |    n_updates            | 9390        |
# |    policy_gradient_loss | 0.00105     |
# |    value_loss           | 0.00897     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.5        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 1.73e-06    |
# |    mean_kterm_on_reach  | 19.5        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 950         |
# |    time_elapsed         | 1920        |
# |    total_timesteps      | 1938000     |
# | train/                  |             |
# |    approx_kl            | 0.009445027 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0282     |
# |    n_updates            | 9490        |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | 13.3         |
# |    mean_error_on_reach  | 1.33e-06     |
# |    mean_kterm_on_reach  | 18.2         |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1008         |
# |    iterations           | 960          |
# |    time_elapsed         | 1942         |
# |    total_timesteps      | 1958400      |
# | train/                  |              |
# |    approx_kl            | 0.0045985496 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0196      |
# |    n_updates            | 9590         |
# |    policy_gradient_loss | 0.00495      |
# |    value_loss           | 0.00148      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.5       |
# |    ep_rew_mean          | 13.3       |
# |    mean_error_on_reach  | 7.59e-07   |
# |    mean_kterm_on_reach  | 19.5       |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1006       |
# |    iterations           | 970        |
# |    time_elapsed         | 1965       |
# |    total_timesteps      | 1978800    |
# | train/                  |            |
# |    approx_kl            | 0.00822509 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0177    |
# |    n_updates            | 9690       |
# |    policy_gradient_loss | 0.00506    |
# |    value_loss           | 0.000995   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 13.3        |
# |    mean_error_on_reach  | 5.96e-07    |
# |    mean_kterm_on_reach  | 26.2        |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 980         |
# |    time_elapsed         | 1987        |
# |    total_timesteps      | 1999200     |
# | train/                  |             |
# |    approx_kl            | 0.010228407 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0305     |
# |    n_updates            | 9790        |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 0.00733     |
# -----------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 88
#      84     # final plots/videos at the representative t*
#      85     plot_trajectories(model, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
#      86                   save=True, timestep=None, img_dir=img_dir, label="final",
#      87                   x_star_steps=plot_xstar)
# ---> 88     make_training_progress_video(img_dir, plot_tstar, N_particles, lam, beta, plot_K_max, c_shape,
#      89                                  label="final", fps=5)
#      90     make_trajectory_video1(
#      91         model, PDEEnvironment, plot_tstar, N_particles,
#
# TypeError: make_training_progress_video() got an unexpected keyword argument 'label'

# %%
make_trajectory_video(
        model, PDEEnvironment, plot_tstar, N_particles,
        img_dir=img_dir, label="final",
)
# Out:
# Rollout done: reached, 14 accepted points, 14 total steps.
# Saved video: runs722\t10_lam0.005_beta20000_N50_c0.5\seed7\images\traj_t10dt_final_reached.mp4
# 'runs722\\t10_lam0.005_beta20000_N50_c0.5\\seed7\\images\\traj_t10dt_final_reached.mp4'

# %%
from importlib import reload
import training_progress_video
reload(training_progress_video)
from training_progress_video import make_training_progress_video

# %%
make_training_progress_video(
    img_dir=img_dir,
    t_star_steps=plot_tstar,
    label="final",
    x_star_steps=plot_xstar,
    fps=1,
)
# Out:
# Found 21 images.
# First frame: traj_t10dt_x50_00100k_reached.png
# Last frame:  traj_t10dt_x50_final_reached.png
# Saved training progress video: runs722\t10_lam0.005_beta20000_N50_c0.5\seed7\images\traj_t10dt_x50_training_progress.mp4
# 'runs722\\t10_lam0.005_beta20000_N50_c0.5\\seed7\\images\\traj_t10dt_x50_training_progress.mp4'
