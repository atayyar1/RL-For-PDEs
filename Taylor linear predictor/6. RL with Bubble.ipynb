# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from trajectory_video2 import make_trajectory_video1
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE 
alpha = 0.05

#   FD reference grid   
nx    = 100
T     = 1
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

#  True solution; Analytical diffusion solution

def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# ### FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:
    def __init__(self, cap0=8192):
        self._cap  = cap0
        self._n    = 0
        self._store     = np.empty((cap0, 3), dtype=float)   # (x, t, u)
        self._normstore = np.empty((cap0, 2), dtype=float)   # (x/dx, t/dt)
        self._idx_set   = set()
        self.rejected_history = []

    def _grow(self):
        self._cap *= 2
        s  = np.empty((self._cap, 3)); s[:self._n]  = self._store[:self._n];     self._store = s
        ns = np.empty((self._cap, 2)); ns[:self._n] = self._normstore[:self._n]; self._normstore = ns

    def add(self, x, t, u):
        if self._n == self._cap:
            self._grow()
        self._store[self._n]     = (x, t, u)
        self._normstore[self._n] = (x / dx, t / dt)
        self._idx_set.add((round(x / dx), round(t / dt)))
        self._n += 1

    # live-slice views so plot/video code that iterates ._pts keeps working
    @property
    def _pts(self):
        return self._store[:self._n]

    @property
    def _norm(self):
        return self._normstore[:self._n]

    def contains(self, x, t):
        return (round(x / dx), round(t / dt)) in self._idx_set

    def find_neighbours(self, x_star, t_star, n, causal=True, box_R=None):
        if self._n < n:
            return None
        pts_arr  = self._store[:self._n]
        norm_arr = self._normstore[:self._n]

        if causal:
            mask = pts_arr[:, 1] <= t_star
        else:
            mask = np.ones(self._n, dtype=bool)

        same_cell = (np.round(pts_arr[:, 0] / dx) == round(x_star / dx)) & \
                    (np.round(pts_arr[:, 1] / dt) == round(t_star / dt))
        mask &= ~same_cell

        if box_R is not None:
            in_box = (np.abs(pts_arr[:, 0] - x_star) <= box_R * dx + 1e-9) & \
                     (np.abs(pts_arr[:, 1] - t_star) <= box_R * dt + 1e-9)
            mask &= in_box

        if mask.sum() < n:
            return None
        norm_c = norm_arr[mask]
        pts_c  = pts_arr[mask]
        target = np.array([x_star / dx, t_star / dt])
        d2     = np.sum((norm_c - target) ** 2, axis=1)
        idx = np.argpartition(d2, n - 1)[:n]
        idx = idx[np.argsort(d2[idx])]
        return [tuple(row) for row in pts_c[idx]]

    def count_in_box(self, x_star, t_star, R):
        ci = round(x_star / dx)
        cj = round(t_star / dt)
        cnt = 0
        for di in range(-R, R + 1):
            for dj in range(-R, R + 1):
                if di == 0 and dj == 0:
                    continue
                if (ci + di, cj + dj) in self._idx_set:
                    cnt += 1
        return cnt

    def __len__(self):
        return self._n

# %% [markdown]
# ### GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), np.sqrt(alpha * np.max(np.abs(dt_i))), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > 1e4:
        return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### PDEEnvironment

# %%
from logging import info

from matplotlib.pyplot import box


class PDEEnvironment(gym.Env):
    ACTIONS = {0: (-1, 1), 1:(-1,2),
               2: (0, 1),  3: (0, 2),
               4: (1, 1),  5: (1, 2)   

               }
    
    def __init__(self, t_star_schedule=None, t_star_steps=2, N_particles=27,err_tol=1e-3, w_err=0.8, w_time=0.2,
             K_max=5000, c_shape=0.05, x_star_schedule=None, R_bubble=4):
        super().__init__()

        self.alpha = alpha
        self.c_shape = c_shape
        self.ERR_CEIL = 2.2
        self.n_neighbours = 5
        self.R_bubble = R_bubble
        self.nx = nx; self.nt = nt
        self.x_fd = x_fd; self.t_fd = t_fd
        self.dx = dx; self.dt = dt; self.T = T

        self.t_star_schedule = dict(t_star_schedule) if t_star_schedule else None

        # ── x* schedule: list of grid indices to sample from. None → fixed center.
        # Store as x_fd values so x* always lands on the grid.
        if x_star_schedule is not None:
            self.x_star_choices = np.array(
                [self.x_fd[int(ix)] for ix in x_star_schedule], dtype=float)
        else:
            self.x_star_choices = None

        # ── Target point (z*) ──
        self.x_star = self.x_fd[self.nx // 2]     # provisional; reset() may override
        self.t_star_steps = t_star_steps
        self.t_star = t_star_steps * dt

        self.K_max = K_max
        self.err_tol = err_tol
        self.w_err = w_err
        self.w_time = w_time
        self.phi_scale = 1.0
        self.n_neighbours = 5
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt
        self.retry_after = 50
        # ── Walker initial positions: FROZEN to domain center, INDEPENDENT of x* ──
        self.N = N_particles
        mid = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step = (mid - margin) / half_n if half_n > 0 else 0
        offsets = [0]; k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1
        init_idx = np.clip(
            np.round(np.array(offsets[:self.N]) + mid).astype(int),
            margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]   # does NOT depend on x_star

        _, self.fd_interp = build_fd_reference()

        self.visited = None
        self.walker_x = None
        self.walker_t = None
        self.walker_u = None
        self.step_count = 0
        self.stencil_log = {}

        # obs: 2N relative coords + t*_norm + x*_norm  → 2N+2
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(2 * self.N + 2,), dtype=np.float32)
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        
        if self.t_star_schedule is not None:
            choices = list(self.t_star_schedule.keys())
            self.t_star_steps = int(self.np_random.choice(choices))
            self.t_star = self.t_star_steps * self.dt
            self.K_max = self.t_star_schedule[self.t_star_steps]

        # ── Resample x* per episode if a schedule is set ──
        if self.x_star_choices is not None:
            self.x_star = float(self.np_random.choice(self.x_star_choices))

        self.visited = VisitedSet()
        self.stencil_log = {}

        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_cells = {} 
        self.phi_scale = max(self._mean_target_distance(), 1e-12)
        self._phi_prev = self._potential()

        return self._build_obs(), {}

    def _build_obs(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        t_star_norm = self.t_star / self.dt          # horizon length in step units
        x_star_norm = self.x_star / self.dx          # NEW: absolute x* in dx units
        return np.array([
            *dx_rel,
            *dt_rel,
            t_star_norm,
            x_star_norm,
        ], dtype=np.float32)

    def _mean_target_distance(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        d = np.sqrt(dx_rel**2 + dt_rel**2)
        return float(np.min(d))

    def _potential(self):
        if self.c_shape == 0.0:
            return 0.0
        return -self.c_shape * self._mean_target_distance() / max(self.phi_scale, 1e-12)

    def _gfdm_solve(self, x_star, t_star, causal=True, box_R=None):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours, causal=causal, box_R=box_R)
        if nb is None:
            return None, False, None, 'no_nb'
        nb = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star
        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason
        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'

    def step(self, action):
        self.step_count += 1
        done = False
        reward = 0.0

        i = int(action) // len(self.ACTIONS)
        j = int(action) % len(self.ACTIONS)
        dx_idx, dt_idx = self.ACTIONS[j]
        dx_move = dx_idx * self.dx
        dt_move = dt_idx * self.dt

        info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

        x_new = self.walker_x[i] + dx_move
        t_new = self.walker_t[i] + dt_move

        # walkers may now rise to t* + R·dt (bubble extends above the star)
        t_ceil = self.t_star + self.R_bubble * self.dt + self.eps_t

        if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= t_ceil):
            info['rejected'] = 'bounds'
        elif self.visited.contains(x_new, t_new):
            info['rejected'] = 'collision'
        else:
            u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
            if not success:
                info['rejected'] = reason
                self.gfdm_rejected_cells[(round(x_new / self.dx), round(t_new / self.dt))] = len(self.visited)
            else:
                self.visited.add(x_new, t_new, u_hat)
                self.walker_x[i] = x_new
                self.walker_t[i] = t_new
                self.walker_u[i] = u_hat
                self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                info['accepted'] = True

        if not info['accepted']:
            self.rejected_history.append((x_new, t_new, info['rejected']))

        # ── Unified termination: bubble filled OR k_max reached ──────────────
        bubble_full = (self.visited.count_in_box(
            self.x_star, self.t_star, self.R_bubble) >= self.n_neighbours)
        timeout = self.step_count >= self.K_max

        if bubble_full or timeout:
            done = True
            info['reached'] = bool(bubble_full)
            info['timeout'] = bool(timeout and not bubble_full)
            
 
            box_R = self.R_bubble if bubble_full else None  

            u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star, causal=False, box_R=box_R)
            
            u_ref = u_true(self.x_star, self.t_star)

            if u_pred is None:
                err      = None
                err_norm = 1.0                      # failed solve → worst-case
            else:
                err      = abs(u_pred - u_ref)
                err_norm = float(np.clip(
                    np.log10(max(err, 1e-12) / self.err_tol) / 3.0, 0.0, 1.0))

            time_norm = self.step_count / max(self.K_max, 1)
            r_acc = -self.w_err  * err_norm
            r_eff = -self.w_time * time_norm
            reward = r_acc + r_eff              # accuracy + speed only

            info['u_pred']    = u_pred
            info['u_ref']     = u_ref
            info['error']     = err
            info['k_term']    = self.step_count
            info['err_norm']  = err_norm
            info['time_norm'] = time_norm
            info['r_acc']     = r_acc
            info['r_eff']     = r_eff

        phi_new = 0.0 if done else self._potential()
        shaping = phi_new - self._phi_prev
        self._phi_prev = phi_new
        reward += shaping
        info['shaping'] = shaping
        info['phi'] = phi_new

        return self._build_obs(), reward, done, False, info

    def action_masks(self) -> np.ndarray:
        n_act = len(self.ACTIONS)

        # per-action grid offsets, built from ACTIONS so this survives you
        # adding new moves later (e.g. the same-t (±1,0) action)
        adx = np.fromiter((self.ACTIONS[j][0] for j in range(n_act)), dtype=int, count=n_act)
        adt = np.fromiter((self.ACTIONS[j][1] for j in range(n_act)), dtype=int, count=n_act)

        # all N*n_act candidate positions at once
        x_new = self.walker_x[:, None] + adx[None, :] * self.dx      # (N, n_act)
        t_new = self.walker_t[:, None] + adt[None, :] * self.dt
        t_ceil = self.t_star + self.R_bubble * self.dt + self.eps_t

        ok = ((x_new >= 0.0) & (x_new <= 1.0) &
              (t_new > 0.0) & (t_new <= t_ceil)).ravel()

        # integer cells: ONE vectorized round instead of ~600 scalar round()/step
        cx = np.round(x_new / self.dx).astype(np.int64).ravel()
        ct = np.round(t_new / self.dt).astype(np.int64).ravel()

        n_pts   = len(self.visited)
        idx_set = self.visited._idx_set
        rej     = self.gfdm_rejected_cells
        retry   = self.retry_after

        for k in range(self.N * n_act):
            if not ok[k]:
                continue
            key = (int(cx[k]), int(ct[k]))
            if key in idx_set:                       # collision (was visited.contains)
                ok[k] = False
                continue
            n_fail = rej.get(key)                    # retry-window block
            if n_fail is not None and n_pts < n_fail + retry:
                ok[k] = False

        if not ok.any():
            ok[:] = True
        return ok

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
import matplotlib.patches as patches

R_bubble     = 4
t_star_steps = 50      # ← change to test different targets
K_max        = 2000

env    = PDEEnvironment(t_star_steps=t_star_steps, K_max=K_max, R_bubble=R_bubble)
obs, _ = env.reset()

trajectories   = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
done           = False
total_accepted = 0
total_rejected = {}

while not done:
    mask   = env.action_masks()
    action = int(np.random.choice(np.flatnonzero(mask)))   # masked random policy
    obs, reward, done, _, info = env.step(action)

    total_accepted += int(info['accepted'])
    if info['rejected']:
        total_rejected[info['rejected']] = total_rejected.get(info['rejected'], 0) + 1
    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

# ── Outcome ───────────────────────────────────────────────────────────────────
reached = info.get('reached', False)
outcome = 'bubble filled' if reached else 'timeout (k_max)'
err     = info.get('error')
u_pred  = info.get('u_pred')
u_ref   = info.get('u_ref')
n_box   = env.visited.count_in_box(env.x_star, env.t_star, env.R_bubble)

print(f"Outcome:        {outcome}")
print(f"Steps (k_term): {info.get('k_term', env.step_count)}")
print(f"Points in box:  {n_box}  (need {env.n_neighbours})")
print(f"u_pred:         {u_pred}")
print(f"u_ref:          {u_ref}")
print(f"|error|:        {'None' if err is None else f'{err:.3e}'}")
print(f"Final reward:   {reward:.4f}   (r_acc={info.get('r_acc')}, r_eff={info.get('r_eff')})")
print(f"Total accepted: {total_accepted}   |   Total rejected: {sum(total_rejected.values())}")
for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")

# ── Plot ──────────────────────────────────────────────────────────────────────
visited_log = [(x, t) for (x, t, _) in env.visited._pts if t > 0.0 and 0.0 < x < 1.0]
Rx = env.R_bubble * env.dx
Rt = env.R_bubble * env.dt

# points inside the box (for highlighting)
in_box = [(x, t) for (x, t) in visited_log
          if abs(x - env.x_star) <= Rx + 1e-9 and abs(t - env.t_star) <= Rt + 1e-9]

# stencil the star solve actually used (non-causal)
_, s_ok, nb_coords, _ = env._gfdm_solve(
    env.x_star, env.t_star, causal=False,
    box_R=env.R_bubble if reached else None)

colors = plt.cm.viridis(np.linspace(0, 1, env.N))

def draw(ax):
    ax.scatter([p[0] for p in visited_log], [p[1] for p in visited_log],
               s=6, color='lightgray', zorder=1)
    # bubble box
    ax.add_patch(patches.Rectangle(
        (env.x_star - Rx, env.t_star - Rt), 2 * Rx, 2 * Rt,
        fill=False, edgecolor='red', linestyle='--', linewidth=1.5, zorder=4))
    # in-box points
    if in_box:
        ax.scatter([p[0] for p in in_box], [p[1] for p in in_box],
                   s=30, facecolors='none', edgecolors='green',
                   linewidths=1.3, zorder=5, label=f'in box ({len(in_box)})')
    # trajectories
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]; ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=0.9, color=colors[i], alpha=0.6, zorder=2)
        ax.scatter(xs[0], ts[0], s=45, color=colors[i], marker='^', zorder=3)
    # star stencil
    if s_ok and nb_coords is not None:
        for (nxp, ntp) in nb_coords:
            ax.plot([env.x_star, nxp], [env.t_star, ntp], '--',
                    color='crimson', linewidth=1.0, alpha=0.85, zorder=6)
        ax.scatter(nb_coords[:, 0], nb_coords[:, 1], s=50, color='crimson',
                   zorder=7, label='star stencil')
    # star
    ax.scatter(env.x_star, env.t_star, s=240, color='red', marker='*',
               zorder=8, label='z*')
    ax.set_xlabel('x'); ax.set_ylabel('t')

fig, (axL, axR) = plt.subplots(1, 2, figsize=(15, 6))

# left: full domain
draw(axL)
axL.set_xlim(0, 1)
axL.set_ylim(0, env.t_star + (env.R_bubble + 3) * env.dt)
axL.set_title('Full domain')
axL.legend(fontsize=8, loc='upper left', markerscale=1.2)

# right: zoom on the bubble
draw(axR)
pad = (env.R_bubble + 2)
axR.set_xlim(env.x_star - pad * env.dx, env.x_star + pad * env.dx)
axR.set_ylim(env.t_star - pad * env.dt, env.t_star + pad * env.dt)
err_str = 'None' if err is None else f'{err:.2e}'
axR.set_title(f'Bubble zoom — {outcome}\nerr={err_str}  |  k={info.get("k_term", env.step_count)}  |  reward={reward:.3f}')
axR.legend(fontsize=8, loc='upper left', markerscale=1.2)

plt.tight_layout()
plt.show()
# Out:
# Outcome:        bubble filled
# Steps (k_term): 859
# Points in box:  5  (need 5)
# u_pred:         0.9787679154183421
# u_ref:          0.9774742068915838
# |error|:        1.294e-03
# Final reward:   -0.1147   (r_acc=-0.029823050818173644, r_eff=-0.0859)
# Total accepted: 859   |   Total rejected: 0

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps, N_particles, err_tol, w_err, w_time, K_max, c_shape,
                      R_bubble=4, save=True, timestep=None, img_dir=".", label=None,
                      x_star_steps=None):          # grid index for x*; None → center
    import matplotlib.patches as patches
    from collections import defaultdict

    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles,
                         err_tol=err_tol, w_err=w_err, w_time=w_time, K_max=K_max,
                         c_shape=c_shape, R_bubble=R_bubble,
                         x_star_schedule=None if x_star_steps is None else [x_star_steps])
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'          # keep tags for filenames/video

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    Rx = env.R_bubble * env.dx
    Rt = env.R_bubble * env.dt

    # points inside the box (field points only)
    in_box = [(x, t) for (x, t) in visited_log
              if 0.0 < t and 0.0 < x < 1.0
              and abs(x - env.x_star) <= Rx + 1e-9 and abs(t - env.t_star) <= Rt + 1e-9]

    # stencil the star solve actually used (box on fill, global-NN on timeout)
    box_R = env.R_bubble if reached else None
    _, s_ok, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star,
                                            causal=False, box_R=box_R)

    rej_colors = {'bounds': 'blue', 'collision': 'orange', 'cond': 'purple',
                  'weights': 'brown', 'geometry': 'red', 'bounds_u': 'magenta',
                  'no_nb': 'teal', None: 'gray'}
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))

    def draw(ax, show_rej=True):
        ax.scatter([p[0] for p in visited_log], [p[1] for p in visited_log],
                   s=4, color='lightgray', zorder=1)
        if show_rej and env.rejected_history:
            by_reason = defaultdict(list)
            for (rx, rt, reason) in env.rejected_history:
                by_reason[reason].append((rx, rt))
            for reason, pts in by_reason.items():
                ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                           s=6, alpha=0.08, linewidths=0, zorder=1,
                           color=rej_colors.get(reason, 'gray'),
                           label=f'rej:{reason} ({len(pts)})')
        # bubble box
        ax.add_patch(patches.Rectangle(
            (env.x_star - Rx, env.t_star - Rt), 2 * Rx, 2 * Rt,
            fill=False, edgecolor='red', linestyle='--', linewidth=1.5, zorder=4))
        # in-box points
        if in_box:
            ax.scatter([p[0] for p in in_box], [p[1] for p in in_box],
                       s=30, facecolors='none', edgecolors='green',
                       linewidths=1.3, zorder=5, label=f'in box ({len(in_box)})')
        # trajectories
        for i, traj in trajectories.items():
            xs = [p[0] for p in traj]; ts = [p[1] for p in traj]
            ax.plot(xs, ts, '-', linewidth=1.2, color=colors[i], alpha=0.7, zorder=2)
            ax.scatter(xs, ts, s=18, color=colors[i], zorder=3)
            ax.scatter(xs[0], ts[0], s=70, color=colors[i], marker='^', zorder=4)
        # star stencil
        if s_ok and nb_coords is not None:
            for (nxp, ntp) in nb_coords:
                ax.plot([env.x_star, nxp], [env.t_star, ntp], '--',
                        color='crimson', linewidth=1.0, alpha=0.85, zorder=6)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1], s=45, color='crimson',
                       zorder=7, label='star stencil')
        # star
        ax.scatter(env.x_star, env.t_star, s=200, color='red', marker='*',
                   zorder=8, label='z*')
        ax.set_xlabel('x'); ax.set_ylabel('t')

    fig, (axL, axR) = plt.subplots(1, 2, figsize=(15, 6))

    # left: full domain
    draw(axL, show_rej=True)
    axL.set_xlim(0, 1)
    axL.set_ylim(0, env.t_star + (env.R_bubble + 3) * env.dt)
    axL.set_title('Full domain')
    axL.legend(fontsize=6, loc='upper left', markerscale=1.5)

    # right: zoom on the bubble
    draw(axR, show_rej=True)
    pad = env.R_bubble + 2
    axR.set_xlim(max(0.0, env.x_star - pad * env.dx), min(1.0, env.x_star + pad * env.dx))
    axR.set_ylim(env.t_star - pad * env.dt, env.t_star + pad * env.dt)
    err_str = 'None' if info.get('error') is None else f'{info["error"]:.2e}'
    axR.set_title(f'Bubble zoom — {outcome}  |  err={err_str}  |  k={info.get("k_term", env.step_count)}')

    sup = f't*={t_star_steps}·dt  |  x*={env.x_star:.2f}  |  {outcome}  |  reward={reward:.3f}'
    if timestep is not None:
        sup += f'  |  step {timestep:,}'
    fig.suptitle(sup, y=1.02)
    plt.tight_layout()

    if save:
        xtag = "" if x_star_steps is None else f"_x{x_star_steps}"
        if label is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt{xtag}_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120, bbox_inches='tight')
        plt.close(fig)
    else:
        plt.show()

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf         = []   # 1 = bubble filled, 0 = timeout
        self.kterm_reach = []
        self.err_reach   = []
        self.kterm_all   = []
        self.err_all     = []
        self.racc_all    = []   # ← NEW: accuracy-reward term
        self.reff_all    = []   # ← NEW: speed/efficiency-reward term

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if not (info.get('reached') or info.get('timeout')):
                continue
            filled = bool(info.get('reached'))
            self.buf.append(1 if filled else 0)

            k = info.get('k_term')
            e = info.get('error')
            if k is not None:
                self.kterm_all.append(k)
                if filled:
                    self.kterm_reach.append(k)
            if e is not None:
                self.err_all.append(e)
                if filled:
                    self.err_reach.append(e)

            ra = info.get('r_acc')          # ← NEW
            re = info.get('r_eff')          # ← NEW
            if ra is not None:
                self.racc_all.append(ra)
            if re is not None:
                self.reff_all.append(re)

        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_all:
            self.logger.record('rollout/mean_kterm',          np.mean(self.kterm_all[-100:]))
        if self.err_all:
            self.logger.record('rollout/mean_error',          np.mean(self.err_all[-100:]))
        if self.kterm_reach:
            self.logger.record('rollout/mean_kterm_on_reach', np.mean(self.kterm_reach[-100:]))
        if self.err_reach:
            self.logger.record('rollout/mean_error_on_reach', np.mean(self.err_reach[-100:]))
        if self.racc_all:
            self.logger.record('rollout/mean_r_acc',          np.mean(self.racc_all[-100:]))   # ← NEW
        if self.reff_all:
            self.logger.record('rollout/mean_r_eff',          np.mean(self.reff_all[-100:]))   # ← NEW
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, N_particles, err_tol, w_err, w_time,
                 K_max, c_shape, plot_freq=50_000, img_dir=".", verbose=0,
                 x_star_steps=None, R_bubble=4):       
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles  = N_particles
        self.err_tol      = err_tol
        self.w_err        = w_err
        self.w_time       = w_time
        self.K_max        = K_max
        self.c_shape      = c_shape
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir
        self.x_star_steps = x_star_steps
        self.R_bubble     = R_bubble                

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles,
                  self.err_tol, self.w_err, self.w_time, self.K_max, self.c_shape,
                  R_bubble=self.R_bubble,      
                  save=True, timestep=self.num_timesteps,
                  img_dir=self.img_dir,
                  x_star_steps=self.x_star_steps)
        return True


def make_env(t_star_schedule, N_particles, err_tol, w_err, w_time, K_max, c_shape,
             x_star_schedule, R_bubble=4):            
    def _init():
        env = PDEEnvironment(t_star_schedule=t_star_schedule, N_particles=N_particles,
                             err_tol=err_tol, w_err=w_err, w_time=w_time,
                             K_max=K_max, c_shape=c_shape,
                             x_star_schedule=x_star_schedule,
                             R_bubble=R_bubble)            # ← NEW
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
N_particles     = 90
t_star_schedule = {100: 5000}   # K_max per t*
x_star_schedule = [50]
seeds           = [10]

n_envs          = 12
n_steps         = 1024
batch_size      = 1024

total_timesteps = 100_000_000

err_tol         = 1e-3
w_err           = 1
w_time          = 0.1
c_shape         = 0.0001
R_bubble        = 4            # ← NEW: box half-width (grid steps) for the star bubble

# representative t* used ONLY for periodic plots/videos (policy trains on all keys)
plot_tstar   = list(t_star_schedule.keys())[0]  # pick the first t* for plotting
plot_K_max   = t_star_schedule[plot_tstar]
plot_xstar   = x_star_schedule[0]  # representative x* for plots

# ── Run directory ────────────────────────────────────────────────────────────
day        = date.today().day
month      = date.today().month 
stages_str = "-".join(str(s) for s in t_star_schedule.keys())
run_name   = (f"t{stages_str}_errtol{err_tol}_werr{w_err}_wtime{w_time}"
              f"_N{N_particles}_c{c_shape}_R{R_bubble}")     # ← NEW: R in run name

run_dir    = os.path.join(f"runs{month}-{day}", run_name)

print(f"Run: {run_dir}")
print(f"Training jointly on t*={list(t_star_schedule.keys())}  "
      f"(periodic plots shown at t*={plot_tstar}, R_bubble={R_bubble})")

for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    # every subprocess gets the SAME schedule and resamples t* per episode in reset()
    vec_env = SubprocVecEnv([
        make_env(t_star_schedule, N_particles, err_tol, w_err, w_time, K_max=None,
         c_shape=c_shape, x_star_schedule=x_star_schedule,
         R_bubble=R_bubble)                                  # ← NEW
        for _ in range(n_envs)
    ])

    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=2e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=batch_size,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    print(f"\n{'='*50}")
    print(f"Joint training over t* schedule: {t_star_schedule}")
    print(f"budget: {total_timesteps//1000}k steps")
    print(f"{'='*50}")

    model.learn(
        total_timesteps=total_timesteps,
        reset_num_timesteps=False,
        tb_log_name=f"seed{seed}",
        log_interval=2,
        callback=[
            ReachedRateCallback(),
            PlotCallback(plot_tstar, N_particles, err_tol, w_err, w_time, plot_K_max, c_shape,
             plot_freq=100_000, img_dir=img_dir, x_star_steps=plot_xstar,
             R_bubble=R_bubble),                             # ← NEW
            CheckpointCallback(
                save_freq=100_000,
                save_path=os.path.join(ckpt_dir, "sched"),
                name_prefix="sched"
            ),
        ],
    )

    model.save(os.path.join(ckpt_dir, "sched_final"))

    # final plots/videos at the representative t*
    plot_trajectories(model, plot_tstar, N_particles, err_tol, w_err, w_time,
                  plot_K_max, c_shape, R_bubble=R_bubble,    # ← NEW
                  save=True, timestep=None,
                  img_dir=img_dir, label="final", x_star_steps=plot_xstar)
# Out:
# Run: runs7-24\t100_errtol0.001_werr1_wtime0.1_N90_c0.0001_R4
# Training jointly on t*=[100]  (periodic plots shown at t*=100, R_bubble=4)
#
# ##################################################
# SEED 10
# ##################################################
# Using cpu device
#
# ==================================================
# Joint training over t* schedule: {100: 5000}
# budget: 100000k steps
# ==================================================
# Logging to runs7-24\t100_errtol0.001_werr1_wtime0.1_N90_c0.0001_R4\seed10\logs\seed10_0
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3956        |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003932847 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -6.02       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0777     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.65e+03     |
# |    ep_rew_mean          | -0.134       |
# |    mean_error           | 0.00212      |
# |    mean_error_on_reach  | 0.00212      |
# |    mean_kterm           | 3.65e+03     |
# |    mean_kterm_on_reach  | 3.65e+03     |
# |    mean_r_acc           | -0.0616      |
# |    mean_r_eff           | -0.0729      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3619         |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031473618 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.89        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0875      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0164      |
# |    value_loss           | 0.00154      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.63e+03     |
# |    ep_rew_mean          | -0.125       |
# |    mean_error           | 0.0018       |
# |    mean_error_on_reach  | 0.0018       |
# |    mean_kterm           | 3.63e+03     |
# |    mean_kterm_on_reach  | 3.63e+03     |
# |    mean_r_acc           | -0.0521      |
# |    mean_r_eff           | -0.0726      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3669         |
# |    iterations           | 6            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039654267 |
# |    clip_fraction        | 0.225        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.95        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.078       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 0.000445     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.72e+03     |
# |    ep_rew_mean          | -0.118       |
# |    mean_error           | 0.00143      |
# |    mean_error_on_reach  | 0.00143      |
# |    mean_kterm           | 3.72e+03     |
# |    mean_kterm_on_reach  | 3.72e+03     |
# |    mean_r_acc           | -0.0433      |
# |    mean_r_eff           | -0.0744      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3594         |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0031781017 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0822      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0158      |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | -0.114       |
# |    mean_error           | 0.00136      |
# |    mean_error_on_reach  | 0.00136      |
# |    mean_kterm           | 3.71e+03     |
# |    mean_kterm_on_reach  | 3.71e+03     |
# |    mean_r_acc           | -0.04        |
# |    mean_r_eff           | -0.0741      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3498         |
# |    iterations           | 10           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0040605515 |
# |    clip_fraction        | 0.254        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.9         |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0718      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 0.00027      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.63e+03     |
# |    ep_rew_mean          | -0.177       |
# |    mean_error           | 0.00276      |
# |    mean_error_on_reach  | 0.00276      |
# |    mean_kterm           | 3.63e+03     |
# |    mean_kterm_on_reach  | 3.63e+03     |
# |    mean_r_acc           | -0.104       |
# |    mean_r_eff           | -0.0726      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3565         |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0033985705 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.87        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0734      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.00237      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.61e+03    |
# |    ep_rew_mean          | -0.206      |
# |    mean_error           | 0.00381     |
# |    mean_error_on_reach  | 0.00381     |
# |    mean_kterm           | 3.61e+03    |
# |    mean_kterm_on_reach  | 3.61e+03    |
# |    mean_r_acc           | -0.134      |
# |    mean_r_eff           | -0.0721     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3628        |
# |    iterations           | 14          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.003684634 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0754     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.62e+03    |
# |    ep_rew_mean          | -0.202      |
# |    mean_error           | 0.00363     |
# |    mean_error_on_reach  | 0.00363     |
# |    mean_kterm           | 3.62e+03    |
# |    mean_kterm_on_reach  | 3.62e+03    |
# |    mean_r_acc           | -0.13       |
# |    mean_r_eff           | -0.0723     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3665        |
# |    iterations           | 16          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.003676552 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0756     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -0.216       |
# |    mean_error           | 0.00438      |
# |    mean_error_on_reach  | 0.00438      |
# |    mean_kterm           | 3.5e+03      |
# |    mean_kterm_on_reach  | 3.5e+03      |
# |    mean_r_acc           | -0.146       |
# |    mean_r_eff           | -0.0701      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 18           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0039023675 |
# |    clip_fraction        | 0.196        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0715      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.00333      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.48e+03    |
# |    ep_rew_mean          | -0.224      |
# |    mean_error           | 0.00491     |
# |    mean_error_on_reach  | 0.00491     |
# |    mean_kterm           | 3.48e+03    |
# |    mean_kterm_on_reach  | 3.48e+03    |
# |    mean_r_acc           | -0.155      |
# |    mean_r_eff           | -0.0696     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3516        |
# |    iterations           | 20          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.004610767 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0736     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -0.227       |
# |    mean_error           | 0.00622      |
# |    mean_error_on_reach  | 0.00622      |
# |    mean_kterm           | 3.5e+03      |
# |    mean_kterm_on_reach  | 3.5e+03      |
# |    mean_r_acc           | -0.157       |
# |    mean_r_eff           | -0.0701      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3551         |
# |    iterations           | 22           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0041566296 |
# |    clip_fraction        | 0.207        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.78        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0754      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.00169      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.44e+03    |
# |    ep_rew_mean          | -0.246      |
# |    mean_error           | 0.00683     |
# |    mean_error_on_reach  | 0.00683     |
# |    mean_kterm           | 3.44e+03    |
# |    mean_kterm_on_reach  | 3.44e+03    |
# |    mean_r_acc           | -0.177      |
# |    mean_r_eff           | -0.0689     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3583        |
# |    iterations           | 24          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004305196 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.068      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.39e+03    |
# |    ep_rew_mean          | -0.246      |
# |    mean_error           | 0.00759     |
# |    mean_error_on_reach  | 0.00759     |
# |    mean_kterm           | 3.39e+03    |
# |    mean_kterm_on_reach  | 3.39e+03    |
# |    mean_r_acc           | -0.178      |
# |    mean_r_eff           | -0.0679     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3449        |
# |    iterations           | 26          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.004819118 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0728     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.34e+03    |
# |    ep_rew_mean          | -0.249      |
# |    mean_error           | 0.00755     |
# |    mean_error_on_reach  | 0.00755     |
# |    mean_kterm           | 3.34e+03    |
# |    mean_kterm_on_reach  | 3.34e+03    |
# |    mean_r_acc           | -0.182      |
# |    mean_r_eff           | -0.0668     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3485        |
# |    iterations           | 28          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.005334633 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.072      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.3e+03      |
# |    ep_rew_mean          | -0.264       |
# |    mean_error           | 0.00817      |
# |    mean_error_on_reach  | 0.00817      |
# |    mean_kterm           | 3.3e+03      |
# |    mean_kterm_on_reach  | 3.3e+03      |
# |    mean_r_acc           | -0.198       |
# |    mean_r_eff           | -0.0661      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3514         |
# |    iterations           | 30           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0052028717 |
# |    clip_fraction        | 0.248        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.76        |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0729      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.00328      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.25e+03    |
# |    ep_rew_mean          | -0.275      |
# |    mean_error           | 0.0084      |
# |    mean_error_on_reach  | 0.0084      |
# |    mean_kterm           | 3.25e+03    |
# |    mean_kterm_on_reach  | 3.25e+03    |
# |    mean_r_acc           | -0.21       |
# |    mean_r_eff           | -0.0651     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3541        |
# |    iterations           | 32          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004712955 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0717     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.21e+03     |
# |    ep_rew_mean          | -0.289       |
# |    mean_error           | 0.00901      |
# |    mean_error_on_reach  | 0.00901      |
# |    mean_kterm           | 3.21e+03     |
# |    mean_kterm_on_reach  | 3.21e+03     |
# |    mean_r_acc           | -0.225       |
# |    mean_r_eff           | -0.0641      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3523         |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.0056704436 |
# |    clip_fraction        | 0.256        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0699      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.22e+03     |
# |    ep_rew_mean          | -0.314       |
# |    mean_error           | 0.00951      |
# |    mean_error_on_reach  | 0.00951      |
# |    mean_kterm           | 3.22e+03     |
# |    mean_kterm_on_reach  | 3.22e+03     |
# |    mean_r_acc           | -0.25        |
# |    mean_r_eff           | -0.0645      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3535         |
# |    iterations           | 36           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0052785967 |
# |    clip_fraction        | 0.244        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0733      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.18e+03     |
# |    ep_rew_mean          | -0.321       |
# |    mean_error           | 0.0111       |
# |    mean_error_on_reach  | 0.0111       |
# |    mean_kterm           | 3.18e+03     |
# |    mean_kterm_on_reach  | 3.18e+03     |
# |    mean_r_acc           | -0.257       |
# |    mean_r_eff           | -0.0635      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3550         |
# |    iterations           | 38           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0058920053 |
# |    clip_fraction        | 0.255        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0735      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.13e+03    |
# |    ep_rew_mean          | -0.326      |
# |    mean_error           | 0.0114      |
# |    mean_error_on_reach  | 0.0114      |
# |    mean_kterm           | 3.13e+03    |
# |    mean_kterm_on_reach  | 3.13e+03    |
# |    mean_r_acc           | -0.263      |
# |    mean_r_eff           | -0.0626     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3570        |
# |    iterations           | 40          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004658085 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0713     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.11e+03    |
# |    ep_rew_mean          | -0.334      |
# |    mean_error           | 0.0127      |
# |    mean_error_on_reach  | 0.0127      |
# |    mean_kterm           | 3.11e+03    |
# |    mean_kterm_on_reach  | 3.11e+03    |
# |    mean_r_acc           | -0.271      |
# |    mean_r_eff           | -0.0622     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3552        |
# |    iterations           | 42          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.005042602 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0748     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00053     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.18e+03     |
# |    ep_rew_mean          | -0.333       |
# |    mean_error           | 0.0128       |
# |    mean_error_on_reach  | 0.0128       |
# |    mean_kterm           | 3.18e+03     |
# |    mean_kterm_on_reach  | 3.18e+03     |
# |    mean_r_acc           | -0.27        |
# |    mean_r_eff           | -0.0636      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3569         |
# |    iterations           | 44           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0068361512 |
# |    clip_fraction        | 0.289        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0783      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.00134      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.15e+03    |
# |    ep_rew_mean          | -0.341      |
# |    mean_error           | 0.0142      |
# |    mean_error_on_reach  | 0.0142      |
# |    mean_kterm           | 3.15e+03    |
# |    mean_kterm_on_reach  | 3.15e+03    |
# |    mean_r_acc           | -0.278      |
# |    mean_r_eff           | -0.0631     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3590        |
# |    iterations           | 46          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.005568363 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0756     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.11e+03    |
# |    ep_rew_mean          | -0.343      |
# |    mean_error           | 0.015       |
# |    mean_error_on_reach  | 0.015       |
# |    mean_kterm           | 3.11e+03    |
# |    mean_kterm_on_reach  | 3.11e+03    |
# |    mean_r_acc           | -0.28       |
# |    mean_r_eff           | -0.0623     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3603        |
# |    iterations           | 48          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.004907519 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0667     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00989    |
# |    value_loss           | 0.00318     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.13e+03     |
# |    ep_rew_mean          | -0.369       |
# |    mean_error           | 0.0164       |
# |    mean_error_on_reach  | 0.0164       |
# |    mean_kterm           | 3.13e+03     |
# |    mean_kterm_on_reach  | 3.13e+03     |
# |    mean_r_acc           | -0.306       |
# |    mean_r_eff           | -0.0626      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3557         |
# |    iterations           | 50           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0050720708 |
# |    clip_fraction        | 0.227        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0751      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.00369      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.05e+03   |
# |    ep_rew_mean          | -0.379     |
# |    mean_error           | 0.0176     |
# |    mean_error_on_reach  | 0.0176     |
# |    mean_kterm           | 3.05e+03   |
# |    mean_kterm_on_reach  | 3.05e+03   |
# |    mean_r_acc           | -0.318     |
# |    mean_r_eff           | -0.061     |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 3571       |
# |    iterations           | 52         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 638976     |
# | train/                  |            |
# |    approx_kl            | 0.00472549 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -5.63      |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0666    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 0.00515    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.01e+03    |
# |    ep_rew_mean          | -0.403      |
# |    mean_error           | 0.022       |
# |    mean_error_on_reach  | 0.022       |
# |    mean_kterm           | 3.01e+03    |
# |    mean_kterm_on_reach  | 3.01e+03    |
# |    mean_r_acc           | -0.343      |
# |    mean_r_eff           | -0.0601     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3581        |
# |    iterations           | 54          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 663552      |
# | train/                  |             |
# |    approx_kl            | 0.004614422 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0718     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00483     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.96e+03     |
# |    ep_rew_mean          | -0.429       |
# |    mean_error           | 0.0245       |
# |    mean_error_on_reach  | 0.0245       |
# |    mean_kterm           | 2.96e+03     |
# |    mean_kterm_on_reach  | 2.96e+03     |
# |    mean_r_acc           | -0.37        |
# |    mean_r_eff           | -0.0592      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3595         |
# |    iterations           | 56           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0048649833 |
# |    clip_fraction        | 0.242        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0668      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 2.8e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.98e+03     |
# |    ep_rew_mean          | -0.432       |
# |    mean_error           | 0.0272       |
# |    mean_error_on_reach  | 0.0272       |
# |    mean_kterm           | 2.98e+03     |
# |    mean_kterm_on_reach  | 2.98e+03     |
# |    mean_r_acc           | -0.373       |
# |    mean_r_eff           | -0.0596      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3579         |
# |    iterations           | 58           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 712704       |
# | train/                  |              |
# |    approx_kl            | 0.0045620375 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.62        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.065       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 0.00101      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92e+03    |
# |    ep_rew_mean          | -0.436      |
# |    mean_error           | 0.0306      |
# |    mean_error_on_reach  | 0.0306      |
# |    mean_kterm           | 2.92e+03    |
# |    mean_kterm_on_reach  | 2.92e+03    |
# |    mean_r_acc           | -0.378      |
# |    mean_r_eff           | -0.0584     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3590        |
# |    iterations           | 60          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.004321064 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0682     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00949    |
# |    value_loss           | 0.0039      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.94e+03     |
# |    ep_rew_mean          | -0.438       |
# |    mean_error           | 0.0316       |
# |    mean_error_on_reach  | 0.0316       |
# |    mean_kterm           | 2.94e+03     |
# |    mean_kterm_on_reach  | 2.94e+03     |
# |    mean_r_acc           | -0.379       |
# |    mean_r_eff           | -0.0588      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3599         |
# |    iterations           | 62           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 761856       |
# | train/                  |              |
# |    approx_kl            | 0.0035655505 |
# |    clip_fraction        | 0.182        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0669      |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 0.00143      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.01e+03    |
# |    ep_rew_mean          | -0.45       |
# |    mean_error           | 0.0334      |
# |    mean_error_on_reach  | 0.0334      |
# |    mean_kterm           | 3.01e+03    |
# |    mean_kterm_on_reach  | 3.01e+03    |
# |    mean_r_acc           | -0.39       |
# |    mean_r_eff           | -0.0602     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3608        |
# |    iterations           | 64          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.003946039 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.073      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.000942    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.04e+03     |
# |    ep_rew_mean          | -0.47        |
# |    mean_error           | 0.0335       |
# |    mean_error_on_reach  | 0.0335       |
# |    mean_kterm           | 3.04e+03     |
# |    mean_kterm_on_reach  | 3.04e+03     |
# |    mean_r_acc           | -0.41        |
# |    mean_r_eff           | -0.0607      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3595         |
# |    iterations           | 66           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 811008       |
# | train/                  |              |
# |    approx_kl            | 0.0040629418 |
# |    clip_fraction        | 0.203        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0752      |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.00112      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.08e+03     |
# |    ep_rew_mean          | -0.469       |
# |    mean_error           | 0.0346       |
# |    mean_error_on_reach  | 0.0346       |
# |    mean_kterm           | 3.08e+03     |
# |    mean_kterm_on_reach  | 3.08e+03     |
# |    mean_r_acc           | -0.408       |
# |    mean_r_eff           | -0.0615      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3605         |
# |    iterations           | 68           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0037748108 |
# |    clip_fraction        | 0.202        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0776      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 0.000441     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.06e+03     |
# |    ep_rew_mean          | -0.49        |
# |    mean_error           | 0.0373       |
# |    mean_error_on_reach  | 0.0373       |
# |    mean_kterm           | 3.06e+03     |
# |    mean_kterm_on_reach  | 3.06e+03     |
# |    mean_r_acc           | -0.429       |
# |    mean_r_eff           | -0.0612      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3614         |
# |    iterations           | 70           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 860160       |
# | train/                  |              |
# |    approx_kl            | 0.0043563014 |
# |    clip_fraction        | 0.211        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0707      |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.1e+03      |
# |    ep_rew_mean          | -0.486       |
# |    mean_error           | 0.0388       |
# |    mean_error_on_reach  | 0.0388       |
# |    mean_kterm           | 3.1e+03      |
# |    mean_kterm_on_reach  | 3.1e+03      |
# |    mean_r_acc           | -0.424       |
# |    mean_r_eff           | -0.062       |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3621         |
# |    iterations           | 72           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0037264589 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0711      |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.000834     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.14e+03     |
# |    ep_rew_mean          | -0.478       |
# |    mean_error           | 0.0368       |
# |    mean_error_on_reach  | 0.0368       |
# |    mean_kterm           | 3.14e+03     |
# |    mean_kterm_on_reach  | 3.14e+03     |
# |    mean_r_acc           | -0.415       |
# |    mean_r_eff           | -0.0629      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3594         |
# |    iterations           | 74           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 909312       |
# | train/                  |              |
# |    approx_kl            | 0.0035554988 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0718      |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 0.00066      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.18e+03     |
# |    ep_rew_mean          | -0.468       |
# |    mean_error           | 0.0371       |
# |    mean_error_on_reach  | 0.0371       |
# |    mean_kterm           | 3.18e+03     |
# |    mean_kterm_on_reach  | 3.18e+03     |
# |    mean_r_acc           | -0.404       |
# |    mean_r_eff           | -0.0635      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3602         |
# |    iterations           | 76           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0034843693 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0722      |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.000993     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.28e+03     |
# |    ep_rew_mean          | -0.47        |
# |    mean_error           | 0.0364       |
# |    mean_error_on_reach  | 0.0364       |
# |    mean_kterm           | 3.28e+03     |
# |    mean_kterm_on_reach  | 3.28e+03     |
# |    mean_r_acc           | -0.404       |
# |    mean_r_eff           | -0.0657      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3608         |
# |    iterations           | 78           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0042279847 |
# |    clip_fraction        | 0.214        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0751      |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.00091      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.36e+03     |
# |    ep_rew_mean          | -0.484       |
# |    mean_error           | 0.0386       |
# |    mean_error_on_reach  | 0.0386       |
# |    mean_kterm           | 3.36e+03     |
# |    mean_kterm_on_reach  | 3.36e+03     |
# |    mean_r_acc           | -0.417       |
# |    mean_r_eff           | -0.0673      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3617         |
# |    iterations           | 80           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0037650669 |
# |    clip_fraction        | 0.162        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0731      |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 0.00157      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.39e+03   |
# |    ep_rew_mean          | -0.481     |
# |    mean_error           | 0.0405     |
# ...
# |    total_timesteps      | 20963328     |
# | train/                  |              |
# |    approx_kl            | 0.0058847424 |
# |    clip_fraction        | 0.355        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0648      |
# |    n_updates            | 17050        |
# |    policy_gradient_loss | -0.0088      |
# |    value_loss           | 3.02e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | -0.0959      |
# |    mean_error           | 0.00215      |
# |    mean_error_on_reach  | 0.00215      |
# |    mean_kterm           | 1.61e+03     |
# |    mean_kterm_on_reach  | 1.61e+03     |
# |    mean_r_acc           | -0.0637      |
# |    mean_r_eff           | -0.0322      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3411         |
# |    iterations           | 1708         |
# |    time_elapsed         | 6152         |
# |    total_timesteps      | 20987904     |
# | train/                  |              |
# |    approx_kl            | 0.0057729348 |
# |    clip_fraction        | 0.354        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0644      |
# |    n_updates            | 17070        |
# |    policy_gradient_loss | -0.00776     |
# |    value_loss           | 7.74e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.74e+03    |
# |    ep_rew_mean          | -0.0902     |
# |    mean_error           | 0.00193     |
# |    mean_error_on_reach  | 0.00193     |
# |    mean_kterm           | 1.74e+03    |
# |    mean_kterm_on_reach  | 1.74e+03    |
# |    mean_r_acc           | -0.0555     |
# |    mean_r_eff           | -0.0348     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3411        |
# |    iterations           | 1710        |
# |    time_elapsed         | 6159        |
# |    total_timesteps      | 21012480    |
# | train/                  |             |
# |    approx_kl            | 0.005837137 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.28       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0668     |
# |    n_updates            | 17090       |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 4.11e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.79e+03     |
# |    ep_rew_mean          | -0.0802      |
# |    mean_error           | 0.00188      |
# |    mean_error_on_reach  | 0.00188      |
# |    mean_kterm           | 1.79e+03     |
# |    mean_kterm_on_reach  | 1.79e+03     |
# |    mean_r_acc           | -0.0445      |
# |    mean_r_eff           | -0.0358      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3411         |
# |    iterations           | 1712         |
# |    time_elapsed         | 6165         |
# |    total_timesteps      | 21037056     |
# | train/                  |              |
# |    approx_kl            | 0.0062262737 |
# |    clip_fraction        | 0.332        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0674      |
# |    n_updates            | 17110        |
# |    policy_gradient_loss | -0.00763     |
# |    value_loss           | 3.46e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.83e+03    |
# |    ep_rew_mean          | -0.0684     |
# |    mean_error           | 0.00206     |
# |    mean_error_on_reach  | 0.00206     |
# |    mean_kterm           | 1.83e+03    |
# |    mean_kterm_on_reach  | 1.83e+03    |
# |    mean_r_acc           | -0.0319     |
# |    mean_r_eff           | -0.0366     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3412        |
# |    iterations           | 1714        |
# |    time_elapsed         | 6172        |
# |    total_timesteps      | 21061632    |
# | train/                  |             |
# |    approx_kl            | 0.005286038 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.057      |
# |    n_updates            | 17130       |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 1.92e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.8e+03    |
# |    ep_rew_mean          | -0.0801    |
# |    mean_error           | 0.00189    |
# |    mean_error_on_reach  | 0.00189    |
# |    mean_kterm           | 1.8e+03    |
# |    mean_kterm_on_reach  | 1.8e+03    |
# |    mean_r_acc           | -0.0442    |
# |    mean_r_eff           | -0.036     |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 3412       |
# |    iterations           | 1716       |
# |    time_elapsed         | 6178       |
# |    total_timesteps      | 21086208   |
# | train/                  |            |
# |    approx_kl            | 0.00422382 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -5.35      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0612    |
# |    n_updates            | 17150      |
# |    policy_gradient_loss | -0.00406   |
# |    value_loss           | 0.00149    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+03    |
# |    ep_rew_mean          | -0.0683     |
# |    mean_error           | 0.00105     |
# |    mean_error_on_reach  | 0.00105     |
# |    mean_kterm           | 1.54e+03    |
# |    mean_kterm_on_reach  | 1.54e+03    |
# |    mean_r_acc           | -0.0376     |
# |    mean_r_eff           | -0.0308     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3412        |
# |    iterations           | 1718        |
# |    time_elapsed         | 6186        |
# |    total_timesteps      | 21110784    |
# | train/                  |             |
# |    approx_kl            | 0.005967196 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 3.46e-06    |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0667     |
# |    n_updates            | 17170       |
# |    policy_gradient_loss | -0.00814    |
# |    value_loss           | 1.59e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.52e+03     |
# |    ep_rew_mean          | -0.0618      |
# |    mean_error           | 0.000891     |
# |    mean_error_on_reach  | 0.000891     |
# |    mean_kterm           | 1.52e+03     |
# |    mean_kterm_on_reach  | 1.52e+03     |
# |    mean_r_acc           | -0.0314      |
# |    mean_r_eff           | -0.0305      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3412         |
# |    iterations           | 1720         |
# |    time_elapsed         | 6192         |
# |    total_timesteps      | 21135360     |
# | train/                  |              |
# |    approx_kl            | 0.0066380426 |
# |    clip_fraction        | 0.329        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.917        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0625      |
# |    n_updates            | 17190        |
# |    policy_gradient_loss | -0.007       |
# |    value_loss           | 1.86e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+03     |
# |    ep_rew_mean          | -0.062       |
# |    mean_error           | 0.000845     |
# |    mean_error_on_reach  | 0.000845     |
# |    mean_kterm           | 1.59e+03     |
# |    mean_kterm_on_reach  | 1.59e+03     |
# |    mean_r_acc           | -0.0303      |
# |    mean_r_eff           | -0.0318      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3413         |
# |    iterations           | 1722         |
# |    time_elapsed         | 6198         |
# |    total_timesteps      | 21159936     |
# | train/                  |              |
# |    approx_kl            | 0.0051771924 |
# |    clip_fraction        | 0.295        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0636      |
# |    n_updates            | 17210        |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 1.49e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.74e+03     |
# |    ep_rew_mean          | -0.0666      |
# |    mean_error           | 0.000869     |
# |    mean_error_on_reach  | 0.000869     |
# |    mean_kterm           | 1.74e+03     |
# |    mean_kterm_on_reach  | 1.74e+03     |
# |    mean_r_acc           | -0.0319      |
# |    mean_r_eff           | -0.0348      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3414         |
# |    iterations           | 1724         |
# |    time_elapsed         | 6205         |
# |    total_timesteps      | 21184512     |
# | train/                  |              |
# |    approx_kl            | 0.0057653114 |
# |    clip_fraction        | 0.327        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0644      |
# |    n_updates            | 17230        |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 1.87e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.71e+03   |
# |    ep_rew_mean          | -0.0679    |
# |    mean_error           | 0.000881   |
# |    mean_error_on_reach  | 0.000881   |
# |    mean_kterm           | 1.71e+03   |
# |    mean_kterm_on_reach  | 1.71e+03   |
# |    mean_r_acc           | -0.0339    |
# |    mean_r_eff           | -0.0341    |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 3412       |
# |    iterations           | 1726       |
# |    time_elapsed         | 6214       |
# |    total_timesteps      | 21209088   |
# | train/                  |            |
# |    approx_kl            | 0.00553221 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0589    |
# |    n_updates            | 17250      |
# |    policy_gradient_loss | -0.00621   |
# |    value_loss           | 1.89e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.71e+03     |
# |    ep_rew_mean          | -0.0571      |
# |    mean_error           | 0.000594     |
# |    mean_error_on_reach  | 0.000594     |
# |    mean_kterm           | 1.71e+03     |
# |    mean_kterm_on_reach  | 1.71e+03     |
# |    mean_r_acc           | -0.023       |
# |    mean_r_eff           | -0.0341      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3413         |
# |    iterations           | 1728         |
# |    time_elapsed         | 6221         |
# |    total_timesteps      | 21233664     |
# | train/                  |              |
# |    approx_kl            | 0.0068174754 |
# |    clip_fraction        | 0.365        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.3         |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0631      |
# |    n_updates            | 17270        |
# |    policy_gradient_loss | -0.00832     |
# |    value_loss           | 7.69e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.74e+03    |
# |    ep_rew_mean          | -0.0483     |
# |    mean_error           | 0.000593    |
# |    mean_error_on_reach  | 0.000593    |
# |    mean_kterm           | 1.74e+03    |
# |    mean_kterm_on_reach  | 1.74e+03    |
# |    mean_r_acc           | -0.0136     |
# |    mean_r_eff           | -0.0348     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3413        |
# |    iterations           | 1730        |
# |    time_elapsed         | 6227        |
# |    total_timesteps      | 21258240    |
# | train/                  |             |
# |    approx_kl            | 0.005159617 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0646     |
# |    n_updates            | 17290       |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 3.8e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.79e+03     |
# |    ep_rew_mean          | -0.0634      |
# |    mean_error           | 0.000688     |
# |    mean_error_on_reach  | 0.000688     |
# |    mean_kterm           | 1.79e+03     |
# |    mean_kterm_on_reach  | 1.79e+03     |
# |    mean_r_acc           | -0.0277      |
# |    mean_r_eff           | -0.0359      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3414         |
# |    iterations           | 1732         |
# |    time_elapsed         | 6233         |
# |    total_timesteps      | 21282816     |
# | train/                  |              |
# |    approx_kl            | 0.0054679425 |
# |    clip_fraction        | 0.269        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0582      |
# |    n_updates            | 17310        |
# |    policy_gradient_loss | -0.00604     |
# |    value_loss           | 9.86e-05     |
# ------------------------------------------

# %%
from importlib import reload

import trajectory_video
reload(trajectory_video)
from trajectory_video import make_trajectory_video

import training_progress_video
reload(training_progress_video)
from training_progress_video import make_training_progress_video

make_trajectory_video(
    model, PDEEnvironment, plot_tstar, N_particles,
    img_dir=img_dir, label="final",
    x_star_steps=plot_xstar, R_bubble=R_bubble,     # ← match trained target + radius
)

make_training_progress_video(
    img_dir=img_dir,
    t_star_steps=plot_tstar,
    label="final",
    x_star_steps=plot_xstar,
    fps=1,
)
# Out:
# Rollout done: reached, 520 accepted points, 538 total steps.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       7 import training_progress_video
#       8 reload(training_progress_video)
#       9 from training_progress_video import make_training_progress_video
#      10
# ---> 11 make_trajectory_video(
#      12     model, PDEEnvironment, plot_tstar, N_particles,
#      13     img_dir=img_dir, label="final",
#      14     x_star_steps=plot_xstar, R_bubble=R_bubble,     # ← match trained target + radius
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\trajectory_video.py:199, in make_trajectory_video(model, PDEEnvironmentClass, t_star_steps, N_particles, img_dir, label, hold_frames, fps, dpi, verbose, R_bubble, x_star_steps)
#     196 os.makedirs(img_dir, exist_ok=True)
#     198 writer = animation.FFMpegWriter(fps=fps, bitrate=1800)
# --> 199 ani.save(out_path, writer=writer, dpi=dpi)
#     200 plt.close(fig)
#     202 if verbose:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\animation.py:1138, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1135 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1136     for anim, d in zip(all_anim, data):
#    1137         # TODO: See if turning off blit is really necessary
# -> 1138         anim._draw_next_frame(d, blit=False)
#    1139         if progress_callback is not None:
#    1140             progress_callback(frame_number, total_frames)
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\animation.py:1174, in Animation._draw_next_frame(self, framedata, blit)
#    1172 self._pre_draw(framedata, blit)
#    1173 self._draw_frame(framedata)
# -> 1174 self._post_draw(framedata, blit)
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\animation.py:1199, in Animation._post_draw(self, framedata, blit)
#    1197     self._blit_draw(self._drawn_artists)
#    1198 else:
# -> 1199     self._fig.canvas.draw_idle()
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\backend_bases.py:1989, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1987 if not self._is_idle_drawing:
#    1988     with self._idle_draw_cntx():
# -> 1989         self.draw(*args, **kwargs)
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:438, in FigureCanvasAgg.draw(self)
#     435 # Acquire a lock on the shared font cache.
#     436 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     437       else nullcontext()):
# --> 438     self.figure.draw(self.renderer)
#     439     # A GUI class may be need to update a window using this draw, so
#     440     # don't forget to call the superclass.
#     441     super().draw()
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\axes\_base.py:3350, in _AxesBase.draw(self, renderer)
#    3347 if artists_rasterized:
#    3348     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3350 mimage._draw_list_compositing_images(
#    3351     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3353 renderer.close_group('axes')
#    3354 self.stale = False
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\text.py:909, in Text.draw(self, renderer)
#     905         textrenderer.draw_tex(gc, x, y, clean_line,
#     906                               self._fontproperties, angle,
#     907                               mtext=mtext)
#     908     else:
# --> 909         textrenderer.draw_text(gc, x, y, clean_line,
#     910                                self._fontproperties, angle,
#     911                                ismath=ismath, mtext=mtext)
#     913 gc.restore()
#     914 renderer.close_group('text')
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:245, in RendererAgg.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     240 items = font._layout(
#     241     s, flags=get_hinting_flag(),
#     242     features=mtext.get_fontfeatures() if mtext is not None else None,
#     243     language=mtext.get_language() if mtext is not None else None)
#     244 size = prop.get_size_in_points()
# --> 245 self._draw_text_glyphs_and_boxes(
#     246     gc, x, y, angle,
#     247     ((item.ft_object, size, item.glyph_index, 0, 1, item.x, item.y)
#     248      for item in items),
#     249     [])
#
# File c:\Users\amt35\OneDrive\RL For PDEs\Taylor linear predictor\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:189, in RendererAgg._draw_text_glyphs_and_boxes(self, gc, x, y, angle, glyphs, boxes)
#     181 font.set_size(size, self.dpi)
#     182 font._set_transform(
#     183     (0x10000 * np.array([[cos, -sin], [sin, cos]])
#     184      @ [[extend, extend * slant], [0, 1]]).round().astype(int),
#    (...)    187      round(0x40 * (self.height - y + dx * sin + dy * cos))]
#     188 )
# --> 189 bitmap = font._render_glyph(
#     190     glyph_index, load_flags,
#     191     RenderMode.NORMAL if gc.get_antialiased() else RenderMode.MONO)
#     192 buffer = bitmap.buffer
#     193 if not gc.get_antialiased():
#
# KeyboardInterrupt:
