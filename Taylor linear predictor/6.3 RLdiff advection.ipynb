# %% [markdown]
# ### Libraries and Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from datetime import date
# %matplotlib inline
from trajectory_video import make_trajectory_video
from trajectory_video2 import make_trajectory_video1
from training_progress_video import make_training_progress_video
import re
import glob
import matplotlib as mpl
import matplotlib.animation as animation
import imageio_ffmpeg
mpl.rcParams["animation.ffmpeg_path"] = imageio_ffmpeg.get_ffmpeg_exe()

# %% [markdown]
# ### PDE and FD reference Parameters and RL action space

# %%
# PDE  — advection-diffusion:  u_t + c u_x = alpha u_xx
alpha = 0.1
c     = 1.0                      # constant advection speed  (Peclet = c*L/alpha = 10)

#   FD reference grid
nx    = 100
T     = 0.5                      # same reference window as the Burgers notebook (was 1)
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

# CFL has TWO limits: advective (c u_x) and diffusive (alpha u_xx).
# Unlike Burgers the advective speed is the constant c, not the local u.
dt_cfl = min(0.9 * dx / max(abs(c), 1e-12),
             0.45 * dx**2 / alpha)
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

# ── True solution: analytical advection-diffusion (Fourier sine series) ──
#    IC:  u0(x) = sin(pi x) + 0.5 sin(2 pi x),   BC: u(0,t) = u(1,t) = 0
#    Substituting  u = exp(beta x - alpha beta^2 t) v,  beta = c / (2 alpha)
#    removes the advection term and leaves the pure heat equation for v,
#    so  v(x,t) = sum_n b_n sin(n pi x) exp(-alpha (n pi)^2 t)  with
#    b_n the sine coefficients of  v0(x) = u0(x) exp(-beta x).
_xq   = np.linspace(0.0, 1.0, 80001)
_beta = c / (2.0 * alpha)
_u0q  = np.sin(np.pi * _xq) + 0.5 * np.sin(2 * np.pi * _xq)
_v0q  = _u0q * np.exp(-_beta * _xq)

_N_SERIES = 800
_n_arr = np.arange(1, _N_SERIES + 1)
_bn    = np.empty(_N_SERIES)
for n in _n_arr:
    _bn[n - 1] = 2.0 * np.trapezoid(_v0q * np.sin(n * np.pi * _xq), _xq)

_lam_ad = -alpha * (_n_arr * np.pi) ** 2

def u_true(x, t):
    x = np.asarray(x, dtype=float)
    scalar = x.ndim == 0
    x = np.atleast_1d(x)

    sin_nx = np.sin(np.pi * np.outer(x, _n_arr))
    exp_t  = np.exp(_lam_ad * t)

    v      = (sin_nx * (_bn * exp_t)).sum(axis=-1)
    result = np.exp(_beta * x - alpha * _beta**2 * t) * v
    return float(result[0]) if scalar else result

# %% [markdown]
# ### FD For advection-diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2
    r_adv  = c * dt / dx                             # constant advection speed c

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         - r_adv * (un[1:-1] - un[:-2])               # upwind c u_x (c > 0)
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))  # diffusion
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %% [markdown]
# ### __ init __

# %%
class VisitedSet:
    def __init__(self, cap0=8192):
        self._cap  = cap0
        self._n    = 0
        self._store     = np.empty((cap0, 3), dtype=float)   # (x, t, u)
        self._normstore = np.empty((cap0, 2), dtype=float)   # (x/dx, t/dt)
        self._idx_set   = set()
        self.rejected_history = []

    def _grow(self):
        self._cap *= 2
        s  = np.empty((self._cap, 3)); s[:self._n]  = self._store[:self._n];     self._store = s
        ns = np.empty((self._cap, 2)); ns[:self._n] = self._normstore[:self._n]; self._normstore = ns

    def add(self, x, t, u):
        if self._n == self._cap:
            self._grow()
        self._store[self._n]     = (x, t, u)
        self._normstore[self._n] = (x / dx, t / dt)
        self._idx_set.add((round(x / dx), round(t / dt)))
        self._n += 1

    # live-slice views so plot/video code that iterates ._pts keeps working
    @property
    def _pts(self):
        return self._store[:self._n]

    @property
    def _norm(self):
        return self._normstore[:self._n]

    def contains(self, x, t):
        return (round(x / dx), round(t / dt)) in self._idx_set

    def find_neighbours(self, x_star, t_star, n, causal=True, box_R=None):
        if self._n < n:
            return None
        pts_arr  = self._store[:self._n]
        norm_arr = self._normstore[:self._n]

        if causal:
            mask = pts_arr[:, 1] <= t_star
        else:
            mask = np.ones(self._n, dtype=bool)

        same_cell = (np.round(pts_arr[:, 0] / dx) == round(x_star / dx)) & \
                    (np.round(pts_arr[:, 1] / dt) == round(t_star / dt))
        mask &= ~same_cell

        if box_R is not None:
            in_box = (np.abs(pts_arr[:, 0] - x_star) <= box_R * dx + 1e-9) & \
                     (np.abs(pts_arr[:, 1] - t_star) <= box_R * dt + 1e-9)
            mask &= in_box

        if mask.sum() < n:
            return None
        norm_c = norm_arr[mask]
        pts_c  = pts_arr[mask]
        target = np.array([x_star / dx, t_star / dt])
        d2     = np.sum((norm_c - target) ** 2, axis=1)
        idx = np.argpartition(d2, n - 1)[:n]
        idx = idx[np.argsort(d2[idx])]
        return [tuple(row) for row in pts_c[idx]]

    def count_in_box(self, x_star, t_star, R):
        ci = round(x_star / dx)
        cj = round(t_star / dt)
        cnt = 0
        for di in range(-R, R + 1):
            for dj in range(-R, R + 1):
                if di == 0 and dj == 0:
                    continue
                if (ci + di, cj + dj) in self._idx_set:
                    cnt += 1
        return cnt

    def __len__(self):
        return self._n

# %% [markdown]
# ### GFDM Solver

# %%
# NOTE (jo-exploration): corrected u_xx row. Substituting u_t = alpha u_xx - c u_x
# RECURSIVELY also reduces u_xt and u_tt to x-derivatives, contributing
# -c dx dt + 0.5 c^2 dt^2. The exact u_xx coefficient is therefore
#     0.5*(dx - c dt)^2 + alpha*dt      [ = 0.5*xi^2 + alpha*dt, xi = dx - c dt ]
# The previous row 0.5*dx^2 + alpha*dt drops both terms. Harmless when |c dt|<<|dx|,
# but it cannot express a 2nd-order advection scheme: with the correction the
# 3-point centred stencil is exactly Lax-Wendroff; without it, FTCS-central
# (unconditionally unstable). Verified symbolically.
def solve_weights(dx_i, dt_i, u_nb=None):
    h = max(np.max(np.abs(dx_i)), np.sqrt(alpha * np.max(np.abs(dt_i))), 1e-12)

    # Advection-diffusion: the transport speed is the constant c.  (In the
    # Burgers notebook this line was c_local = mean(u_nb), the local
    # linearisation of u u_x; u_nb is kept in the signature so the call site
    # and the rest of the environment stay identical.)
    c_local = c

    A = np.array([
        np.ones(len(dx_i)),
        (dx_i - c_local * dt_i) / h,               # u_x row: carries -c u_x from u_t
        (0.5 * (dx_i - c_local * dt_i)**2 + alpha * dt_i) / h**2,   # u_xx row (CORRECTED)
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > 1e4:
        return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    if abs(w.sum() - 1.0) > 1e-6:       # jo-exploration: rank-deficient A

        return None, 'inconsistent'
    #if np.max(np.abs(w)) > 3.0 / len(dx_i):
    #    return None, 'weights'
    #if np.min(w) < -1.0:
    #    return None, 'weights'

    return w, 'ok'

# %% [markdown]
# ### PDEEnvironment

# %%
from logging import info

from matplotlib.pyplot import box


class PDEEnvironment(gym.Env):
    ACTIONS = {0: (-1,1),
               1: (-1,2),
               2: (0, 1),  
               3: (0, 2), 
               4: (1, 1),
               5: (1, 2)  

               }
    
    def __init__(self, R_bubble,t_star_schedule=None, t_star_steps=2, N_particles=27,err_tol=1e-3, w_err=0.8, w_time=0.2,
             K_max=5000, c_shape=0.05, x_star_schedule=None,
             causal_moves=False):
        super().__init__()

        self.alpha = alpha
        self.c = c                      # constant advection speed
        self.c_shape = c_shape
        self.ERR_CEIL = 2.2
        self.n_neighbours = 5
        self.R_bubble = R_bubble
        self.nx = nx; self.nt = nt
        self.x_fd = x_fd; self.t_fd = t_fd
        self.dx = dx; self.dt = dt; self.T = T

        self.t_star_schedule = dict(t_star_schedule) if t_star_schedule else None

        # ── x* schedule: list of grid indices to sample from. None → fixed center.
        # Store as x_fd values so x* always lands on the grid.
        if x_star_schedule is not None:
            self.x_star_choices = np.array(
                [self.x_fd[int(ix)] for ix in x_star_schedule], dtype=float)
        else:
            self.x_star_choices = None

        # ── Target point (z*) ──
        self.x_star = self.x_fd[self.nx // 2]     # provisional; reset() may override
        self.t_star_steps = t_star_steps
        self.t_star = t_star_steps * dt

        self.K_max = K_max
        self.err_tol = err_tol
        self.w_err = w_err
        self.w_time = w_time
        self.phi_scale = 1.0
        self.n_neighbours = 5
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt
        self.retry_after = 50
        # Neighbour search for WALKER MOVES: False -> stencils may draw on points
        # both below and above t_new (the star solve was already non-causal).
        self.causal_moves = causal_moves
        # ── Walker initial positions: FROZEN to domain center, INDEPENDENT of x* ──
        self.N = N_particles
        mid = self.nx // 2
        margin = 2
        half_n = self.N // 2
        step = (mid - margin) / half_n if half_n > 0 else 0
        offsets = [0]; k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1
        init_idx = np.clip(
            np.round(np.array(offsets[:self.N]) + mid).astype(int),
            margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]   # does NOT depend on x_star

        _, self.fd_interp = build_fd_reference()

        self.visited = None
        self.walker_x = None
        self._bubble_dirty = True
        self._bubble_solve = (None, False)
        self.walker_t = None
        self.walker_u = None
        self.step_count = 0
        self.stencil_log = {}

        # obs: 2N relative coords + t*_norm + x*_norm  → 2N+2
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(2 * self.N + 2,), dtype=np.float32)
        self.action_space = spaces.Discrete(self.N * len(self.ACTIONS))

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        
        if self.t_star_schedule is not None:
            choices = list(self.t_star_schedule.keys())
            self.t_star_steps = int(self.np_random.choice(choices))
            self.t_star = self.t_star_steps * self.dt
            self.K_max = self.t_star_schedule[self.t_star_steps]

        # ── Resample x* per episode if a schedule is set ──
        if self.x_star_choices is not None:
            self.x_star = float(self.np_random.choice(self.x_star_choices))

        self.visited = VisitedSet()
        self.stencil_log = {}

        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        self.rejected_history = []
        self.gfdm_rejected_cells = {} 
        self.phi_scale = max(self._mean_target_distance(), 1e-12)
        self._phi_prev = self._potential()
        self._bubble_dirty = True
        self._bubble_solve = (None, False)

        return self._build_obs(), {}

    def _build_obs(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        t_star_norm = self.t_star / self.dt          # horizon length in step units
        x_star_norm = self.x_star / self.dx          # NEW: absolute x* in dx units
        return np.array([
            *dx_rel,
            *dt_rel,
            t_star_norm,
            x_star_norm,
        ], dtype=np.float32)

    def _mean_target_distance(self):
        dx_rel = (self.walker_x - self.x_star) / self.dx
        dt_rel = (self.walker_t - self.t_star) / self.dt
        d = np.sqrt(dx_rel**2 + dt_rel**2)
        return float(np.mean(d))

    def _potential(self):
        if self.c_shape == 0.0:
            return 0.0
        return -self.c_shape * self._mean_target_distance() / max(self.phi_scale, 1e-12)

    def _gfdm_solve(self, x_star, t_star, causal=True, box_R=None, ):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours, causal=causal, box_R=box_R)
        if nb is None:
            return None, False, None, 'no_nb'
        nb = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        #if np.min(dx_i) * np.max(dx_i) > 0:          # all neighbours on one x-side → bad stencil
        #    return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i, nb[:, 2])      
        if w is None:
            return None, False, None, reason
        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.5:                                 
            return None, False, None, 'bounds_u'
        
        return u_hat, True, nb[:, :2], 'ok'

    def step(self, action):
        self.step_count += 1
        done = False
        reward = 0.0

        i = int(action) // len(self.ACTIONS)
        j = int(action) % len(self.ACTIONS)
        dx_idx, dt_idx = self.ACTIONS[j]
        dx_move = dx_idx * self.dx
        dt_move = dt_idx * self.dt

        info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

        x_new = self.walker_x[i] + dx_move
        t_new = self.walker_t[i] + dt_move

        # walkers may now rise to t* + R·dt (bubble extends above the star)
        t_ceil = self.t_star + self.R_bubble * self.dt + self.eps_t

        if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= t_ceil):
            info['rejected'] = 'bounds'
        elif self.visited.contains(x_new, t_new):
            info['rejected'] = 'collision'
        else:
            u_hat, success, nb_coords, reason = self._gfdm_solve(
                x_new, t_new, causal=self.causal_moves)
            if not success:
                info['rejected'] = reason
                self.gfdm_rejected_cells[(round(x_new / self.dx), round(t_new / self.dt))] = len(self.visited)
            else:
                self.visited.add(x_new, t_new, u_hat)
                self.walker_x[i] = x_new
                self.walker_t[i] = t_new
                self.walker_u[i] = u_hat
                self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                info['accepted'] = True
                # only a point landing inside the box can change the star solve
                if (abs(x_new - self.x_star) <= self.R_bubble * self.dx + 1e-9 and
                    abs(t_new - self.t_star) <= self.R_bubble * self.dt + 1e-9):
                    self._bubble_dirty = True

        if not info['accepted']:
            self.rejected_history.append((x_new, t_new, info['rejected']))

                # ── Unified termination: SOLVABLE bubble OR k_max reached ────────────
        # The stopping rule must ask the same question as the scoring rule:
        # "is there an admissible stencil at z*", not "are 5 points near z*".
        # Cheap counter gates the real solve; cached until the box changes.
        if self._bubble_dirty:
            self._bubble_dirty = False
            if self.visited.count_in_box(
                    self.x_star, self.t_star, self.R_bubble) >= self.n_neighbours:
                u_box, ok_box, _, _ = self._gfdm_solve(
                    self.x_star, self.t_star, causal=False, box_R=self.R_bubble)
                self._bubble_solve = (u_box, ok_box)
            else:
                self._bubble_solve = (None, False)

        bubble_full = self._bubble_solve[1]
        timeout     = self.step_count >= self.K_max

        if bubble_full or timeout:
            done = True
            info['reached'] = bool(bubble_full)
            info['timeout'] = bool(timeout and not bubble_full)

            if bubble_full:
                u_pred = self._bubble_solve[0]        # already solved, don't redo it
            else:
                u_pred, _, _, _ = self._gfdm_solve(
                    self.x_star, self.t_star, causal=False, box_R=None)
            
            u_ref = u_true(self.x_star, self.t_star)

            if u_pred is None:
                err      = None
                err_norm = 1.0                      # failed solve → worst-case
            else:
                err      = abs(u_pred - u_ref)
                err_norm = float(np.clip(
                    np.log10(max(err, 1e-12) / self.err_tol) / 3.0, 0.0, 1.0))

            time_norm = self.step_count / max(self.K_max, 1)
            r_acc = -self.w_err  * err_norm
            r_eff = -self.w_time * time_norm
            reward = r_acc + r_eff              # accuracy + speed only

            info['u_pred']    = u_pred
            info['u_ref']     = u_ref
            info['error']     = err
            info['k_term']    = self.step_count
            info['err_norm']  = err_norm
            info['time_norm'] = time_norm
            info['r_acc']     = r_acc
            info['r_eff']     = r_eff

        phi_new = 0.0 if done else self._potential()
        shaping = phi_new - self._phi_prev
        self._phi_prev = phi_new
        reward += shaping
        info['shaping'] = shaping
        info['phi'] = phi_new

        return self._build_obs(), reward, done, False, info

    def action_masks(self) -> np.ndarray:
        n_act = len(self.ACTIONS)

        # per-action grid offsets, built from ACTIONS so this survives you
        # adding new moves later (e.g. the same-t (±1,0) action)
        adx = np.fromiter((self.ACTIONS[j][0] for j in range(n_act)), dtype=int, count=n_act)
        adt = np.fromiter((self.ACTIONS[j][1] for j in range(n_act)), dtype=int, count=n_act)

        # all N*n_act candidate positions at once
        x_new = self.walker_x[:, None] + adx[None, :] * self.dx      # (N, n_act)
        t_new = self.walker_t[:, None] + adt[None, :] * self.dt
        t_ceil = self.t_star + self.R_bubble * self.dt + self.eps_t

        ok = ((x_new >= 0.0) & (x_new <= 1.0) &
              (t_new > 0.0) & (t_new <= t_ceil)).ravel()

        # integer cells: ONE vectorized round instead of ~600 scalar round()/step
        cx = np.round(x_new / self.dx).astype(np.int64).ravel()
        ct = np.round(t_new / self.dt).astype(np.int64).ravel()

        n_pts   = len(self.visited)
        idx_set = self.visited._idx_set
        rej     = self.gfdm_rejected_cells
        retry   = self.retry_after

        for k in range(self.N * n_act):
            if not ok[k]:
                continue
            key = (int(cx[k]), int(ct[k]))
            if key in idx_set:                       # collision (was visited.contains)
                ok[k] = False
                continue
            n_fail = rej.get(key)                    # retry-window block
            if n_fail is not None and n_pts < n_fail + retry:
                ok[k] = False

        if not ok.any():
            ok[:] = True
        return ok

# %%
import inspect; print(inspect.signature(solve_weights))
# Out:
# (dx_i, dt_i, u_nb=None)

# %% [markdown]
# ### Sanity Check: Random Policy Baseline

# %%
import matplotlib.patches as patches

R_bubble     = 3
t_star_steps = 50      # ← change to test different targets
K_max        = 2000

env    = PDEEnvironment(t_star_steps=t_star_steps, K_max=K_max, R_bubble=R_bubble)
obs, _ = env.reset()

trajectories   = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
done           = False
total_accepted = 0
total_rejected = {}

while not done:
    mask   = env.action_masks()
    action = int(np.random.choice(np.flatnonzero(mask)))   # masked random policy
    obs, reward, done, _, info = env.step(action)

    total_accepted += int(info['accepted'])
    if info['rejected']:
        total_rejected[info['rejected']] = total_rejected.get(info['rejected'], 0) + 1
    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

# ── Outcome ───────────────────────────────────────────────────────────────────
reached = info.get('reached', False)
outcome = 'bubble filled' if reached else 'timeout (k_max)'
err     = info.get('error')
u_pred  = info.get('u_pred')
u_ref   = info.get('u_ref')
n_box   = env.visited.count_in_box(env.x_star, env.t_star, env.R_bubble)

print(f"Outcome:        {outcome}")
print(f"Steps (k_term): {info.get('k_term', env.step_count)}")
print(f"Points in box:  {n_box}  (need {env.n_neighbours})")
print(f"u_pred:         {u_pred}")
print(f"u_ref:          {u_ref}")
print(f"|error|:        {'None' if err is None else f'{err:.3e}'}")
print(f"Final reward:   {reward:.4f}   (r_acc={info.get('r_acc')}, r_eff={info.get('r_eff')})")
print(f"Total accepted: {total_accepted}   |   Total rejected: {sum(total_rejected.values())}")
for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")

# ── Plot ──────────────────────────────────────────────────────────────────────
visited_log = [(x, t) for (x, t, _) in env.visited._pts if t > 0.0 and 0.0 < x < 1.0]
Rx = env.R_bubble * env.dx
Rt = env.R_bubble * env.dt

# points inside the box (for highlighting)
in_box = [(x, t) for (x, t) in visited_log
          if abs(x - env.x_star) <= Rx + 1e-9 and abs(t - env.t_star) <= Rt + 1e-9]

# stencil the star solve actually used (non-causal)
_, s_ok, nb_coords, _ = env._gfdm_solve(
    env.x_star, env.t_star, causal=False,
    box_R=env.R_bubble if reached else None)

colors = plt.cm.viridis(np.linspace(0, 1, env.N))

def draw(ax):
    ax.scatter([p[0] for p in visited_log], [p[1] for p in visited_log],
               s=6, color='lightgray', zorder=1)
    # bubble box
    ax.add_patch(patches.Rectangle(
        (env.x_star - Rx, env.t_star - Rt), 2 * Rx, 2 * Rt,
        fill=False, edgecolor='red', linestyle='--', linewidth=1.5, zorder=4))
    # in-box points
    if in_box:
        ax.scatter([p[0] for p in in_box], [p[1] for p in in_box],
                   s=30, facecolors='none', edgecolors='green',
                   linewidths=1.3, zorder=5, label=f'in box ({len(in_box)})')
    # trajectories
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]; ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=0.9, color=colors[i], alpha=0.6, zorder=2)
        ax.scatter(xs[0], ts[0], s=45, color=colors[i], marker='^', zorder=3)
    # star stencil
    if s_ok and nb_coords is not None:
        for (nxp, ntp) in nb_coords:
            ax.plot([env.x_star, nxp], [env.t_star, ntp], '--',
                    color='crimson', linewidth=1.0, alpha=0.85, zorder=6)
        ax.scatter(nb_coords[:, 0], nb_coords[:, 1], s=50, color='crimson',
                   zorder=7, label='star stencil')
    # star
    ax.scatter(env.x_star, env.t_star, s=240, color='red', marker='*',
               zorder=8, label='z*')
    ax.set_xlabel('x'); ax.set_ylabel('t')

fig, (axL, axR) = plt.subplots(1, 2, figsize=(15, 6))

# left: full domain
draw(axL)
axL.set_xlim(0, 1)
axL.set_ylim(0, env.t_star + (env.R_bubble + 3) * env.dt)
axL.set_title('Full domain')
axL.legend(fontsize=8, loc='upper left', markerscale=1.2)

# right: zoom on the bubble
draw(axR)
pad = (env.R_bubble + 2)
axR.set_xlim(env.x_star - pad * env.dx, env.x_star + pad * env.dx)
axR.set_ylim(env.t_star - pad * env.dt, env.t_star + pad * env.dt)
err_str = 'None' if err is None else f'{err:.2e}'
axR.set_title(f'Bubble zoom — {outcome}\nerr={err_str}  |  k={info.get("k_term", env.step_count)}  |  reward={reward:.3f}')
axR.legend(fontsize=8, loc='upper left', markerscale=1.2)

plt.tight_layout()
plt.show()
# Out:
# Outcome:        bubble filled
# Steps (k_term): 950
# Points in box:  5  (need 5)
# u_pred:         0.9977848993691665
# u_ref:          1.0273227909816771
# |error|:        2.954e-02
# Final reward:   -0.4636   (r_acc=-0.3921011980112652, r_eff=-0.095)
# Total accepted: 936   |   Total rejected: 14
#   cond      : 14

# %% [markdown]
# ## Plot Trajactories

# %%
def plot_trajectories(model, t_star_steps, N_particles, err_tol, w_err, w_time, K_max, c_shape,
                      R_bubble, save=True, timestep=None, img_dir=".", label=None,
                      x_star_steps=None):          # grid index for x*; None → center
    import matplotlib.patches as patches
    from collections import defaultdict

    env = PDEEnvironment(t_star_steps=t_star_steps, N_particles=N_particles,
                         err_tol=err_tol, w_err=w_err, w_time=w_time, K_max=K_max,
                         c_shape=c_shape, R_bubble=R_bubble,
                         x_star_schedule=None if x_star_steps is None else [x_star_steps])
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'          # keep tags for filenames/video

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    Rx = env.R_bubble * env.dx
    Rt = env.R_bubble * env.dt

    # points inside the box (field points only)
    in_box = [(x, t) for (x, t) in visited_log
              if 0.0 < t and 0.0 < x < 1.0
              and abs(x - env.x_star) <= Rx + 1e-9 and abs(t - env.t_star) <= Rt + 1e-9]

    # stencil the star solve actually used (box on fill, global-NN on timeout)
    box_R = env.R_bubble if reached else None
    u_pred_star, s_ok, nb_coords, fail_reason = env._gfdm_solve(
        env.x_star, env.t_star, causal=False, box_R=box_R)

    # ── NEW: predicted vs exact at z* (prefer the values the env actually scored) ──
    u_pred = info.get('u_pred', u_pred_star)
    u_ref  = info.get('u_ref')
    if u_ref is None:
        u_ref = float(np.atleast_1d(u_true(env.x_star, env.t_star))[0])

    # ── NEW: exact solution at EVERY computed field point (grouped by time level) ──
    pts = np.array(env.visited._pts)                      # (n, 3) = (x, t, u)
    fld = pts[(pts[:, 1] > 0.0) & (pts[:, 0] > 0.0) & (pts[:, 0] < 1.0)]
    if len(fld):
        u_ex = np.empty(len(fld))
        for tv in np.unique(fld[:, 1]):                   # few unique levels → cheap
            m = fld[:, 1] == tv
            u_ex[m] = np.atleast_1d(u_true(fld[m, 0], float(tv)))
        err_fld = np.abs(fld[:, 2] - u_ex)
    else:
        u_ex = np.empty(0); err_fld = np.empty(0)

    rej_colors = {'bounds': 'blue', 'collision': 'orange', 'cond': 'purple',
                  'weights': 'brown', 'geometry': 'red', 'bounds_u': 'magenta',
                  'no_nb': 'teal', None: 'gray'}
    colors = plt.cm.viridis(np.linspace(0, 1, env.N))

    def draw(ax, show_rej=True):
        ax.scatter([p[0] for p in visited_log], [p[1] for p in visited_log],
                   s=4, color='lightgray', zorder=1)
        if show_rej and env.rejected_history:
            by_reason = defaultdict(list)
            for (rx, rt, reason) in env.rejected_history:
                by_reason[reason].append((rx, rt))
            for reason, pts_r in by_reason.items():
                ax.scatter([p[0] for p in pts_r], [p[1] for p in pts_r],
                           s=6, alpha=0.08, linewidths=0, zorder=1,
                           color=rej_colors.get(reason, 'gray'),
                           label=f'rej:{reason} ({len(pts_r)})')
        # bubble box
        ax.add_patch(patches.Rectangle(
            (env.x_star - Rx, env.t_star - Rt), 2 * Rx, 2 * Rt,
            fill=False, edgecolor='red', linestyle='--', linewidth=1.5, zorder=4))
        # in-box points
        if in_box:
            ax.scatter([p[0] for p in in_box], [p[1] for p in in_box],
                       s=30, facecolors='none', edgecolors='green',
                       linewidths=1.3, zorder=5, label=f'in box ({len(in_box)})')
        # trajectories
        for i, traj in trajectories.items():
            xs = [p[0] for p in traj]; ts = [p[1] for p in traj]
            ax.plot(xs, ts, '-', linewidth=1.2, color=colors[i], alpha=0.7, zorder=2)
            ax.scatter(xs, ts, s=18, color=colors[i], zorder=3)
            ax.scatter(xs[0], ts[0], s=70, color=colors[i], marker='^', zorder=4)
        # star stencil
        if s_ok and nb_coords is not None:
            for (nxp, ntp) in nb_coords:
                ax.plot([env.x_star, nxp], [env.t_star, ntp], '--',
                        color='crimson', linewidth=1.0, alpha=0.85, zorder=6)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1], s=45, color='crimson',
                       zorder=7, label='star stencil')
        # star
        ax.scatter(env.x_star, env.t_star, s=200, color='red', marker='*',
                   zorder=8, label='z*')
        ax.set_xlabel('x'); ax.set_ylabel('t')

    fig, ((axL, axR), (axS, axE)) = plt.subplots(2, 2, figsize=(15, 11))

    # ── top-left: full domain ────────────────────────────────────────────────
    draw(axL, show_rej=True)
    axL.set_xlim(0, 1)
    axL.set_ylim(0, env.t_star + (env.R_bubble + 3) * env.dt)
    axL.set_title('Full domain')
    axL.legend(fontsize=6, loc='upper left', markerscale=1.5)

    # ── top-right: zoom on the bubble ────────────────────────────────────────
    draw(axR, show_rej=True)
    pad = env.R_bubble + 2
    axR.set_xlim(max(0.0, env.x_star - pad * env.dx), min(1.0, env.x_star + pad * env.dx))
    axR.set_ylim(env.t_star - pad * env.dt, env.t_star + pad * env.dt)
    err_str = 'None' if info.get('error') is None else f'{info["error"]:.2e}'
    axR.set_title(f'Bubble zoom — {outcome}  |  err={err_str}  |  k={info.get("k_term", env.step_count)}')

    # ── NEW bottom-left: solution profile, exact vs computed ─────────────────
    xs_fine = np.linspace(0.0, 1.0, 400)
    axS.plot(xs_fine, u_true(xs_fine, env.t_star), '-', color='black',
             linewidth=2.0, zorder=2, label=f'exact  u(x, t*)')
    axS.plot(xs_fine, u_true(xs_fine, 0.0), ':', color='gray',
             linewidth=1.2, zorder=1, label='initial condition')
    # computed points within the bubble's time band
    band = np.abs(fld[:, 1] - env.t_star) <= Rt + 1e-9 if len(fld) else np.zeros(0, bool)
    if band.any():
        axS.scatter(fld[band, 0], fld[band, 2], s=28, color='tab:blue', zorder=3,
                    label=f'computed  |t−t*| ≤ {env.R_bubble}·dt  ({band.sum()})')
    axS.scatter([env.x_star], [u_ref], s=90, facecolors='none', edgecolors='black',
                linewidths=1.8, zorder=5, label=f'exact @ z*  = {u_ref:.5f}')
    if u_pred is not None:
        axS.scatter([env.x_star], [u_pred], s=220, color='red', marker='*', zorder=6,
                    label=f'predicted @ z* = {u_pred:.5f}')
        axS.plot([env.x_star, env.x_star], [u_ref, u_pred], '-', color='red',
                 linewidth=1.5, alpha=0.7, zorder=4)
        s_title = f'Solution at t*  —  |u_pred − u_exact| = {abs(u_pred - u_ref):.3e}'
    else:
        s_title = f'Solution at t*  —  star solve FAILED ({fail_reason})'
    axS.axvline(env.x_star, color='red', linestyle='--', linewidth=0.8, alpha=0.4, zorder=1)
    axS.set_xlabel('x'); axS.set_ylabel('u')
    axS.set_title(s_title)
    axS.legend(fontsize=7, loc='upper right')

    # ── NEW bottom-right: error of every computed point vs time ──────────────
    if len(err_fld):
        sc = axE.scatter(fld[:, 1], np.maximum(err_fld, 1e-16), s=10,
                         c=np.abs(fld[:, 0] - env.x_star), cmap='viridis',
                         alpha=0.75, zorder=2)
        cb = fig.colorbar(sc, ax=axE); cb.set_label('|x − x*|', fontsize=8)
    axE.axhline(err_tol, color='green', linestyle='--', linewidth=1.2,
                label=f'err_tol = {err_tol:g}')
    axE.axvline(env.t_star, color='red', linestyle='--', linewidth=0.8, alpha=0.5)
    if info.get('error') is not None:
        axE.scatter([env.t_star], [max(info['error'], 1e-16)], s=220, color='red',
                    marker='*', zorder=5, label=f"err @ z* = {info['error']:.2e}")
    axE.set_yscale('log')
    axE.set_xlabel('t'); axE.set_ylabel('|u_computed − u_exact|')
    axE.set_title(f'Error accumulation over the field  ({len(err_fld)} computed points)')
    axE.legend(fontsize=7, loc='upper left')

    sup = f't*={t_star_steps}·dt  |  x*={env.x_star:.2f}  |  {outcome}  |  reward={reward:.3f}'
    if timestep is not None:
        sup += f'  |  step {timestep:,}'
    fig.suptitle(sup, y=1.00)
    plt.tight_layout()

    if save:
        xtag = "" if x_star_steps is None else f"_x{x_star_steps}"
        if label is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt{xtag}_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt{xtag}_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120, bbox_inches='tight')
        plt.close(fig)
    else:
        plt.show()

# %%
class ReachedRateCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.buf         = []   # 1 = bubble filled, 0 = timeout
        self.kterm_reach = []
        self.err_reach   = []
        self.kterm_all   = []
        self.err_all     = []
        self.racc_all    = []   # ← NEW: accuracy-reward term
        self.reff_all    = []   # ← NEW: speed/efficiency-reward term

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if not (info.get('reached') or info.get('timeout')):
                continue
            filled = bool(info.get('reached'))
            self.buf.append(1 if filled else 0)

            k = info.get('k_term')
            e = info.get('error')
            if k is not None:
                self.kterm_all.append(k)
                if filled:
                    self.kterm_reach.append(k)
            if e is not None:
                self.err_all.append(e)
                if filled:
                    self.err_reach.append(e)

            ra = info.get('r_acc')          # ← NEW
            re = info.get('r_eff')          # ← NEW
            if ra is not None:
                self.racc_all.append(ra)
            if re is not None:
                self.reff_all.append(re)

        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_all:
            self.logger.record('rollout/mean_kterm',          np.mean(self.kterm_all[-100:]))
        if self.err_all:
            self.logger.record('rollout/mean_error',          np.mean(self.err_all[-100:]))
        if self.kterm_reach:
            self.logger.record('rollout/mean_kterm_on_reach', np.mean(self.kterm_reach[-100:]))
        if self.err_reach:
            self.logger.record('rollout/mean_error_on_reach', np.mean(self.err_reach[-100:]))
        if self.racc_all:
            self.logger.record('rollout/mean_r_acc',          np.mean(self.racc_all[-100:]))   # ← NEW
        if self.reff_all:
            self.logger.record('rollout/mean_r_eff',          np.mean(self.reff_all[-100:]))   # ← NEW
        return True

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, N_particles, err_tol, w_err, w_time,
                 K_max, c_shape, R_bubble, plot_freq=50_000, img_dir=".", verbose=0,
                 x_star_steps=None):       
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.N_particles  = N_particles
        self.err_tol      = err_tol
        self.w_err        = w_err
        self.w_time       = w_time
        self.K_max        = K_max
        self.c_shape      = c_shape
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir
        self.x_star_steps = x_star_steps
        self.R_bubble     = R_bubble                

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, self.N_particles,
                  self.err_tol, self.w_err, self.w_time, self.K_max, self.c_shape,
                  R_bubble=self.R_bubble,      
                  save=True, timestep=self.num_timesteps,
                  img_dir=self.img_dir,
                  x_star_steps=self.x_star_steps)
        return True


def make_env(t_star_schedule, N_particles, err_tol, w_err, w_time, K_max, c_shape,
             x_star_schedule, R_bubble):            
    def _init():
        env = PDEEnvironment(t_star_schedule=t_star_schedule, N_particles=N_particles,
                             err_tol=err_tol, w_err=w_err, w_time=w_time,
                             K_max=K_max, c_shape=c_shape,
                             x_star_schedule=x_star_schedule,
                             R_bubble=R_bubble)            # ← NEW
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
N_particles     = 30
t_star_schedule = {10: 1000}   # K_max per t*
x_star_schedule = [50]
seeds           = [3]

n_envs          = 12
n_steps         = 1024
batch_size      = 1024

total_timesteps =  10_000_000

err_tol         = 3e-4
w_err           = 1
w_time          = 0.1
c_shape         = 0.3
R_bubble        = 4           # ← NEW: box half-width (grid steps) for the star bubble

# representative t* used ONLY for periodic plo
# 
# ts/videos (policy trains on all keys)
plot_tstar   = list(t_star_schedule.keys())[0]  # pick the first t* for plotting
plot_K_max   = t_star_schedule[plot_tstar]
plot_xstar   = x_star_schedule[0]  # representative x* for plots

# ── Run directory ────────────────────────────────────────────────────────────
day        = date.today().day
month      = date.today().month 
stages_str = "-".join(str(s) for s in t_star_schedule.keys())
run_name   = (f"t{stages_str}_errtol{err_tol}_werr{w_err}_wtime{w_time}"
              f"_N{N_particles}_c{c_shape}_R{R_bubble}")     # ← NEW: R in run name

run_dir    = os.path.join(f"runs_advection_{month}-{day}", run_name)

print(f"Run: {run_dir}")
print(f"Training jointly on t*={list(t_star_schedule.keys())}  "
      f"(periodic plots shown at t*={plot_tstar}, R_bubble={R_bubble})")

for seed in seeds:

    seed_dir  = os.path.join(run_dir, f"seed{seed}")
    img_dir   = os.path.join(seed_dir, "images")
    ckpt_dir  = os.path.join(seed_dir, "checkpoints")

    os.makedirs(img_dir,  exist_ok=True)
    os.makedirs(ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}\nSEED {seed}\n{'#'*50}")

    # every subprocess gets the SAME schedule and resamples t* per episode in reset()
    vec_env = SubprocVecEnv([
        make_env(t_star_schedule, N_particles, err_tol, w_err, w_time, K_max=None,
         c_shape=c_shape, x_star_schedule=x_star_schedule,
         R_bubble=R_bubble)                                  # ← NEW
        for _ in range(n_envs)
    ])

    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_dir, "logs"),
        learning_rate=2e-4,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=batch_size,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    print(f"\n{'='*50}")
    print(f"Joint training over t* schedule: {t_star_schedule}")
    print(f"budget: {total_timesteps//1000}k steps")
    print(f"{'='*50}")

    model.learn(
        total_timesteps=total_timesteps,
        reset_num_timesteps=False,
        tb_log_name=f"seed{seed}",
        log_interval=2,
        callback=[
            ReachedRateCallback(),
            PlotCallback(plot_tstar, N_particles, err_tol, w_err, w_time, plot_K_max, c_shape,
             plot_freq=100_000, img_dir=img_dir, x_star_steps=plot_xstar,
             R_bubble=R_bubble),                             # ← NEW
            CheckpointCallback(
                save_freq=100_000,
                save_path=os.path.join(ckpt_dir, "sched"),
                name_prefix="sched"
            ),
        ],
    )

    model.save(os.path.join(ckpt_dir, "sched_final"))

    # final plots/videos at the representative t*
    plot_trajectories(model, plot_tstar, N_particles, err_tol, w_err, w_time,
                  plot_K_max, c_shape, R_bubble=R_bubble,    # ← NEW
                  save=True, timestep=None,
                  img_dir=img_dir, label="final", x_star_steps=plot_xstar)
# Out:
# Run: runs_advection_9-3\t10_errtol0.0003_werr1_wtime0.1_N30_c0.3_R4
# Training jointly on t*=[10]  (periodic plots shown at t*=10, R_bubble=4)
#
# ##################################################
# SEED 3
# ##################################################
# Using cpu device
#
# ==================================================
# Joint training over t* schedule: {10: 1000}
# budget: 10000k steps
# ==================================================
# Logging to runs_advection_9-3\t10_errtol0.0003_werr1_wtime0.1_N30_c0.3_R4\seed3\logs\seed3_0
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | 0.152        |
# |    mean_error           | 0.00143      |
# |    mean_error_on_reach  | 0.00143      |
# |    mean_kterm           | 143          |
# |    mean_kterm_on_reach  | 143          |
# |    mean_r_acc           | -0.134       |
# |    mean_r_eff           | -0.0143      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3431         |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0038148903 |
# |    clip_fraction        | 0.21         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.062       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 0.00638      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 0.141        |
# |    mean_error           | 0.00141      |
# |    mean_error_on_reach  | 0.00141      |
# |    mean_kterm           | 142          |
# |    mean_kterm_on_reach  | 142          |
# |    mean_r_acc           | -0.145       |
# |    mean_r_eff           | -0.0142      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3418         |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0034513474 |
# |    clip_fraction        | 0.19         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.12        |
# |    explained_variance   | 0.355        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0671      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.00232      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 0.151        |
# |    mean_error           | 0.00133      |
# |    mean_error_on_reach  | 0.00133      |
# |    mean_kterm           | 145          |
# |    mean_kterm_on_reach  | 145          |
# |    mean_r_acc           | -0.134       |
# |    mean_r_eff           | -0.0145      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3348         |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0033969115 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.11        |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0648      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00194      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 0.159        |
# |    mean_error           | 0.00142      |
# |    mean_error_on_reach  | 0.00142      |
# |    mean_kterm           | 148          |
# |    mean_kterm_on_reach  | 148          |
# |    mean_r_acc           | -0.126       |
# |    mean_r_eff           | -0.0148      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3349         |
# |    iterations           | 8            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0032142017 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.08        |
# |    explained_variance   | 0.363        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0629      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 0.182        |
# |    mean_error           | 0.000994     |
# |    mean_error_on_reach  | 0.000994     |
# |    mean_kterm           | 134          |
# |    mean_kterm_on_reach  | 134          |
# |    mean_r_acc           | -0.105       |
# |    mean_r_eff           | -0.0134      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3248         |
# |    iterations           | 10           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0032054605 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.08        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0668      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.00129      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | 0.163        |
# |    mean_error           | 0.00117      |
# |    mean_error_on_reach  | 0.00117      |
# |    mean_kterm           | 131          |
# |    mean_kterm_on_reach  | 131          |
# |    mean_r_acc           | -0.124       |
# |    mean_r_eff           | -0.0131      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3259         |
# |    iterations           | 12           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0029848095 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.07        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0613      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 0.161        |
# |    mean_error           | 0.00121      |
# |    mean_error_on_reach  | 0.00121      |
# |    mean_kterm           | 138          |
# |    mean_kterm_on_reach  | 138          |
# |    mean_r_acc           | -0.125       |
# |    mean_r_eff           | -0.0138      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3274         |
# |    iterations           | 14           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0029145116 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0657      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00989     |
# |    value_loss           | 0.00136      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 0.161        |
# |    mean_error           | 0.00128      |
# |    mean_error_on_reach  | 0.00128      |
# |    mean_kterm           | 137          |
# |    mean_kterm_on_reach  | 137          |
# |    mean_r_acc           | -0.125       |
# |    mean_r_eff           | -0.0137      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3272         |
# |    iterations           | 16           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0030397829 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0696      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 0.00147      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | 0.172      |
# |    mean_error           | 0.00104    |
# |    mean_error_on_reach  | 0.00104    |
# |    mean_kterm           | 132        |
# |    mean_kterm_on_reach  | 132        |
# |    mean_r_acc           | -0.115     |
# |    mean_r_eff           | -0.0132    |
# |    reached_rate         | 1          |
# | time/                   |            |
# |    fps                  | 3241       |
# |    iterations           | 18         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.00299941 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -5.03      |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0676    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 0.00135    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 0.167        |
# |    mean_error           | 0.00115      |
# |    mean_error_on_reach  | 0.00115      |
# |    mean_kterm           | 132          |
# |    mean_kterm_on_reach  | 132          |
# |    mean_r_acc           | -0.12        |
# |    mean_r_eff           | -0.0132      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3242         |
# |    iterations           | 20           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0027467534 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.03        |
# |    explained_variance   | 0.0911       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0653      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 0.18         |
# |    mean_error           | 0.00101      |
# |    mean_error_on_reach  | 0.00101      |
# |    mean_kterm           | 130          |
# |    mean_kterm_on_reach  | 130          |
# |    mean_r_acc           | -0.107       |
# |    mean_r_eff           | -0.013       |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3243         |
# |    iterations           | 22           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0029052275 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.02        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0666      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 0.00123      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 114          |
# |    ep_rew_mean          | 0.194        |
# |    mean_error           | 0.000843     |
# |    mean_error_on_reach  | 0.000843     |
# |    mean_kterm           | 114          |
# |    mean_kterm_on_reach  | 114          |
# |    mean_r_acc           | -0.0944      |
# |    mean_r_eff           | -0.0114      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3235         |
# |    iterations           | 24           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0029800106 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.03        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0666      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 0.199        |
# |    mean_error           | 0.000774     |
# |    mean_error_on_reach  | 0.000774     |
# |    mean_kterm           | 111          |
# |    mean_kterm_on_reach  | 111          |
# |    mean_r_acc           | -0.0903      |
# |    mean_r_eff           | -0.0111      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3192         |
# |    iterations           | 26           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 319488       |
# | train/                  |              |
# |    approx_kl            | 0.0028834473 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.03        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0693      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.00123      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 0.195       |
# |    mean_error           | 0.000756    |
# |    mean_error_on_reach  | 0.000756    |
# |    mean_kterm           | 102         |
# |    mean_kterm_on_reach  | 102         |
# |    mean_r_acc           | -0.095      |
# |    mean_r_eff           | -0.0102     |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3180        |
# |    iterations           | 28          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.002838733 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.0973      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0659     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 0.207        |
# |    mean_error           | 0.000861     |
# |    mean_error_on_reach  | 0.000861     |
# |    mean_kterm           | 102          |
# |    mean_kterm_on_reach  | 102          |
# |    mean_r_acc           | -0.0823      |
# |    mean_r_eff           | -0.0102      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3173         |
# |    iterations           | 30           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0029753672 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.02        |
# |    explained_variance   | 0.0534       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0626      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.00129      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.8         |
# |    ep_rew_mean          | 0.207        |
# |    mean_error           | 0.000729     |
# |    mean_error_on_reach  | 0.000729     |
# |    mean_kterm           | 93.8         |
# |    mean_kterm_on_reach  | 93.8         |
# |    mean_r_acc           | -0.0838      |
# |    mean_r_eff           | -0.00937     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3162         |
# |    iterations           | 32           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0028995962 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5.02        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0673      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.00134      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.4        |
# |    ep_rew_mean          | 0.194       |
# |    mean_error           | 0.000921    |
# |    mean_error_on_reach  | 0.000921    |
# |    mean_kterm           | 89.4        |
# |    mean_kterm_on_reach  | 89.4        |
# |    mean_r_acc           | -0.0971     |
# |    mean_r_eff           | -0.00894    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3114        |
# |    iterations           | 34          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.002789816 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0655     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.0013      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.1        |
# |    ep_rew_mean          | 0.201       |
# |    mean_error           | 0.000762    |
# |    mean_error_on_reach  | 0.000762    |
# |    mean_kterm           | 85.1        |
# |    mean_kterm_on_reach  | 85.1        |
# |    mean_r_acc           | -0.0901     |
# |    mean_r_eff           | -0.00851    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3080        |
# |    iterations           | 36          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.002952155 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.0404      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0673     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.000997    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80          |
# |    ep_rew_mean          | 0.205       |
# |    mean_error           | 0.000775    |
# |    mean_error_on_reach  | 0.000775    |
# |    mean_kterm           | 80          |
# |    mean_kterm_on_reach  | 80          |
# |    mean_r_acc           | -0.0873     |
# |    mean_r_eff           | -0.008      |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 3058        |
# |    iterations           | 38          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.002701739 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.0343      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.067      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.5         |
# |    ep_rew_mean          | 0.219        |
# |    mean_error           | 0.000686     |
# |    mean_error_on_reach  | 0.000686     |
# |    mean_kterm           | 85.5         |
# |    mean_kterm_on_reach  | 85.5         |
# |    mean_r_acc           | -0.0728      |
# |    mean_r_eff           | -0.00855     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 3021         |
# |    iterations           | 40           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0029195112 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -5           |
# |    explained_variance   | 0.0754       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0685      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.7         |
# |    ep_rew_mean          | 0.225        |
# |    mean_error           | 0.000538     |
# |    mean_error_on_reach  | 0.000538     |
# |    mean_kterm           | 84.7         |
# |    mean_kterm_on_reach  | 84.7         |
# |    mean_r_acc           | -0.067       |
# |    mean_r_eff           | -0.00847     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2977         |
# |    iterations           | 42           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 516096       |
# | train/                  |              |
# |    approx_kl            | 0.0027546992 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.98        |
# |    explained_variance   | 0.0901       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0638      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.7         |
# |    ep_rew_mean          | 0.202        |
# |    mean_error           | 0.000705     |
# |    mean_error_on_reach  | 0.000705     |
# |    mean_kterm           | 82.7         |
# |    mean_kterm_on_reach  | 82.7         |
# |    mean_r_acc           | -0.0893      |
# |    mean_r_eff           | -0.00827     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2956         |
# |    iterations           | 44           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0028895522 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.0461       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.064       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00117      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79           |
# |    ep_rew_mean          | 0.218        |
# |    mean_error           | 0.000574     |
# |    mean_error_on_reach  | 0.000574     |
# |    mean_kterm           | 79           |
# |    mean_kterm_on_reach  | 79           |
# |    mean_r_acc           | -0.0744      |
# |    mean_r_eff           | -0.0079      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2925         |
# |    iterations           | 46           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 565248       |
# | train/                  |              |
# |    approx_kl            | 0.0030043733 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0664      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.5        |
# |    ep_rew_mean          | 0.226       |
# |    mean_error           | 0.00069     |
# |    mean_error_on_reach  | 0.00069     |
# |    mean_kterm           | 78.5        |
# |    mean_kterm_on_reach  | 78.5        |
# |    mean_r_acc           | -0.0659     |
# |    mean_r_eff           | -0.00785    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 2899        |
# |    iterations           | 48          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.002742675 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0663     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000963    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.9         |
# |    ep_rew_mean          | 0.228        |
# |    mean_error           | 0.000551     |
# |    mean_error_on_reach  | 0.000551     |
# |    mean_kterm           | 69.9         |
# |    mean_kterm_on_reach  | 69.9         |
# |    mean_r_acc           | -0.0652      |
# |    mean_r_eff           | -0.00699     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2867         |
# |    iterations           | 50           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0025206192 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0.0943       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0636      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00915     |
# |    value_loss           | 0.00128      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71           |
# |    ep_rew_mean          | 0.238        |
# |    mean_error           | 0.000448     |
# |    mean_error_on_reach  | 0.000448     |
# |    mean_kterm           | 71           |
# |    mean_kterm_on_reach  | 71           |
# |    mean_r_acc           | -0.0546      |
# |    mean_r_eff           | -0.0071      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2844         |
# |    iterations           | 52           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0027566038 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.92        |
# |    explained_variance   | 0.0732       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0613      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00956     |
# |    value_loss           | 0.00109      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.8         |
# |    ep_rew_mean          | 0.214        |
# |    mean_error           | 0.000646     |
# |    mean_error_on_reach  | 0.000646     |
# |    mean_kterm           | 66.8         |
# |    mean_kterm_on_reach  | 66.8         |
# |    mean_r_acc           | -0.0791      |
# |    mean_r_eff           | -0.00668     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2832         |
# |    iterations           | 54           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 663552       |
# | train/                  |              |
# |    approx_kl            | 0.0028298881 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0659      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.00085      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.1         |
# |    ep_rew_mean          | 0.25         |
# |    mean_error           | 0.000399     |
# |    mean_error_on_reach  | 0.000399     |
# |    mean_kterm           | 64.1         |
# |    mean_kterm_on_reach  | 64.1         |
# |    mean_r_acc           | -0.044       |
# |    mean_r_eff           | -0.00641     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2824         |
# |    iterations           | 56           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0028602353 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.89        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0666      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.000726     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.6         |
# |    ep_rew_mean          | 0.232        |
# |    mean_error           | 0.000474     |
# |    mean_error_on_reach  | 0.000474     |
# |    mean_kterm           | 60.6         |
# |    mean_kterm_on_reach  | 60.6         |
# |    mean_r_acc           | -0.0623      |
# |    mean_r_eff           | -0.00606     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2798         |
# |    iterations           | 58           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 712704       |
# | train/                  |              |
# |    approx_kl            | 0.0027914904 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0604      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 0.00091      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.1         |
# |    ep_rew_mean          | 0.243        |
# |    mean_error           | 0.000416     |
# |    mean_error_on_reach  | 0.000416     |
# |    mean_kterm           | 66.1         |
# |    mean_kterm_on_reach  | 66.1         |
# |    mean_r_acc           | -0.0501      |
# |    mean_r_eff           | -0.00661     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2773         |
# |    iterations           | 60           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0026908675 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.0414       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0644      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00925     |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.5         |
# |    ep_rew_mean          | 0.23         |
# |    mean_error           | 0.000484     |
# |    mean_error_on_reach  | 0.000484     |
# |    mean_kterm           | 64.5         |
# |    mean_kterm_on_reach  | 64.5         |
# |    mean_r_acc           | -0.0633      |
# |    mean_r_eff           | -0.00646     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2755         |
# |    iterations           | 62           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 761856       |
# | train/                  |              |
# |    approx_kl            | 0.0028387292 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0664      |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00998     |
# |    value_loss           | 0.000879     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.5         |
# |    ep_rew_mean          | 0.241        |
# |    mean_error           | 0.000472     |
# |    mean_error_on_reach  | 0.000472     |
# |    mean_kterm           | 56.5         |
# |    mean_kterm_on_reach  | 56.5         |
# |    mean_r_acc           | -0.0533      |
# |    mean_r_eff           | -0.00565     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2742         |
# |    iterations           | 64           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0026322464 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | -0.00189     |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0661      |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.000973     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | 0.258       |
# |    mean_error           | 0.000342    |
# |    mean_error_on_reach  | 0.000342    |
# |    mean_kterm           | 56.9        |
# |    mean_kterm_on_reach  | 56.9        |
# |    mean_r_acc           | -0.0367     |
# |    mean_r_eff           | -0.00569    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 2717        |
# |    iterations           | 66          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 811008      |
# | train/                  |             |
# |    approx_kl            | 0.002996845 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.067      |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000981    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.6         |
# |    ep_rew_mean          | 0.25         |
# |    mean_error           | 0.00037      |
# |    mean_error_on_reach  | 0.00037      |
# |    mean_kterm           | 56.6         |
# |    mean_kterm_on_reach  | 56.6         |
# |    mean_r_acc           | -0.0441      |
# |    mean_r_eff           | -0.00566     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2702         |
# |    iterations           | 68           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0027027158 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0.0832       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0662      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.000848     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.8         |
# |    ep_rew_mean          | 0.252        |
# |    mean_error           | 0.000378     |
# |    mean_error_on_reach  | 0.000378     |
# |    mean_kterm           | 58.8         |
# |    mean_kterm_on_reach  | 58.8         |
# |    mean_r_acc           | -0.0424      |
# |    mean_r_eff           | -0.00588     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2689         |
# |    iterations           | 70           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 860160       |
# | train/                  |              |
# |    approx_kl            | 0.0025613157 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.81        |
# |    explained_variance   | 0.0347       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0624      |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00852     |
# |    value_loss           | 0.000974     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57.7         |
# |    ep_rew_mean          | 0.254        |
# |    mean_error           | 0.000356     |
# |    mean_error_on_reach  | 0.000356     |
# |    mean_kterm           | 57.7         |
# |    mean_kterm_on_reach  | 57.7         |
# |    mean_r_acc           | -0.04        |
# |    mean_r_eff           | -0.00577     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2675         |
# |    iterations           | 72           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0027930422 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.8         |
# |    explained_variance   | 0.0574       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0628      |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.000694     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.4         |
# |    ep_rew_mean          | 0.231        |
# |    mean_error           | 0.00053      |
# |    mean_error_on_reach  | 0.00053      |
# |    mean_kterm           | 58.4         |
# |    mean_kterm_on_reach  | 58.4         |
# |    mean_r_acc           | -0.0634      |
# |    mean_r_eff           | -0.00584     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2654         |
# |    iterations           | 74           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 909312       |
# | train/                  |              |
# |    approx_kl            | 0.0027253816 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0.0486       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0608      |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00815     |
# |    value_loss           | 0.000909     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.1         |
# |    ep_rew_mean          | 0.27         |
# |    mean_error           | 0.000291     |
# |    mean_error_on_reach  | 0.000291     |
# |    mean_kterm           | 52.1         |
# |    mean_kterm_on_reach  | 52.1         |
# |    mean_r_acc           | -0.0244      |
# |    mean_r_eff           | -0.00521     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2642         |
# |    iterations           | 76           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0027908578 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.0937       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0604      |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00927     |
# |    value_loss           | 0.00071      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53           |
# |    ep_rew_mean          | 0.254        |
# |    mean_error           | 0.000399     |
# |    mean_error_on_reach  | 0.000399     |
# |    mean_kterm           | 53           |
# |    mean_kterm_on_reach  | 53           |
# |    mean_r_acc           | -0.0411      |
# |    mean_r_eff           | -0.0053      |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2628         |
# |    iterations           | 78           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0026589332 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.061       |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00846     |
# |    value_loss           | 0.000704     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.4         |
# |    ep_rew_mean          | 0.254        |
# |    mean_error           | 0.000371     |
# |    mean_error_on_reach  | 0.000371     |
# |    mean_kterm           | 49.4         |
# |    mean_kterm_on_reach  | 49.4         |
# |    mean_r_acc           | -0.041       |
# |    mean_r_eff           | -0.00494     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 2615         |
# |    iterations           | 80           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# ...
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0371     |
# |    n_updates            | 7870        |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 8.86e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | 0.298       |
# |    mean_error           | 8.46e-05    |
# |    mean_error_on_reach  | 8.46e-05    |
# |    mean_kterm           | 16.2        |
# |    mean_kterm_on_reach  | 16.2        |
# |    mean_r_acc           | 0           |
# |    mean_r_eff           | -0.00162    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1822        |
# |    iterations           | 790         |
# |    time_elapsed         | 5325        |
# |    total_timesteps      | 9707520     |
# | train/                  |             |
# |    approx_kl            | 0.003205564 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0278     |
# |    n_updates            | 7890        |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 4.8e-06     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | 0.297       |
# |    mean_error           | 0.000103    |
# |    mean_error_on_reach  | 0.000103    |
# |    mean_kterm           | 16.7        |
# |    mean_kterm_on_reach  | 16.7        |
# |    mean_r_acc           | -0.00156    |
# |    mean_r_eff           | -0.00167    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1821        |
# |    iterations           | 792         |
# |    time_elapsed         | 5343        |
# |    total_timesteps      | 9732096     |
# | train/                  |             |
# |    approx_kl            | 0.004299553 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0307     |
# |    n_updates            | 7910        |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 1.64e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | 0.295       |
# |    mean_error           | 0.000106    |
# |    mean_error_on_reach  | 0.000106    |
# |    mean_kterm           | 18.5        |
# |    mean_kterm_on_reach  | 18.5        |
# |    mean_r_acc           | -0.003      |
# |    mean_r_eff           | -0.00185    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1820        |
# |    iterations           | 794         |
# |    time_elapsed         | 5360        |
# |    total_timesteps      | 9756672     |
# | train/                  |             |
# |    approx_kl            | 0.005445805 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0386     |
# |    n_updates            | 7930        |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 1.38e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.2         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 7.13e-05     |
# |    mean_error_on_reach  | 7.13e-05     |
# |    mean_kterm           | 19.2         |
# |    mean_kterm_on_reach  | 19.2         |
# |    mean_r_acc           | 0            |
# |    mean_r_eff           | -0.00192     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 796          |
# |    time_elapsed         | 5376         |
# |    total_timesteps      | 9781248      |
# | train/                  |              |
# |    approx_kl            | 0.0032956193 |
# |    clip_fraction        | 0.194        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.042       |
# |    n_updates            | 7950         |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 2.48e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.4         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 8.21e-05     |
# |    mean_error_on_reach  | 8.21e-05     |
# |    mean_kterm           | 18.4         |
# |    mean_kterm_on_reach  | 18.4         |
# |    mean_r_acc           | 0            |
# |    mean_r_eff           | -0.00184     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1818         |
# |    iterations           | 798          |
# |    time_elapsed         | 5393         |
# |    total_timesteps      | 9805824      |
# | train/                  |              |
# |    approx_kl            | 0.0036572767 |
# |    clip_fraction        | 0.204        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.045       |
# |    n_updates            | 7970         |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 1.66e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.2         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 7.98e-05     |
# |    mean_error_on_reach  | 7.98e-05     |
# |    mean_kterm           | 19.2         |
# |    mean_kterm_on_reach  | 19.2         |
# |    mean_r_acc           | -0.000328    |
# |    mean_r_eff           | -0.00192     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 800          |
# |    time_elapsed         | 5409         |
# |    total_timesteps      | 9830400      |
# | train/                  |              |
# |    approx_kl            | 0.0048950473 |
# |    clip_fraction        | 0.257        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0353      |
# |    n_updates            | 7990         |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 1.32e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 8.28e-05     |
# |    mean_error_on_reach  | 8.28e-05     |
# |    mean_kterm           | 18.2         |
# |    mean_kterm_on_reach  | 18.2         |
# |    mean_r_acc           | -0.000611    |
# |    mean_r_eff           | -0.00182     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 802          |
# |    time_elapsed         | 5427         |
# |    total_timesteps      | 9854976      |
# | train/                  |              |
# |    approx_kl            | 0.0029121505 |
# |    clip_fraction        | 0.21         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0385      |
# |    n_updates            | 8010         |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 3.43e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.8         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 6.85e-05     |
# |    mean_error_on_reach  | 6.85e-05     |
# |    mean_kterm           | 18.8         |
# |    mean_kterm_on_reach  | 18.8         |
# |    mean_r_acc           | 0            |
# |    mean_r_eff           | -0.00188     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 804          |
# |    time_elapsed         | 5442         |
# |    total_timesteps      | 9879552      |
# | train/                  |              |
# |    approx_kl            | 0.0036095984 |
# |    clip_fraction        | 0.226        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0339      |
# |    n_updates            | 8030         |
# |    policy_gradient_loss | -0.00445     |
# |    value_loss           | 1.29e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.4         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 7.39e-05     |
# |    mean_error_on_reach  | 7.39e-05     |
# |    mean_kterm           | 17.4         |
# |    mean_kterm_on_reach  | 17.4         |
# |    mean_r_acc           | 0            |
# |    mean_r_eff           | -0.00174     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1814         |
# |    iterations           | 806          |
# |    time_elapsed         | 5459         |
# |    total_timesteps      | 9904128      |
# | train/                  |              |
# |    approx_kl            | 0.0060263947 |
# |    clip_fraction        | 0.301        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.032       |
# |    n_updates            | 8050         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 3.32e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | 0.298       |
# |    mean_error           | 7.35e-05    |
# |    mean_error_on_reach  | 7.35e-05    |
# |    mean_kterm           | 16.7        |
# |    mean_kterm_on_reach  | 16.7        |
# |    mean_r_acc           | 0           |
# |    mean_r_eff           | -0.00167    |
# |    reached_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1813        |
# |    iterations           | 808         |
# |    time_elapsed         | 5476        |
# |    total_timesteps      | 9928704     |
# | train/                  |             |
# |    approx_kl            | 0.004640591 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | -0.213      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0347     |
# |    n_updates            | 8070        |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 3.74e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.6         |
# |    ep_rew_mean          | 0.297        |
# |    mean_error           | 7.78e-05     |
# |    mean_error_on_reach  | 7.78e-05     |
# |    mean_kterm           | 16.6         |
# |    mean_kterm_on_reach  | 16.6         |
# |    mean_r_acc           | -0.00143     |
# |    mean_r_eff           | -0.00166     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1811         |
# |    iterations           | 810          |
# |    time_elapsed         | 5494         |
# |    total_timesteps      | 9953280      |
# | train/                  |              |
# |    approx_kl            | 0.0034818219 |
# |    clip_fraction        | 0.238        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.327        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0283      |
# |    n_updates            | 8090         |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 1.23e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.7         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 7.08e-05     |
# |    mean_error_on_reach  | 7.08e-05     |
# |    mean_kterm           | 16.7         |
# |    mean_kterm_on_reach  | 16.7         |
# |    mean_r_acc           | -0.000197    |
# |    mean_r_eff           | -0.00167     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1810         |
# |    iterations           | 812          |
# |    time_elapsed         | 5512         |
# |    total_timesteps      | 9977856      |
# | train/                  |              |
# |    approx_kl            | 0.0032068284 |
# |    clip_fraction        | 0.206        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0338      |
# |    n_updates            | 8110         |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 4.99e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.4         |
# |    ep_rew_mean          | 0.298        |
# |    mean_error           | 7.95e-05     |
# |    mean_error_on_reach  | 7.95e-05     |
# |    mean_kterm           | 17.4         |
# |    mean_kterm_on_reach  | 17.4         |
# |    mean_r_acc           | 0            |
# |    mean_r_eff           | -0.00174     |
# |    reached_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1808         |
# |    iterations           | 814          |
# |    time_elapsed         | 5531         |
# |    total_timesteps      | 10002432     |
# | train/                  |              |
# |    approx_kl            | 0.0033539373 |
# |    clip_fraction        | 0.196        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0324      |
# |    n_updates            | 8130         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 3.45e-06     |
# ------------------------------------------

# %%
from importlib import reload

import trajectory_video
reload(trajectory_video)
from trajectory_video import make_trajectory_video

import training_progress_video
reload(training_progress_video)
from training_progress_video import make_training_progress_video

make_trajectory_video(
    model, PDEEnvironment, plot_tstar, N_particles,
    img_dir=img_dir, label="final",
    x_star_steps=plot_xstar, R_bubble=R_bubble,     # ← match trained target + radius
)

make_training_progress_video(
    img_dir=img_dir,                    
    t_star_steps=plot_tstar,
    label="final",
    x_star_steps=plot_xstar,
    fps=1 
)
# Out:
# Rollout done: reached, 11 accepted points, 11 total steps.
# Saved video: runs_advection_9-3\t10_errtol0.0003_werr1_wtime0.1_N30_c0.3_R4\seed3\images\traj_t10dt_final_reached.mp4
# Found 101 images.
# First frame: traj_t10dt_x50_00100k_reached.png
# Last frame:  traj_t10dt_x50_final_reached.png
# Saved training progress video: runs_advection_9-3\t10_errtol0.0003_werr1_wtime0.1_N30_c0.3_R4\seed3\images\traj_t10dt_x50_training_progress.mp4
# 'runs_advection_9-3\\t10_errtol0.0003_werr1_wtime0.1_N30_c0.3_R4\\seed3\\images\\traj_t10dt_x50_training_progress.mp4'

# %%
print("box drawn with R =", env.R_bubble)   # right after the plot call
# Out:
# box drawn with R = 3
