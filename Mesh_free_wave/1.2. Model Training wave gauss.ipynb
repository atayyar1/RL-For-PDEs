# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate wave equation data (Dirichlet BC)
# -----------------------
def wave_solver_dirichlet(u0, ut0, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D wave equation (Dirichlet BCs u(0,t)=u(1,t)=0)."""
    Nx = len(u0)
    u = u0.copy()
    u_prev = u0.copy()  # u at previous time step
    
    # Initialize first time step using initial velocity
    u_new = u.copy()
    for i in range(1, Nx - 1):
        lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
        u_new[i] = u[i] + dt * ut0[i] + 0.5 * c**2 * dt**2 * lap
    u_prev = u.copy()
    u = u_new.copy()
    
    traj = [u0.copy(), u.copy()]
    
    for _ in range(n_steps - 1):
        u_new = u.copy()
        
        # discrete Laplacian on interior points only
        for i in range(1, Nx - 1):
            lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
            u_new[i] = 2*u[i] - u_prev[i] + c**2 * dt**2 * lap
        
        # Dirichlet boundaries
        u_new[0] = 0.0
        u_new[-1] = 0.0
        
        u_prev = u.copy()
        u = u_new.copy()
        traj.append(u.copy())
    
    return np.stack(traj)  # shape (T, Nx)

def generate_wave_data(Nx=128, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)

    # initial condition compatible with Dirichlet BC
    u0  = np.exp(-((x-0.3)/0.05)**2)
    ut0 = np.zeros_like(x)


    data = wave_solver_dirichlet(u0, ut0, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
c = 1.0
n_steps = 9000

x, data = generate_wave_data(Nx, c, dt0, n_steps)

# %%
t_plot = n_steps  # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Wave Equation: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.785414e+00
# [Epoch 2/150] train MSE = 9.564019e-01
# [Epoch 3/150] train MSE = 4.927949e-01
# [Epoch 4/150] train MSE = 2.428235e-01
# [Epoch 5/150] train MSE = 1.138322e-01
# [Epoch 6/150] train MSE = 5.077108e-02
# [Epoch 7/150] train MSE = 2.159755e-02
# [Epoch 8/150] train MSE = 8.798916e-03
# [Epoch 9/150] train MSE = 3.475157e-03
# [Epoch 10/150] train MSE = 1.373080e-03
# [Epoch 11/150] train MSE = 5.893888e-04
# [Epoch 12/150] train MSE = 3.122853e-04
# [Epoch 13/150] train MSE = 2.202240e-04
# [Epoch 14/150] train MSE = 1.912202e-04
# [Epoch 15/150] train MSE = 1.824478e-04
# [Epoch 16/150] train MSE = 1.797300e-04
# [Epoch 17/150] train MSE = 1.786863e-04
# [Epoch 18/150] train MSE = 1.780737e-04
# [Epoch 19/150] train MSE = 1.775593e-04
# [Epoch 20/150] train MSE = 1.770145e-04
# [Epoch 21/150] train MSE = 1.764806e-04
# [Epoch 22/150] train MSE = 1.759326e-04
# [Epoch 23/150] train MSE = 1.753211e-04
# [Epoch 24/150] train MSE = 1.747218e-04
# [Epoch 25/150] train MSE = 1.741161e-04
# [Epoch 26/150] train MSE = 1.734851e-04
# [Epoch 27/150] train MSE = 1.728712e-04
# [Epoch 28/150] train MSE = 1.722401e-04
# [Epoch 29/150] train MSE = 1.715163e-04
# [Epoch 30/150] train MSE = 1.708352e-04
# [Epoch 31/150] train MSE = 1.701631e-04
# [Epoch 32/150] train MSE = 1.694426e-04
# [Epoch 33/150] train MSE = 1.686721e-04
# [Epoch 34/150] train MSE = 1.679685e-04
# [Epoch 35/150] train MSE = 1.671812e-04
# [Epoch 36/150] train MSE = 1.664186e-04
# [Epoch 37/150] train MSE = 1.656463e-04
# [Epoch 38/150] train MSE = 1.648328e-04
# [Epoch 39/150] train MSE = 1.640494e-04
# [Epoch 40/150] train MSE = 1.632171e-04
# [Epoch 41/150] train MSE = 1.623827e-04
# [Epoch 42/150] train MSE = 1.615348e-04
# [Epoch 43/150] train MSE = 1.606607e-04
# [Epoch 44/150] train MSE = 1.598136e-04
# [Epoch 45/150] train MSE = 1.589511e-04
# [Epoch 46/150] train MSE = 1.580794e-04
# [Epoch 47/150] train MSE = 1.572058e-04
# [Epoch 48/150] train MSE = 1.562594e-04
# [Epoch 49/150] train MSE = 1.553635e-04
# [Epoch 50/150] train MSE = 1.544586e-04
# [Epoch 51/150] train MSE = 1.535287e-04
# [Epoch 52/150] train MSE = 1.526455e-04
# [Epoch 53/150] train MSE = 1.516839e-04
# [Epoch 54/150] train MSE = 1.507790e-04
# [Epoch 55/150] train MSE = 1.498162e-04
# [Epoch 56/150] train MSE = 1.488801e-04
# [Epoch 57/150] train MSE = 1.479176e-04
# [Epoch 58/150] train MSE = 1.469414e-04
# [Epoch 59/150] train MSE = 1.459925e-04
# [Epoch 60/150] train MSE = 1.451613e-04
# [Epoch 61/150] train MSE = 1.441076e-04
# [Epoch 62/150] train MSE = 1.431628e-04
# [Epoch 63/150] train MSE = 1.422083e-04
# [Epoch 64/150] train MSE = 1.413596e-04
# [Epoch 65/150] train MSE = 1.403187e-04
# [Epoch 66/150] train MSE = 1.394071e-04
# [Epoch 67/150] train MSE = 1.384627e-04
# [Epoch 68/150] train MSE = 1.375339e-04
# [Epoch 69/150] train MSE = 1.366018e-04
# [Epoch 70/150] train MSE = 1.357106e-04
# [Epoch 71/150] train MSE = 1.347606e-04
# [Epoch 72/150] train MSE = 1.338369e-04
# [Epoch 73/150] train MSE = 1.329569e-04
# [Epoch 74/150] train MSE = 1.322328e-04
# [Epoch 75/150] train MSE = 1.312198e-04
# [Epoch 76/150] train MSE = 1.303739e-04
# [Epoch 77/150] train MSE = 1.295009e-04
# [Epoch 78/150] train MSE = 1.286547e-04
# [Epoch 79/150] train MSE = 1.278127e-04
# [Epoch 80/150] train MSE = 1.270093e-04
# [Epoch 81/150] train MSE = 1.262069e-04
# [Epoch 82/150] train MSE = 1.253676e-04
# [Epoch 83/150] train MSE = 1.247861e-04
# [Epoch 84/150] train MSE = 1.238971e-04
# [Epoch 85/150] train MSE = 1.231860e-04
# [Epoch 86/150] train MSE = 1.224470e-04
# [Epoch 87/150] train MSE = 1.216933e-04
# [Epoch 88/150] train MSE = 1.211046e-04
# [Epoch 89/150] train MSE = 1.204019e-04
# [Epoch 90/150] train MSE = 1.197612e-04
# [Epoch 91/150] train MSE = 1.192057e-04
# [Epoch 92/150] train MSE = 1.185586e-04
# [Epoch 93/150] train MSE = 1.179263e-04
# [Epoch 94/150] train MSE = 1.174176e-04
# [Epoch 95/150] train MSE = 1.168114e-04
# [Epoch 96/150] train MSE = 1.163213e-04
# [Epoch 97/150] train MSE = 1.158271e-04
# [Epoch 98/150] train MSE = 1.152939e-04
# [Epoch 99/150] train MSE = 1.149216e-04
# [Epoch 100/150] train MSE = 1.144247e-04
# [Epoch 101/150] train MSE = 1.140481e-04
# [Epoch 102/150] train MSE = 1.135862e-04
# [Epoch 103/150] train MSE = 1.131482e-04
# [Epoch 104/150] train MSE = 1.129255e-04
# [Epoch 105/150] train MSE = 1.126496e-04
# [Epoch 106/150] train MSE = 1.122211e-04
# [Epoch 107/150] train MSE = 1.119099e-04
# [Epoch 108/150] train MSE = 1.115428e-04
# [Epoch 109/150] train MSE = 1.112939e-04
# [Epoch 110/150] train MSE = 1.109602e-04
# [Epoch 111/150] train MSE = 1.106428e-04
# [Epoch 112/150] train MSE = 1.105452e-04
# [Epoch 113/150] train MSE = 1.105006e-04
# [Epoch 114/150] train MSE = 1.100807e-04
# [Epoch 115/150] train MSE = 1.099618e-04
# [Epoch 116/150] train MSE = 1.097138e-04
# [Epoch 117/150] train MSE = 1.097511e-04
# [Epoch 118/150] train MSE = 1.095189e-04
# [Epoch 119/150] train MSE = 1.094280e-04
# [Epoch 120/150] train MSE = 1.091751e-04
# [Epoch 121/150] train MSE = 1.090742e-04
# [Epoch 122/150] train MSE = 1.091017e-04
# [Epoch 123/150] train MSE = 1.090021e-04
# [Epoch 124/150] train MSE = 1.088613e-04
# [Epoch 125/150] train MSE = 1.086842e-04
# [Epoch 126/150] train MSE = 1.087309e-04
# [Epoch 127/150] train MSE = 1.086325e-04
# [Epoch 128/150] train MSE = 1.085864e-04
# [Epoch 129/150] train MSE = 1.087114e-04
# [Epoch 130/150] train MSE = 1.085919e-04
# [Epoch 131/150] train MSE = 1.085933e-04
# [Epoch 132/150] train MSE = 1.085443e-04
# [Epoch 133/150] train MSE = 1.084097e-04
# [Epoch 134/150] train MSE = 1.084597e-04
# [Epoch 135/150] train MSE = 1.085626e-04
# [Epoch 136/150] train MSE = 1.084993e-04
# [Epoch 137/150] train MSE = 1.084266e-04
# [Epoch 138/150] train MSE = 1.085695e-04
# [Epoch 139/150] train MSE = 1.083746e-04
# [Epoch 140/150] train MSE = 1.085328e-04
# [Epoch 141/150] train MSE = 1.085700e-04
# [Epoch 142/150] train MSE = 1.083924e-04
# [Epoch 143/150] train MSE = 1.085239e-04
# [Epoch 144/150] train MSE = 1.086802e-04
# [Epoch 145/150] train MSE = 1.087431e-04
# [Epoch 146/150] train MSE = 1.084768e-04
# [Epoch 147/150] train MSE = 1.085023e-04
# [Epoch 148/150] train MSE = 1.087038e-04
# [Epoch 149/150] train MSE = 1.084044e-04
# [Epoch 150/150] train MSE = 1.088558e-04

# %%
model_mlp =  MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 2.769679e-02
# [Epoch 2/150] train MSE = 4.787660e-03
# [Epoch 3/150] train MSE = 2.033823e-03
# [Epoch 4/150] train MSE = 1.453091e-03
# [Epoch 5/150] train MSE = 1.115321e-03
# [Epoch 6/150] train MSE = 9.258443e-04
# [Epoch 7/150] train MSE = 7.948681e-04
# [Epoch 8/150] train MSE = 6.920849e-04
# [Epoch 9/150] train MSE = 6.167809e-04
# [Epoch 10/150] train MSE = 5.527874e-04
# [Epoch 11/150] train MSE = 4.952437e-04
# [Epoch 12/150] train MSE = 4.527129e-04
# [Epoch 13/150] train MSE = 4.145533e-04
# [Epoch 14/150] train MSE = 3.852797e-04
# [Epoch 15/150] train MSE = 3.541143e-04
# [Epoch 16/150] train MSE = 3.319044e-04
# [Epoch 17/150] train MSE = 3.085439e-04
# [Epoch 18/150] train MSE = 2.957531e-04
# [Epoch 19/150] train MSE = 2.737116e-04
# [Epoch 20/150] train MSE = 2.671531e-04
# [Epoch 21/150] train MSE = 2.503556e-04
# [Epoch 22/150] train MSE = 2.337698e-04
# [Epoch 23/150] train MSE = 2.266039e-04
# [Epoch 24/150] train MSE = 2.288204e-04
# [Epoch 25/150] train MSE = 2.115134e-04
# [Epoch 26/150] train MSE = 2.046589e-04
# [Epoch 27/150] train MSE = 1.932645e-04
# [Epoch 28/150] train MSE = 1.890831e-04
# [Epoch 29/150] train MSE = 2.016465e-04
# [Epoch 30/150] train MSE = 1.860167e-04
# [Epoch 31/150] train MSE = 1.743491e-04
# [Epoch 32/150] train MSE = 1.673074e-04
# [Epoch 33/150] train MSE = 1.684946e-04
# [Epoch 34/150] train MSE = 1.758532e-04
# [Epoch 35/150] train MSE = 1.628869e-04
# [Epoch 36/150] train MSE = 1.590038e-04
# [Epoch 37/150] train MSE = 1.606090e-04
# [Epoch 38/150] train MSE = 1.506038e-04
# [Epoch 39/150] train MSE = 1.948538e-04
# [Epoch 40/150] train MSE = 1.458112e-04
# [Epoch 41/150] train MSE = 1.508024e-04
# [Epoch 42/150] train MSE = 1.398734e-04
# [Epoch 43/150] train MSE = 1.395181e-04
# [Epoch 44/150] train MSE = 1.538012e-04
# [Epoch 45/150] train MSE = 1.411273e-04
# [Epoch 46/150] train MSE = 1.351158e-04
# [Epoch 47/150] train MSE = 1.419533e-04
# [Epoch 48/150] train MSE = 1.409802e-04
# [Epoch 49/150] train MSE = 1.380846e-04
# [Epoch 50/150] train MSE = 1.266160e-04
# [Epoch 51/150] train MSE = 1.526107e-04
# [Epoch 52/150] train MSE = 1.278529e-04
# [Epoch 53/150] train MSE = 1.247017e-04
# [Epoch 54/150] train MSE = 1.296272e-04
# [Epoch 55/150] train MSE = 1.400600e-04
# [Epoch 56/150] train MSE = 1.256626e-04
# [Epoch 57/150] train MSE = 1.399618e-04
# [Epoch 58/150] train MSE = 1.432624e-04
# [Epoch 59/150] train MSE = 1.345376e-04
# [Epoch 60/150] train MSE = 1.237350e-04
# [Epoch 61/150] train MSE = 1.259510e-04
# [Epoch 62/150] train MSE = 1.333893e-04
# [Epoch 63/150] train MSE = 1.262459e-04
# [Epoch 64/150] train MSE = 1.301174e-04
# [Epoch 65/150] train MSE = 1.222602e-04
# [Epoch 66/150] train MSE = 1.430441e-04
# [Epoch 67/150] train MSE = 1.185071e-04
# [Epoch 68/150] train MSE = 1.277752e-04
# [Epoch 69/150] train MSE = 1.222034e-04
# [Epoch 70/150] train MSE = 1.173582e-04
# [Epoch 71/150] train MSE = 1.183823e-04
# [Epoch 72/150] train MSE = 1.249990e-04
# [Epoch 73/150] train MSE = 1.250288e-04
# [Epoch 74/150] train MSE = 1.178396e-04
# [Epoch 75/150] train MSE = 1.286502e-04
# [Epoch 76/150] train MSE = 1.170294e-04
# [Epoch 77/150] train MSE = 1.183686e-04
# [Epoch 78/150] train MSE = 1.110935e-04
# [Epoch 79/150] train MSE = 1.188087e-04
# [Epoch 80/150] train MSE = 1.171981e-04
# [Epoch 81/150] train MSE = 1.270380e-04
# [Epoch 82/150] train MSE = 1.329533e-04
# [Epoch 83/150] train MSE = 1.247731e-04
# [Epoch 84/150] train MSE = 1.127546e-04
# [Epoch 85/150] train MSE = 1.148484e-04
# [Epoch 86/150] train MSE = 1.189298e-04
# [Epoch 87/150] train MSE = 1.107049e-04
# [Epoch 88/150] train MSE = 1.150522e-04
# [Epoch 89/150] train MSE = 1.322300e-04
# [Epoch 90/150] train MSE = 1.088893e-04
# [Epoch 91/150] train MSE = 1.263314e-04
# [Epoch 92/150] train MSE = 1.114182e-04
# [Epoch 93/150] train MSE = 1.181632e-04
# [Epoch 94/150] train MSE = 1.150793e-04
# [Epoch 95/150] train MSE = 1.127354e-04
# [Epoch 96/150] train MSE = 1.128102e-04
# [Epoch 97/150] train MSE = 1.179725e-04
# [Epoch 98/150] train MSE = 1.142503e-04
# [Epoch 99/150] train MSE = 1.104839e-04
# [Epoch 100/150] train MSE = 1.094933e-04
# [Epoch 101/150] train MSE = 1.158401e-04
# [Epoch 102/150] train MSE = 1.185008e-04
# [Epoch 103/150] train MSE = 1.238394e-04
# [Epoch 104/150] train MSE = 1.116805e-04
# [Epoch 105/150] train MSE = 1.104409e-04
# [Epoch 106/150] train MSE = 1.145445e-04
# [Epoch 107/150] train MSE = 1.127302e-04
# [Epoch 108/150] train MSE = 1.120113e-04
# [Epoch 109/150] train MSE = 1.065840e-04
# [Epoch 110/150] train MSE = 1.130026e-04
# [Epoch 111/150] train MSE = 1.175872e-04
# [Epoch 112/150] train MSE = 1.193932e-04
# [Epoch 113/150] train MSE = 1.106540e-04
# [Epoch 114/150] train MSE = 1.048095e-04
# [Epoch 115/150] train MSE = 1.263357e-04
# [Epoch 116/150] train MSE = 1.069035e-04
# [Epoch 117/150] train MSE = 1.074702e-04
# [Epoch 118/150] train MSE = 1.112607e-04
# [Epoch 119/150] train MSE = 1.066889e-04
# [Epoch 120/150] train MSE = 1.046857e-04
# [Epoch 121/150] train MSE = 1.059418e-04
# [Epoch 122/150] train MSE = 1.117987e-04
# [Epoch 123/150] train MSE = 1.162546e-04
# [Epoch 124/150] train MSE = 1.113979e-04
# [Epoch 125/150] train MSE = 1.109584e-04
# [Epoch 126/150] train MSE = 1.167461e-04
# [Epoch 127/150] train MSE = 1.114809e-04
# [Epoch 128/150] train MSE = 1.061458e-04
# [Epoch 129/150] train MSE = 1.058273e-04
# [Epoch 130/150] train MSE = 1.077360e-04
# [Epoch 131/150] train MSE = 1.038168e-04
# [Epoch 132/150] train MSE = 1.170359e-04
# [Epoch 133/150] train MSE = 1.030498e-04
# [Epoch 134/150] train MSE = 1.049934e-04
# [Epoch 135/150] train MSE = 1.066614e-04
# [Epoch 136/150] train MSE = 1.078297e-04
# [Epoch 137/150] train MSE = 1.068210e-04
# [Epoch 138/150] train MSE = 1.016759e-04
# [Epoch 139/150] train MSE = 1.105145e-04
# [Epoch 140/150] train MSE = 1.056283e-04
# [Epoch 141/150] train MSE = 1.028253e-04
# [Epoch 142/150] train MSE = 1.131139e-04
# [Epoch 143/150] train MSE = 1.070435e-04
# [Epoch 144/150] train MSE = 1.023755e-04
# [Epoch 145/150] train MSE = 1.049421e-04
# [Epoch 146/150] train MSE = 1.035424e-04
# [Epoch 147/150] train MSE = 1.104496e-04
# [Epoch 148/150] train MSE = 1.036855e-04
# [Epoch 149/150] train MSE = 1.029068e-04
# [Epoch 150/150] train MSE = 1.017701e-04

# %%
test_loss_lin = eval_integrator_B(
    model_lin, data, R=R, k=k, N_test=20_000
)

test_loss_mlp = eval_integrator_B(
    model_mlp, data, R=R, k=k, N_test=20_000
)

print(f"Linear test MSE: {test_loss_lin:.6e}")
print(f"MLP test MSE:    {test_loss_mlp:.6e}")
# Out:
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 1.101703e-04
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 1.171525e-04
# Linear test MSE: 1.101703e-04
# MLP test MSE:    1.171525e-04

# %%
# ===== Save models =====

torch.save(
    {
        "model_type": "linear",
        "state_dict": model_lin.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "linear_integrator_Square_gauss.pth",
)

torch.save(
    {
        "model_type": "mlp",
        "state_dict": model_mlp.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "hidden": 128,
            "num_layers": 3,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "small_mlp_integrator_Square_gauss.pth",
)

print("Models saved: linear_integrator_gauss.pth, mlp_integrator_gauss.pth")
# Out:
# Models saved: linear_integrator_gauss.pth, mlp_integrator_gauss.pth

# %%
% laod models
# ===== Load model =====

ckpt = torch.load("mlp_integrator_Square_gauss.pth", map_location="cuda")

if ckpt["model_type"] == "linear":
    model = LinearIntegrator(k=ckpt["config"]["k"])
elif ckpt["model_type"] == "mlp":
    model = MLPIntegrator(
        k=ckpt["config"]["k"],
        hidden=ckpt["config"]["hidden"],
        num_layers=ckpt["config"]["num_layers"],
    )
else:
    raise ValueError("Unknown model type")

model.load_state_dict(ckpt["state_dict"])
model = model.to("cuda")
model.eval()

print(f"Loaded {ckpt['model_type']} model with config:")
print(ckpt["config"])

# %%
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
visualize_B_compare_models(data, model_lin, model_mlp, R=5, k=5)
# Out:
# C:\Users\amt35\AppData\Local\Temp\ipykernel_27376\406914228.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Cumulative test error comparison
n_points = 10000
step = 500
n_steps = n_points // step

test_ds = BDataset(data, N_samples=n_points, R=R, k=k, seed=456, pregenerate=True)
loader = DataLoader(test_ds, batch_size=step, shuffle=False, num_workers=0, pin_memory=True)

loss_fn = nn.MSELoss()
cum_err_lin, cum_err_mlp = [], []
total_lin, total_mlp = 0.0, 0.0

model_lin.eval()
model_mlp.eval()
with torch.no_grad():
    for i, (feats, target) in enumerate(loader):
        feats = feats.to(device)
        target = target.to(device)
        
        pred_lin = model_lin(feats)
        pred_mlp = model_mlp(feats)
        
        loss_lin = loss_fn(pred_lin, target).item()
        loss_mlp = loss_fn(pred_mlp, target).item()
        
        total_lin += loss_lin * step
        total_mlp += loss_mlp * step
        
        cum_err_lin.append(total_lin )
        cum_err_mlp.append(total_mlp )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Cumulative error
x = np.arange(step, n_points + 1, step)
ax1.semilogy(x, cum_err_lin, 'o-', label='Linear', color='C0', markersize=4)
ax1.semilogy(x, cum_err_mlp, 's-', label='MLP', color='C1', markersize=4)
ax1.set_xlabel('Number of test points')
ax1.set_ylabel('Cumulative MSE')
ax1.set_title('Cumulative Test Error')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Error ratio
ratio = np.array(cum_err_mlp) / np.array(cum_err_lin)
ax2.plot(x, ratio, 'k-', linewidth=2)
ax2.axhline(1, color='r', linestyle='--', alpha=0.5, label='Equal')
ax2.set_xlabel('Number of test points')
ax2.set_ylabel('MLP / Linear')
ax2.set_title('Error Ratio (MLP/Linear)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
