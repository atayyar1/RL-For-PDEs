# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate wave equation data (Dirichlet BC)
# -----------------------
def wave_solver_dirichlet(u0, ut0, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D wave equation (Dirichlet BCs u(0,t)=u(1,t)=0)."""
    Nx = len(u0)
    u = u0.copy()
    u_prev = u0.copy()  # u at previous time step
    
    # Initialize first time step using initial velocity
    u_new = u.copy()
    for i in range(1, Nx - 1):
        lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
        u_new[i] = u[i] + dt * ut0[i] + 0.5 * c**2 * dt**2 * lap
    u_prev = u.copy()
    u = u_new.copy()
    
    traj = [u0.copy(), u.copy()]
    
    for _ in range(n_steps - 1):
        u_new = u.copy()
        
        # discrete Laplacian on interior points only
        for i in range(1, Nx - 1):
            lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
            u_new[i] = 2*u[i] - u_prev[i] + c**2 * dt**2 * lap
        
        # Dirichlet boundaries
        u_new[0] = 0.0
        u_new[-1] = 0.0
        
        u_prev = u.copy()
        u = u_new.copy()
        traj.append(u.copy())
    
    return np.stack(traj)  # shape (T, Nx)

def generate_wave_data(Nx=128, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)

    # initial condition compatible with Dirichlet BC
    u0 = np.sin(2*np.pi * x)   # = 0 at x=0 and x=1
    ut0 = np.zeros_like(x)   # zero initial velocity (nice and simple)

    data = wave_solver_dirichlet(u0, ut0, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
c = 1.0
n_steps = 9000

x, data = generate_wave_data(Nx, c, dt0, n_steps)

# %%
t_plot = n_steps//1 # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Wave Equation: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) / true * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.335754e+00
# [Epoch 2/150] train MSE = 7.195182e-01
# [Epoch 3/150] train MSE = 3.738341e-01
# [Epoch 4/150] train MSE = 1.846291e-01
# [Epoch 5/150] train MSE = 8.708415e-02
# [Epoch 6/150] train MSE = 3.929003e-02
# [Epoch 7/150] train MSE = 1.696872e-02
# [Epoch 8/150] train MSE = 6.998577e-03
# [Epoch 9/150] train MSE = 2.768726e-03
# [Epoch 10/150] train MSE = 1.070135e-03
# [Epoch 11/150] train MSE = 4.267660e-04
# [Epoch 12/150] train MSE = 1.994587e-04
# [Epoch 13/150] train MSE = 1.243064e-04
# [Epoch 14/150] train MSE = 1.011819e-04
# [Epoch 15/150] train MSE = 9.464162e-05
# [Epoch 16/150] train MSE = 9.291902e-05
# [Epoch 17/150] train MSE = 9.247849e-05
# [Epoch 18/150] train MSE = 9.237556e-05
# [Epoch 19/150] train MSE = 9.233817e-05
# [Epoch 20/150] train MSE = 9.231873e-05
# [Epoch 21/150] train MSE = 9.231093e-05
# [Epoch 22/150] train MSE = 9.230932e-05
# [Epoch 23/150] train MSE = 9.227984e-05
# [Epoch 24/150] train MSE = 9.227683e-05
# [Epoch 25/150] train MSE = 9.226439e-05
# [Epoch 26/150] train MSE = 9.223930e-05
# [Epoch 27/150] train MSE = 9.225735e-05
# [Epoch 28/150] train MSE = 9.219733e-05
# [Epoch 29/150] train MSE = 9.219690e-05
# [Epoch 30/150] train MSE = 9.218935e-05
# [Epoch 31/150] train MSE = 9.215306e-05
# [Epoch 32/150] train MSE = 9.213667e-05
# [Epoch 33/150] train MSE = 9.213379e-05
# [Epoch 34/150] train MSE = 9.211422e-05
# [Epoch 35/150] train MSE = 9.209485e-05
# [Epoch 36/150] train MSE = 9.207542e-05
# [Epoch 37/150] train MSE = 9.206506e-05
# [Epoch 38/150] train MSE = 9.201183e-05
# [Epoch 39/150] train MSE = 9.202465e-05
# [Epoch 40/150] train MSE = 9.199019e-05
# [Epoch 41/150] train MSE = 9.198308e-05
# [Epoch 42/150] train MSE = 9.193620e-05
# [Epoch 43/150] train MSE = 9.194091e-05
# [Epoch 44/150] train MSE = 9.190687e-05
# [Epoch 45/150] train MSE = 9.192193e-05
# [Epoch 46/150] train MSE = 9.186191e-05
# [Epoch 47/150] train MSE = 9.184404e-05
# [Epoch 48/150] train MSE = 9.178621e-05
# [Epoch 49/150] train MSE = 9.180588e-05
# [Epoch 50/150] train MSE = 9.172197e-05
# [Epoch 51/150] train MSE = 9.168619e-05
# [Epoch 52/150] train MSE = 9.166830e-05
# [Epoch 53/150] train MSE = 9.165434e-05
# [Epoch 54/150] train MSE = 9.163145e-05
# [Epoch 55/150] train MSE = 9.157157e-05
# [Epoch 56/150] train MSE = 9.152533e-05
# [Epoch 57/150] train MSE = 9.146717e-05
# [Epoch 58/150] train MSE = 9.144988e-05
# [Epoch 59/150] train MSE = 9.143770e-05
# [Epoch 60/150] train MSE = 9.133833e-05
# [Epoch 61/150] train MSE = 9.132733e-05
# [Epoch 62/150] train MSE = 9.126715e-05
# [Epoch 63/150] train MSE = 9.136457e-05
# [Epoch 64/150] train MSE = 9.119840e-05
# [Epoch 65/150] train MSE = 9.111214e-05
# [Epoch 66/150] train MSE = 9.109425e-05
# [Epoch 67/150] train MSE = 9.107486e-05
# [Epoch 68/150] train MSE = 9.111138e-05
# [Epoch 69/150] train MSE = 9.099807e-05
# [Epoch 70/150] train MSE = 9.100095e-05
# [Epoch 71/150] train MSE = 9.102178e-05
# [Epoch 72/150] train MSE = 9.086200e-05
# [Epoch 73/150] train MSE = 9.081671e-05
# [Epoch 74/150] train MSE = 9.076485e-05
# [Epoch 75/150] train MSE = 9.083637e-05
# [Epoch 76/150] train MSE = 9.077460e-05
# [Epoch 77/150] train MSE = 9.056703e-05
# [Epoch 78/150] train MSE = 9.064335e-05
# [Epoch 79/150] train MSE = 9.045746e-05
# [Epoch 80/150] train MSE = 9.036564e-05
# [Epoch 81/150] train MSE = 9.035776e-05
# [Epoch 82/150] train MSE = 9.024528e-05
# [Epoch 83/150] train MSE = 9.039567e-05
# [Epoch 84/150] train MSE = 9.028412e-05
# [Epoch 85/150] train MSE = 9.009182e-05
# [Epoch 86/150] train MSE = 9.009914e-05
# [Epoch 87/150] train MSE = 8.991351e-05
# [Epoch 88/150] train MSE = 8.988230e-05
# [Epoch 89/150] train MSE = 8.985231e-05
# [Epoch 90/150] train MSE = 8.969748e-05
# [Epoch 91/150] train MSE = 8.965368e-05
# [Epoch 92/150] train MSE = 8.971013e-05
# [Epoch 93/150] train MSE = 8.951502e-05
# [Epoch 94/150] train MSE = 8.945551e-05
# [Epoch 95/150] train MSE = 8.937650e-05
# [Epoch 96/150] train MSE = 8.924028e-05
# [Epoch 97/150] train MSE = 8.917522e-05
# [Epoch 98/150] train MSE = 8.906553e-05
# [Epoch 99/150] train MSE = 8.909841e-05
# [Epoch 100/150] train MSE = 8.901181e-05
# [Epoch 101/150] train MSE = 8.884127e-05
# [Epoch 102/150] train MSE = 8.897220e-05
# [Epoch 103/150] train MSE = 8.913761e-05
# [Epoch 104/150] train MSE = 8.871403e-05
# [Epoch 105/150] train MSE = 8.840668e-05
# [Epoch 106/150] train MSE = 8.865321e-05
# [Epoch 107/150] train MSE = 8.827968e-05
# [Epoch 108/150] train MSE = 8.818418e-05
# [Epoch 109/150] train MSE = 8.809470e-05
# [Epoch 110/150] train MSE = 8.800911e-05
# [Epoch 111/150] train MSE = 8.789067e-05
# [Epoch 112/150] train MSE = 8.782033e-05
# [Epoch 113/150] train MSE = 8.774812e-05
# [Epoch 114/150] train MSE = 8.764200e-05
# [Epoch 115/150] train MSE = 8.743236e-05
# [Epoch 116/150] train MSE = 8.723680e-05
# [Epoch 117/150] train MSE = 8.740999e-05
# [Epoch 118/150] train MSE = 8.704102e-05
# [Epoch 119/150] train MSE = 8.742820e-05
# [Epoch 120/150] train MSE = 8.689325e-05
# [Epoch 121/150] train MSE = 8.656034e-05
# [Epoch 122/150] train MSE = 8.678938e-05
# [Epoch 123/150] train MSE = 8.667432e-05
# [Epoch 124/150] train MSE = 8.624736e-05
# [Epoch 125/150] train MSE = 8.628300e-05
# [Epoch 126/150] train MSE = 8.617814e-05
# [Epoch 127/150] train MSE = 8.579014e-05
# [Epoch 128/150] train MSE = 8.560242e-05
# [Epoch 129/150] train MSE = 8.558741e-05
# [Epoch 130/150] train MSE = 8.568620e-05
# [Epoch 131/150] train MSE = 8.525363e-05
# [Epoch 132/150] train MSE = 8.524799e-05
# [Epoch 133/150] train MSE = 8.511415e-05
# [Epoch 134/150] train MSE = 8.495207e-05
# [Epoch 135/150] train MSE = 8.496710e-05
# [Epoch 136/150] train MSE = 8.461346e-05
# [Epoch 137/150] train MSE = 8.494208e-05
# [Epoch 138/150] train MSE = 8.445106e-05
# [Epoch 139/150] train MSE = 8.431285e-05
# [Epoch 140/150] train MSE = 8.389139e-05
# [Epoch 141/150] train MSE = 8.365706e-05
# [Epoch 142/150] train MSE = 8.391486e-05
# [Epoch 143/150] train MSE = 8.353846e-05
# [Epoch 144/150] train MSE = 8.332366e-05
# [Epoch 145/150] train MSE = 8.304695e-05
# [Epoch 146/150] train MSE = 8.315624e-05
# [Epoch 147/150] train MSE = 8.318338e-05
# [Epoch 148/150] train MSE = 8.307870e-05
# [Epoch 149/150] train MSE = 8.270483e-05
# [Epoch 150/150] train MSE = 8.253820e-05

# %%
model_mlp =  MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 7.047284e-02
# [Epoch 2/150] train MSE = 4.953043e-03
# [Epoch 3/150] train MSE = 3.174081e-03
# [Epoch 4/150] train MSE = 2.360463e-03
# [Epoch 5/150] train MSE = 1.862994e-03
# [Epoch 6/150] train MSE = 1.506898e-03
# [Epoch 7/150] train MSE = 1.280438e-03
# [Epoch 8/150] train MSE = 1.092353e-03
# [Epoch 9/150] train MSE = 9.469885e-04
# [Epoch 10/150] train MSE = 8.377789e-04
# [Epoch 11/150] train MSE = 7.464274e-04
# [Epoch 12/150] train MSE = 6.785990e-04
# [Epoch 13/150] train MSE = 6.121321e-04
# [Epoch 14/150] train MSE = 5.562948e-04
# [Epoch 15/150] train MSE = 5.004922e-04
# [Epoch 16/150] train MSE = 4.951918e-04
# [Epoch 17/150] train MSE = 4.415692e-04
# [Epoch 18/150] train MSE = 4.005525e-04
# [Epoch 19/150] train MSE = 3.745492e-04
# [Epoch 20/150] train MSE = 3.504056e-04
# [Epoch 21/150] train MSE = 3.498799e-04
# [Epoch 22/150] train MSE = 3.107308e-04
# [Epoch 23/150] train MSE = 3.024849e-04
# [Epoch 24/150] train MSE = 3.089768e-04
# [Epoch 25/150] train MSE = 2.634641e-04
# [Epoch 26/150] train MSE = 2.612965e-04
# [Epoch 27/150] train MSE = 2.342010e-04
# [Epoch 28/150] train MSE = 2.568335e-04
# [Epoch 29/150] train MSE = 2.264185e-04
# [Epoch 30/150] train MSE = 2.215496e-04
# [Epoch 31/150] train MSE = 1.946033e-04
# [Epoch 32/150] train MSE = 1.934881e-04
# [Epoch 33/150] train MSE = 1.911989e-04
# [Epoch 34/150] train MSE = 2.009575e-04
# [Epoch 35/150] train MSE = 1.893298e-04
# [Epoch 36/150] train MSE = 1.687884e-04
# [Epoch 37/150] train MSE = 1.858381e-04
# [Epoch 38/150] train MSE = 1.559687e-04
# [Epoch 39/150] train MSE = 1.620166e-04
# [Epoch 40/150] train MSE = 1.764449e-04
# [Epoch 41/150] train MSE = 1.676897e-04
# [Epoch 42/150] train MSE = 1.634058e-04
# [Epoch 43/150] train MSE = 1.369106e-04
# [Epoch 44/150] train MSE = 1.342493e-04
# [Epoch 45/150] train MSE = 1.626280e-04
# [Epoch 46/150] train MSE = 1.428359e-04
# [Epoch 47/150] train MSE = 1.187672e-04
# [Epoch 48/150] train MSE = 1.317392e-04
# [Epoch 49/150] train MSE = 1.462803e-04
# [Epoch 50/150] train MSE = 1.166487e-04
# [Epoch 51/150] train MSE = 1.466532e-04
# [Epoch 52/150] train MSE = 1.715390e-04
# [Epoch 53/150] train MSE = 1.118924e-04
# [Epoch 54/150] train MSE = 1.187531e-04
# [Epoch 55/150] train MSE = 1.147649e-04
# [Epoch 56/150] train MSE = 1.229434e-04
# [Epoch 57/150] train MSE = 1.359340e-04
# [Epoch 58/150] train MSE = 1.082268e-04
# [Epoch 59/150] train MSE = 1.049399e-04
# [Epoch 60/150] train MSE = 1.199522e-04
# [Epoch 61/150] train MSE = 1.012359e-04
# [Epoch 62/150] train MSE = 1.377633e-04
# [Epoch 63/150] train MSE = 1.131515e-04
# [Epoch 64/150] train MSE = 1.217247e-04
# [Epoch 65/150] train MSE = 1.034911e-04
# [Epoch 66/150] train MSE = 1.257331e-04
# [Epoch 67/150] train MSE = 1.045777e-04
# [Epoch 68/150] train MSE = 9.434886e-05
# [Epoch 69/150] train MSE = 1.043667e-04
# [Epoch 70/150] train MSE = 1.283791e-04
# [Epoch 71/150] train MSE = 1.075093e-04
# [Epoch 72/150] train MSE = 1.095036e-04
# [Epoch 73/150] train MSE = 9.740495e-05
# [Epoch 74/150] train MSE = 1.172802e-04
# [Epoch 75/150] train MSE = 1.127009e-04
# [Epoch 76/150] train MSE = 1.050902e-04
# [Epoch 77/150] train MSE = 1.190888e-04
# [Epoch 78/150] train MSE = 8.892757e-05
# [Epoch 79/150] train MSE = 1.028651e-04
# [Epoch 80/150] train MSE = 9.577030e-05
# [Epoch 81/150] train MSE = 9.290716e-05
# [Epoch 82/150] train MSE = 1.113500e-04
# [Epoch 83/150] train MSE = 1.032333e-04
# [Epoch 84/150] train MSE = 1.019358e-04
# [Epoch 85/150] train MSE = 9.666070e-05
# [Epoch 86/150] train MSE = 9.330753e-05
# [Epoch 87/150] train MSE = 1.142132e-04
# [Epoch 88/150] train MSE = 1.070555e-04
# [Epoch 89/150] train MSE = 1.244167e-04
# [Epoch 90/150] train MSE = 9.633095e-05
# [Epoch 91/150] train MSE = 9.385406e-05
# [Epoch 92/150] train MSE = 8.793175e-05
# [Epoch 93/150] train MSE = 8.809367e-05
# [Epoch 94/150] train MSE = 8.907589e-05
# [Epoch 95/150] train MSE = 9.894259e-05
# [Epoch 96/150] train MSE = 1.025650e-04
# [Epoch 97/150] train MSE = 1.141483e-04
# [Epoch 98/150] train MSE = 8.865798e-05
# [Epoch 99/150] train MSE = 8.632958e-05
# [Epoch 100/150] train MSE = 8.485143e-05
# [Epoch 101/150] train MSE = 9.502896e-05
# [Epoch 102/150] train MSE = 1.030613e-04
# [Epoch 103/150] train MSE = 1.031963e-04
# [Epoch 104/150] train MSE = 9.398769e-05
# [Epoch 105/150] train MSE = 8.808094e-05
# [Epoch 106/150] train MSE = 9.087692e-05
# [Epoch 107/150] train MSE = 1.012138e-04
# [Epoch 108/150] train MSE = 9.941868e-05
# [Epoch 109/150] train MSE = 9.652057e-05
# [Epoch 110/150] train MSE = 8.933035e-05
# [Epoch 111/150] train MSE = 1.174257e-04
# [Epoch 112/150] train MSE = 8.695122e-05
# [Epoch 113/150] train MSE = 8.457414e-05
# [Epoch 114/150] train MSE = 9.663712e-05
# [Epoch 115/150] train MSE = 8.382354e-05
# [Epoch 116/150] train MSE = 9.030168e-05
# [Epoch 117/150] train MSE = 8.420230e-05
# [Epoch 118/150] train MSE = 8.860020e-05
# [Epoch 119/150] train MSE = 8.373110e-05
# [Epoch 120/150] train MSE = 9.706893e-05
# [Epoch 121/150] train MSE = 8.607927e-05
# [Epoch 122/150] train MSE = 9.378190e-05
# [Epoch 123/150] train MSE = 9.907343e-05
# [Epoch 124/150] train MSE = 9.829986e-05
# [Epoch 125/150] train MSE = 9.086063e-05
# [Epoch 126/150] train MSE = 8.295040e-05
# [Epoch 127/150] train MSE = 8.321947e-05
# [Epoch 128/150] train MSE = 9.448509e-05
# [Epoch 129/150] train MSE = 8.193167e-05
# [Epoch 130/150] train MSE = 8.427304e-05
# [Epoch 131/150] train MSE = 9.386548e-05
# [Epoch 132/150] train MSE = 8.671576e-05
# [Epoch 133/150] train MSE = 8.532862e-05
# [Epoch 134/150] train MSE = 1.154887e-04
# [Epoch 135/150] train MSE = 1.007661e-04
# [Epoch 136/150] train MSE = 7.903678e-05
# [Epoch 137/150] train MSE = 9.018638e-05
# [Epoch 138/150] train MSE = 9.206609e-05
# [Epoch 139/150] train MSE = 8.003694e-05
# [Epoch 140/150] train MSE = 8.916434e-05
# [Epoch 141/150] train MSE = 8.738604e-05
# [Epoch 142/150] train MSE = 8.923855e-05
# [Epoch 143/150] train MSE = 8.442020e-05
# [Epoch 144/150] train MSE = 8.077351e-05
# [Epoch 145/150] train MSE = 8.196426e-05
# [Epoch 146/150] train MSE = 9.108599e-05
# [Epoch 147/150] train MSE = 8.292810e-05
# [Epoch 148/150] train MSE = 8.012865e-05
# [Epoch 149/150] train MSE = 8.315189e-05
# [Epoch 150/150] train MSE = 8.501561e-05

# %%
test_loss_lin = eval_integrator_B(
    model_lin, data, R=R, k=k, N_test=20_000
)

test_loss_mlp = eval_integrator_B(
    model_mlp, data, R=R, k=k, N_test=20_000
)

print(f"Linear test MSE: {test_loss_lin:.6e}")
print(f"MLP test MSE:    {test_loss_mlp:.6e}")
# Out:
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 8.276307e-05
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 8.386498e-05
# Linear test MSE: 8.276307e-05
# MLP test MSE:    8.386498e-05

# %%
# ===== Save models =====

torch.save(
    {
        "model_type": "linear",
        "state_dict": model_lin.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "linear_integrator_Square.pth",
)

torch.save(
    {
        "model_type": "mlp",
        "state_dict": model_mlp.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "hidden": 128,
            "num_layers": 3,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "small_mlp_integrator_Square.pth",
)

print("Models saved: linear_integrator.pth, mlp_integrator.pth")
# Out:
# Models saved: linear_integrator.pth, mlp_integrator.pth

# %%
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
visualize_B_compare_models(data, model_lin, model_mlp, R=5, k=5)
# Out:
# C:\Users\amt35\AppData\Local\Temp\ipykernel_48944\736158891.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
