# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate wave equation data (Dirichlet BC)
# -----------------------
def wave_solver_dirichlet(u0, ut0, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D wave equation (Dirichlet BCs u(0,t)=u(1,t)=0)."""
    Nx = len(u0)
    u = u0.copy()
    u_prev = u0.copy()  # u at previous time step
    
    # Initialize first time step using initial velocity
    u_new = u.copy()
    for i in range(1, Nx - 1):
        lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
        u_new[i] = u[i] + dt * ut0[i] + 0.5 * c**2 * dt**2 * lap
    u_prev = u.copy()
    u = u_new.copy()
    
    traj = [u0.copy(), u.copy()]
    
    for _ in range(n_steps - 1):
        u_new = u.copy()
        
        # discrete Laplacian on interior points only
        for i in range(1, Nx - 1):
            lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
            u_new[i] = 2*u[i] - u_prev[i] + c**2 * dt**2 * lap
        
        # Dirichlet boundaries
        u_new[0] = 0.0
        u_new[-1] = 0.0
        
        u_prev = u.copy()
        u = u_new.copy()
        traj.append(u.copy())
    
    return np.stack(traj)  # shape (T, Nx)

def generate_wave_data(Nx=128, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)

    # initial condition compatible with Dirichlet BC
    u0 = np.sin(2*np.pi * x)   # = 0 at x=0 and x=1
    ut0 = np.zeros_like(x)   # zero initial velocity (nice and simple)

    data = wave_solver_dirichlet(u0, ut0, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
c = 1.0
n_steps = 9000

x, data = generate_wave_data(Nx, c, dt0, n_steps)

# %%
t_plot = n_steps//2 # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Wave Equation: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) / true * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 3.305279e+00
# [Epoch 2/150] train MSE = 1.967723e+00
# [Epoch 3/150] train MSE = 1.117825e+00
# [Epoch 4/150] train MSE = 6.022233e-01
# [Epoch 5/150] train MSE = 3.058933e-01
# [Epoch 6/150] train MSE = 1.454936e-01
# [Epoch 7/150] train MSE = 6.460953e-02
# [Epoch 8/150] train MSE = 2.673525e-02
# [Epoch 9/150] train MSE = 1.033156e-02
# [Epoch 10/150] train MSE = 3.748952e-03
# [Epoch 11/150] train MSE = 1.308077e-03
# [Epoch 12/150] train MSE = 4.687426e-04
# [Epoch 13/150] train MSE = 2.009761e-04
# [Epoch 14/150] train MSE = 1.219214e-04
# [Epoch 15/150] train MSE = 1.003188e-04
# [Epoch 16/150] train MSE = 9.481475e-05
# [Epoch 17/150] train MSE = 9.349731e-05
# [Epoch 18/150] train MSE = 9.320312e-05
# [Epoch 19/150] train MSE = 9.313220e-05
# [Epoch 20/150] train MSE = 9.310737e-05
# [Epoch 21/150] train MSE = 9.309392e-05
# [Epoch 22/150] train MSE = 9.308020e-05
# [Epoch 23/150] train MSE = 9.307596e-05
# [Epoch 24/150] train MSE = 9.306107e-05
# [Epoch 25/150] train MSE = 9.304084e-05
# [Epoch 26/150] train MSE = 9.302673e-05
# [Epoch 27/150] train MSE = 9.301501e-05
# [Epoch 28/150] train MSE = 9.300570e-05
# [Epoch 29/150] train MSE = 9.298329e-05
# [Epoch 30/150] train MSE = 9.296561e-05
# [Epoch 31/150] train MSE = 9.294470e-05
# [Epoch 32/150] train MSE = 9.293056e-05
# [Epoch 33/150] train MSE = 9.290668e-05
# [Epoch 34/150] train MSE = 9.289283e-05
# [Epoch 35/150] train MSE = 9.286783e-05
# [Epoch 36/150] train MSE = 9.284470e-05
# [Epoch 37/150] train MSE = 9.282047e-05
# [Epoch 38/150] train MSE = 9.282113e-05
# [Epoch 39/150] train MSE = 9.278525e-05
# [Epoch 40/150] train MSE = 9.275310e-05
# [Epoch 41/150] train MSE = 9.273569e-05
# [Epoch 42/150] train MSE = 9.271391e-05
# [Epoch 43/150] train MSE = 9.268157e-05
# [Epoch 44/150] train MSE = 9.265892e-05
# [Epoch 45/150] train MSE = 9.263597e-05
# [Epoch 46/150] train MSE = 9.260542e-05
# [Epoch 47/150] train MSE = 9.259090e-05
# [Epoch 48/150] train MSE = 9.255748e-05
# [Epoch 49/150] train MSE = 9.251801e-05
# [Epoch 50/150] train MSE = 9.249654e-05
# [Epoch 51/150] train MSE = 9.246569e-05
# [Epoch 52/150] train MSE = 9.244176e-05
# [Epoch 53/150] train MSE = 9.241979e-05
# [Epoch 54/150] train MSE = 9.237793e-05
# [Epoch 55/150] train MSE = 9.234697e-05
# [Epoch 56/150] train MSE = 9.231230e-05
# [Epoch 57/150] train MSE = 9.226324e-05
# [Epoch 58/150] train MSE = 9.223267e-05
# [Epoch 59/150] train MSE = 9.220126e-05
# [Epoch 60/150] train MSE = 9.215877e-05
# [Epoch 61/150] train MSE = 9.212791e-05
# [Epoch 62/150] train MSE = 9.208511e-05
# [Epoch 63/150] train MSE = 9.203715e-05
# [Epoch 64/150] train MSE = 9.198379e-05
# [Epoch 65/150] train MSE = 9.195602e-05
# [Epoch 66/150] train MSE = 9.190293e-05
# [Epoch 67/150] train MSE = 9.184715e-05
# [Epoch 68/150] train MSE = 9.181457e-05
# [Epoch 69/150] train MSE = 9.176578e-05
# [Epoch 70/150] train MSE = 9.172113e-05
# [Epoch 71/150] train MSE = 9.169532e-05
# [Epoch 72/150] train MSE = 9.163973e-05
# [Epoch 73/150] train MSE = 9.159703e-05
# [Epoch 74/150] train MSE = 9.151884e-05
# [Epoch 75/150] train MSE = 9.145187e-05
# [Epoch 76/150] train MSE = 9.140620e-05
# [Epoch 77/150] train MSE = 9.133341e-05
# [Epoch 78/150] train MSE = 9.130591e-05
# [Epoch 79/150] train MSE = 9.123107e-05
# [Epoch 80/150] train MSE = 9.118376e-05
# [Epoch 81/150] train MSE = 9.114644e-05
# [Epoch 82/150] train MSE = 9.105684e-05
# [Epoch 83/150] train MSE = 9.098675e-05
# [Epoch 84/150] train MSE = 9.095395e-05
# [Epoch 85/150] train MSE = 9.087580e-05
# [Epoch 86/150] train MSE = 9.080252e-05
# [Epoch 87/150] train MSE = 9.070096e-05
# [Epoch 88/150] train MSE = 9.067807e-05
# [Epoch 89/150] train MSE = 9.058686e-05
# [Epoch 90/150] train MSE = 9.047923e-05
# [Epoch 91/150] train MSE = 9.040555e-05
# [Epoch 92/150] train MSE = 9.035006e-05
# [Epoch 93/150] train MSE = 9.026906e-05
# [Epoch 94/150] train MSE = 9.019963e-05
# [Epoch 95/150] train MSE = 9.010276e-05
# [Epoch 96/150] train MSE = 9.002782e-05
# [Epoch 97/150] train MSE = 8.994603e-05
# [Epoch 98/150] train MSE = 8.985666e-05
# [Epoch 99/150] train MSE = 8.977983e-05
# [Epoch 100/150] train MSE = 8.966944e-05
# [Epoch 101/150] train MSE = 8.955512e-05
# [Epoch 102/150] train MSE = 8.949005e-05
# [Epoch 103/150] train MSE = 8.940890e-05
# [Epoch 104/150] train MSE = 8.929619e-05
# [Epoch 105/150] train MSE = 8.920767e-05
# [Epoch 106/150] train MSE = 8.911228e-05
# [Epoch 107/150] train MSE = 8.904498e-05
# [Epoch 108/150] train MSE = 8.888281e-05
# [Epoch 109/150] train MSE = 8.880305e-05
# [Epoch 110/150] train MSE = 8.866837e-05
# [Epoch 111/150] train MSE = 8.857428e-05
# [Epoch 112/150] train MSE = 8.847323e-05
# [Epoch 113/150] train MSE = 8.834015e-05
# [Epoch 114/150] train MSE = 8.824305e-05
# [Epoch 115/150] train MSE = 8.811362e-05
# [Epoch 116/150] train MSE = 8.799013e-05
# [Epoch 117/150] train MSE = 8.786189e-05
# [Epoch 118/150] train MSE = 8.772668e-05
# [Epoch 119/150] train MSE = 8.762494e-05
# [Epoch 120/150] train MSE = 8.753190e-05
# [Epoch 121/150] train MSE = 8.737322e-05
# [Epoch 122/150] train MSE = 8.725455e-05
# [Epoch 123/150] train MSE = 8.721574e-05
# [Epoch 124/150] train MSE = 8.715738e-05
# [Epoch 125/150] train MSE = 8.681151e-05
# [Epoch 126/150] train MSE = 8.670997e-05
# [Epoch 127/150] train MSE = 8.658986e-05
# [Epoch 128/150] train MSE = 8.647978e-05
# [Epoch 129/150] train MSE = 8.638686e-05
# [Epoch 130/150] train MSE = 8.611918e-05
# [Epoch 131/150] train MSE = 8.606466e-05
# [Epoch 132/150] train MSE = 8.590054e-05
# [Epoch 133/150] train MSE = 8.581876e-05
# [Epoch 134/150] train MSE = 8.555063e-05
# [Epoch 135/150] train MSE = 8.539840e-05
# [Epoch 136/150] train MSE = 8.530426e-05
# [Epoch 137/150] train MSE = 8.504463e-05
# [Epoch 138/150] train MSE = 8.492865e-05
# [Epoch 139/150] train MSE = 8.474654e-05
# [Epoch 140/150] train MSE = 8.463284e-05
# [Epoch 141/150] train MSE = 8.441164e-05
# [Epoch 142/150] train MSE = 8.443272e-05
# [Epoch 143/150] train MSE = 8.409055e-05
# [Epoch 144/150] train MSE = 8.397125e-05
# [Epoch 145/150] train MSE = 8.370261e-05
# [Epoch 146/150] train MSE = 8.368315e-05
# [Epoch 147/150] train MSE = 8.354958e-05
# [Epoch 148/150] train MSE = 8.335723e-05
# [Epoch 149/150] train MSE = 8.305735e-05
# [Epoch 150/150] train MSE = 8.306729e-05

# %%
model_mlp =  MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 6.746473e-02
# [Epoch 2/150] train MSE = 4.841887e-03
# [Epoch 3/150] train MSE = 3.274603e-03
# [Epoch 4/150] train MSE = 2.498450e-03
# [Epoch 5/150] train MSE = 1.997856e-03
# [Epoch 6/150] train MSE = 1.651965e-03
# [Epoch 7/150] train MSE = 1.409495e-03
# [Epoch 8/150] train MSE = 1.207992e-03
# [Epoch 9/150] train MSE = 1.052660e-03
# [Epoch 10/150] train MSE = 9.306112e-04
# [Epoch 11/150] train MSE = 8.294550e-04
# [Epoch 12/150] train MSE = 7.535247e-04
# [Epoch 13/150] train MSE = 6.768157e-04
# [Epoch 14/150] train MSE = 6.151665e-04
# [Epoch 15/150] train MSE = 5.657290e-04
# [Epoch 16/150] train MSE = 5.221779e-04
# [Epoch 17/150] train MSE = 4.868911e-04
# [Epoch 18/150] train MSE = 4.528191e-04
# [Epoch 19/150] train MSE = 4.211148e-04
# [Epoch 20/150] train MSE = 4.012850e-04
# [Epoch 21/150] train MSE = 3.718127e-04
# [Epoch 22/150] train MSE = 3.476856e-04
# [Epoch 23/150] train MSE = 3.320890e-04
# [Epoch 24/150] train MSE = 3.126624e-04
# [Epoch 25/150] train MSE = 3.226052e-04
# [Epoch 26/150] train MSE = 2.995064e-04
# [Epoch 27/150] train MSE = 2.649212e-04
# [Epoch 28/150] train MSE = 2.455845e-04
# [Epoch 29/150] train MSE = 2.423547e-04
# [Epoch 30/150] train MSE = 2.350579e-04
# [Epoch 31/150] train MSE = 2.290393e-04
# [Epoch 32/150] train MSE = 2.290686e-04
# [Epoch 33/150] train MSE = 2.091883e-04
# [Epoch 34/150] train MSE = 1.960288e-04
# [Epoch 35/150] train MSE = 2.216156e-04
# [Epoch 36/150] train MSE = 1.966872e-04
# [Epoch 37/150] train MSE = 2.065109e-04
# [Epoch 38/150] train MSE = 1.659634e-04
# [Epoch 39/150] train MSE = 1.589198e-04
# [Epoch 40/150] train MSE = 1.632761e-04
# [Epoch 41/150] train MSE = 1.556648e-04
# [Epoch 42/150] train MSE = 1.881127e-04
# [Epoch 43/150] train MSE = 1.713682e-04
# [Epoch 44/150] train MSE = 1.366598e-04
# [Epoch 45/150] train MSE = 1.375713e-04
# [Epoch 46/150] train MSE = 1.705940e-04
# [Epoch 47/150] train MSE = 1.772913e-04
# [Epoch 48/150] train MSE = 1.391250e-04
# [Epoch 49/150] train MSE = 1.253263e-04
# [Epoch 50/150] train MSE = 1.551159e-04
# [Epoch 51/150] train MSE = 1.310492e-04
# [Epoch 52/150] train MSE = 1.360330e-04
# [Epoch 53/150] train MSE = 1.271173e-04
# [Epoch 54/150] train MSE = 1.481073e-04
# [Epoch 55/150] train MSE = 1.537226e-04
# [Epoch 56/150] train MSE = 1.271290e-04
# [Epoch 57/150] train MSE = 1.098756e-04
# [Epoch 58/150] train MSE = 1.082208e-04
# [Epoch 59/150] train MSE = 1.106865e-04
# [Epoch 60/150] train MSE = 1.096478e-04
# [Epoch 61/150] train MSE = 1.769619e-04
# [Epoch 62/150] train MSE = 1.038130e-04
# [Epoch 63/150] train MSE = 1.035194e-04
# [Epoch 64/150] train MSE = 1.197527e-04
# [Epoch 65/150] train MSE = 1.047258e-04
# [Epoch 66/150] train MSE = 1.031733e-04
# [Epoch 67/150] train MSE = 1.747847e-04
# [Epoch 68/150] train MSE = 1.152396e-04
# [Epoch 69/150] train MSE = 1.035607e-04
# [Epoch 70/150] train MSE = 9.517303e-05
# [Epoch 71/150] train MSE = 9.925692e-05
# [Epoch 72/150] train MSE = 1.095924e-04
# [Epoch 73/150] train MSE = 1.073037e-04
# [Epoch 74/150] train MSE = 9.935730e-05
# [Epoch 75/150] train MSE = 1.370853e-04
# [Epoch 76/150] train MSE = 1.050722e-04
# [Epoch 77/150] train MSE = 9.219253e-05
# [Epoch 78/150] train MSE = 1.028351e-04
# [Epoch 79/150] train MSE = 1.021958e-04
# [Epoch 80/150] train MSE = 1.048675e-04
# [Epoch 81/150] train MSE = 9.309499e-05
# [Epoch 82/150] train MSE = 1.318073e-04
# [Epoch 83/150] train MSE = 9.222415e-05
# [Epoch 84/150] train MSE = 1.036083e-04
# [Epoch 85/150] train MSE = 1.137910e-04
# [Epoch 86/150] train MSE = 8.675232e-05
# [Epoch 87/150] train MSE = 1.163224e-04
# [Epoch 88/150] train MSE = 1.043787e-04
# [Epoch 89/150] train MSE = 1.027322e-04
# [Epoch 90/150] train MSE = 1.035148e-04
# [Epoch 91/150] train MSE = 9.363488e-05
# [Epoch 92/150] train MSE = 9.370696e-05
# [Epoch 93/150] train MSE = 8.639660e-05
# [Epoch 94/150] train MSE = 9.803377e-05
# [Epoch 95/150] train MSE = 9.428688e-05
# [Epoch 96/150] train MSE = 1.232265e-04
# [Epoch 97/150] train MSE = 8.871451e-05
# [Epoch 98/150] train MSE = 9.914632e-05
# [Epoch 99/150] train MSE = 9.084486e-05
# [Epoch 100/150] train MSE = 1.115671e-04
# [Epoch 101/150] train MSE = 9.461927e-05
# [Epoch 102/150] train MSE = 8.651826e-05
# [Epoch 103/150] train MSE = 1.098775e-04
# [Epoch 104/150] train MSE = 1.081153e-04
# [Epoch 105/150] train MSE = 1.004408e-04
# [Epoch 106/150] train MSE = 8.718046e-05
# [Epoch 107/150] train MSE = 8.766539e-05
# [Epoch 108/150] train MSE = 8.944448e-05
# [Epoch 109/150] train MSE = 9.846180e-05
# [Epoch 110/150] train MSE = 9.159831e-05
# [Epoch 111/150] train MSE = 1.025693e-04
# [Epoch 112/150] train MSE = 8.944229e-05
# [Epoch 113/150] train MSE = 9.376526e-05
# [Epoch 114/150] train MSE = 9.608880e-05
# [Epoch 115/150] train MSE = 9.464040e-05
# [Epoch 116/150] train MSE = 9.321512e-05
# [Epoch 117/150] train MSE = 8.682132e-05
# [Epoch 118/150] train MSE = 8.501006e-05
# [Epoch 119/150] train MSE = 1.034452e-04
# [Epoch 120/150] train MSE = 8.998078e-05
# [Epoch 121/150] train MSE = 9.703751e-05
# [Epoch 122/150] train MSE = 9.413332e-05
# [Epoch 123/150] train MSE = 8.651330e-05
# [Epoch 124/150] train MSE = 8.782728e-05
# [Epoch 125/150] train MSE = 8.692715e-05
# [Epoch 126/150] train MSE = 9.831878e-05
# [Epoch 127/150] train MSE = 9.087021e-05
# [Epoch 128/150] train MSE = 8.862589e-05
# [Epoch 129/150] train MSE = 8.824188e-05
# [Epoch 130/150] train MSE = 8.615780e-05
# [Epoch 131/150] train MSE = 8.262902e-05
# [Epoch 132/150] train MSE = 9.761422e-05
# [Epoch 133/150] train MSE = 8.578851e-05
# [Epoch 134/150] train MSE = 9.640466e-05
# [Epoch 135/150] train MSE = 8.361969e-05
# [Epoch 136/150] train MSE = 8.707393e-05
# [Epoch 137/150] train MSE = 9.882972e-05
# [Epoch 138/150] train MSE = 8.584956e-05
# [Epoch 139/150] train MSE = 8.789171e-05
# [Epoch 140/150] train MSE = 8.298833e-05
# [Epoch 141/150] train MSE = 8.563077e-05
# [Epoch 142/150] train MSE = 9.317334e-05
# [Epoch 143/150] train MSE = 9.414867e-05
# [Epoch 144/150] train MSE = 8.072606e-05
# [Epoch 145/150] train MSE = 9.237572e-05
# [Epoch 146/150] train MSE = 9.799246e-05
# [Epoch 147/150] train MSE = 8.076349e-05
# [Epoch 148/150] train MSE = 7.888357e-05
# [Epoch 149/150] train MSE = 9.110334e-05
# [Epoch 150/150] train MSE = 8.150446e-05

# %%
test_loss_lin = eval_integrator_B(
    model_lin, data, R=R, k=k, N_test=20_000
)

test_loss_mlp = eval_integrator_B(
    model_mlp, data, R=R, k=k, N_test=20_000
)

print(f"Linear test MSE: {test_loss_lin:.6e}")
print(f"MLP test MSE:    {test_loss_mlp:.6e}")
# Out:
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 8.264618e-05
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 7.990924e-05
# Linear test MSE: 8.264618e-05
# MLP test MSE:    7.990924e-05

# %%
# ===== Save models =====

torch.save(
    {
        "model_type": "linear",
        "state_dict": model_lin.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "linear_integrator_Square.pth",
)

torch.save(
    {
        "model_type": "mlp",
        "state_dict": model_mlp.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "hidden": 128,
            "num_layers": 3,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "small_mlp_integrator_Square.pth",
)

print("Models saved: linear_integrator.pth, mlp_integrator.pth")
# Out:
# Models saved: linear_integrator.pth, mlp_integrator.pth

# %%
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
visualize_B_compare_models(data, model_lin, model_mlp, R=5, k=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 visualize_B_compare_models(data, model_lin, model_mlp, R=5, k=5)
#
# NameError: name 'visualize_B_compare_models' is not defined

# %%
# Cumulative test error comparison
n_points = 10000
step = 500
n_steps = n_points // step

test_ds = BDataset(data, N_samples=n_points, R=R, k=k, seed=456, pregenerate=True)
loader = DataLoader(test_ds, batch_size=step, shuffle=False, num_workers=0, pin_memory=True)

loss_fn = nn.MSELoss()
cum_err_lin, cum_err_mlp = [], []
total_lin, total_mlp = 0.0, 0.0

model_lin.eval()
model_mlp.eval()
with torch.no_grad():
    for i, (feats, target) in enumerate(loader):
        feats = feats.to(device)
        target = target.to(device)
        
        pred_lin = model_lin(feats)
        pred_mlp = model_mlp(feats)
        
        loss_lin = loss_fn(pred_lin, target).item()
        loss_mlp = loss_fn(pred_mlp, target).item()
        
        total_lin += loss_lin * step
        total_mlp += loss_mlp * step
        
        cum_err_lin.append(total_lin )
        cum_err_mlp.append(total_mlp )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Cumulative error
x = np.arange(step, n_points + 1, step)
ax1.semilogy(x, cum_err_lin, 'o-', label='Linear', color='C0', markersize=4)
ax1.semilogy(x, cum_err_mlp, 's-', label='MLP', color='C1', markersize=4)
ax1.set_xlabel('Number of test points')
ax1.set_ylabel('Cumulative MSE')
ax1.set_title('Cumulative Test Error')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Error ratio
ratio = np.array(cum_err_mlp) / np.array(cum_err_lin)
ax2.plot(x, ratio, 'k-', linewidth=2)
ax2.axhline(1, color='r', linestyle='--', alpha=0.5, label='Equal')
ax2.set_xlabel('Number of test points')
ax2.set_ylabel('MLP / Linear')
ax2.set_title('Error Ratio (MLP/Linear)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
