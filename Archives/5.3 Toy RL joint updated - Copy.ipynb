# %% [markdown]
# Libraries

# %%
import numpy as np
from scipy.spatial import KDTree
from scipy.interpolate import RegularGridInterpolator
import gymnasium as gym
from gymnasium import spaces

# %% [markdown]
# PDE and FD reference Parameters

# %%
# PDE 
alpha = 0.05

#   FD reference grid   
nx    = 30
T     = 0.6
x_fd  = np.linspace(0.0, 1.0, nx)
dx    = x_fd[1] - x_fd[0]

dt_cfl = 0.45 * dx**2 / alpha
nt     = max(int(np.ceil(T / dt_cfl)) + 1, 10)
t_fd   = np.linspace(0.0, T, nt)
dt     = t_fd[1] - t_fd[0]

# %% [markdown]
# Analytical diffusion solution

# %%
def u_true(x, t):
    return np.sin(np.pi * x) * np.exp(-alpha * np.pi**2 * t)

# %% [markdown]
# FD For diffusion

# %%
def build_fd_reference():
    u = np.zeros((nx, nt))
    u[:, 0] = u_true(x_fd, 0.0)

    r_diff = alpha * dt / dx**2

    for it in range(nt - 1):
        un = u[:, it]
        u[1:-1, it+1] = (un[1:-1]
                         + r_diff * (un[2:] - 2*un[1:-1] + un[:-2]))
        u[0,   it+1] = 0.0
        u[-1,  it+1] = 0.0

    interp = RegularGridInterpolator(
        (x_fd, t_fd), u, method='linear',
            bounds_error=False, fill_value=None
    )
    return u, interp

# %%
ACTIONS = {
    0: (-1, 1),   # left + forward
    1: ( 0, 1),   # straight forward
    2: ( 1, 1),   # right + forward
}

# %% [markdown]
# __init__

# %%
class VisitedSet:

    def __init__(self, rebuild_every=200):
        self._pts           = []
        self._norm          = []
        self._tree          = None
        self._dirty         = 0
        self._rebuild_every = rebuild_every
        self._idx_set       = set()                    # NEW
        self.rejected_history = []  # (x, t) per rejected move

    def add(self, x, t, u):
        self._idx_set.add((round(x / dx), round(t / dt)))   # NEW
        self._pts.append((x, t, u))
        self._norm.append((x / dx, t / dt))
        self._dirty += 1
        if self._dirty >= self._rebuild_every:
            self._rebuild()

    def _rebuild(self):
        self._tree  = KDTree(np.array(self._norm))
        self._dirty = 0

    def _ensure(self):
        if self._tree is None:
            self._rebuild()
    def contains(self, x, t):                          # NEW
        return (round(x / dx), round(t / dt)) in self._idx_set
    def find_neighbours(self, x_star, t_star, n):
            if len(self._pts) < n:
                return None

            pts_arr  = np.asarray(self._pts)
            norm_arr = np.asarray(self._norm)

            mask = pts_arr[:, 1] < t_star
            if mask.sum() < n:
                return None

            norm_c = norm_arr[mask]
            pts_c  = pts_arr[mask]

            target = np.array([x_star / dx, t_star / dt])
            d2     = np.sum((norm_c - target) ** 2, axis=1)

            idx = np.argpartition(d2, n - 1)[:n]
            idx = idx[np.argsort(d2[idx])]

            return [tuple(row) for row in pts_c[idx]]

    def __len__(self):
            return len(self._pts)

# %% [markdown]
# GFDM Solver

# %%
def solve_weights(dx_i, dt_i):
    h = max(np.max(np.abs(dx_i)), 1e-12)

    A = np.array([
        np.ones(len(dx_i)),
        dx_i / h,
        (0.5 * dx_i**2 + alpha * dt_i) / h**2,
    ])
    b = np.array([1.0, 0.0, 0.0])

    cond = np.linalg.cond(A)
    if cond > 1e4:
        return None, 'cond'

    w = np.linalg.lstsq(A, b, rcond=None)[0]

    if np.max(np.abs(w)) > 3.0 / len(dx_i):
        return None, 'weights'
    if np.min(w) < -1.0:
        return None, 'weights'

    return w, 'ok'

# %% [markdown]
# PDEEnvironment

# %%
class PDEEnvironment(gym.Env):

    def __init__(self, t_star_steps=2):
        super().__init__()

        #   PDE constants  
        self.alpha = alpha

        #G6id variables  
        self.nx   = nx
        self.nt   = nt
        self.x_fd = x_fd
        self.t_fd = t_fd
        self.dx   = dx
        self.dt   = dt
        self.T    = T
        self.last_gfdm_rejected = None  # Track the last GFDN rejection reason

        # ── Target point (z*) ───────────────────────────────────────────────────
        self.x_star = self.x_fd[self.nx // 2]
        self.t_star = t_star_steps * dt

        # ── RL parameters ───────────────────────────────────────────────────────
        self.K_max  = 500
        self.lam    = 0.002
        self.Kx     = 1
        self.Kt     = 1
        self.beta = 100.0

        # ── GFDM neighbours ─────────────────────────────────────────────────────
        self.n_neighbours = 5

        # ── Termination tolerance ───────────────────────────────────────────────
        self.eps_x = 0.5 * dx
        self.eps_t = 0.5 * dt

        # ── Walker initial positions ─────────────────────────────────────────────
        self.N = 30

        mid    = self.nx // 2
        margin = 0
        half_n = self.N // 2
        step   = (mid - margin) / half_n if half_n > 0 else 0

        offsets = [0]
        k = 1
        while len(offsets) < self.N:
            offsets.append(k * step)
            if len(offsets) < self.N:
                offsets.append(-k * step)
            k += 1

        init_idx = np.clip(np.round(np.array(offsets[:self.N]) + mid).astype(int), margin, self.nx - 1 - margin)
        self.walker_init_x = self.x_fd[init_idx]

        # ── FD reference built once ──────────────────────────────────────────────
        _, self.fd_interp = build_fd_reference()

        # ── Episode state (reset() fills these) ──────────────────────────────────
        self.visited     = None
        self.walker_x    = None
        self.walker_t    = None
        self.walker_u    = None
        self.step_count  = 0
        self.stencil_log = {}

        # ── Gym spaces ───────────────────────────────────────────────────────────
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(3 * self.N + 2,), dtype=np.float32
        )
        self.action_space = spaces.Discrete(self.N * 3)


    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.visited     = VisitedSet()
        self.stencil_log = {}

        # ── Seed with IC ─────────────────────────────────────────────────────────
        for ix in range(self.nx):
            x = self.x_fd[ix]
            self.visited.add(x, 0.0, u_true(x, 0.0))

        # ── Seed with BCs ────────────────────────────────────────────────────────
        for it in range(1, self.nt):
            self.visited.add(0.0, self.t_fd[it], 0.0)
            self.visited.add(1.0, self.t_fd[it], 0.0)

        # ── Place walkers at t=0 ─────────────────────────────────────────────────
        self.walker_x = np.array(self.walker_init_x, dtype=float)
        self.walker_t = np.zeros(self.N)
        self.walker_u = np.array([u_true(x, 0.0) for x in self.walker_x])
        self.step_count = 0
        # remove current_walker reset
        self.rejected_history = []
        self.gfdm_rejected_set = set()
        return self._build_obs(), {}


    def _build_obs(self):
        return np.array([
            *self.walker_x,
            *self.walker_t,
            *self.walker_u,
            self.x_star,
            self.t_star
        ], dtype=np.float32)

    def _gfdm_solve(self, x_star, t_star):
        nb = self.visited.find_neighbours(x_star, t_star, self.n_neighbours)
        if nb is None:
            return None, False, None, 'no_nb'

        nb   = np.array(nb)
        dx_i = nb[:, 0] - x_star
        dt_i = nb[:, 1] - t_star

        if not (np.min(dx_i) < 0 < np.max(dx_i)):
            return None, False, None, 'geometry'

        w, reason = solve_weights(dx_i, dt_i)
        if w is None:
            return None, False, None, reason

        u_hat = float(w @ nb[:, 2])
        if abs(u_hat) > 1.1:
            return None, False, None, 'bounds_u'
        return u_hat, True, nb[:, :2], 'ok'
    def step(self, action):

            self.step_count += 1
            done   = False
            reward = 0.0

            i              = int(action) // 3
            j              = int(action) % 3
            dx_idx, dt_idx = ACTIONS[j]
            dx = dx_idx * self.dx
            dt = dt_idx * self.dt

            info = {'walker': i, 'accepted': False, 'rejected': None, 'reached': False}

            x_new = self.walker_x[i] + dx
            t_new = self.walker_t[i] + dt

            if not (0.0 <= x_new <= 1.0 and 0.0 < t_new <= self.T):
                info['rejected'] = 'bounds'

            elif self.visited.contains(x_new, t_new):
                info['rejected'] = 'collision'

            else:
                u_hat, success, nb_coords, reason = self._gfdm_solve(x_new, t_new)
                if not success:
                    info['rejected'] = reason
                    self.gfdm_rejected_set.add(int(action))
                    
                else:
                    self.gfdm_rejected_set.clear()
                    self.visited.add(x_new, t_new, u_hat)
                    self.walker_x[i] = x_new
                    self.walker_t[i] = t_new
                    self.walker_u[i] = u_hat
                    self.stencil_log[(round(x_new, 8), round(t_new, 8))] = nb_coords
                    info['accepted'] = True

                    if (abs(x_new - self.x_star) < self.eps_x and
                        abs(t_new - self.t_star) < self.eps_t):
                        done = True
                        info['reached'] = True

            # ── track rejected positions ──────────────────────────────────────────
            if not info['accepted']:
                self.rejected_history.append((x_new, t_new, info['rejected']))
            # ─────────────────────────────────────────────────────────────────────

            if done:
                u_pred, _, _, _ = self._gfdm_solve(self.x_star, self.t_star)
                u_ref           = u_true(self.x_star, self.t_star)

                if u_pred is None:
                    reward        = -1.0
                    info['error'] = None
                else:
                    reward = -(self.beta * abs(u_pred - u_ref) + self.lam * self.step_count)
                    info['u_pred'] = u_pred
                    info['u_ref']  = u_ref
                    info['error']  = abs(u_pred - u_ref)
                    info['k_term'] = self.step_count

            elif self.step_count >= self.K_max:
                done = True
                reward = -1.0 - self.lam * self.step_count
                info['timeout'] = True

            return self._build_obs(), reward, done, False, info
    def action_masks(self) -> np.ndarray:
        mask = np.ones(self.N * 3, dtype=bool)
        for i in range(self.N):
            for j in range(3):
                dx_idx, dt_idx = ACTIONS[j]
                x_new = self.walker_x[i] + dx_idx * self.dx
                t_new = self.walker_t[i] + dt_idx * self.dt
                if not (0.0 <= x_new <= 1.0 and
                        0.0 < t_new <= self.T and
                        not self.visited.contains(x_new, t_new)):
                    mask[i * 3 + j] = False
        for a in self.gfdm_rejected_set:
            mask[a] = False
        if not mask.any():
            mask[:] = True
        return mask

# %%
env      = PDEEnvironment()
state, _ = env.reset()

trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}

done           = False
total_accepted = 0
total_rejected = {}

while not done:
    action = env.action_space.sample()                         # Discrete(60) sample
    state, reward, done, _, info = env.step(action)

    total_accepted += int(info['accepted'])
    if info['rejected']:
        reason = info['rejected']
        total_rejected[reason] = total_rejected.get(reason, 0) + 1

    if info['accepted']:
        i = info['walker']
        trajectories[i].append((env.walker_x[i], env.walker_t[i]))

visited_log = [(x, t) for (x, t, _) in env.visited._pts
               if t > 0.0 and 0.0 < x < 1.0]

print(f"Steps:          {env.step_count}")
print(f"Reward:         {reward:.6f}")
print(f"Reached:        {info.get('reached', False)}")
print(f"Timeout:        {info.get('timeout', False)}")
print(f"Total accepted: {total_accepted}")
print(f"Total rejected: {sum(total_rejected.values())}")
print("Rejection reasons:")
for reason, count in sorted(total_rejected.items(), key=lambda kv: -kv[1]):
    print(f"  {reason:10s}: {count}")

# walker distribution check — tells you if one walker is dominating
walker_counts = {}
for i, traj in trajectories.items():
    walker_counts[i] = len(traj) - 1  # subtract starting position
print("\nAccepted moves per walker:")
for i, count in sorted(walker_counts.items()):
    print(f"  Walker {i:d}: {count}")

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))

vx = [p[0] for p in visited_log]
vt = [p[1] for p in visited_log]
ax.scatter(vx, vt, s=4, color='lightgray', zorder=1, label='Visited')

colors = plt.cm.viridis(np.linspace(0, 1, env.N))
for i, traj in trajectories.items():
    xs = [p[0] for p in traj]
    ts = [p[1] for p in traj]
    ax.plot(xs, ts, '-', linewidth=1.5, zorder=2)
    ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
    ax.scatter(xs[0], ts[0], s=80, color=colors[i],
               marker='^', zorder=4, label=f'Walker {i}')

ax.scatter(env.x_star, env.t_star, s=150, color='red',
           marker='*', zorder=5, label='z*')

ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_title('Walker trajectories in x-t domain')
ax.set_xlim(0, 1)
ax.set_ylim(0, env.t_star * 2)
plt.tight_layout()
plt.show()
# Out:
# Steps:          500
# Reward:         -1.500000
# Reached:        False
# Timeout:        True
# Total accepted: 185
# Total rejected: 315
# Rejection reasons:
#   collision : 211
#   geometry  : 52
#   weights   : 47
#   bounds    : 5
#
# Accepted moves per walker:
#   Walker 0: 13
#   Walker 1: 10
#   Walker 2: 4
#   Walker 3: 8
#   Walker 4: 1
#   Walker 5: 0
#   Walker 6: 9
#   Walker 7: 10
#   Walker 8: 6
#   Walker 9: 2
#   Walker 10: 4
#   Walker 11: 1
#   Walker 12: 11
#   Walker 13: 7
#   Walker 14: 5
#   Walker 15: 5
#   Walker 16: 8
#   Walker 17: 9
#   Walker 18: 3
#   Walker 19: 0
#   Walker 20: 11
#   Walker 21: 7
#   Walker 22: 1
#   Walker 23: 7
#   Walker 24: 12
#   Walker 25: 2
#   Walker 26: 9
#   Walker 27: 9
#   Walker 28: 11
#   Walker 29: 0

# %%
def plot_trajectories(model, t_star_steps, save=True, timestep=None,
                      img_dir=".", label=None):
    env = PDEEnvironment(t_star_steps=t_star_steps)
    obs, _ = env.reset()
    trajectories = {i: [(env.walker_x[i], env.walker_t[i])] for i in range(env.N)}
    done = False

    while not done:
        action, _ = model.predict(obs, deterministic=True, action_masks=env.action_masks())
        obs, reward, done, _, info = env.step(action)
        if info['accepted']:
            i = info['walker']
            trajectories[i].append((env.walker_x[i], env.walker_t[i]))

    visited_log = [(x, t) for (x, t, _) in env.visited._pts]
    fig, ax = plt.subplots(figsize=(8, 6))

    vx = [p[0] for p in visited_log]
    vt = [p[1] for p in visited_log]
    ax.scatter(vx, vt, s=4, color='lightgray', zorder=1)

    # ── Rejected positions ───────────────────────────────────────────────────
    rej_colors = {
        'bounds':    'blue',
        'collision': 'orange',
        'cond':      'purple',
        'weights':   'brown',
        'geometry':  'red',
        None:        'gray',
    }
    if env.rejected_history:
        from collections import defaultdict
        by_reason = defaultdict(list)
        for (rx, rt, reason) in env.rejected_history:
            by_reason[reason].append((rx, rt))
        for reason, pts in by_reason.items():
            ax.scatter([p[0] for p in pts], [p[1] for p in pts],
                       s=6, alpha=0.08, linewidths=0, zorder=1,
                       color=rej_colors.get(reason, 'gray'),
                       label=f'rej:{reason} ({len(pts)})')
    # ─────────────────────────────────────────────────────────────────────────

    colors = plt.cm.viridis(np.linspace(0, 1, env.N))
    for i, traj in trajectories.items():
        xs = [p[0] for p in traj]
        ts = [p[1] for p in traj]
        ax.plot(xs, ts, '-', linewidth=1.5, color=colors[i], zorder=2)
        ax.scatter(xs, ts, s=30, color=colors[i], zorder=3)
        ax.scatter(xs[0], ts[0], s=80, color=colors[i], marker='^', zorder=4)

    reached = info.get('reached', False)
    outcome = 'reached' if reached else 'timeout'

    # ── Stencil at z* ────────────────────────────────────────────────────────
    if reached:
        _, success, nb_coords, _ = env._gfdm_solve(env.x_star, env.t_star)
        if success and nb_coords is not None:
            for (nx_, nt_) in nb_coords:
                ax.plot([env.x_star, nx_], [env.t_star, nt_],
                        '--', color='red', linewidth=0.8,
                        alpha=0.7, zorder=5)
            ax.scatter(nb_coords[:, 0], nb_coords[:, 1],
                       s=40, color='red', zorder=6, alpha=0.7)

    ax.scatter(env.x_star, env.t_star, s=150, color='red', marker='*', zorder=7)
    ax.set_xlabel('x')
    ax.set_ylabel('t')

    title = f't_star={t_star_steps}·dt  |  {outcome}'
    if timestep is not None:
        title += f'  |  step {timestep:,}'
    ax.set_title(title)
    ax.set_xlim(0, 1)
    ax.set_ylim(0, env.t_star * 2)

    if env.rejected_history:
        ax.legend(fontsize=6, loc='upper left', markerscale=2)

    plt.tight_layout()

    if save:
        if label is not None:
            fname = f'traj_t{t_star_steps}dt_{label}_{outcome}.png'
        elif timestep is not None:
            fname = f'traj_t{t_star_steps}dt_{timestep//1000:05d}k_{outcome}.png'
        else:
            fname = f'traj_t{t_star_steps}dt_{outcome}.png'
        fig.savefig(os.path.join(img_dir, fname), dpi=120)

    plt.close(fig)

# %%
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker

class ReachedRateCallback(BaseCallback):
    def __init__(self, t_star_steps=None, n_eval=50, eval_freq=500, verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.n_eval       = n_eval
        self.eval_freq    = eval_freq
        self.buf          = []
        self.kterm_buf    = []
        self.err_buf      = []

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached'):
                self.buf.append(1)
                k = info.get('k_term')
                e = info.get('error')
                if k is not None and e is not None:
                    self.kterm_buf.append(k)
                    self.err_buf.append(e)
            elif info.get('timeout'):
                self.buf.append(0)
        if self.buf:
            self.logger.record('rollout/reached_rate',
                               sum(self.buf[-100:]) / len(self.buf[-100:]))
        if self.kterm_buf:
            self.logger.record('rollout/mean_kterm_on_reach',
                               np.mean(self.kterm_buf[-100:]))
            self.logger.record('rollout/mean_error_on_reach',
                               np.mean(self.err_buf[-100:]))
        return True
    
class CurriculumGateCallback(BaseCallback):
    def __init__(self, target_rate=0.95, patience=200, verbose=0):
        super().__init__(verbose)
        self.target_rate = target_rate
        self.patience    = patience
        self.buf         = []
        self.streak      = 0

    def _on_step(self) -> bool:
        for info in self.locals['infos']:
            if info.get('reached') or info.get('timeout'):
                self.buf.append(int(info.get('reached', False)))
        if len(self.buf) >= 20:
            rate = sum(self.buf[-20:]) / 20
            self.streak = self.streak + 1 if rate >= self.target_rate else 0
        return self.streak < self.patience

# %%
import torch
print(torch.__version__)
# Out:
# 2.12.1+cpu

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, plot_freq=50_000, img_dir=".", verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, save=True,
                              timestep=self.num_timesteps, img_dir=self.img_dir)
        return True


def make_env(t_star_steps):
    def _init():
        env = PDEEnvironment(t_star_steps=t_star_steps)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

# %%
# %matplotlib inline

# %%
class PlotCallback(BaseCallback):
    def __init__(self, t_star_steps, plot_freq=50_000, img_dir=".", verbose=0):
        super().__init__(verbose)
        self.t_star_steps = t_star_steps
        self.plot_freq    = plot_freq
        self.last_plot_at = 0
        self.img_dir      = img_dir

    def _on_step(self) -> bool:
        if self.num_timesteps - self.last_plot_at >= self.plot_freq:
            self.last_plot_at = self.num_timesteps
            plot_trajectories(self.model, self.t_star_steps, save=True,
                              timestep=self.num_timesteps, img_dir=self.img_dir)
        return True


def make_env(t_star_steps):
    def _init():
        env = PDEEnvironment(t_star_steps=t_star_steps)
        env = ActionMasker(env, lambda e: e.action_masks())
        return Monitor(env)
    return _init

import os

# ── Run configuration ────────────────────────────────────────────────────────
curriculum = [15]
lam        = 0.002
beta       = 100
K_max      = 500
n_envs       = 15
n_steps      = 2048//n_envs

# ── Run directory ────────────────────────────────────────────────────────────
stages_str = "-".join(str(s) for s in curriculum)
run_name   = f"curriculum_t{stages_str}_lam{lam}_beta{beta}_K{K_max}"
run_dir    = os.path.join("runs30", run_name)
img_dir    = os.path.join(run_dir, "images")
ckpt_dir   = os.path.join(run_dir, "checkpoints")

os.makedirs(img_dir,  exist_ok=True)
os.makedirs(ckpt_dir, exist_ok=True)

print(f"Run directory: {run_dir}")
# ── Model ────────────────────────────────────────────────────────────────────
for seed in [1]:

    seed_run_name = f"{run_name}_seed{seed}"
    seed_run_dir  = os.path.join("runs30", seed_run_name)
    seed_img_dir  = os.path.join(seed_run_dir, "images")
    seed_ckpt_dir = os.path.join(seed_run_dir, "checkpoints")

    os.makedirs(seed_img_dir,  exist_ok=True)
    os.makedirs(seed_ckpt_dir, exist_ok=True)

    print(f"\n{'#'*50}")
    print(f"SEED {seed}")
    print(f"{'#'*50}")

    vec_env = SubprocVecEnv([make_env(curriculum[0]) for _ in range(n_envs)])
    model = MaskablePPO(
        "MlpPolicy",
        vec_env,
        verbose=1,
        seed=seed,
        tensorboard_log=os.path.join(seed_run_dir, "logs"),
        learning_rate=5e-5,
        clip_range=0.1,
        n_steps=n_steps,
        batch_size=60,
        gamma=1.0,
        ent_coef=0.01,
        device="cpu",
    )

    # ── Curriculum ────────────────────────────────────────────────────────────
    timesteps_per_stage = {
        15: 4_000_000,   # more budget since it's harder
    }

    for t_star_steps in curriculum:
        print(f"\n{'='*50}")
        print(f"Stage: t_star = {t_star_steps}·dt = {t_star_steps * dt:.4f}  |  "
              f"budget: {t_star_steps * 1_500_000 // 1000}k steps")
        print(f"{'='*50}")

        vec_env = SubprocVecEnv([make_env(t_star_steps) for _ in range(n_envs)])
        model.set_env(vec_env)

        model.learn(
            total_timesteps=timesteps_per_stage[t_star_steps],
            reset_num_timesteps=False,
            tb_log_name=seed_run_name,
            log_interval=10,
            callback=[
                ReachedRateCallback(t_star_steps=t_star_steps, n_eval=50, eval_freq=500),
                PlotCallback(t_star_steps, plot_freq=100_000, img_dir=seed_img_dir),
                CheckpointCallback(
                    save_freq=100_000,
                    save_path=os.path.join(seed_ckpt_dir, f"tstar{t_star_steps}"),
                    name_prefix=f"tstar{t_star_steps}"
                ),
            ],
        )

        model.save(os.path.join(seed_ckpt_dir, f"tstar{t_star_steps}_final"))
        plot_trajectories(model, t_star_steps, save=True,
                          timestep=None, img_dir=seed_img_dir, label="final")
# Out:
# Run directory: runs30\curriculum_t15_lam0.001_beta100_K500
#
# ##################################################
# SEED 1
# ##################################################
# Using cpu device
#
# ==================================================
# Stage: t_star = 15·dt = 0.1579  |  budget: 22500k steps
# ==================================================
# Logging to runs30\curriculum_t15_lam0.001_beta100_K500_seed1\logs\curriculum_t15_lam0.001_beta100_K500_seed1_0
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 448         |
# |    ep_rew_mean          | -1.09       |
# |    mean_error_on_reach  | 0.000152    |
# |    mean_kterm_on_reach  | 359         |
# |    reached_rate         | 0.375       |
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.003860937 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0352     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 458         |
# |    ep_rew_mean          | -1.15       |
# |    mean_error_on_reach  | 0.000166    |
# |    mean_kterm_on_reach  | 367         |
# |    reached_rate         | 0.316       |
# | time/                   |             |
# |    fps                  | 1935        |
# |    iterations           | 20          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 40800       |
# | train/                  |             |
# |    approx_kl            | 0.003835926 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.041      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00996    |
# |    value_loss           | 0.00882     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 463          |
# |    ep_rew_mean          | -1.2         |
# |    mean_error_on_reach  | 0.000176     |
# |    mean_kterm_on_reach  | 369          |
# |    reached_rate         | 0.28         |
# | time/                   |              |
# |    fps                  | 1933         |
# |    iterations           | 30           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 61200        |
# | train/                  |              |
# |    approx_kl            | 0.0043576923 |
# |    clip_fraction        | 0.184        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.38        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0432      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00773      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | -1.11       |
# |    mean_error_on_reach  | 0.000176    |
# |    mean_kterm_on_reach  | 367         |
# |    reached_rate         | 0.35        |
# | time/                   |             |
# |    fps                  | 1901        |
# |    iterations           | 40          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 81600       |
# | train/                  |             |
# |    approx_kl            | 0.003625928 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0563     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00366     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 445          |
# |    ep_rew_mean          | -1.08        |
# |    mean_error_on_reach  | 0.000162     |
# |    mean_kterm_on_reach  | 361          |
# |    reached_rate         | 0.37         |
# | time/                   |              |
# |    fps                  | 1874         |
# |    iterations           | 50           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 102000       |
# | train/                  |              |
# |    approx_kl            | 0.0030809161 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0467      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00845     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | -1.03        |
# |    mean_error_on_reach  | 0.000151     |
# |    mean_kterm_on_reach  | 359          |
# |    reached_rate         | 0.41         |
# | time/                   |              |
# |    fps                  | 1897         |
# |    iterations           | 60           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 122400       |
# | train/                  |              |
# |    approx_kl            | 0.0035904262 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0525      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0076      |
# |    value_loss           | 0.00335      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 434          |
# |    ep_rew_mean          | -0.989       |
# |    mean_error_on_reach  | 0.00014      |
# |    mean_kterm_on_reach  | 361          |
# |    reached_rate         | 0.45         |
# | time/                   |              |
# |    fps                  | 1898         |
# |    iterations           | 70           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 142800       |
# | train/                  |              |
# |    approx_kl            | 0.0018892852 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0402      |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 0.00197      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 433          |
# |    ep_rew_mean          | -0.988       |
# |    mean_error_on_reach  | 0.000127     |
# |    mean_kterm_on_reach  | 353          |
# |    reached_rate         | 0.45         |
# | time/                   |              |
# |    fps                  | 1912         |
# |    iterations           | 80           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 163200       |
# | train/                  |              |
# |    approx_kl            | 0.0034668655 |
# |    clip_fraction        | 0.0902       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0329      |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.00759     |
# |    value_loss           | 0.00174      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | -0.92        |
# |    mean_error_on_reach  | 0.000118     |
# |    mean_kterm_on_reach  | 329          |
# |    reached_rate         | 0.49         |
# | time/                   |              |
# |    fps                  | 1927         |
# |    iterations           | 90           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 183600       |
# | train/                  |              |
# |    approx_kl            | 0.0027332793 |
# |    clip_fraction        | 0.078        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0212      |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00628     |
# |    value_loss           | 0.00432      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 384          |
# |    ep_rew_mean          | -0.8         |
# |    mean_error_on_reach  | 0.00011      |
# |    mean_kterm_on_reach  | 322          |
# |    reached_rate         | 0.59         |
# | time/                   |              |
# |    fps                  | 1925         |
# |    iterations           | 100          |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 204000       |
# | train/                  |              |
# |    approx_kl            | 0.0023698956 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0172      |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 375          |
# |    ep_rew_mean          | -0.745       |
# |    mean_error_on_reach  | 0.000107     |
# |    mean_kterm_on_reach  | 302          |
# |    reached_rate         | 0.65         |
# | time/                   |              |
# |    fps                  | 1935         |
# |    iterations           | 110          |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 224400       |
# | train/                  |              |
# |    approx_kl            | 0.0029099414 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0251      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 0.00126      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | -0.812       |
# |    mean_error_on_reach  | 0.000105     |
# |    mean_kterm_on_reach  | 304          |
# |    reached_rate         | 0.6          |
# | time/                   |              |
# |    fps                  | 1949         |
# |    iterations           | 120          |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 244800       |
# | train/                  |              |
# |    approx_kl            | 0.0027946557 |
# |    clip_fraction        | 0.0909       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0417      |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.00731     |
# |    value_loss           | 0.000927     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | -0.882       |
# |    mean_error_on_reach  | 0.000103     |
# |    mean_kterm_on_reach  | 311          |
# |    reached_rate         | 0.54         |
# | time/                   |              |
# |    fps                  | 1958         |
# |    iterations           | 130          |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 265200       |
# | train/                  |              |
# |    approx_kl            | 0.0020338425 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0313      |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 0.00132      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 421          |
# |    ep_rew_mean          | -0.953       |
# |    mean_error_on_reach  | 0.000119     |
# |    mean_kterm_on_reach  | 314          |
# |    reached_rate         | 0.48         |
# | time/                   |              |
# |    fps                  | 1962         |
# |    iterations           | 140          |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 285600       |
# | train/                  |              |
# |    approx_kl            | 0.0025497582 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2           |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0323      |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 422          |
# |    ep_rew_mean          | -0.936       |
# |    mean_error_on_reach  | 0.000123     |
# |    mean_kterm_on_reach  | 331          |
# |    reached_rate         | 0.5          |
# | time/                   |              |
# |    fps                  | 1959         |
# |    iterations           | 150          |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 306000       |
# | train/                  |              |
# |    approx_kl            | 0.0024976956 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0141      |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 0.00532      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 402          |
# |    ep_rew_mean          | -0.83        |
# |    mean_error_on_reach  | 0.000126     |
# |    mean_kterm_on_reach  | 333          |
# |    reached_rate         | 0.59         |
# | time/                   |              |
# |    fps                  | 1965         |
# |    iterations           | 160          |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 326400       |
# | train/                  |              |
# |    approx_kl            | 0.0013851476 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0318      |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 0.00486      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | -0.922      |
# |    mean_error_on_reach  | 0.000127    |
# |    mean_kterm_on_reach  | 331         |
# |    reached_rate         | 0.5         |
# | time/                   |             |
# |    fps                  | 1973        |
# |    iterations           | 170         |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 346800      |
# | train/                  |             |
# |    approx_kl            | 0.002028789 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0209     |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 405          |
# |    ep_rew_mean          | -0.931       |
# |    mean_error_on_reach  | 0.000124     |
# |    mean_kterm_on_reach  | 313          |
# |    reached_rate         | 0.48         |
# | time/                   |              |
# |    fps                  | 1979         |
# |    iterations           | 180          |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 367200       |
# | train/                  |              |
# |    approx_kl            | 0.0018653946 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0283      |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 0.00752      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 395          |
# |    ep_rew_mean          | -0.901       |
# |    mean_error_on_reach  | 0.00012      |
# |    mean_kterm_on_reach  | 304          |
# |    reached_rate         | 0.5          |
# | time/                   |              |
# |    fps                  | 1975         |
# |    iterations           | 190          |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 387600       |
# | train/                  |              |
# |    approx_kl            | 0.0028577275 |
# |    clip_fraction        | 0.099        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00722     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00615     |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 408          |
# |    ep_rew_mean          | -0.974       |
# |    mean_error_on_reach  | 0.000125     |
# |    mean_kterm_on_reach  | 302          |
# |    reached_rate         | 0.44         |
# | time/                   |              |
# |    fps                  | 1944         |
# |    iterations           | 200          |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 408000       |
# | train/                  |              |
# |    approx_kl            | 0.0028267745 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0291      |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 418          |
# |    ep_rew_mean          | -0.984       |
# |    mean_error_on_reach  | 0.000137     |
# |    mean_kterm_on_reach  | 298          |
# |    reached_rate         | 0.44         |
# | time/                   |              |
# |    fps                  | 1949         |
# |    iterations           | 210          |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 428400       |
# | train/                  |              |
# |    approx_kl            | 0.0021197256 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0228      |
# |    n_updates            | 2090         |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 0.00883      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 398          |
# |    ep_rew_mean          | -0.885       |
# |    mean_error_on_reach  | 0.000142     |
# |    mean_kterm_on_reach  | 300          |
# |    reached_rate         | 0.52         |
# | time/                   |              |
# |    fps                  | 1954         |
# |    iterations           | 220          |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 448800       |
# | train/                  |              |
# |    approx_kl            | 0.0017894944 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0231      |
# |    n_updates            | 2190         |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 0.00347      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 381          |
# |    ep_rew_mean          | -0.82        |
# |    mean_error_on_reach  | 0.000153     |
# |    mean_kterm_on_reach  | 300          |
# |    reached_rate         | 0.57         |
# | time/                   |              |
# |    fps                  | 1958         |
# |    iterations           | 230          |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 469200       |
# | train/                  |              |
# |    approx_kl            | 0.0030007616 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0326      |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 0.00424      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 394          |
# |    ep_rew_mean          | -0.903       |
# |    mean_error_on_reach  | 0.000163     |
# |    mean_kterm_on_reach  | 296          |
# |    reached_rate         | 0.5          |
# | time/                   |              |
# |    fps                  | 1963         |
# |    iterations           | 240          |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 489600       |
# | train/                  |              |
# |    approx_kl            | 0.0030128418 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0122      |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 0.00413      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | -0.973      |
# |    mean_error_on_reach  | 0.000161    |
# |    mean_kterm_on_reach  | 290         |
# |    reached_rate         | 0.44        |
# | time/                   |             |
# |    fps                  | 1961        |
# |    iterations           | 250         |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 510000      |
# | train/                  |             |
# |    approx_kl            | 0.002763124 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0271     |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | -0.919       |
# |    mean_error_on_reach  | 0.000166     |
# |    mean_kterm_on_reach  | 283          |
# |    reached_rate         | 0.48         |
# | time/                   |              |
# |    fps                  | 1967         |
# |    iterations           | 260          |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 530400       |
# | train/                  |              |
# |    approx_kl            | 0.0021291475 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00664     |
# |    n_updates            | 2590         |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 0.00481      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | -0.883       |
# |    mean_error_on_reach  | 0.000155     |
# |    mean_kterm_on_reach  | 281          |
# |    reached_rate         | 0.51         |
# | time/                   |              |
# |    fps                  | 1973         |
# |    iterations           | 270          |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 550800       |
# | train/                  |              |
# |    approx_kl            | 0.0025823358 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0308      |
# |    n_updates            | 2690         |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 0.00263      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 405         |
# |    ep_rew_mean          | -0.98       |
# |    mean_error_on_reach  | 0.000142    |
# |    mean_kterm_on_reach  | 279         |
# |    reached_rate         | 0.43        |
# | time/                   |             |
# |    fps                  | 1976        |
# |    iterations           | 280         |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 571200      |
# | train/                  |             |
# |    approx_kl            | 0.003329461 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0245     |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 0.00367     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 395          |
# |    ep_rew_mean          | -0.949       |
# |    mean_error_on_reach  | 0.00012      |
# |    mean_kterm_on_reach  | 270          |
# |    reached_rate         | 0.45         |
# | time/                   |              |
# |    fps                  | 1980         |
# |    iterations           | 290          |
# |    time_elapsed         | 298          |
# |    total_timesteps      | 591600       |
# | train/                  |              |
# |    approx_kl            | 0.0020040208 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.014       |
# |    n_updates            | 2890         |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 0.00429      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -0.983       |
# |    mean_error_on_reach  | 0.000108     |
# |    mean_kterm_on_reach  | 267          |
# |    reached_rate         | 0.42         |
# | time/                   |              |
# |    fps                  | 1978         |
# |    iterations           | 300          |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 612000       |
# | train/                  |              |
# |    approx_kl            | 0.0017356686 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0333      |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 0.00281      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.03        |
# |    mean_error_on_reach  | 9.91e-05     |
# |    mean_kterm_on_reach  | 257          |
# |    reached_rate         | 0.37         |
# | time/                   |              |
# |    fps                  | 1981         |
# |    iterations           | 310          |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 632400       |
# | train/                  |              |
# |    approx_kl            | 0.0020108987 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0151      |
# |    n_updates            | 3090         |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 0.00362      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 379          |
# |    ep_rew_mean          | -0.952       |
# |    mean_error_on_reach  | 8.24e-05     |
# |    mean_kterm_on_reach  | 235          |
# |    reached_rate         | 0.43         |
# | time/                   |              |
# |    fps                  | 1984         |
# |    iterations           | 320          |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 652800       |
# | train/                  |              |
# |    approx_kl            | 0.0019088899 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0155      |
# |    n_updates            | 3190         |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 0.00392      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 356          |
# |    ep_rew_mean          | -0.85        |
# |    mean_error_on_reach  | 7.64e-05     |
# |    mean_kterm_on_reach  | 223          |
# |    reached_rate         | 0.51         |
# | time/                   |              |
# |    fps                  | 1987         |
# |    iterations           | 330          |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 673200       |
# | train/                  |              |
# |    approx_kl            | 0.0015327677 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0083      |
# |    n_updates            | 3290         |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 0.00455      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | -0.815       |
# |    mean_error_on_reach  | 7.44e-05     |
# |    mean_kterm_on_reach  | 220          |
# |    reached_rate         | 0.54         |
# | time/                   |              |
# |    fps                  | 1990         |
# |    iterations           | 340          |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 693600       |
# | train/                  |              |
# |    approx_kl            | 0.0016030751 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0201      |
# |    n_updates            | 3390         |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 0.00801      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | -0.822       |
# |    mean_error_on_reach  | 7.26e-05     |
# |    mean_kterm_on_reach  | 226          |
# |    reached_rate         | 0.54         |
# | time/                   |              |
# |    fps                  | 1988         |
# |    iterations           | 350          |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 714000       |
# | train/                  |              |
# |    approx_kl            | 0.0021696342 |
# |    clip_fraction        | 0.0646       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0251      |
# |    n_updates            | 3490         |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 0.00624      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | -0.906       |
# |    mean_error_on_reach  | 7.76e-05     |
# |    mean_kterm_on_reach  | 239          |
# |    reached_rate         | 0.48         |
# | time/                   |              |
# |    fps                  | 1989         |
# |    iterations           | 360          |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 734400       |
# | train/                  |              |
# |    approx_kl            | 0.0020211856 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.025       |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.00685     |
# |    value_loss           | 0.00177      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | -0.926       |
# |    mean_error_on_reach  | 7.44e-05     |
# |    mean_kterm_on_reach  | 244          |
# |    reached_rate         | 0.46         |
# | time/                   |              |
# |    fps                  | 1992         |
# |    iterations           | 370          |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 754800       |
# | train/                  |              |
# |    approx_kl            | 0.0010251391 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.015       |
# |    n_updates            | 3690         |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 0.00509      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 353          |
# |    ep_rew_mean          | -0.806       |
# |    mean_error_on_reach  | 7.25e-05     |
# |    mean_kterm_on_reach  | 243          |
# |    reached_rate         | 0.55         |
# | time/                   |              |
# |    fps                  | 1997         |
# |    iterations           | 380          |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 775200       |
# | train/                  |              |
# |    approx_kl            | 0.0013099769 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0133      |
# |    n_updates            | 3790         |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 0.00994      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | -0.721       |
# |    mean_error_on_reach  | 7.29e-05     |
# |    mean_kterm_on_reach  | 232          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 2000         |
# |    iterations           | 390          |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 795600       |
# | train/                  |              |
# |    approx_kl            | 0.0016234613 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0229      |
# |    n_updates            | 3890         |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | -0.714       |
# |    mean_error_on_reach  | 8.2e-05      |
# |    mean_kterm_on_reach  | 231          |
# |    reached_rate         | 0.62         |
# | time/                   |              |
# |    fps                  | 2000         |
# |    iterations           | 400          |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 816000       |
# | train/                  |              |
# |    approx_kl            | 0.0015229424 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0171      |
# |    n_updates            | 3990         |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 0.0046       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | -0.764       |
# |    mean_error_on_reach  | 8.78e-05     |
# |    mean_kterm_on_reach  | 227          |
# |    reached_rate         | 0.58         |
# | time/                   |              |
# |    fps                  | 2002         |
# |    iterations           | 410          |
# |    time_elapsed         | 417          |
# |    total_timesteps      | 836400       |
# | train/                  |              |
# |    approx_kl            | 0.0016140488 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0192      |
# |    n_updates            | 4090         |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 0.00267      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 357          |
# |    ep_rew_mean          | -0.833       |
# |    mean_error_on_reach  | 0.000103     |
# |    mean_kterm_on_reach  | 226          |
# |    reached_rate         | 0.53         |
# | time/                   |              |
# |    fps                  | 2005         |
# |    iterations           | 420          |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 856800       |
# | train/                  |              |
# |    approx_kl            | 0.0012118103 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00242     |
# |    n_updates            | 4190         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 0.0037       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 376          |
# |    ep_rew_mean          | -0.912       |
# |    mean_error_on_reach  | 0.000109     |
# |    mean_kterm_on_reach  | 230          |
# |    reached_rate         | 0.47         |
# | time/                   |              |
# |    fps                  | 2008         |
# |    iterations           | 430          |
# |    time_elapsed         | 436          |
# |    total_timesteps      | 877200       |
# | train/                  |              |
# |    approx_kl            | 0.0012209838 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0134      |
# |    n_updates            | 4290         |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 0.00493      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | -0.795       |
# |    mean_error_on_reach  | 0.000113     |
# |    mean_kterm_on_reach  | 236          |
# |    reached_rate         | 0.57         |
# | time/                   |              |
# |    fps                  | 2011         |
# |    iterations           | 440          |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 897600       |
# | train/                  |              |
# |    approx_kl            | 0.0016529751 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00775     |
# |    n_updates            | 4390         |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 0.00311      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | -0.81       |
# |    mean_error_on_reach  | 0.00011     |
# |    mean_kterm_on_reach  | 242         |
# |    reached_rate         | 0.56        |
# | time/                   |             |
# |    fps                  | 2011        |
# |    iterations           | 450         |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 918000      |
# | train/                  |             |
# |    approx_kl            | 0.001345284 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.000588   |
# |    n_updates            | 4490        |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 0.00602     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 373          |
# |    ep_rew_mean          | -0.868       |
# |    mean_error_on_reach  | 9.57e-05     |
# |    mean_kterm_on_reach  | 244          |
# |    reached_rate         | 0.51         |
# | time/                   |              |
# |    fps                  | 2011         |
# |    iterations           | 460          |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 938400       |
# | train/                  |              |
# |    approx_kl            | 0.0011237835 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00998     |
# |    n_updates            | 4590         |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 0.0113       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 365          |
# |    ep_rew_mean          | -0.81        |
# |    mean_error_on_reach  | 9.08e-05     |
# ...
# |    total_timesteps      | 3692400      |
# | train/                  |              |
# |    approx_kl            | 0.0020699077 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0192      |
# |    n_updates            | 18090        |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 0.00301      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | -0.474      |
# |    mean_error_on_reach  | 0.000152    |
# |    mean_kterm_on_reach  | 307         |
# |    reached_rate         | 0.87        |
# | time/                   |             |
# |    fps                  | 2029        |
# |    iterations           | 1820        |
# |    time_elapsed         | 1829        |
# |    total_timesteps      | 3712800     |
# | train/                  |             |
# |    approx_kl            | 0.001491833 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0105     |
# |    n_updates            | 18190       |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 0.000618    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | -0.416       |
# |    mean_error_on_reach  | 0.000168     |
# |    mean_kterm_on_reach  | 293          |
# |    reached_rate         | 0.91         |
# | time/                   |              |
# |    fps                  | 2030         |
# |    iterations           | 1830         |
# |    time_elapsed         | 1838         |
# |    total_timesteps      | 3733200      |
# | train/                  |              |
# |    approx_kl            | 0.0021850697 |
# |    clip_fraction        | 0.0905       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0161      |
# |    n_updates            | 18290        |
# |    policy_gradient_loss | -0.00648     |
# |    value_loss           | 0.000972     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.519       |
# |    mean_error_on_reach  | 0.000162     |
# |    mean_kterm_on_reach  | 298          |
# |    reached_rate         | 0.83         |
# | time/                   |              |
# |    fps                  | 2030         |
# |    iterations           | 1840         |
# |    time_elapsed         | 1848         |
# |    total_timesteps      | 3753600      |
# | train/                  |              |
# |    approx_kl            | 0.0019199881 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00342     |
# |    n_updates            | 18390        |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 0.00295      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | -0.511       |
# |    mean_error_on_reach  | 0.000165     |
# |    mean_kterm_on_reach  | 295          |
# |    reached_rate         | 0.83         |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 1850         |
# |    time_elapsed         | 1857         |
# |    total_timesteps      | 3774000      |
# | train/                  |              |
# |    approx_kl            | 0.0019465268 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0182      |
# |    n_updates            | 18490        |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.00133      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 319          |
# |    ep_rew_mean          | -0.464       |
# |    mean_error_on_reach  | 0.000182     |
# |    mean_kterm_on_reach  | 289          |
# |    reached_rate         | 0.87         |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 1860         |
# |    time_elapsed         | 1867         |
# |    total_timesteps      | 3794400      |
# | train/                  |              |
# |    approx_kl            | 0.0020149292 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0251      |
# |    n_updates            | 18590        |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | -0.467       |
# |    mean_error_on_reach  | 0.000187     |
# |    mean_kterm_on_reach  | 283          |
# |    reached_rate         | 0.86         |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 1870         |
# |    time_elapsed         | 1877         |
# |    total_timesteps      | 3814800      |
# | train/                  |              |
# |    approx_kl            | 0.0017360406 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0243      |
# |    n_updates            | 18690        |
# |    policy_gradient_loss | -0.00374     |
# |    value_loss           | 0.00356      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | -0.517       |
# |    mean_error_on_reach  | 0.000169     |
# |    mean_kterm_on_reach  | 284          |
# |    reached_rate         | 0.82         |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 1880         |
# |    time_elapsed         | 1887         |
# |    total_timesteps      | 3835200      |
# | train/                  |              |
# |    approx_kl            | 0.0024215253 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0233      |
# |    n_updates            | 18790        |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 0.00295      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | -0.504       |
# |    mean_error_on_reach  | 0.000161     |
# |    mean_kterm_on_reach  | 288          |
# |    reached_rate         | 0.83         |
# | time/                   |              |
# |    fps                  | 2030         |
# |    iterations           | 1890         |
# |    time_elapsed         | 1898         |
# |    total_timesteps      | 3855600      |
# | train/                  |              |
# |    approx_kl            | 0.0017777452 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0134      |
# |    n_updates            | 18890        |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | -0.515       |
# |    mean_error_on_reach  | 0.000168     |
# |    mean_kterm_on_reach  | 283          |
# |    reached_rate         | 0.82         |
# | time/                   |              |
# |    fps                  | 2029         |
# |    iterations           | 1900         |
# |    time_elapsed         | 1909         |
# |    total_timesteps      | 3876000      |
# | train/                  |              |
# |    approx_kl            | 0.0016373319 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.021       |
# |    n_updates            | 18990        |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 0.00234      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | -0.441       |
# |    mean_error_on_reach  | 0.000157     |
# |    mean_kterm_on_reach  | 272          |
# |    reached_rate         | 0.87         |
# | time/                   |              |
# |    fps                  | 2029         |
# |    iterations           | 1910         |
# |    time_elapsed         | 1919         |
# |    total_timesteps      | 3896400      |
# | train/                  |              |
# |    approx_kl            | 0.0019776467 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0198      |
# |    n_updates            | 19090        |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 0.00177      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | -0.485       |
# |    mean_error_on_reach  | 0.000156     |
# |    mean_kterm_on_reach  | 273          |
# |    reached_rate         | 0.84         |
# | time/                   |              |
# |    fps                  | 2029         |
# |    iterations           | 1920         |
# |    time_elapsed         | 1930         |
# |    total_timesteps      | 3916800      |
# | train/                  |              |
# |    approx_kl            | 0.0021521111 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0261      |
# |    n_updates            | 19190        |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 0.00158      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | -0.488      |
# |    mean_error_on_reach  | 0.000154    |
# |    mean_kterm_on_reach  | 280         |
# |    reached_rate         | 0.84        |
# | time/                   |             |
# |    fps                  | 2029        |
# |    iterations           | 1930        |
# |    time_elapsed         | 1939        |
# |    total_timesteps      | 3937200     |
# | train/                  |             |
# |    approx_kl            | 0.002034977 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0248     |
# |    n_updates            | 19290       |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | -0.532       |
# |    mean_error_on_reach  | 0.00016      |
# |    mean_kterm_on_reach  | 290          |
# |    reached_rate         | 0.82         |
# | time/                   |              |
# |    fps                  | 2030         |
# |    iterations           | 1940         |
# |    time_elapsed         | 1949         |
# |    total_timesteps      | 3957600      |
# | train/                  |              |
# |    approx_kl            | 0.0017896569 |
# |    clip_fraction        | 0.0943       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00656     |
# |    n_updates            | 19390        |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 0.00254      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | -0.559      |
# |    mean_error_on_reach  | 0.000155    |
# |    mean_kterm_on_reach  | 298         |
# |    reached_rate         | 0.8         |
# | time/                   |             |
# |    fps                  | 2030        |
# |    iterations           | 1950        |
# |    time_elapsed         | 1959        |
# |    total_timesteps      | 3978000     |
# | train/                  |             |
# |    approx_kl            | 0.002389457 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00452    |
# |    n_updates            | 19490       |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 0.00283     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -0.537       |
# |    mean_error_on_reach  | 0.000152     |
# |    mean_kterm_on_reach  | 298          |
# |    reached_rate         | 0.81         |
# | time/                   |              |
# |    fps                  | 2031         |
# |    iterations           | 1960         |
# |    time_elapsed         | 1968         |
# |    total_timesteps      | 3998400      |
# | train/                  |              |
# |    approx_kl            | 0.0019352296 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0399      |
# |    n_updates            | 19590        |
# |    policy_gradient_loss | -0.00575     |
# |    value_loss           | 0.00397      |
# ------------------------------------------
