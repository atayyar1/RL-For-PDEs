# %%
import numpy as np
import matplotlib.pyplot as plt
import torch, torch.nn as nn, torch.optim as optim
import torch
import torch.nn as nn
import matplotlib.patches as patches

from torch.utils.data import Dataset, DataLoader

device = "cuda"
torch.backends.cudnn.benchmark = True

# %%
# -----------------------
# 1. Generate wave equation data (Dirichlet BC)
# -----------------------
def wave_solver_dirichlet(u0, ut0, c=1.0, dx=1/128, dt=1e-4, n_steps=2000):
    """Explicit finite-difference solver for 1D wave equation (Dirichlet BCs u(0,t)=u(1,t)=0)."""
    Nx = len(u0)
    u = u0.copy()
    u_prev = u0.copy()  # u at previous time step
    
    # Initialize first time step using initial velocity
    u_new = u.copy()
    for i in range(1, Nx - 1):
        lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
        u_new[i] = u[i] + dt * ut0[i] + 0.5 * c**2 * dt**2 * lap
    u_prev = u.copy()
    u = u_new.copy()
    
    traj = [u0.copy(), u.copy()]
    
    for _ in range(n_steps - 1):
        u_new = u.copy()
        
        # discrete Laplacian on interior points only
        for i in range(1, Nx - 1):
            lap = (u[i+1] - 2*u[i] + u[i-1]) / dx**2
            u_new[i] = 2*u[i] - u_prev[i] + c**2 * dt**2 * lap
        
        # Dirichlet boundaries
        u_new[0] = 0.0
        u_new[-1] = 0.0
        
        u_prev = u.copy()
        u = u_new.copy()
        traj.append(u.copy())
    
    return np.stack(traj)  # shape (T, Nx)

def generate_wave_data(Nx=128, c=1.0, dt=1e-4, n_steps=4000):
    dx = 1.0 / (Nx - 1)
    x = np.linspace(0, 1, Nx)

    # initial condition compatible with Dirichlet BC
    u0  = np.exp(-((x-0.3)/0.05)**2)
    ut0 = np.zeros_like(x)


    data = wave_solver_dirichlet(u0, ut0, c, dx, dt, n_steps)
    return x, data  # data[t, x]

# -----------------------
# 3. Training setup
# -----------------------
Nx = 500
dt0 = 1e-4
c = 1.0
n_steps = 9000

x, data = generate_wave_data(Nx, c, dt0, n_steps)

# %%
t_plot = n_steps  # or whatever final index you used

plt.figure(figsize=(8,4))
plt.plot(x, data[0], label="t = 0", linewidth=2)
plt.plot(x, data[t_plot], label=f"t = {t_plot}", linewidth=2)
plt.title("Wave Equation: Initial vs Final State")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def sample_one_B(u, R=5, k=5, max_tries=50, u_scale=None, rng=np.random):
    """
    Sample a single Scheme-B training example using an index-space square.

    Square geometry:
        t in [t0-R, t0+R], x in [x0-R, x0+R]

    Returns:
        feats_flat: (k*3,) with [dt_scaled, dx_scaled, u_scaled]
        target: scalar normalized u(t0,x0)
    """
    Nt, Nx = u.shape

    if u_scale is None:
        u_scale = np.max(np.abs(u)) + 1e-8

    for _ in range(max_tries):

        # ---- 1. sample random center ----
        t0 =  rng.randint(0, Nt)
        x0 =  rng.randint(0, Nx)

        # ---- 2. square bounds ----
        t_min = max(0, t0 - R)
        t_max = min(Nt - 1, t0 + R)
        x_min = max(0, x0 - R)
        x_max = min(Nx - 1, x0 + R)

        # ---- 3. collect candidates ----
        cand = []
        for t in range(t_min, t_max + 1):
            for x in range(x_min, x_max + 1):
                if t == t0 and x == x0:
                    continue
                cand.append((t, x))

        if len(cand) < k:
            continue

        # ---- 4. pick k random neighbors ----
        cand = np.array(cand)
        idx = np.random.choice(len(cand), size=k, replace=False)
        neigh = cand[idx]

        # ---- 5. build feature vector ----
        feats = []
        for (tn, xn) in neigh:
            dt_scaled = (t0 - tn)
            dx_scaled = (x0 - xn)
            u_scaled = u[tn, xn] / u_scale
            feats.append([dt_scaled, dx_scaled, u_scaled])

        feats = np.array(feats, dtype=np.float32).reshape(-1)
        target = np.float32(u[t0, x0] / u_scale)
        return feats, target

    raise RuntimeError("Failed to sample B-example; try changing R/k.")

# %%
class BDataset(Dataset):
    """
    Scheme-B dataset:
    - u: PDE solution, shape (Nt, Nx)
    - N_samples: number of samples
    """
    def __init__(self, u, N_samples=50000, R=5, k=5, seed=0, pregenerate=False):
        self.u = u
        self.N_samples = N_samples
        self.R = R
        self.k = k
        self.rng = np.random.RandomState(seed)

        # global normalization for u
        self.u_scale = np.max(np.abs(u)) + 1e-8

        self.pregenerate = pregenerate
        if pregenerate:
            print(f"Pre-generating {N_samples} samples...")
            feats = []
            targets = []

            for i in range(N_samples):
                if (i + 1) % 10000 == 0:
                    print(f"  Generated {i+1}/{N_samples}")

                f, t = sample_one_B(
                    self.u,
                    R=self.R,
                    k=self.k,
                    u_scale=self.u_scale,
                    rng=self.rng,
                )
                feats.append(f)
                targets.append(t)

            self.feats_tensor = torch.from_numpy(
                np.asarray(feats, dtype=np.float32)
            )
            self.targets_tensor = torch.from_numpy(
                np.asarray(targets, dtype=np.float32)
            )

            print("Pre-generation complete.")

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        if self.pregenerate:
            return self.feats_tensor[idx], self.targets_tensor[idx]
        else:
            feats, target = sample_one_B(
                self.u,
                R=self.R,
                k=self.k,
                u_scale=self.u_scale,
                rng=self.rng,
            )
            return (
                torch.from_numpy(feats),
                torch.tensor(target, dtype=torch.float32),
            )

# %%
class LinearIntegrator(nn.Module):
    def __init__(self, k=5):
        super().__init__()
        self.lin = nn.Linear(k * 3, 1)

    def forward(self, x):
        return self.lin(x).squeeze(-1)

# %%
class MLPIntegrator(nn.Module):
    def __init__(self, k=5, hidden=128, num_layers=3):
        super().__init__()
        in_dim = k * 3
        layers = [nn.Linear(in_dim, hidden), nn.ReLU()]

        for _ in range(num_layers - 2):
            layers += [nn.Linear(hidden, hidden), nn.ReLU()]

        layers.append(nn.Linear(hidden, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x).squeeze(-1)

# %%
def train_integrator_B(
    model,
    u,
    epochs=50,
    batch_size=2048,
    k=5,
    R=5,
    N_samples=100000,
    lr=1e-3,
    pregenerate=True,
):
    """
    Minimal training loop for Scheme-B integrators.

    Args:
        model: torch.nn.Module (linear or MLP)
        u: numpy array (Nt, Nx)
    Returns:
        model: trained model
        train_losses: list of epoch-wise MSE
    """
    device = "cuda"
    model = model.to(device)

    dataset = BDataset(
        u,
        N_samples=N_samples,
        R=R,
        k=k,
        pregenerate=pregenerate,
    )

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_losses = []

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)

            opt.zero_grad()
            pred = model(feats)
            loss = loss_fn(pred, target)
            loss.backward()
            opt.step()

            total_loss += loss.item() * feats.size(0)

        avg_loss = total_loss / len(dataset)
        train_losses.append(avg_loss)

        print(f"[Epoch {epoch+1}/{epochs}] train MSE = {avg_loss:.6e}")

    return model, train_losses

# %%
def eval_integrator_B(model, u, R, k, N_test=10000, batch_size=4096,):
    device = "cuda"
    model.eval()
    test_ds = BDataset( u, N_samples=N_test,R=R,k=k, seed=123,pregenerate=True,    )
    loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0,pin_memory=True,)
    loss_fn = nn.MSELoss()
    total_loss = 0.0
    with torch.no_grad():
        for feats, target in loader:
            feats = feats.to(device)
            target = target.to(device)
            pred = model(feats)
            loss = loss_fn(pred, target)
            total_loss += loss.item() * feats.size(0)
    avg_loss = total_loss / N_test
    print(f"[Eval] MSE = {avg_loss:.6e}")
    return avg_loss

# %%
def visualize_B_compare_models(u, model_lin, model_mlp, R=5, k=5):
    device = "cuda"
    model_lin.eval()
    model_mlp.eval()

    Nt, Nx = u.shape

    # ---- choose one random center ----
    t0 = np.random.randint(0, Nt)
    x0 = np.random.randint(0, Nx)

    # ---- square neighborhood ----
    t_min = max(0, t0 - R)
    t_max = min(Nt - 1, t0 + R)
    x_min = max(0, x0 - R)
    x_max = min(Nx - 1, x0 + R)

    cand = [(t, x) for t in range(t_min, t_max + 1)
                    for x in range(x_min, x_max + 1)
                    if not (t == t0 and x == x0)]
    cand = np.array(cand)

    idx = np.random.choice(len(cand), size=k, replace=False)
    neigh = cand[idx]

    # ---- features ----
    u_scale = np.max(np.abs(u)) + 1e-8
    feats = []
    for (tn, xn) in neigh:
        feats.append([t0 - tn, x0 - xn, u[tn, xn] / u_scale])
    feats = np.array(feats, dtype=np.float32).reshape(1, -1)
    feats_torch = torch.from_numpy(feats).to(device)

    with torch.no_grad():
        pred_lin = model_lin(feats_torch).item() * u_scale
        pred_mlp = model_mlp(feats_torch).item() * u_scale

    true = u[t0, x0]

    # ---- plotting ----
    fig, axes = plt.subplots(
        1, 2,
        figsize=(9, 4),
        sharey=True,
        gridspec_kw={"wspace": 0.08},  # panels closer
    )

    for ax, title, pred in zip(
        axes,
        ["Linear model", "MLP model"],
        [pred_lin, pred_mlp],
    ):
        # square
        rect = plt.Rectangle(
            (x_min, t_min),
            x_max - x_min,
            t_max - t_min,
            fill=False,
            edgecolor="blue",
            linewidth=1.8,
        )
        ax.add_patch(rect)

        # neighbors
        ax.scatter(neigh[:, 1], neigh[:, 0], s=110, label="neighbors")
        for (tn, xn) in neigh:
            ax.plot([x0, xn], [t0, tn], alpha=0.6)

        # target
        ax.scatter([x0], [t0], c="red", s=180, label="target", zorder=5)

        ax.set_title(
            f"{title}\n"
            f"pred = {pred:.5f}, rel err = {(true - pred) * 100:.2f}%",
            fontsize=10,
        )

        ax.set_xlim(x_min - 2, x_max + 2)
        ax.set_ylim(t_max + 2, t_min - 2)
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("x")

    axes[0].set_ylabel("t (time index, upward)")

    # ---- shared legend ----
    handles, labels = axes[0].get_legend_handles_labels()
     

    # ---- shared true value ----
    fig.suptitle(
        f"True value at target: u(t₀, x₀) = {true:.5f}",
        y=1.05,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

# %%
# =========================
# Experiments
# =========================

R = 5
k = 5
epochs = 150
batch_size = 2048
N_samples = 100000
lr = 1e-3

# %%
model_lin = LinearIntegrator(k=k)
model_lin, loss_lin = train_integrator_B(
    model_lin,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 1.975372e+00
# [Epoch 2/150] train MSE = 1.084976e+00
# [Epoch 3/150] train MSE = 5.618823e-01
# [Epoch 4/150] train MSE = 2.769418e-01
# [Epoch 5/150] train MSE = 1.307461e-01
# [Epoch 6/150] train MSE = 5.915184e-02
# [Epoch 7/150] train MSE = 2.551480e-02
# [Epoch 8/150] train MSE = 1.044274e-02
# [Epoch 9/150] train MSE = 4.056369e-03
# [Epoch 10/150] train MSE = 1.532606e-03
# [Epoch 11/150] train MSE = 6.049398e-04
# [Epoch 12/150] train MSE = 2.889391e-04
# [Epoch 13/150] train MSE = 1.896053e-04
# [Epoch 14/150] train MSE = 1.605469e-04
# [Epoch 15/150] train MSE = 1.526121e-04
# [Epoch 16/150] train MSE = 1.504246e-04
# [Epoch 17/150] train MSE = 1.496899e-04
# [Epoch 18/150] train MSE = 1.492924e-04
# [Epoch 19/150] train MSE = 1.489291e-04
# [Epoch 20/150] train MSE = 1.485385e-04
# [Epoch 21/150] train MSE = 1.482098e-04
# [Epoch 22/150] train MSE = 1.478206e-04
# [Epoch 23/150] train MSE = 1.474283e-04
# [Epoch 24/150] train MSE = 1.470150e-04
# [Epoch 25/150] train MSE = 1.465874e-04
# [Epoch 26/150] train MSE = 1.461981e-04
# [Epoch 27/150] train MSE = 1.457705e-04
# [Epoch 28/150] train MSE = 1.452819e-04
# [Epoch 29/150] train MSE = 1.448189e-04
# [Epoch 30/150] train MSE = 1.443783e-04
# [Epoch 31/150] train MSE = 1.439562e-04
# [Epoch 32/150] train MSE = 1.434599e-04
# [Epoch 33/150] train MSE = 1.429337e-04
# [Epoch 34/150] train MSE = 1.424542e-04
# [Epoch 35/150] train MSE = 1.419761e-04
# [Epoch 36/150] train MSE = 1.414474e-04
# [Epoch 37/150] train MSE = 1.408826e-04
# [Epoch 38/150] train MSE = 1.403713e-04
# [Epoch 39/150] train MSE = 1.398584e-04
# [Epoch 40/150] train MSE = 1.393098e-04
# [Epoch 41/150] train MSE = 1.387588e-04
# [Epoch 42/150] train MSE = 1.382146e-04
# [Epoch 43/150] train MSE = 1.376390e-04
# [Epoch 44/150] train MSE = 1.370780e-04
# [Epoch 45/150] train MSE = 1.366433e-04
# [Epoch 46/150] train MSE = 1.359100e-04
# [Epoch 47/150] train MSE = 1.353661e-04
# [Epoch 48/150] train MSE = 1.347958e-04
# [Epoch 49/150] train MSE = 1.341849e-04
# [Epoch 50/150] train MSE = 1.335847e-04
# [Epoch 51/150] train MSE = 1.329962e-04
# [Epoch 52/150] train MSE = 1.324305e-04
# [Epoch 53/150] train MSE = 1.318325e-04
# [Epoch 54/150] train MSE = 1.311853e-04
# [Epoch 55/150] train MSE = 1.305980e-04
# [Epoch 56/150] train MSE = 1.300686e-04
# [Epoch 57/150] train MSE = 1.294952e-04
# [Epoch 58/150] train MSE = 1.287984e-04
# [Epoch 59/150] train MSE = 1.282026e-04
# [Epoch 60/150] train MSE = 1.276382e-04
# [Epoch 61/150] train MSE = 1.271092e-04
# [Epoch 62/150] train MSE = 1.263908e-04
# [Epoch 63/150] train MSE = 1.258543e-04
# [Epoch 64/150] train MSE = 1.252216e-04
# [Epoch 65/150] train MSE = 1.246533e-04
# [Epoch 66/150] train MSE = 1.241483e-04
# [Epoch 67/150] train MSE = 1.234916e-04
# [Epoch 68/150] train MSE = 1.229465e-04
# [Epoch 69/150] train MSE = 1.223789e-04
# [Epoch 70/150] train MSE = 1.218213e-04
# [Epoch 71/150] train MSE = 1.212986e-04
# [Epoch 72/150] train MSE = 1.207462e-04
# [Epoch 73/150] train MSE = 1.202179e-04
# [Epoch 74/150] train MSE = 1.196674e-04
# [Epoch 75/150] train MSE = 1.191366e-04
# [Epoch 76/150] train MSE = 1.186313e-04
# [Epoch 77/150] train MSE = 1.181073e-04
# [Epoch 78/150] train MSE = 1.176343e-04
# [Epoch 79/150] train MSE = 1.171933e-04
# [Epoch 80/150] train MSE = 1.167429e-04
# [Epoch 81/150] train MSE = 1.162968e-04
# [Epoch 82/150] train MSE = 1.157498e-04
# [Epoch 83/150] train MSE = 1.153977e-04
# [Epoch 84/150] train MSE = 1.149327e-04
# [Epoch 85/150] train MSE = 1.146954e-04
# [Epoch 86/150] train MSE = 1.141614e-04
# [Epoch 87/150] train MSE = 1.138362e-04
# [Epoch 88/150] train MSE = 1.133937e-04
# [Epoch 89/150] train MSE = 1.130153e-04
# [Epoch 90/150] train MSE = 1.126447e-04
# [Epoch 91/150] train MSE = 1.123325e-04
# [Epoch 92/150] train MSE = 1.119831e-04
# [Epoch 93/150] train MSE = 1.117156e-04
# [Epoch 94/150] train MSE = 1.113387e-04
# [Epoch 95/150] train MSE = 1.111468e-04
# [Epoch 96/150] train MSE = 1.108681e-04
# [Epoch 97/150] train MSE = 1.105661e-04
# [Epoch 98/150] train MSE = 1.103065e-04
# [Epoch 99/150] train MSE = 1.102014e-04
# [Epoch 100/150] train MSE = 1.099870e-04
# [Epoch 101/150] train MSE = 1.096195e-04
# [Epoch 102/150] train MSE = 1.095424e-04
# [Epoch 103/150] train MSE = 1.093328e-04
# [Epoch 104/150] train MSE = 1.090925e-04
# [Epoch 105/150] train MSE = 1.091057e-04
# [Epoch 106/150] train MSE = 1.091490e-04
# [Epoch 107/150] train MSE = 1.087634e-04
# [Epoch 108/150] train MSE = 1.084937e-04
# [Epoch 109/150] train MSE = 1.083249e-04
# [Epoch 110/150] train MSE = 1.085448e-04
# [Epoch 111/150] train MSE = 1.082731e-04
# [Epoch 112/150] train MSE = 1.080765e-04
# [Epoch 113/150] train MSE = 1.080979e-04
# [Epoch 114/150] train MSE = 1.078969e-04
# [Epoch 115/150] train MSE = 1.077239e-04
# [Epoch 116/150] train MSE = 1.078715e-04
# [Epoch 117/150] train MSE = 1.075951e-04
# [Epoch 118/150] train MSE = 1.076186e-04
# [Epoch 119/150] train MSE = 1.077562e-04
# [Epoch 120/150] train MSE = 1.078446e-04
# [Epoch 121/150] train MSE = 1.075208e-04
# [Epoch 122/150] train MSE = 1.080659e-04
# [Epoch 123/150] train MSE = 1.077984e-04
# [Epoch 124/150] train MSE = 1.074816e-04
# [Epoch 125/150] train MSE = 1.073699e-04
# [Epoch 126/150] train MSE = 1.075719e-04
# [Epoch 127/150] train MSE = 1.073068e-04
# [Epoch 128/150] train MSE = 1.073486e-04
# [Epoch 129/150] train MSE = 1.076882e-04
# [Epoch 130/150] train MSE = 1.075955e-04
# [Epoch 131/150] train MSE = 1.075573e-04
# [Epoch 132/150] train MSE = 1.073685e-04
# [Epoch 133/150] train MSE = 1.073465e-04
# [Epoch 134/150] train MSE = 1.072809e-04
# [Epoch 135/150] train MSE = 1.073098e-04
# [Epoch 136/150] train MSE = 1.072272e-04
# [Epoch 137/150] train MSE = 1.073866e-04
# [Epoch 138/150] train MSE = 1.074113e-04
# [Epoch 139/150] train MSE = 1.075441e-04
# [Epoch 140/150] train MSE = 1.074292e-04
# [Epoch 141/150] train MSE = 1.073071e-04
# [Epoch 142/150] train MSE = 1.073896e-04
# [Epoch 143/150] train MSE = 1.076123e-04
# [Epoch 144/150] train MSE = 1.075374e-04
# [Epoch 145/150] train MSE = 1.076004e-04
# [Epoch 146/150] train MSE = 1.075794e-04
# [Epoch 147/150] train MSE = 1.076939e-04
# [Epoch 148/150] train MSE = 1.076896e-04
# [Epoch 149/150] train MSE = 1.075478e-04
# [Epoch 150/150] train MSE = 1.074137e-04

# %%
model_mlp =  MLPIntegrator(k=k, hidden=128, num_layers=3)
model_mlp, loss_mlp = train_integrator_B(
    model_mlp,
    data,
    epochs=epochs,
    batch_size=batch_size,
    k=k,
    R=R,
    N_samples=N_samples,
    lr=lr,
)
# Out:
# Pre-generating 100000 samples...
#   Generated 10000/100000
#   Generated 20000/100000
#   Generated 30000/100000
#   Generated 40000/100000
#   Generated 50000/100000
#   Generated 60000/100000
#   Generated 70000/100000
#   Generated 80000/100000
#   Generated 90000/100000
#   Generated 100000/100000
# Pre-generation complete.
# [Epoch 1/150] train MSE = 2.241266e-02
# [Epoch 2/150] train MSE = 3.198128e-03
# [Epoch 3/150] train MSE = 1.715769e-03
# [Epoch 4/150] train MSE = 1.237265e-03
# [Epoch 5/150] train MSE = 9.476599e-04
# [Epoch 6/150] train MSE = 7.885922e-04
# [Epoch 7/150] train MSE = 6.870119e-04
# [Epoch 8/150] train MSE = 6.124373e-04
# [Epoch 9/150] train MSE = 5.250683e-04
# [Epoch 10/150] train MSE = 4.708183e-04
# [Epoch 11/150] train MSE = 4.293666e-04
# [Epoch 12/150] train MSE = 3.908346e-04
# [Epoch 13/150] train MSE = 3.557852e-04
# [Epoch 14/150] train MSE = 3.325977e-04
# [Epoch 15/150] train MSE = 3.177557e-04
# [Epoch 16/150] train MSE = 2.989507e-04
# [Epoch 17/150] train MSE = 2.924508e-04
# [Epoch 18/150] train MSE = 2.672882e-04
# [Epoch 19/150] train MSE = 2.593380e-04
# [Epoch 20/150] train MSE = 2.376737e-04
# [Epoch 21/150] train MSE = 2.359396e-04
# [Epoch 22/150] train MSE = 2.235895e-04
# [Epoch 23/150] train MSE = 2.330421e-04
# [Epoch 24/150] train MSE = 2.262235e-04
# [Epoch 25/150] train MSE = 1.944372e-04
# [Epoch 26/150] train MSE = 2.075929e-04
# [Epoch 27/150] train MSE = 2.015689e-04
# [Epoch 28/150] train MSE = 1.840410e-04
# [Epoch 29/150] train MSE = 1.881799e-04
# [Epoch 30/150] train MSE = 1.757776e-04
# [Epoch 31/150] train MSE = 1.914963e-04
# [Epoch 32/150] train MSE = 1.725245e-04
# [Epoch 33/150] train MSE = 1.713959e-04
# [Epoch 34/150] train MSE = 1.765356e-04
# [Epoch 35/150] train MSE = 1.608580e-04
# [Epoch 36/150] train MSE = 1.514399e-04
# [Epoch 37/150] train MSE = 1.561820e-04
# [Epoch 38/150] train MSE = 1.466658e-04
# [Epoch 39/150] train MSE = 1.579730e-04
# [Epoch 40/150] train MSE = 1.550410e-04
# [Epoch 41/150] train MSE = 1.494972e-04
# [Epoch 42/150] train MSE = 1.426102e-04
# [Epoch 43/150] train MSE = 1.622759e-04
# [Epoch 44/150] train MSE = 1.463581e-04
# [Epoch 45/150] train MSE = 1.382658e-04
# [Epoch 46/150] train MSE = 1.521050e-04
# [Epoch 47/150] train MSE = 1.324700e-04
# [Epoch 48/150] train MSE = 1.579370e-04
# [Epoch 49/150] train MSE = 1.313118e-04
# [Epoch 50/150] train MSE = 1.449024e-04
# [Epoch 51/150] train MSE = 1.369690e-04
# [Epoch 52/150] train MSE = 1.353778e-04
# [Epoch 53/150] train MSE = 1.484855e-04
# [Epoch 54/150] train MSE = 1.270510e-04
# [Epoch 55/150] train MSE = 1.260274e-04
# [Epoch 56/150] train MSE = 1.221272e-04
# [Epoch 57/150] train MSE = 1.292024e-04
# [Epoch 58/150] train MSE = 1.308101e-04
# [Epoch 59/150] train MSE = 1.313246e-04
# [Epoch 60/150] train MSE = 1.326462e-04
# [Epoch 61/150] train MSE = 1.273404e-04
# [Epoch 62/150] train MSE = 1.394198e-04
# [Epoch 63/150] train MSE = 1.259241e-04
# [Epoch 64/150] train MSE = 1.300508e-04
# [Epoch 65/150] train MSE = 1.347789e-04
# [Epoch 66/150] train MSE = 1.278227e-04
# [Epoch 67/150] train MSE = 1.307677e-04
# [Epoch 68/150] train MSE = 1.192484e-04
# [Epoch 69/150] train MSE = 1.238249e-04
# [Epoch 70/150] train MSE = 1.203833e-04
# [Epoch 71/150] train MSE = 1.236263e-04
# [Epoch 72/150] train MSE = 1.196353e-04
# [Epoch 73/150] train MSE = 1.155925e-04
# [Epoch 74/150] train MSE = 1.184789e-04
# [Epoch 75/150] train MSE = 1.514050e-04
# [Epoch 76/150] train MSE = 1.200718e-04
# [Epoch 77/150] train MSE = 1.177502e-04
# [Epoch 78/150] train MSE = 1.120510e-04
# [Epoch 79/150] train MSE = 1.127953e-04
# [Epoch 80/150] train MSE = 1.212734e-04
# [Epoch 81/150] train MSE = 1.131476e-04
# [Epoch 82/150] train MSE = 1.286395e-04
# [Epoch 83/150] train MSE = 1.223740e-04
# [Epoch 84/150] train MSE = 1.161438e-04
# [Epoch 85/150] train MSE = 1.291881e-04
# [Epoch 86/150] train MSE = 1.244152e-04
# [Epoch 87/150] train MSE = 1.167533e-04
# [Epoch 88/150] train MSE = 1.227917e-04
# [Epoch 89/150] train MSE = 1.109285e-04
# [Epoch 90/150] train MSE = 1.115818e-04
# [Epoch 91/150] train MSE = 1.095565e-04
# [Epoch 92/150] train MSE = 1.174237e-04
# [Epoch 93/150] train MSE = 1.200091e-04
# [Epoch 94/150] train MSE = 1.203687e-04
# [Epoch 95/150] train MSE = 1.187138e-04
# [Epoch 96/150] train MSE = 1.116719e-04
# [Epoch 97/150] train MSE = 1.270951e-04
# [Epoch 98/150] train MSE = 1.111784e-04
# [Epoch 99/150] train MSE = 1.212914e-04
# [Epoch 100/150] train MSE = 1.278467e-04
# [Epoch 101/150] train MSE = 1.072796e-04
# [Epoch 102/150] train MSE = 1.092881e-04
# [Epoch 103/150] train MSE = 1.106673e-04
# [Epoch 104/150] train MSE = 1.136683e-04
# [Epoch 105/150] train MSE = 1.124763e-04
# [Epoch 106/150] train MSE = 1.097740e-04
# [Epoch 107/150] train MSE = 1.115386e-04
# [Epoch 108/150] train MSE = 1.096261e-04
# [Epoch 109/150] train MSE = 1.093279e-04
# [Epoch 110/150] train MSE = 1.189660e-04
# [Epoch 111/150] train MSE = 1.087815e-04
# [Epoch 112/150] train MSE = 1.072643e-04
# [Epoch 113/150] train MSE = 1.104668e-04
# [Epoch 114/150] train MSE = 1.060268e-04
# [Epoch 115/150] train MSE = 1.100485e-04
# [Epoch 116/150] train MSE = 1.194167e-04
# [Epoch 117/150] train MSE = 1.082986e-04
# [Epoch 118/150] train MSE = 1.066297e-04
# [Epoch 119/150] train MSE = 1.186268e-04
# [Epoch 120/150] train MSE = 1.062690e-04
# [Epoch 121/150] train MSE = 1.159141e-04
# [Epoch 122/150] train MSE = 1.116087e-04
# [Epoch 123/150] train MSE = 1.040103e-04
# [Epoch 124/150] train MSE = 1.085655e-04
# [Epoch 125/150] train MSE = 1.075025e-04
# [Epoch 126/150] train MSE = 1.050780e-04
# [Epoch 127/150] train MSE = 1.069555e-04
# [Epoch 128/150] train MSE = 1.099983e-04
# [Epoch 129/150] train MSE = 1.177465e-04
# [Epoch 130/150] train MSE = 1.027580e-04
# [Epoch 131/150] train MSE = 1.026222e-04
# [Epoch 132/150] train MSE = 1.202685e-04
# [Epoch 133/150] train MSE = 1.070871e-04
# [Epoch 134/150] train MSE = 1.072828e-04
# [Epoch 135/150] train MSE = 1.068861e-04
# [Epoch 136/150] train MSE = 1.071875e-04
# [Epoch 137/150] train MSE = 1.036557e-04
# [Epoch 138/150] train MSE = 1.049629e-04
# [Epoch 139/150] train MSE = 1.099590e-04
# [Epoch 140/150] train MSE = 1.064384e-04
# [Epoch 141/150] train MSE = 1.064925e-04
# [Epoch 142/150] train MSE = 1.047275e-04
# [Epoch 143/150] train MSE = 1.129803e-04
# [Epoch 144/150] train MSE = 1.092410e-04
# [Epoch 145/150] train MSE = 1.117109e-04
# [Epoch 146/150] train MSE = 1.026974e-04
# [Epoch 147/150] train MSE = 1.020478e-04
# [Epoch 148/150] train MSE = 1.060823e-04
# [Epoch 149/150] train MSE = 1.022055e-04
# [Epoch 150/150] train MSE = 1.061405e-04

# %%
test_loss_lin = eval_integrator_B(
    model_lin, data, R=R, k=k, N_test=20_000
)

test_loss_mlp = eval_integrator_B(
    model_mlp, data, R=R, k=k, N_test=20_000
)

print(f"Linear test MSE: {test_loss_lin:.6e}")
print(f"MLP test MSE:    {test_loss_mlp:.6e}")
# Out:
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 1.079356e-04
# Pre-generating 20000 samples...
#   Generated 10000/20000
#   Generated 20000/20000
# Pre-generation complete.
# [Eval] MSE = 1.234613e-04
# Linear test MSE: 1.079356e-04
# MLP test MSE:    1.234613e-04

# %%
# ===== Save models =====

torch.save(
    {
        "model_type": "linear",
        "state_dict": model_lin.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "linear_integrator_Square_gauss.pth",
)

torch.save(
    {
        "model_type": "mlp",
        "state_dict": model_mlp.state_dict(),
        "config": {
            "k": k,
            "R": R,
            "hidden": 128,
            "num_layers": 3,
            "u_scale": np.max(np.abs(data)) + 1e-8,
        },
    },
    "small_mlp_integrator_Square_gauss.pth",
)

print("Models saved: linear_integrator_gauss.pth, mlp_integrator_gauss.pth")
# Out:
# Models saved: linear_integrator_gauss.pth, mlp_integrator_gauss.pth

# %%
 
# ===== Load model =====

ckpt = torch.load("small_mlp_integrator_Square_gauss.pth", map_location="cuda")

if ckpt["model_type"] == "linear":
    model = LinearIntegrator(k=ckpt["config"]["k"])
elif ckpt["model_type"] == "mlp":
    model = MLPIntegrator(
        k=ckpt["config"]["k"],
        hidden=ckpt["config"]["hidden"],
        num_layers=ckpt["config"]["num_layers"],
    )
else:
    raise ValueError("Unknown model type")

model.load_state_dict(ckpt["state_dict"])
model = model.to("cuda")
model.eval()

print(f"Loaded {ckpt['model_type']} model with config:")
print(ckpt["config"])
# Out:
# Loaded mlp model with config:
# {'k': 5, 'R': 5, 'hidden': 128, 'num_layers': 3, 'u_scale': np.float64(0.9998554427182372)}
# C:\Users\amt35\AppData\Local\Temp\ipykernel_30796\1189516554.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load("small_mlp_integrator_Square_gauss.pth", map_location="cuda")

# %%
plt.figure(figsize=(7, 4))

# Training curves
plt.semilogy(loss_lin, label="Linear (train)", color="C0")
plt.semilogy(loss_mlp, label="MLP (train)", color="C1")

# Final training values
final_lin = loss_lin[-1]
final_mlp = loss_mlp[-1]

# Mark final points
epoch_last = len(loss_lin) - 1
plt.scatter(epoch_last, final_lin, color="C0", zorder=5)
plt.scatter(epoch_last, final_mlp, color="C1", zorder=5)

# Evaluation errors
plt.axhline(
    test_loss_lin,
    color="C0",
    linestyle="--",
    alpha=0.8,
    label=f"Linear (eval) = {test_loss_lin:.2e}"
)
plt.axhline(
    test_loss_mlp,
    color="C1",
    linestyle="--",
    alpha=0.8,
    label=f"MLP (eval) = {test_loss_mlp:.2e}"
)

# ---- Text box with final train errors ----
textstr = (
    f"Final train MSE:\n"
    f"  Linear = {final_lin:.2e}\n"
    f"  MLP    = {final_mlp:.2e}"
)

plt.text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.9)
)

plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training and Evaluation Error (Linear vs MLP)")
plt.legend()
plt.grid(False)   # <-- remove grey grid lines
plt.tight_layout()
plt.show()

# %%
visualize_B_compare_models(data, model_lin, model_mlp, R=5, k=5)
# Out:
# C:\Users\amt35\AppData\Local\Temp\ipykernel_30796\406914228.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Cumulative test error comparison
n_points = 10000
step = 500
n_steps = n_points // step

test_ds = BDataset(data, N_samples=n_points, R=R, k=k, seed=456, pregenerate=True)
loader = DataLoader(test_ds, batch_size=step, shuffle=False, num_workers=0, pin_memory=True)

loss_fn = nn.MSELoss()
cum_err_lin, cum_err_mlp = [], []
total_lin, total_mlp = 0.0, 0.0

model_lin.eval()
model_mlp.eval()
with torch.no_grad():
    for i, (feats, target) in enumerate(loader):
        feats = feats.to(device)
        target = target.to(device)
        
        pred_lin = model_lin(feats)
        pred_mlp = model_mlp(feats)
        
        loss_lin = loss_fn(pred_lin, target).item()
        loss_mlp = loss_fn(pred_mlp, target).item()
        
        total_lin += loss_lin * step
        total_mlp += loss_mlp * step
        
        cum_err_lin.append(total_lin )
        cum_err_mlp.append(total_mlp )

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Cumulative error
x = np.arange(step, n_points + 1, step)
ax1.semilogy(x, cum_err_lin, 'o-', label='Linear', color='C0', markersize=4)
ax1.semilogy(x, cum_err_mlp, 's-', label='MLP', color='C1', markersize=4)
ax1.set_xlabel('Number of test points')
ax1.set_ylabel('Cumulative MSE')
ax1.set_title('Cumulative Test Error')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Error ratio
ratio = np.array(cum_err_mlp) / np.array(cum_err_lin)
ax2.plot(x, ratio, 'k-', linewidth=2)
ax2.axhline(1, color='r', linestyle='--', alpha=0.5, label='Equal')
ax2.set_xlabel('Number of test points')
ax2.set_ylabel('MLP / Linear')
ax2.set_title('Error Ratio (MLP/Linear)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pre-generating 10000 samples...
#   Generated 10000/10000
# Pre-generation complete.
